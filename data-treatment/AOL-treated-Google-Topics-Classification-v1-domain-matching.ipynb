# %% [markdown]
# # Google Topics v1 Classification Domain Matching

# %%
import pandas, re, os, multiprocessing, tqdm, tldextract

# %%
# Loads unique domains from AOL-treated dataset into aol DataFrame.
aol = pandas.read_csv('AOL-treated-unique-domains.csv',
                      low_memory=False, on_bad_lines='warn',
                      usecols=[1]).rename(columns={'0':'domain'})

# %%
# Loads Google Topics v1 classification into topics DataFrame.
topics = pandas.read_csv('Google-Topics-Classification-v1.txt',
                         index_col=False, low_memory=False, on_bad_lines='warn')

# %%
display(aol)
# Out:
#                             domain
# 0        tintonfallsrecreation.com
# 1             elevationbaptist.org
# 2                localchurches.org
# 3                fabolousworld.com
# 4              majestictheatre.net
# ...                            ...
# 1300479               suresave.com
# 1300480          missouricosmo.com
# 1300481                dimpres.com
# 1300482                 hempel.com
# 1300483    natgreeneflyfishers.org
#
# [1300484 rows x 1 columns]

# %%
display(topics)
# Out:
#                  domain          topics
# 0        037hdmovie.com            '12'
# 1          0gomovies.sh  '12','43','45'
# 2           1.nbryb.com             '1'
# 3          10.nbryb.com       '1','243'
# 4         1000kitap.com     '100','253'
# ...                 ...             ...
# 9041             zus.pl              ''
# 9042  zvierata.bazos.sk           '289'
# 9043   zvirata.bazos.cz           '289'
# 9044         zyadda.com       '1','254'
# 9045         zyuken.net           '227'
#
# [9046 rows x 2 columns]

# %%
aol_unique = set(aol['domain'].to_list())

# %%
topics_unique = set(topics['domain'].to_list())

# %%
display(len(aol_unique.intersection(topics_unique)))
# Out:
# 1545

# %%
# %%time
size_1 = []
size_2 = []
size_3 = []
size_4 = []
size_5 = []
check = []

# Separate domains from AOL-treated dataset according to number of levels.
# For instance, 'gov.br' into size_2, 'saude.gov.br' into size_3.
for case in aol_unique:
    count = len(re.findall(r'\.', case))
    if count == 0:
        size_1.append(case)
    elif count == 1:
        size_2.append(case)
    elif count == 2:
        size_3.append(case)
    elif count == 3:
        size_4.append(case)
    elif count == 4:
        size_5.append(case)
    else:
        check.append(case)

print(len(size_1),len(size_2),len(size_3),len(size_4),len(size_5),len(check))
# Out:
# 0 1194526 99442 6494 22 0
# CPU times: user 1.73 s, sys: 8.36 ms, total: 1.73 s
# Wall time: 1.73 s

# %%
# %%time
# Takes only domains with three or more levels.
aol_unique_reduced = []
aol_unique_reduced.extend(size_3)
aol_unique_reduced.extend(size_4)
aol_unique_reduced.extend(size_5)
# Out:
# CPU times: user 1.98 ms, sys: 3.32 ms, total: 5.29 ms
# Wall time: 5.14 ms

# %%
print(len(aol_unique_reduced))
# Out:
# 105958

# %% [markdown]
# ## Multiprocessing

# %%
# Setup of multiprocessing library for multithreaded domain matching.
data1 = None
data2 = None

def init(_data1,_data2):
    global data1
    data1 = _data1
    global data2
    data2 = _data2

pool_size = multiprocessing.cpu_count() * 1

os.system('taskset -cp 0-%d %s' % (pool_size, os.getpid()))

jobs_count = pool_size * 10

n = round(len(aol_unique_reduced)/jobs_count)
l = [list(aol_unique_reduced)[i:i + n] for i in range(0, len(list(aol_unique_reduced)), n)]

def job(l):
    topics_unique = set(topics['domain'].to_list())
    topics_unique_re = [re.compile('.*\.'+case) for case in topics_unique]
    full = []
    partial = {}
    for dom in l:
        # Appends domain from AOL-treated dataset if also in the aggregated Citizen Lab test list.
        if dom in topics_unique:
            full.append(dom)
        # Tries to perform a partial match otherwise, i.e. map a subdomain to the respective domain.
        # For instance, 'covid.saude.gov.br' would partially match 'saude.gov.br'.
        else:
            partial[dom] = [case.pattern.strip('.*\\.') for case in topics_unique_re if any(map(case.search, [dom])) == True]
    return(full, partial)

with multiprocessing.Pool(processes=pool_size, maxtasksperchild=1, initializer=init,
                          initargs=(topics[['domain','topics']])) as pool:
    pool_outputs = list(tqdm.tqdm(pool.imap(job, l),
                                  total=sum(1 for _ in l)))
    pool.close()
    pool.join()
# Out:
# pid 1089221's current affinity list: 0-39
# pid 1089221's new affinity list: 0-39
# 100%|████████████████████| 400/400 [01:12<00:00,  5.53it/s]

# %%
# %%time
# Collects multiprocessing results.
full_match = []
partial_match = {}
for output in pool_outputs:
    if len(output[0]) > 0:
        full_match.extend(output[0])
    for k, v in output[1].items():
        if len(v) > 0:
            partial_match[k] = v
full_match.extend(list(set(size_2).intersection(topics_unique)))
# Out:
# CPU times: user 351 ms, sys: 40 ms, total: 391 ms
# Wall time: 383 ms

# %%
print(len(full_match), len(partial_match))
# Out:
# 1545 1274

# %%
display(full_match)
# Out:
# ['officedepot.com.mx',
#  'google.com.br',
#  'google.co.nz',
#  'independent.co.uk',
#  'unionbankonline.co.in',
#  'dominos.co.uk',
#  'aldi.co.uk',
#  'currys.co.uk',
#  'google.co.kr',
#  'google.com.hk',
#  'o2.co.uk',
#  'news.com.au',
#  'mercadolibre.com.uy',
#  'wickes.co.uk',
#  'mcdonalds.co.jp',
#  'jobs.nhs.uk',
#  'bbc.co.uk',
#  'stuff.co.nz',
#  'submarino.com.br',
#  'boticario.com.br',
#  'walla.co.il',
#  'wiggle.co.uk',
#  'mercadolibre.com.ar',
#  'pets4homes.co.uk',
#  'imovelweb.com.br',
#  'kanald.com.tr',
#  'google.com.sa',
#  'sams.com.mx',
#  'kalunga.com.br',
#  'bunnings.com.au',
#  'google.com.pe',
#  'commbank.com.au',
#  'thestar.com.my',
#  'google.com.co',
#  'thetimes.co.uk',
#  'ofuxico.com.br',
#  'dailystar.co.uk',
#  'lagaceta.com.ar',
#  'jbhifi.com.au',
#  'ntv.co.jp',
#  'uol.com.br',
#  'ebay.co.uk',
#  'trademe.co.nz',
#  'clicrbs.com.br',
#  'ciudad.com.ar',
#  'fanatik.com.tr',
#  'pagina12.com.ar',
#  'vivastreet.co.uk',
#  'nld.com.vn',
#  'costco.com.mx',
#  'iceland.co.uk',
#  'divyabhaskar.co.in',
#  'bharian.com.my',
#  'ntv.com.tr',
#  'thesun.co.uk',
#  'smh.com.au',
#  'pravda.com.ua',
#  'upsc.gov.in',
#  'vodafone.co.uk',
#  'gamer.com.tw',
#  'google.com.uy',
#  'bb.com.br',
#  'eluniversal.com.mx',
#  'imss.gob.mx',
#  'caixa.gov.br',
#  'google.com.tr',
#  'marisa.com.br',
#  'spareroom.co.uk',
#  'buscape.com.br',
#  'honda.com.br',
#  'google.com.vn',
#  'indiapost.gov.in',
#  'solodeportes.com.ar',
#  'manchestereveningnews.co.uk',
#  'google.com.tw',
#  'atv.com.tr',
#  'telegraph.co.uk',
#  'jang.com.pk',
#  'maybank2u.com.my',
#  'target.com.au',
#  'google.com.mx',
#  'sunat.gob.pe',
#  'rakuten.co.jp',
#  'kmart.com.au',
#  'google.co.za',
#  'google.com.ph',
#  'google.com.au',
#  'three.co.uk',
#  'set.or.th',
#  'dailynews.co.th',
#  'sonhos.com.br',
#  'abc.com.py',
#  'bigw.com.au',
#  'nzherald.co.nz',
#  'consultaremedios.com.br',
#  '104.com.tw',
#  'sainsburys.co.uk',
#  'mercadolibre.com.mx',
#  'google.co.il',
#  'auspost.com.au',
#  'globes.co.il',
#  'thairath.co.th',
#  'sat.gob.mx',
#  'tfl.gov.uk',
#  'uai.com.br',
#  'sabah.com.tr',
#  'haaretz.co.il',
#  'express.co.uk',
#  'google.com.gt',
#  'matichon.co.th',
#  'oi.com.br',
#  'voegol.com.br',
#  'ynet.co.il',
#  'casasbahia.com.br',
#  'computrabajo.com.mx',
#  'ole.com.ar',
#  'sodimac.com.pe',
#  'vivo.com.br',
#  'excelsior.com.mx',
#  'panorama.com.al',
#  'gumtree.co.za',
#  'mercadolibre.com.co',
#  'itau.com.br',
#  'proceso.com.mx',
#  'domain.com.au',
#  'google.com.ec',
#  'hoseasons.co.uk',
#  'homedepot.com.mx',
#  'computrabajo.com.pe',
#  'next.co.uk',
#  'lacapital.com.ar',
#  'metoffice.gov.uk',
#  'itmedia.co.jp',
#  'casadoscontos.com.br',
#  'tripadvisor.co.uk',
#  'tigo.com.gt',
#  'excite.co.jp',
#  'bom.gov.au',
#  'jdsports.co.uk',
#  'montevideo.com.uy',
#  'lanacion.com.ar',
#  'lidl.co.uk',
#  'milliyet.com.tr',
#  'walmart.com.mx',
#  'preloved.co.uk',
#  'nationallottery.co.za',
#  'autotrader.co.za',
#  'homebase.co.uk',
#  'diariodecuyo.com.ar',
#  'books.com.tw',
#  'thenews.com.pk',
#  'makro.co.za',
#  'dmm.co.jp',
#  'correios.com.br',
#  'seek.com.au',
#  'google.co.ve',
#  'dantri.com.vn',
#  'dailymail.co.uk',
#  'rightmove.co.uk',
#  'hmv.co.jp',
#  'yomiuri.co.jp',
#  'lovehoney.co.uk',
#  'matalan.co.uk',
#  'gumtree.com.au',
#  'eldeber.com.bo',
#  'amazon.co.jp',
#  'newsnow.co.uk',
#  '24h.com.vn',
#  'mercadolibre.com.ve',
#  'lse.co.uk',
#  'lpga.or.jp',
#  'hurriyet.com.tr',
#  'reed.co.uk',
#  'showtv.com.tr',
#  'americanas.com.br',
#  'oricon.co.jp',
#  'mercadolivre.com.br',
#  'jal.co.jp',
#  'autotrader.co.uk',
#  'argos.co.uk',
#  'honda.co.jp',
#  'google.co.in',
#  'metro.co.uk',
#  'google.co.jp',
#  'jobstreet.com.ph',
#  'abc.net.au',
#  'serasa.com.br',
#  'ebay.com.au',
#  'radios.com.br',
#  'google.com.sg',
#  'indianrail.gov.in',
#  'utusan.com.my',
#  'google.com.my',
#  'sears.com.mx',
#  'google.com.ar',
#  'dogstrust.org.uk',
#  'pontofrio.com.br',
#  'elpais.com.uy',
#  'lojasrenner.com.br',
#  'dailyrecord.co.uk',
#  'google.co.id',
#  'terra.com.br',
#  'mirror.co.uk',
#  'nintendo.co.jp',
#  'google.com.pk',
#  'unisa.ac.za',
#  'google.co.uk',
#  'ancestry.co.uk',
#  'singaporepools.com.sg',
#  '1999.co.jp',
#  'occ.com.mx',
#  'cumhuriyet.com.tr',
#  'carsales.com.au',
#  'netvasco.com.br',
#  'liverpool.com.mx',
#  'privateproperty.co.za',
#  'amazon.co.uk',
#  'realestate.com.au',
#  'maariv.co.il',
#  'yahoo.co.jp',
#  'globe.com.ph',
#  'bna.com.ar',
#  'sanborns.com.mx',
#  'zillow.com',
#  'elcorteingles.pt',
#  'antena3.com',
#  'kicker.de',
#  'boxrec.com',
#  'redfin.com',
#  'blizzard.com',
#  'shmu.sk',
#  'thumbzilla.com',
#  'welt.de',
#  'hottopic.com',
#  'aufeminin.com',
#  'jeevansathi.com',
#  'nrl.com',
#  'usatoday.com',
#  'google.se',
#  'freemail.hu',
#  'justdial.com',
#  'vodafone.es',
#  'toyota.jp',
#  'worldstar.com',
#  'ign.com',
#  'tradera.com',
#  'amd.com',
#  'caradisiac.com',
#  'infojobs.net',
#  'meetup.com',
#  'catofashions.com',
#  'menards.com',
#  'ideal.es',
#  'epicgames.com',
#  'anandabazar.com',
#  'cookpad.com',
#  'poradnikzdrowie.pl',
#  'bedbathandbeyond.com',
#  'auctionzip.com',
#  'worldofwarcraft.com',
#  'cdc.gov',
#  'prosport.ro',
#  'adultfriendfinder.com',
#  'tacobell.com',
#  'decolar.com',
#  'landsend.com',
#  'lasprovincias.es',
#  'thesimsresource.com',
#  'joemonster.org',
#  'underarmour.com',
#  'iltempo.it',
#  'officedepot.com',
#  'seneweb.com',
#  'blackpeoplemeet.com',
#  'otto.de',
#  'sba.gov',
#  'lavozdegalicia.es',
#  'nespresso.com',
#  'wral.com',
#  'canadiantire.ca',
#  'onlinesbi.com',
#  'hibbett.com',
#  'realtor.com',
#  'cotilleando.com',
#  'pagesjaunes.fr',
#  'sex.com',
#  'kinopoisk.ru',
#  'youngliving.com',
#  'parismatch.com',
#  'gocomics.com',
#  'ingatlan.com',
#  'elle.com',
#  'superdrug.com',
#  'crutchfield.com',
#  'lg.com',
#  'totalwine.com',
#  'centrum.cz',
#  'windguru.cz',
#  'eurocarparts.com',
#  'thefreedictionary.com',
#  'hollisterco.com',
#  'registrocivil.cl',
#  'tripadvisor.it',
#  'infobae.com',
#  'southwest.com',
#  'gazeta.pl',
#  'billboard.com',
#  'allrecipes.com',
#  'europa.eu',
#  'entrepreneur.com',
#  'skyscrapercity.com',
#  'theweathernetwork.com',
#  'haber7.com',
#  'investopedia.com',
#  '1001fonts.com',
#  'livescore.cz',
#  'nairaland.com',
#  'super.cz',
#  'ncsecu.org',
#  'cdiscount.com',
#  'kyero.com',
#  'interpals.net',
#  'vistaprint.com',
#  'immowelt.de',
#  'bhaskar.com',
#  'sport.es',
#  'juegos.com',
#  'longhornsteakhouse.com',
#  'office.com',
#  'swarovski.com',
#  'dreamstime.com',
#  'azlyrics.com',
#  'abc.es',
#  'orsay.com',
#  'kijiji.ca',
#  'tirerack.com',
#  'chip.de',
#  'tportal.hr',
#  'google.fi',
#  'silverdaddies.com',
#  'indeed.com',
#  'premierleague.com',
#  'npr.org',
#  'shutterstock.com',
#  'albayan.ae',
#  'nifty.org',
#  'newgrounds.com',
#  'google.nl',
#  'wetter.com',
#  'riverisland.com',
#  'tripadvisor.fr',
#  'filmaffinity.com',
#  'king.com',
#  'breitbart.com',
#  'diariolibre.com',
#  'pagesix.com',
#  'cnbc.com',
#  'gov.il',
#  'abc.com',
#  'vnexpress.net',
#  'barchart.com',
#  'tweakers.net',
#  'oggi.it',
#  'olivegarden.com',
#  'portfolio.hu',
#  'insider.com',
#  '4shared.com',
#  'dexonline.ro',
#  'juntadeandalucia.es',
#  'jegs.com',
#  'trovaprezzi.it',
#  'rtp.pt',
#  'schwab.com',
#  'webmd.com',
#  'wireclub.com',
#  'o2.pl',
#  'chase.com',
#  'forbes.com',
#  'voyeurweb.com',
#  'ilmattino.it',
#  'blocket.se',
#  'semana.com',
#  'rds.ca',
#  'toom.de',
#  'victoriassecret.com',
#  'nationalgeographic.com',
#  'google.ru',
#  'msn.com',
#  'sapo.pt',
#  'skyscanner.net',
#  'discounttire.com',
#  'volkskrant.nl',
#  'indiaglitz.com',
#  'study.com',
#  'in.gr',
#  'sweetwater.com',
#  'va.gov',
#  'coches.net',
#  'capitalone.com',
#  'nadaguides.com',
#  'investing.com',
#  'finishline.com',
#  'history.com',
#  'har.com',
#  'rawstory.com',
#  'aljazeera.net',
#  'ebay.it',
#  'vol.at',
#  'altex.ro',
#  'screenrant.com',
#  'lrytas.lt',
#  'gds.it',
#  'aa.com',
#  'garnstudio.com',
#  'nouvelobs.com',
#  'prensalibre.com',
#  'gazzetta.it',
#  'publico.pt',
#  'youtube.com',
#  'attheraces.com',
#  'neopets.com',
#  'heb.com',
#  'bigbadtoystore.com',
#  'hemnet.se',
#  'correos.es',
#  'dhnet.be',
#  'draugiem.lv',
#  'zazzle.com',
#  'tournamentsoftware.com',
#  'behindthename.com',
#  'sexstories.com',
#  'crazyshit.com',
#  'myherbalife.com',
#  'delfi.ee',
#  'gsmarena.com',
#  'ltdcommodities.com',
#  'harborfreight.com',
#  'usps.com',
#  'ae.com',
#  'delfi.lt',
#  'svd.se',
#  'boots.com',
#  'bestbuy.ca',
#  'bbc.com',
#  'malaysiakini.com',
#  'gumtree.pl',
#  'rottentomatoes.com',
#  'zennioptical.com',
#  'carrefour.es',
#  'td.com',
#  'monografias.com',
#  'marapets.com',
#  'pandora.com',
#  'sohu.com',
#  'reuters.com',
#  'chainreactioncycles.com',
#  'conjuguemos.com',
#  'vietnamnet.vn',
#  'fotocasa.es',
#  'iaai.com',
#  'rentacenter.com',
#  'punyu.com',
#  'nfl.com',
#  'istockphoto.com',
#  'potterybarn.com',
#  'imobiliare.ro',
#  'tycsports.com',
#  'ea.com',
#  'imvu.com',
#  'cda.pl',
#  'lequipe.fr',
#  'tiktok.com',
#  'quotidiano.net',
#  'missyusa.com',
#  'elcomercio.com',
#  'grubhub.com',
#  'samsung.com',
#  'andhrajyothy.com',
#  'newlook.com',
#  'mapquest.com',
#  'academy.com',
#  'tagesschau.de',
#  'futbolred.com',
#  'estrepublicain.fr',
#  'hollandandbarrett.com',
#  'nelly.com',
#  'ebay.ie',
#  'nicematin.com',
#  'pch.com',
#  'gismeteo.ru',
#  'cabelas.com',
#  'webstaurantstore.com',
#  'midwayusa.com',
#  'ancestry.com',
#  'vimm.net',
#  'carrefour.fr',
#  'cardkingdom.com',
#  'caracoltv.com',
#  'worldjournal.com',
#  'expedia.com',
#  'google.ca',
#  'brainyquote.com',
#  'pizzahut.com',
#  'boursorama.com',
#  'goldengate.hu',
#  'livescience.com',
#  'mixi.jp',
#  'formula1.com',
#  'menupix.com',
#  'bloomingdales.com',
#  'joann.com',
#  'radiozet.pl',
#  'citi.com',
#  'google.at',
#  'autotrader.com',
#  'explorelearning.com',
#  'goodhousekeeping.com',
#  'airg.com',
#  'uline.com',
#  'tsn.ca',
#  'libertaddigital.com',
#  'bunte.de',
#  'united.com',
#  'ganeshaspeaks.com',
#  'nos.nl',
#  'bt.com',
#  'livedoor.com',
#  'globo.com',
#  'hvg.hu',
#  'minijuegos.com',
#  'marriott.com',
#  'google.de',
#  'stockcharts.com',
#  'horoscope.com',
#  'spanishdict.com',
#  'shine.com',
#  'sante.fr',
#  'kay.com',
#  'mail.ru',
#  'woman.ru',
#  'ansa.it',
#  'naslovi.net',
#  'egun.de',
#  'fragrancenet.com',
#  'cbc.ca',
#  'euroleague.net',
#  'google.lk',
#  'hotnews.ro',
#  'wetterzentrale.de',
#  'russianfood.com',
#  'dhl.de',
#  'tigerdroppings.com',
#  'repubblica.it',
#  'laprensa.hn',
#  'vocabulary.com',
#  'cars.com',
#  'perfectgirls.net',
#  'expressen.se',
#  'wsj.com',
#  'duluthtrading.com',
#  'petsmart.com',
#  'kayak.com',
#  'xe.com',
#  'squirt.org',
#  'pornpics.com',
#  'minsal.cl',
#  'boostmobile.com',
#  'multiplication.com',
#  'priceline.com',
#  'bridgebase.com',
#  'kindgirls.com',
#  'casadellibro.com',
#  'blesk.cz',
#  'carsforsale.com',
#  'google.it',
#  'latimes.com',
#  'usbank.com',
#  'fossil.com',
#  'dairyqueen.com',
#  'melaleuca.com',
#  'greetingsisland.com',
#  'eonline.com',
#  'discover.com',
#  'hermes.com',
#  'hobbylobby.com',
#  'tf1.fr',
#  'autogidas.lt',
#  'qvc.com',
#  'nps.gov',
#  'biglots.com',
#  'hrblock.com',
#  'autoscout24.de',
#  'nordstrom.com',
#  'orf.at',
#  'newspapers.com',
#  'nowtv.com',
#  'pichunter.com',
#  'kathimerini.gr',
#  'eurosport.fr',
#  'telegraaf.nl',
#  'netspend.com',
#  'freetaxusa.com',
#  'mlb.com',
#  'gamestop.com',
#  'google.pl',
#  'lenovo.com',
#  'famousfootwear.com',
#  'canarias7.es',
#  'larazon.es',
#  'haberturk.com',
#  'amazon.com',
#  'fidelity.com',
#  'dn.se',
#  '90minut.pl',
#  'vegasinsider.com',
#  'uniqlo.com',
#  'itv.com',
#  'shoecarnival.com',
#  'losarcanos.com',
#  'ducksters.com',
#  'uscis.gov',
#  'dafont.com',
#  'rtve.es',
#  'canalrcn.com',
#  'lampsplus.com',
#  'hsn.com',
#  'drmartens.com',
#  'adac.de',
#  'tff.org',
#  'timeanddate.com',
#  'ebay.de',
#  'origo.hu',
#  'lne.es',
#  'scielo.br',
#  'dagbladet.no',
#  'google.lv',
#  'thehill.com',
#  '24ur.com',
#  'telcel.com',
#  'accuweather.com',
#  'lenta.ru',
#  'diy.com',
#  'mercadolibre.cl',
#  'starfall.com',
#  'funimation.com',
#  'callofduty.com',
#  'screwfix.com',
#  'walmart.ca',
#  'xataka.com',
#  'mitbbs.com',
#  'sprint.com',
#  'ilmessaggero.it',
#  'immonet.de',
#  'wizardingworld.com',
#  'assoass.com',
#  'ibm.com',
#  'paypal.com',
#  'covers.com',
#  'todocoleccion.net',
#  'familysearch.org',
#  'ksl.com',
#  'insomnia.gr',
#  'eros.com',
#  'allocine.fr',
#  'tibia.com',
#  'hornbach.de',
#  'fedex.com',
#  'lotterypost.com',
#  'fingerhut.com',
#  'apartments.com',
#  'meetic.fr',
#  'marksandspencer.com',
#  'gunbroker.com',
#  'khaleejtimes.com',
#  'yle.fi',
#  'alarabiya.net',
#  'skechers.com',
#  'patch.com',
#  'portalinmobiliario.com',
#  'pogo.com',
#  'instructables.com',
#  'blick.ch',
#  'pbskids.org',
#  'macys.com',
#  'ebay.at',
#  'proxibid.com',
#  'loopnet.com',
#  'postfun.com',
#  'google.sk',
#  'rosario3.com',
#  'livescores.com',
#  'nasa.gov',
#  'interia.pl',
#  'uhaul.com',
#  'google.ro',
#  'mercadolibre.com',
#  'gamesradar.com',
#  'adressa.no',
#  'sbazar.cz',
#  'rtvslo.si',
#  'sodimac.cl',
#  'rte.ie',
#  'latercera.com',
#  'google.com',
#  'news24.com',
#  'guitarcenter.com',
#  'dr.dk',
#  'shutterfly.com',
#  'nettiauto.com',
#  'wordpress.org',
#  'movistar.es',
#  'rtl.be',
#  'qatarliving.com',
#  'senukai.lt',
#  'ar15.com',
#  'tuttosport.com',
#  'payscale.com',
#  'publix.com',
#  'w3schools.com',
#  'thedrive.com',
#  'chosun.com',
#  'telmex.com',
#  'hotels.com',
#  'playground.ru',
#  'nhs.uk',
#  'au.com',
#  'dhgate.com',
#  'rotowire.com',
#  'sanook.com',
#  'kleinezeitung.at',
#  'pitchfork.com',
#  '24sata.hr',
#  'esquire.com',
#  'vanguardia.com',
#  'netflix.com',
#  'jeuxvideo.com',
#  'ancestry.ca',
#  'adam4adam.com',
#  'bartleby.com',
#  'ebay.es',
#  'flalottery.com',
#  'elcorteingles.es',
#  'timesofindia.com',
#  'bathandbodyworks.com',
#  'ledauphine.com',
#  'johnlewis.com',
#  'smokva.com',
#  'kidshealth.org',
#  'tiava.com',
#  'teamtalk.com',
#  'nypost.com',
#  'linternaute.com',
#  'manhunt.net',
#  'ashleyfurniture.com',
#  'tchatche.com',
#  'delta.com',
#  'drugs.com',
#  'adidas.com',
#  'mumsnet.com',
#  'scmp.com',
#  'wordreference.com',
#  'kakaku.com',
#  'nrk.no',
#  'datezone.com',
#  'sueddeutsche.de',
#  'oreillyauto.com',
#  'newegg.com',
#  'ft.com',
#  'yaplakal.com',
#  'playstation.com',
#  'diariovasco.com',
#  'caranddriver.com',
#  'laredoute.fr',
#  '7sur7.be',
#  'cbsnews.com',
#  'index.hu',
#  'g2g.com',
#  'tripadvisor.es',
#  'scapino.nl',
#  'sudoku.com',
#  'mobile01.com',
#  'pcgamer.com',
#  'pap.fr',
#  'sii.cl',
#  'britannica.com',
#  'rtl.fr',
#  'target.com',
#  'edmunds.com',
#  'skybet.com',
#  'forocoches.com',
#  'google.ae',
#  'pakwheels.com',
#  'sony.jp',
#  'fernsehserien.de',
#  'tagged.com',
#  'expatriates.com',
#  'indiamart.com',
#  'chefkoch.de',
#  'derstandard.at',
#  'papajohns.com',
#  'consumerreports.org',
#  'bhphotovideo.com',
#  'bhg.com',
#  'udn.com',
#  'marktplaats.nl',
#  '750g.com',
#  'joyclub.de',
#  'lapresse.ca',
#  'cvs.com',
#  'galottery.com',
#  'nature.com',
#  'vesti.ru',
#  'clasificadosonline.com',
#  'bershka.com',
#  'chileautos.cl',
#  'rent.com',
#  'cox.com',
#  'property24.com',
#  'ojogo.pt',
#  'skatteverket.se',
#  'myfreecams.com',
#  'ozon.ru',
#  'etsy.com',
#  'csfd.cz',
#  'sunporno.com',
#  'bseindia.com',
#  'ilsole24ore.com',
#  'slate.com',
#  'gulfnews.com',
#  'xuite.net',
#  'hindustantimes.com',
#  'ameba.jp',
#  'cadenaser.com',
#  'bankofamerica.com',
#  'hyundai.com',
#  'urbandictionary.com',
#  'truckpaper.com',
#  'kirklands.com',
#  'trojmiasto.pl',
#  'tvgids.nl',
#  'freesexyindians.com',
#  'milenio.com',
#  'nclottery.com',
#  'rossmann.de',
#  'yelp.com',
#  'dxlive.com',
#  '3movs.com',
#  'build.com',
#  'brigitte.de',
#  'drudgereport.com',
#  'michigan.gov',
#  'aastocks.com',
#  'ebay.fr',
#  'icicibank.com',
#  'tabelog.com',
#  'rbcroyalbank.com',
#  'ica.se',
#  'torn.com',
#  'dlsite.com',
#  'sciaga.pl',
#  'astrology.com',
#  'sbicard.com',
#  'dickssportinggoods.com',
#  'athome.com',
#  'rambler.ru',
#  'brainpop.com',
#  'zeit.de',
#  'opticsplanet.com',
#  'mass.gov',
#  'alibaba.com',
#  'britishairways.com',
#  'poste.it',
#  'krone.at',
#  'dominos.com',
#  'arkadium.com',
#  'nuskin.com',
#  'whattoexpect.com',
#  'nike.com',
#  'utorrent.com',
#  'sfgate.com',
#  'viz.com',
#  'slobodnadalmacija.hr',
#  'rvtrader.com',
#  'naver.com',
#  'pnp.de',
#  'wetteronline.de',
#  'people.com',
#  'ad.nl',
#  'jutarnji.hr',
#  'scoresandodds.com',
#  'kooora.com',
#  'daserste.de',
#  'moneysavingexpert.com',
#  '20minutos.es',
#  'furaffinity.net',
#  'bt.dk',
#  'bloomberg.com',
#  'sportchek.ca',
#  'pricesmart.com',
#  'grammy.com',
#  'bancsabadell.com',
#  'o2online.de',
#  'soccerstand.com',
#  'zoominfo.com',
#  'tvn.cl',
#  'habitaclia.com',
#  'jpay.com',
#  'famousbirthdays.com',
#  'gab.com',
#  'carfax.com',
#  'hilton.com',
#  'jumbo.com',
#  'rona.ca',
#  'cellufun.com',
#  'antenna.gr',
#  'hotukdeals.com',
#  'tvmovie.de',
#  'si.com',
#  'xxx.com',
#  'marketwatch.com',
#  'tipcars.com',
#  'rackroomshoes.com',
#  'telecinco.es',
#  'tmz.com',
#  'tv2.no',
#  'uefa.com',
#  'indianexpress.com',
#  'rotter.net',
#  'delfi.lv',
#  'google.es',
#  'lego.com',
#  'tesco.com',
#  'ixbt.com',
#  'jstor.org',
#  'sgcarmart.com',
#  'di.se',
#  'coldwellbankerhomes.com',
#  'sauto.cz',
#  'hm.com',
#  'budsgunshop.com',
#  'applebees.com',
#  'boardgamegeek.com',
#  'komputerswiat.pl',
#  'erotikforum.at',
#  'tim.it',
#  'yoox.com',
#  'wordpress.com',
#  'skype.com',
#  'google.lt',
#  'chess.com',
#  'crateandbarrel.com',
#  'kitco.com',
#  'banamex.com',
#  'thesaurus.com',
#  'who.int',
#  'lepoint.fr',
#  'predskazanie.ru',
#  'thepiratebay.org',
#  'channelnewsasia.com',
#  'ebay.com',
#  'medicinenet.com',
#  'dictionary.com',
#  'specialized.com',
#  'toutelatele.com',
#  'ultimahora.es',
#  'gumtree.com',
#  'att.net',
#  'blogto.com',
#  'literotica.com',
#  'viabcp.com',
#  'michaels.com',
#  'samsclub.com',
#  'easyjet.com',
#  'forever21.com',
#  'nvidia.com',
#  'lci.fr',
#  'yallakora.com',
#  'euroresidentes.com',
#  'flightaware.com',
#  'cycletrader.com',
#  'xnxx.net',
#  'equibase.com',
#  'auto.ru',
#  'dell.com',
#  'royallepage.ca',
#  'sahibinden.com',
#  'sierra.com',
#  'gratka.pl',
#  'b92.net',
#  'idnes.cz',
#  'bricklink.com',
#  'tanea.gr',
#  'lotteryusa.com',
#  'casa.it',
#  'visir.is',
#  'xoom.com',
#  'morningstar.com',
#  'univision.com',
#  'petco.com',
#  'belk.com',
#  ...]

# %%
display(partial_match)
# Out:
# {'ciberhabitat.gob.mx': ['gob.mx'],
#  'sath.nhs.uk': ['nhs.uk'],
#  'asambleadf.gob.mx': ['gob.mx'],
#  'sheffield-ha.nhs.uk': ['nhs.uk'],
#  'wmids.nhs.uk': ['nhs.uk'],
#  'bcu.gub.uy': ['gub.uy'],
#  'london.nhs.uk': ['nhs.uk'],
#  'nwheartaudit.nhs.uk': ['nhs.uk'],
#  'whitehorsedc.gov.uk': ['gov.uk'],
#  'esonora.gob.mx': ['gob.mx'],
#  'lincoln.gov.uk': ['gov.uk'],
#  'wokingham.gov.uk': ['gov.uk'],
#  'osha.nhs.uk': ['nhs.uk'],
#  'mountedgcumbe.gov.uk': ['gov.uk'],
#  'nelincs.gov.uk': ['gov.uk'],
#  'delegacionbenitojuarez.gob.mx': ['gob.mx'],
#  'tabasco.gob.mx': ['gob.mx'],
#  'agwsha.nhs.uk': ['nhs.uk'],
#  'orlc.gob.pe': ['gob.pe'],
#  'contactopyme.gob.mx': ['gob.mx'],
#  'networks.nhs.uk': ['nhs.uk'],
#  'pas.gov.uk': ['gov.uk'],
#  'seebc.gob.mx': ['gob.mx'],
#  'sedesol.gob.mx': ['gob.mx'],
#  'chester.gov.uk': ['gov.uk'],
#  'housingcorp.gov.uk': ['gov.uk'],
#  'mcga.gov.uk': ['gov.uk'],
#  'legalservices.gov.uk': ['gov.uk'],
#  'staffordshire.gov.uk': ['gov.uk'],
#  'scotlandspeople.gov.uk': ['gov.uk'],
#  'edomexico.gob.mx': ['gob.mx'],
#  'nurseseyesite.nhs.uk': ['nhs.uk'],
#  'sagarpa.gob.mx': ['gob.mx'],
#  'historic-scotland.gov.uk': ['gov.uk'],
#  'scarborough.gov.uk': ['gov.uk'],
#  'ait.gov.uk': ['gov.uk'],
#  'magic.gov.uk': ['gov.uk'],
#  'doeni.gov.uk': ['gov.uk'],
#  'msi.gob.pe': ['gob.pe'],
#  'mi5.gov.uk': ['gov.uk'],
#  'directorio.gob.mx': ['gob.mx'],
#  'defesa.gov.br': ['gov.br'],
#  'dsdni.gov.uk': ['gov.uk'],
#  'nochistlan.gob.mx': ['gob.mx'],
#  'leeds.gov.uk': ['gov.uk'],
#  'preventinghomefalls.gov.uk': ['gov.uk'],
#  'rbbh.nhs.uk': ['nhs.uk'],
#  'westlincspct.nhs.uk': ['nhs.uk'],
#  'mof.gov.il': ['gov.il'],
#  'bankisrael.gov.il': ['gov.il'],
#  'mindbodysoul.gov.uk': ['gov.uk'],
#  'agepositive.gov.uk': ['gov.uk'],
#  'imbel.gov.br': ['gov.br'],
#  'ceredigion.gov.uk': ['gov.uk'],
#  'dwi.gov.uk': ['gov.uk'],
#  'guildford.gov.uk': ['gov.uk'],
#  'cofemermir.gob.mx': ['gob.mx'],
#  'dfes.gov.uk': ['gov.uk'],
#  'cofetel.gob.mx': ['gob.mx'],
#  'dfid.gov.uk': ['gov.uk'],
#  'pgi.gov.pl': ['gov.pl'],
#  'uksport.gov.uk': ['gov.uk'],
#  'fife.gov.uk': ['gov.uk'],
#  'bournemouth.gov.uk': ['gov.uk'],
#  'mazamitla.gob.mx': ['gob.mx'],
#  'strategy.gov.uk': ['gov.uk'],
#  'ecultura.gob.mx': ['gob.mx'],
#  'patent.gov.uk': ['gov.uk'],
#  'conam.gob.pe': ['gob.pe'],
#  'ashfield-dc.gov.uk': ['gov.uk'],
#  'coventrypct.nhs.uk': ['nhs.uk'],
#  'rnhrd.nhs.uk': ['nhs.uk'],
#  'emexico.gob.mx': ['gob.mx'],
#  'hastings.gov.uk': ['gov.uk'],
#  'dundeecity.gov.uk': ['gov.uk'],
#  'cadereytademontes.gob.mx': ['gob.mx'],
#  'chelwest.nhs.uk': ['nhs.uk'],
#  'leics.gov.uk': ['gov.uk'],
#  'bradford.gov.uk': ['gov.uk'],
#  'purbeck.gov.uk': ['gov.uk'],
#  'foresight.gov.uk': ['gov.uk'],
#  'valeofglamorgan.gov.uk': ['gov.uk'],
#  'swlstg-tr.nhs.uk': ['nhs.uk'],
#  'wsh.nhs.uk': ['nhs.uk'],
#  'dfee.gov.uk': ['gov.uk'],
#  'ciudadvalles.gob.mx': ['gob.mx'],
#  'dgi.gub.uy': ['gub.uy'],
#  'perinatal.nhs.uk': ['nhs.uk'],
#  'eastherts.gov.uk': ['gov.uk'],
#  'southtees.nhs.uk': ['nhs.uk'],
#  'cardiff.gov.uk': ['gov.uk'],
#  'buckscc.gov.uk': ['gov.uk'],
#  'turismomichoacan.gob.mx': ['gob.mx'],
#  'cmha.nhs.uk': ['nhs.uk'],
#  'drugs.gov.uk': ['gov.uk'],
#  'communitiesscotland.gov.uk': ['gov.uk'],
#  'munijesusmaria.gob.pe': ['gob.pe'],
#  'indepa.gob.pe': ['gob.pe'],
#  'tin.nhs.uk': ['nhs.uk'],
#  'csa.gov.uk': ['gov.uk'],
#  'cancercarealliance.nhs.uk': ['nhs.uk'],
#  'galaxy-h.gov.uk': ['gov.uk'],
#  'civil-service.gov.uk': ['gov.uk'],
#  'blackburn.gov.uk': ['gov.uk'],
#  'reading.gov.uk': ['gov.uk'],
#  'waveney.gov.uk': ['gov.uk'],
#  'brasil.gov.br': ['gov.br'],
#  'salt.gov.uk': ['gov.uk'],
#  'chambanet.gob.mx': ['gob.mx'],
#  'yucatan.gob.mx': ['gob.mx'],
#  'doh.gov.uk': ['gov.uk'],
#  'sectur.gob.mx': ['gob.mx'],
#  'easthants.gov.uk': ['gov.uk'],
#  'eastcambsandfenland-pct.nhs.uk': ['nhs.uk'],
#  'hmcourts-service.gov.uk': ['gov.uk'],
#  'dtlr.gov.uk': ['gov.uk'],
#  'interlegis.gov.br': ['gov.br'],
#  'shepway.gov.uk': ['gov.uk'],
#  'bnsc.gov.uk': ['gov.uk'],
#  'precisa.gob.mx': ['gob.mx'],
#  'bathnes.gov.uk': ['gov.uk'],
#  'camaradediputados.gob.mx': ['gob.mx'],
#  'nhsplus.nhs.uk': ['nhs.uk'],
#  'dsa.gov.uk': ['gov.uk'],
#  'childcarecareers.gov.uk': ['gov.uk'],
#  'elmbridge.gov.uk': ['gov.uk'],
#  'cnca.gob.mx': ['gob.mx'],
#  'sfo.gov.uk': ['gov.uk'],
#  'cornwall.gov.uk': ['gov.uk'],
#  'oxfordshire.gov.uk': ['gov.uk'],
#  'highwaycode.gov.uk': ['gov.uk'],
#  'minsa.gob.pe': ['gob.pe'],
#  'salford.gov.uk': ['gov.uk'],
#  'chihuahua.gob.mx': ['gob.mx'],
#  'rotherham.gov.uk': ['gov.uk'],
#  'mgip.gov.pl': ['gov.pl'],
#  'lgdu-wales.gov.uk': ['gov.uk'],
#  'pronosticos.gob.mx': ['gob.mx'],
#  'ibge.gov.br': ['gov.br'],
#  'barnsley.gov.uk': ['gov.uk'],
#  'urtip.gov.pl': ['gov.pl'],
#  'losreyesmichoacan.gob.mx': ['gob.mx'],
#  'nhsleadershipqualities.nhs.uk': ['nhs.uk'],
#  'semarnat.gob.mx': ['gob.mx'],
#  'gobernacion.gob.mx': ['gob.mx'],
#  'agritacna.gob.pe': ['gob.pe'],
#  'mhra.gov.uk': ['gov.uk'],
#  'riobravo.gob.mx': ['gob.mx'],
#  'portspct.nhs.uk': ['nhs.uk'],
#  'nhsprofessionals.nhs.uk': ['nhs.uk'],
#  'ges.gov.uk': ['gov.uk'],
#  'teachernet.gov.uk': ['gov.uk'],
#  'comms.gov.uk': ['gov.uk'],
#  'joint-reviews.gov.uk': ['gov.uk'],
#  'ipswich.gov.uk': ['gov.uk'],
#  'nuneaton.gov.uk': ['gov.uk'],
#  'eastsussex.gov.uk': ['gov.uk'],
#  'nwml.gov.uk': ['gov.uk'],
#  'calderdale.gov.uk': ['gov.uk'],
#  'iwight.gov.uk': ['gov.uk'],
#  'lda.gov.uk': ['gov.uk'],
#  'regiontumbes.gob.pe': ['gob.pe'],
#  'ldh.nhs.uk': ['nhs.uk'],
#  'envirowise.gov.uk': ['gov.uk'],
#  'ukho.gov.uk': ['gov.uk'],
#  'mecatlan.gob.mx': ['gob.mx'],
#  'mawwfire.gov.uk': ['gov.uk'],
#  'bfi.gov.uk': ['gov.uk'],
#  'huntinginquiry.gov.uk': ['gov.uk'],
#  'basingstoke.gov.uk': ['gov.uk'],
#  'barking-dagenham.gov.uk': ['gov.uk'],
#  'ocpa.gov.uk': ['gov.uk'],
#  'jobcentreplus.gov.uk': ['gov.uk'],
#  'midsussex.gov.uk': ['gov.uk'],
#  'gos.gov.uk': ['gov.uk'],
#  'fareham.gov.uk': ['gov.uk'],
#  'refer.nhs.uk': ['nhs.uk'],
#  'mot.gov.il': ['gov.il'],
#  'ubht.nhs.uk': ['nhs.uk'],
#  'secver.gob.mx': ['gob.mx'],
#  'screening.nhs.uk': ['nhs.uk'],
#  'stosyth.gov.uk': ['gov.uk'],
#  'nhscareers.nhs.uk': ['nhs.uk'],
#  'turismobc.gob.mx': ['gob.mx'],
#  'sonora.gob.mx': ['gob.mx'],
#  'rree.gob.pe': ['gob.pe'],
#  'peru.gob.pe': ['gob.pe'],
#  'ukvisas.gov.uk': ['gov.uk'],
#  'warwickshire.gov.uk': ['gov.uk'],
#  'turismo.gub.uy': ['gub.uy'],
#  'nbt.nhs.uk': ['nhs.uk'],
#  'newham.gov.uk': ['gov.uk'],
#  'nhsweb.nhs.uk': ['nhs.uk'],
#  'enriquegobernador.gob.mx': ['gob.mx'],
#  'toluca.gob.mx': ['gob.mx'],
#  'arun.gov.uk': ['gov.uk'],
#  'hepc.nhs.uk': ['nhs.uk'],
#  'cherwell-dc.gov.uk': ['gov.uk'],
#  'charity-commission.gov.uk': ['gov.uk'],
#  'gps.gov.uk': ['gov.uk'],
#  'workpermits.gov.uk': ['gov.uk'],
#  'lewishampct.nhs.uk': ['nhs.uk'],
#  'oft.gov.uk': ['gov.uk'],
#  'cbs.gov.il': ['gov.il'],
#  'npsa.nhs.uk': ['nhs.uk'],
#  'mexicocity.gob.mx': ['gob.mx'],
#  'gro-scotland.gov.uk': ['gov.uk'],
#  'ealing.gov.uk': ['gov.uk'],
#  'tonala.gob.mx': ['gob.mx'],
#  'parliamentary-counsel.gov.uk': ['gov.uk'],
#  'tda.gov.uk': ['gov.uk'],
#  'inapam.gob.mx': ['gob.mx'],
#  'helpisathand.gov.uk': ['gov.uk'],
#  'forestry.gov.uk': ['gov.uk'],
#  'uruapan.gob.mx': ['gob.mx'],
#  'knowledgenetwork.gov.uk': ['gov.uk'],
#  'broxtowe.gov.uk': ['gov.uk'],
#  'sheffieldchildrens.nhs.uk': ['nhs.uk'],
#  'liconsa.gob.mx': ['gob.mx'],
#  'drdni.gov.uk': ['gov.uk'],
#  'rhondda-cynon-taff.gov.uk': ['gov.uk'],
#  'mod.gov.il': ['gov.il'],
#  'ssa-sin.gob.mx': ['gob.mx'],
#  'dh.gov.uk': ['gov.uk'],
#  'oxfordeyehospital.nhs.uk': ['nhs.uk'],
#  'civilservice.gov.uk': ['gov.uk'],
#  'cookstown.gov.uk': ['gov.uk'],
#  'waverley.gov.uk': ['gov.uk'],
#  'carestandardstribunal.gov.uk': ['gov.uk'],
#  'oxfordradcliffe.nhs.uk': ['nhs.uk'],
#  'oxon-lea.gov.uk': ['gov.uk'],
#  'wmcoe.gov.uk': ['gov.uk'],
#  'sra.gob.mx': ['gob.mx'],
#  'alg.gov.uk': ['gov.uk'],
#  'lagosdemoreno.gob.mx': ['gob.mx'],
#  'cityoflondon.gov.uk': ['gov.uk'],
#  'vivienda.gob.pe': ['gob.pe'],
#  'wandsworth-pct.nhs.uk': ['nhs.uk'],
#  'glastonbury.gov.uk': ['gov.uk'],
#  'eu2005.gov.uk': ['gov.uk'],
#  'successforall.gov.uk': ['gov.uk'],
#  'tna.gov.uk': ['gov.uk'],
#  'guasave.gob.mx': ['gob.mx'],
#  'birminghamcancer.nhs.uk': ['nhs.uk'],
#  'ms.gov.pl': ['gov.pl'],
#  'nhsia.nhs.uk': ['nhs.uk'],
#  'vehiclelicence.gov.uk': ['gov.uk'],
#  'nio.gov.uk': ['gov.uk'],
#  'planningportal.gov.uk': ['gov.uk'],
#  'tenampa.gob.mx': ['gob.mx'],
#  'bcb.gov.br': ['gov.br'],
#  'merseycare.nhs.uk': ['nhs.uk'],
#  'pendle.gov.uk': ['gov.uk'],
#  'sanfrancisco.gob.mx': ['gob.mx'],
#  'exmoor-nationalpark.gov.uk': ['gov.uk'],
#  'bndes.gov.br': ['gov.br'],
#  'dmddownload.nhs.uk': ['nhs.uk'],
#  'jalisco.gob.mx': ['gob.mx'],
#  'maldon.gov.uk': ['gov.uk'],
#  'oxford.gov.uk': ['gov.uk'],
#  'opsi.gov.uk': ['gov.uk'],
#  'poole.gov.uk': ['gov.uk'],
#  'gamadero.gob.mx': ['gob.mx'],
#  'gsr.gov.uk': ['gov.uk'],
#  'nlg.nhs.uk': ['nhs.uk'],
#  'forestresearch.gov.uk': ['gov.uk'],
#  'connectingforhealth.nhs.uk': ['nhs.uk'],
#  'tijuana.gob.mx': ['gob.mx'],
#  'solihull.gov.uk': ['gov.uk'],
#  'economia.gob.mx': ['gob.mx'],
#  'conaculta.gob.mx': ['gob.mx'],
#  'ine.gob.mx': ['gob.mx'],
#  'zamora.gob.mx': ['gob.mx'],
#  'guadalajara.gob.mx': ['gob.mx'],
#  'eastriding.gov.uk': ['gov.uk'],
#  'uktradeinvest.gov.uk': ['gov.uk'],
#  'south-ribblebc.gov.uk': ['gov.uk'],
#  'aib.gov.uk': ['gov.uk'],
#  'morelia.gob.mx': ['gob.mx'],
#  'congresotabasco.gob.mx': ['gob.mx'],
#  'g8.gov.uk': ['gov.uk'],
#  'dvla.gov.uk': ['gov.uk'],
#  'lbhf.gov.uk': ['gov.uk'],
#  'statistics.gov.uk': ['gov.uk'],
#  'coahuila.gob.mx': ['gob.mx'],
#  'devonline.gov.uk': ['gov.uk'],
#  'sir-benfro.gov.uk': ['gov.uk'],
#  'justice.gov.il': ['gov.il'],
#  'mansfield.gov.uk': ['gov.uk'],
#  'dartford.gov.uk': ['gov.uk'],
#  'northamptonshire.nhs.uk': ['nhs.uk'],
#  'lg-employers.gov.uk': ['gov.uk'],
#  'rochdale.gov.uk': ['gov.uk'],
#  'somerset.nhs.uk': ['nhs.uk'],
#  'lambeth.gov.uk': ['gov.uk'],
#  'euro.gov.uk': ['gov.uk'],
#  'ets.gov.uk': ['gov.uk'],
#  'bseinquiry.gov.uk': ['gov.uk'],
#  'qroo.gob.mx': ['gob.mx'],
#  'acapulco.gob.mx': ['gob.mx'],
#  'sirddinbych.gov.uk': ['gov.uk'],
#  '21stcentury.gov.br': ['gov.br'],
#  'iaa.gov.il': ['gov.il'],
#  'tramitescoahuila.gob.mx': ['gob.mx'],
#  'emra.gov.uk': ['gov.uk'],
#  'agri.gov.il': ['gov.il'],
#  'wivenhoe.gov.uk': ['gov.uk'],
#  'inspiringlearningforall.gov.uk': ['gov.uk'],
#  'mtc.gob.pe': ['gob.pe'],
#  'peatlandsni.gov.uk': ['gov.uk'],
#  'dt.gob.cl': ['gob.cl'],
#  'caixaeconomicafederal.gov.br': ['gov.br'],
#  'dhsspsni.gov.uk': ['gov.uk'],
#  'tmbc.gov.uk': ['gov.uk'],
#  'powys.gov.uk': ['gov.uk'],
#  'sfpcoahuila.gob.mx': ['gob.mx'],
#  'police.gov.il': ['gov.il'],
#  'easington.gov.uk': ['gov.uk'],
#  'scot.nhs.uk': ['nhs.uk'],
#  'woking.gov.uk': ['gov.uk'],
#  'jne.gob.pe': ['gob.pe'],
#  'bridgend.gov.uk': ['gov.uk'],
#  'uhl-tr.nhs.uk': ['nhs.uk'],
#  'health.gov.il': ['gov.il'],
#  'cheshire.gov.uk': ['gov.uk'],
#  'camara.gov.br': ['gov.br'],
#  'informatics.nhs.uk': ['nhs.uk'],
#  'lgiu.gov.uk': ['gov.uk'],
#  'breastfeeding.nhs.uk': ['nhs.uk'],
#  'number10.gov.uk': ['gov.uk'],
#  'healthyheart.nhs.uk': ['nhs.uk'],
#  'binape.gob.pe': ['gob.pe'],
#  'christchurch.gov.uk': ['gov.uk'],
#  'gsi.gov.il': ['gov.il'],
#  'wales.nhs.uk': ['nhs.uk'],
#  'acuerdonacional.gob.pe': ['gob.pe'],
#  'passport-application.gov.uk': ['gov.uk'],
#  'chrd-pct.nhs.uk': ['nhs.uk'],
#  'reniec.gob.pe': ['gob.pe'],
#  'conae.gob.mx': ['gob.mx'],
#  'assetsrecovery.gov.uk': ['gov.uk'],
#  'igp.gob.pe': ['gob.pe'],
#  'doctoronline.nhs.uk': ['nhs.uk'],
#  'sbs.gov.uk': ['gov.uk'],
#  'nottinghamcity.gov.uk': ['gov.uk'],
#  'richmondshire.gov.uk': ['gov.uk'],
#  'tamaulipas.gob.mx': ['gob.mx'],
#  'rail-reg.gov.uk': ['gov.uk'],
#  'nisra.gov.uk': ['gov.uk'],
#  'iea.gob.mx': ['gob.mx'],
#  'staffsamb.nhs.uk': ['nhs.uk'],
#  'enfield.gov.uk': ['gov.uk'],
#  'treasury.gov.uk': ['gov.uk'],
#  'jerez.gob.mx': ['gob.mx'],
#  'qehkl.nhs.uk': ['nhs.uk'],
#  'ccw.gov.uk': ['gov.uk'],
#  'stroud.gov.uk': ['gov.uk'],
#  'bc.gov.br': ['gov.br'],
#  'agricultura.gov.br': ['gov.br'],
#  'nayarit.gob.mx': ['gob.mx'],
#  'eastrenfrewshire.gov.uk': ['gov.uk'],
#  'tiger.gov.uk': ['gov.uk'],
#  'seneam.gob.mx': ['gob.mx'],
#  'leicester.gov.uk': ['gov.uk'],
#  'congresso.gov.br': ['gov.br'],
#  'lake-district.gov.uk': ['gov.uk'],
#  'westsussex.gov.uk': ['gov.uk'],
#  'redbridge.gov.uk': ['gov.uk'],
#  'dmd.nhs.uk': ['nhs.uk'],
#  'munipiura.gob.pe': ['gob.pe'],
#  'childcarelink.gov.uk': ['gov.uk'],
#  'wiredforhealth.gov.uk': ['gov.uk'],
#  'i-bio.gov.uk': ['gov.uk'],
#  'defra.gov.uk': ['gov.uk'],
#  'blaenau-gwent.gov.uk': ['gov.uk'],
#  'nyrdtc.nhs.uk': ['nhs.uk'],
#  'lewes.gov.uk': ['gov.uk'],
#  'rbwm.gov.uk': ['gov.uk'],
#  'cozumel.gob.mx': ['gob.mx'],
#  'stoke.gov.uk': ['gov.uk'],
#  'countrysideaccess.gov.uk': ['gov.uk'],
#  'kprm.gov.pl': ['gov.pl'],
#  'sec-sonora.gob.mx': ['gob.mx'],
#  'anglesey.gov.uk': ['gov.uk'],
#  'hedgehogs.gov.uk': ['gov.uk'],
#  'sis.gov.uk': ['gov.uk'],
#  'congresobc.gob.mx': ['gob.mx'],
#  'nhsinherts.nhs.uk': ['nhs.uk'],
#  'pm.gov.uk': ['gov.uk'],
#  'nelh.nhs.uk': ['nhs.uk'],
#  'immunisation.nhs.uk': ['nhs.uk'],
#  'ehsni.gov.uk': ['gov.uk'],
#  'westyorksfire.gov.uk': ['gov.uk'],
#  'civilserviceappealboard.gov.uk': ['gov.uk'],
#  'londonpharmacy.nhs.uk': ['nhs.uk'],
#  'brent.gov.uk': ['gov.uk'],
#  'funcionpublica.gob.mx': ['gob.mx'],
#  'childsupportagency.gov.uk': ['gov.uk'],
#  'childtrustfund.gov.uk': ['gov.uk'],
#  'pgr.gob.mx': ['gob.mx'],
#  'israel-mfa.gov.il': ['gov.il'],
#  'hullcc.gov.uk': ['gov.uk'],
#  'homeoffice.gov.uk': ['gov.uk'],
#  'informationcommissioner.gov.uk': ['gov.uk'],
#  'northtyneside.gov.uk': ['gov.uk'],
#  'wandsworthpct.nhs.uk': ['nhs.uk'],
#  'stockton.gov.uk': ['gov.uk'],
#  'coatzacoalcos.gob.mx': ['gob.mx'],
#  'ribblevalley.gov.uk': ['gov.uk'],
#  'gmccn.nhs.uk': ['nhs.uk'],
#  'munihuacho.gob.pe': ['gob.pe'],
#  'lbwf.gov.uk': ['gov.uk'],
#  'derrycity.gov.uk': ['gov.uk'],
#  'newbury.gov.uk': ['gov.uk'],
#  'exeter.nhs.uk': ['nhs.uk'],
#  'tartanday.gov.uk': ['gov.uk'],
#  'pue.gob.mx': ['gob.mx'],
#  'munisjl.gob.pe': ['gob.pe'],
#  'hook.gov.uk': ['gov.uk'],
#  'casaruibarbosa.gov.br': ['gov.br'],
#  'consumerdirect.gov.uk': ['gov.uk'],
#  'workingintheuk.gov.uk': ['gov.uk'],
#  'mtop.gub.uy': ['gub.uy'],
#  'aduanet.gob.pe': ['gob.pe'],
#  'rushmoor.gov.uk': ['gov.uk'],
#  'south-derbys.gov.uk': ['gov.uk'],
#  'pj.gob.pe': ['gob.pe'],
#  'riddor.gov.uk': ['gov.uk'],
#  'gibraltar.gov.uk': ['gov.uk'],
#  'copelandbc.gov.uk': ['gov.uk'],
#  'natpact.nhs.uk': ['nhs.uk'],
#  'knesset.gov.il': ['gov.il'],
#  'cete-sonora.gob.mx': ['gob.mx'],
#  'previdenciasocial.gov.br': ['gov.br'],
#  'spirescentre.nhs.uk': ['nhs.uk'],
#  'tehila.gov.il': ['gov.il'],
#  'landregisteronline.gov.uk': ['gov.uk'],
#  'trafford.gov.uk': ['gov.uk'],
#  'torridge.gov.uk': ['gov.uk'],
#  'cancernorth.nhs.uk': ['nhs.uk'],
#  'north-dorset.gov.uk': ['gov.uk'],
#  'bromleyhospitals.nhs.uk': ['nhs.uk'],
#  'bradford.nhs.uk': ['nhs.uk'],
#  'royalsurrey.nhs.uk': ['nhs.uk'],
#  'dpb.nhs.uk': ['nhs.uk'],
#  'stj.gov.br': ['gov.br'],
#  'fazenda.gov.br': ['gov.br'],
#  'inah.gob.mx': ['gob.mx'],
#  'derbyshire.gov.uk': ['gov.uk'],
#  'lincolnshire.gov.uk': ['gov.uk'],
#  'e-hidalgo.gob.mx': ['gob.mx'],
#  'dft.gov.uk': ['gov.uk'],
#  'digitaltelevision.gov.uk': ['gov.uk'],
#  'coal.gov.uk': ['gov.uk'],
#  'londonprepared.gov.uk': ['gov.uk'],
#  'infonavit.gob.mx': ['gob.mx'],
#  'bedfordshire.gov.uk': ['gov.uk'],
#  'lawcom.gov.uk': ['gov.uk'],
#  'senado.gob.mx': ['gob.mx'],
#  'inafed.gob.mx': ['gob.mx'],
#  'edinburgh.gov.uk': ['gov.uk'],
#  'trf1.gov.br': ['gov.br'],
#  'eera.gov.uk': ['gov.uk'],
#  'castlemorpeth.gov.uk': ['gov.uk'],
#  'cddhcu.gob.mx': ['gob.mx'],
#  'guiaweb.gob.cl': ['gob.cl'],
#  'hants.gov.uk': ['gov.uk'],
#  'sunderland.gov.uk': ['gov.uk'],
#  'devon.gov.uk': ['gov.uk'],
#  'scotland.gov.uk': ['gov.uk'],
#  'tourism.gov.il': ['gov.il'],
#  'everychildmatters.gov.uk': ['gov.uk'],
#  'iow.gov.uk': ['gov.uk'],
#  'kent.gov.uk': ['gov.uk'],
#  'gloscc.gov.uk': ['gov.uk'],
#  'gro.gov.uk': ['gov.uk'],
#  'cafcass.gov.uk': ['gov.uk'],
#  'e-lindsey.gov.uk': ['gov.uk'],
#  'firekills.gov.uk': ['gov.uk'],
#  'shetland.gov.uk': ['gov.uk'],
#  'rio.gov.pl': ['gov.pl'],
#  'pro.gov.uk': ['gov.uk'],
#  'hambleton.gov.uk': ['gov.uk'],
#  'cjf.gov.br': ['gov.br'],
#  'nogales.gob.mx': ['gob.mx'],
#  'kentandmedway.nhs.uk': ['nhs.uk'],
#  'carterton-tc.gov.uk': ['gov.uk'],
#  'mindef.gob.pe': ['gob.pe'],
#  'miraflores.gob.pe': ['gob.pe'],
#  'southyorkshire.nhs.uk': ['nhs.uk'],
#  'forensic.gov.uk': ['gov.uk'],
#  'ost.gov.uk': ['gov.uk'],
#  'stat.gov.pl': ['gov.pl'],
#  'dinama.gub.uy': ['gub.uy'],
#  'oisc.gov.uk': ['gov.uk'],
#  'eemspct.nhs.uk': ['nhs.uk'],
#  'esht.nhs.uk': ['nhs.uk'],
#  'ico.gov.uk': ['gov.uk'],
#  'acnfp.gov.uk': ['gov.uk'],
#  'eastbourne.gov.uk': ['gov.uk'],
#  'extranjeria.gob.cl': ['gob.cl'],
#  'norwich.gov.uk': ['gov.uk'],
#  'medway.gov.uk': ['gov.uk'],
#  'groni.gov.uk': ['gov.uk'],
#  'employmentappeals.gov.uk': ['gov.uk'],
#  'glimari.gob.cl': ['gob.cl'],
#  'michoacan.gob.mx': ['gob.mx'],
#  'kingston.gov.uk': ['gov.uk'],
#  'roadsni.gov.uk': ['gov.uk'],
#  'woodchurch-pc.gov.uk': ['gov.uk'],
#  'oaxaca.gob.mx': ['gob.mx'],
#  'cefp.gob.mx': ['gob.mx'],
#  'york.gov.uk': ['gov.uk'],
#  'cgma.gov.uk': ['gov.uk'],
#  'staffordclinic.nhs.uk': ['nhs.uk'],
#  'xalapa.gob.mx': ['gob.mx'],
#  'cre.gob.mx': ['gob.mx'],
#  'turismozacatecas.gob.mx': ['gob.mx'],
#  'swindonpct.nhs.uk': ['nhs.uk'],
#  'kpk.gov.pl': ['gov.pl'],
#  'vizcaino.gob.mx': ['gob.mx'],
#  'wales.gov.uk': ['gov.uk'],
#  'durham.gov.uk': ['gov.uk'],
#  'cprm.gov.br': ['gov.br'],
#  'northtynesidepct.nhs.uk': ['nhs.uk'],
#  'estonia.gov.uk': ['gov.uk'],
#  'gloucester.gov.uk': ['gov.uk'],
#  'maib.gov.uk': ['gov.uk'],
#  'buckshealth.nhs.uk': ['nhs.uk'],
#  'wolverhampton.gov.uk': ['gov.uk'],
#  'n-somerset.gov.uk': ['gov.uk'],
#  'northumberland.gov.uk': ['gov.uk'],
#  'sthelens.gov.uk': ['gov.uk'],
#  'caddie.gov.uk': ['gov.uk'],
#  'basildon.gov.uk': ['gov.uk'],
#  'congreso.gob.pe': ['gob.pe'],
#  'shropshirefire.gov.uk': ['gov.uk'],
#  'torreon.gob.mx': ['gob.mx'],
#  'derby.gov.uk': ['gov.uk'],
#  'dwp.gov.uk': ['gov.uk'],
#  'bassetlawdiabetes.nhs.uk': ['nhs.uk'],
#  'westberks.gov.uk': ['gov.uk'],
#  'stockport.gov.uk': ['gov.uk'],
#  'guardianship.gov.uk': ['gov.uk'],
#  'mf.gov.pl': ['gov.pl'],
#  'comitan.gob.mx': ['gob.mx'],
#  'cambsphn.nhs.uk': ['nhs.uk'],
#  'cosla.gov.uk': ['gov.uk'],
#  'haifa.gov.il': ['gov.il'],
#  'delicias.gob.mx': ['gob.mx'],
#  'pgjebc.gob.mx': ['gob.mx'],
#  'rotherhampct.nhs.uk': ['nhs.uk'],
#  'tradingstandards.gov.uk': ['gov.uk'],
#  'foros.gob.mx': ['gob.mx'],
#  'durango.gob.mx': ['gob.mx'],
#  'eyecareservices.nhs.uk': ['nhs.uk'],
#  'staffordshirefire.gov.uk': ['gov.uk'],
#  'sanmiguelallende.gob.mx': ['gob.mx'],
#  'nationalarchives.gov.uk': ['gov.uk'],
#  'portsmouth.gov.uk': ['gov.uk'],
#  'harrowpct.nhs.uk': ['nhs.uk'],
#  'cambridge.gov.uk': ['gov.uk'],
#  'cityofworcester.gov.uk': ['gov.uk'],
#  'moia.gov.il': ['gov.il'],
#  'mfa.gov.il': ['gov.il'],
#  'adur.gov.uk': ['gov.uk'],
#  'nl.gob.mx': ['gob.mx'],
#  'sanluispotosi.gob.mx': ['gob.mx'],
#  'inca.gov.br': ['gov.br'],
#  'tanzania-online.gov.uk': ['gov.uk'],
#  'mmrthefacts.nhs.uk': ['nhs.uk'],
#  'worcestershire.gov.uk': ['gov.uk'],
#  'info.gov.il': ['gov.il'],
#  'mec.gov.br': ['gov.br'],
#  'northcumbriahealth.nhs.uk': ['nhs.uk'],
#  'e-morelos.gob.mx': ['gob.mx'],
#  'neath-porttalbot.gov.uk': ['gov.uk'],
#  'ine.gub.uy': ['gub.uy'],
#  'tendringdc.gov.uk': ['gov.uk'],
#  'silicone-review.gov.uk': ['gov.uk'],
#  'openaccess.gov.uk': ['gov.uk'],
#  'surreycc.gov.uk': ['gov.uk'],
#  'southend.gov.uk': ['gov.uk'],
#  'mc.gov.br': ['gov.br'],
#  'exeter.gov.uk': ['gov.uk'],
#  'leeds.nhs.uk': ['nhs.uk'],
#  'dumgal.gov.uk': ['gov.uk'],
#  'kettering.gov.uk': ['gov.uk'],
#  'bancomext.gob.mx': ['gob.mx'],
#  'ime.gob.mx': ['gob.mx'],
#  'nics.gov.uk': ['gov.uk'],
#  'udskior.gov.pl': ['gov.pl'],
#  'munisanbartolo.gob.pe': ['gob.pe'],
#  'dss.gov.uk': ['gov.uk'],
#  'tel-aviv.gov.il': ['gov.il'],
#  'harlowpct.nhs.uk': ['nhs.uk'],
#  'minedu.gob.pe': ['gob.pe'],
#  'turismochiapas.gob.mx': ['gob.mx'],
#  'senamhi.gob.pe': ['gob.pe'],
#  'companieshouse.gov.uk': ['gov.uk'],
#  'chiapas.gob.mx': ['gob.mx'],
#  'ynysmon.gov.uk': ['gov.uk'],
#  'bwhct.nhs.uk': ['nhs.uk'],
#  'london-fire.gov.uk': ['gov.uk'],
#  'cmm.gob.mx': ['gob.mx'],
#  'redebrasil.gov.br': ['gov.br'],
#  'denbighshire.gov.uk': ['gov.uk'],
#  'targetingbenefitfraud.gov.uk': ['gov.uk'],
#  'parlamento.gub.uy': ['gub.uy'],
#  'parking-appeals.gov.uk': ['gov.uk'],
#  'wrexham.gov.uk': ['gov.uk'],
#  'colerainebc.gov.uk': ['gov.uk'],
#  'irapuato.gob.mx': ['gob.mx'],
#  'stockportmbc.gov.uk': ['gov.uk'],
#  'vosa.gov.uk': ['gov.uk'],
#  'pa.gob.mx': ['gob.mx'],
#  'mj.gov.br': ['gov.br'],
#  'coi.gov.uk': ['gov.uk'],
#  'edu-negev.gov.il': ['gov.il'],
#  'anvisa.gov.br': ['gov.br'],
#  'sentencing-guidelines.gov.uk': ['gov.uk'],
#  'ros.gov.uk': ['gov.uk'],
#  'abin.gov.br': ['gov.br'],
#  'kingsch.nhs.uk': ['nhs.uk'],
#  'banjercito.gob.mx': ['gob.mx'],
#  'midlothian.gov.uk': ['gov.uk'],
#  'nihe.gov.uk': ['gov.uk'],
#  'herefordshire.gov.uk': ['gov.uk'],
#  'dif.gob.mx': ['gob.mx'],
#  'disclosure.gov.uk': ['gov.uk'],
#  'derbyhospitals.nhs.uk': ['nhs.uk'],
#  'nrr.nhs.uk': ['nhs.uk'],
#  'britishembassy.gov.uk': ['gov.uk'],
#  'norfolk.gov.uk': ['gov.uk'],
#  'concytec.gob.pe': ['gob.pe'],
#  'redcar-cleveland.gov.uk': ['gov.uk'],
#  'inmujeres.gob.mx': ['gob.mx'],
#  'exec.nhs.uk': ['nhs.uk'],
#  'minem.gob.pe': ['gob.pe'],
#  'dudley.gov.uk': ['gov.uk'],
#  'inmetro.gov.br': ['gov.br'],
#  'lsc.gov.uk': ['gov.uk'],
#  'peterborough.gov.uk': ['gov.uk'],
#  'trafford.nhs.uk': ['nhs.uk'],
#  'puntogob.gob.mx': ['gob.mx'],
#  'coventry.gov.uk': ['gov.uk'],
#  'newark-sherwooddc.gov.uk': ['gov.uk'],
#  'sefton.gov.uk': ['gov.uk'],
#  'mincetur.gob.pe': ['gob.pe'],
#  'eppingforestdc.gov.uk': ['gov.uk'],
#  'hgc.gov.uk': ['gov.uk'],
#  'lisburncity.gov.uk': ['gov.uk'],
#  'inade.gob.pe': ['gob.pe'],
#  'ccc.gob.mx': ['gob.mx'],
#  'saludbc.gob.mx': ['gob.mx'],
#  'chi.nhs.uk': ['nhs.uk'],
#  'gnn.gov.uk': ['gov.uk'],
#  'rochford.gov.uk': ['gov.uk'],
#  'eng-h.gov.uk': ['gov.uk'],
#  'sheffield.gov.uk': ['gov.uk'],
#  'rbht.nhs.uk': ['nhs.uk'],
#  'minag.gob.pe': ['gob.pe'],
#  'municipiochihuahua.gob.mx': ['gob.mx'],
#  'lichfield.gov.uk': ['gov.uk'],
#  'n-i.nhs.uk': ['nhs.uk'],
#  'eastdunbarton.gov.uk': ['gov.uk'],
#  'coremisgm.gob.mx': ['gob.mx'],
#  'childrenfirst.nhs.uk': ['nhs.uk'],
#  'socitm.gov.uk': ['gov.uk'],
#  'eastdevon.gov.uk': ['gov.uk'],
#  'ic.nhs.uk': ['nhs.uk'],
#  'shropshire-cc.gov.uk': ['gov.uk'],
#  'fco.gov.uk': ['gov.uk'],
#  'inictel.gob.pe': ['gob.pe'],
#  'pesticides.gov.uk': ['gov.uk'],
#  'rpa.gov.uk': ['gov.uk'],
#  'sidmouth.gov.uk': ['gov.uk'],
#  'newtownabbey.gov.uk': ['gov.uk'],
#  'ofgem.gov.uk': ['gov.uk'],
#  'dbh.nhs.uk': ['nhs.uk'],
#  'hfea.gov.uk': ['gov.uk'],
#  'library.nhs.uk': ['nhs.uk'],
#  'bracknellforest.gov.uk': ['gov.uk'],
#  'swansea.gov.uk': ['gov.uk'],
#  'mma.gov.br': ['gov.br'],
#  'sindicatura.gob.mx': ['gob.mx'],
#  'coggeshall-pc.gov.uk': ['gov.uk'],
#  'dorchester-tc.gov.uk': ['gov.uk'],
#  'scotborders.gov.uk': ['gov.uk'],
#  'niassembly.gov.uk': ['gov.uk'],
#  'dspdprogramme.gov.uk': ['gov.uk'],
#  'csl.gov.uk': ['gov.uk'],
#  'blythvalley.gov.uk': ['gov.uk'],
#  'southportandormskirk.nhs.uk': ['nhs.uk'],
#  'rugby.gov.uk': ['gov.uk'],
#  'ipen.gob.pe': ['gob.pe'],
#  'gchq.gov.uk': ['gov.uk'],
#  'paisano.gob.mx': ['gob.mx'],
#  'transportes.gov.br': ['gov.br'],
#  'inba.gob.mx': ['gob.mx'],
#  'broadland.gov.uk': ['gov.uk'],
#  'bolton.nhs.uk': ['nhs.uk'],
#  'highland.gov.uk': ['gov.uk'],
#  'ea-transactions.gov.uk': ['gov.uk'],
#  'cotswold.gov.uk': ['gov.uk'],
#  'st-marys.nhs.uk': ['nhs.uk'],
#  'saude.gov.br': ['gov.br'],
#  'farrier-reg.gov.uk': ['gov.uk'],
#  'preston.gov.uk': ['gov.uk'],
#  'dac.gov.br': ['gov.br'],
#  'northteespct.nhs.uk': ['nhs.uk'],
#  'guanajuato.gob.mx': ['gob.mx'],
#  'nsht.nhs.uk': ['nhs.uk'],
#  'birmingham.gov.uk': ['gov.uk'],
#  'altamira.gob.mx': ['gob.mx'],
#  'mgap.gub.uy': ['gub.uy'],
#  'peoplesnetwork.gov.uk': ['gov.uk'],
#  'sonoraturismo.gob.mx': ['gob.mx'],
#  'chichester.gov.uk': ['gov.uk'],
#  'sps.gov.uk': ['gov.uk'],
#  'sae.gob.mx': ['gob.mx'],
#  'cnbv.gob.mx': ['gob.mx'],
#  'ceara.gov.br': ['gov.br'],
#  'muniags.gob.mx': ['gob.mx'],
#  'mein.gov.pl': ['gov.pl'],
#  'westminster.gov.uk': ['gov.uk'],
#  'runnymede.gov.uk': ['gov.uk'],
#  'hidalgo.gob.mx': ['gob.mx'],
#  'elbalero.gob.mx': ['gob.mx'],
#  'eastlothian.gov.uk': ['gov.uk'],
#  'zacatecas.gob.mx': ['gob.mx'],
#  'tapachula.gob.mx': ['gob.mx'],
#  'dca.gov.uk': ['gov.uk'],
#  'scotcourts.gov.uk': ['gov.uk'],
#  'flintshire.gov.uk': ['gov.uk'],
#  'e-mexico.gob.mx': ['gob.mx'],
#  'mazatlan.gob.mx': ['gob.mx'],
#  'bancodemexico.gob.mx': ['gob.mx'],
#  'arthurrankhouse.nhs.uk': ['nhs.uk'],
#  'impi.gob.mx': ['gob.mx'],
#  'presidencia.gob.mx': ['gob.mx'],
#  'sais.gov.uk': ['gov.uk'],
#  'parentscentre.gov.uk': ['gov.uk'],
#  'planningni.gov.uk': ['gov.uk'],
#  'wandsworth.gov.uk': ['gov.uk'],
#  'chelmsford.gov.uk': ['gov.uk'],
#  'middlesbrough.gov.uk': ['gov.uk'],
#  'hey.nhs.uk': ['nhs.uk'],
#  'kgp.gov.pl': ['gov.pl'],
#  'scottishexecutive.gov.uk': ['gov.uk'],
#  'economia-montevideo.gob.mx': ['gob.mx'],
#  'jfrs.gov.br': ['gov.br'],
#  'banderilla.gob.mx': ['gob.mx'],
#  'prodigy.nhs.uk': ['nhs.uk'],
#  'rlbuht.nhs.uk': ['nhs.uk'],
#  'conabio.gob.mx': ['gob.mx'],
#  'wealden.gov.uk': ['gov.uk'],
#  'turismo.gov.br': ['gov.br'],
#  'wlga.gov.uk': ['gov.uk'],
#  'wirral.gov.uk': ['gov.uk'],
#  'bristol-city.gov.uk': ['gov.uk'],
#  'pembrokeshire.gov.uk': ['gov.uk'],
#  'businesslink.gov.uk': ['gov.uk'],
#  'cst.gov.uk': ['gov.uk'],
#  'lbbd.gov.uk': ['gov.uk'],
#  'softwarelibremorelos.gob.mx': ['gob.mx'],
#  'stirling.gov.uk': ['gov.uk'],
#  'thurrock.gov.uk': ['gov.uk'],
#  'cabinetoffice.gov.uk': ['gov.uk'],
#  'carmarthenshire.gov.uk': ['gov.uk'],
#  'cps.gov.uk': ['gov.uk'],
#  'proni.gov.uk': ['gov.uk'],
#  'estyn.gov.uk': ['gov.uk'],
#  'msp.gub.uy': ['gub.uy'],
#  'countryside.gov.uk': ['gov.uk'],
#  'dti.gov.uk': ['gov.uk'],
#  'devfire.gov.uk': ['gov.uk'],
#  'futureleaders.nhs.uk': ['nhs.uk'],
#  'friendsofscotland.gov.uk': ['gov.uk'],
#  'mcht.nhs.uk': ['nhs.uk'],
#  'conafor.gob.mx': ['gob.mx'],
#  'healthyliving.gov.uk': ['gov.uk'],
#  'diariooficial.gob.mx': ['gob.mx'],
#  'sutton.gov.uk': ['gov.uk'],
#  'nas.gov.uk': ['gov.uk'],
#  'nava.gob.mx': ['gob.mx'],
#  'cne-siar.gov.uk': ['gov.uk'],
#  'secodaem.gob.mx': ['gob.mx'],
#  'isb.nhs.uk': ['nhs.uk'],
#  'idea-knowledge.gov.uk': ['gov.uk'],
#  'bedford.gov.uk': ['gov.uk'],
#  'tunbridgewells.gov.uk': ['gov.uk'],
#  'charitycommission.gov.uk': ['gov.uk'],
#  'carrick.gov.uk': ['gov.uk'],
#  'mte.gov.br': ['gov.br'],
#  'municipiodeoaxaca.gob.mx': ['gob.mx'],
#  'aswcs.nhs.uk': ['nhs.uk'],
#  'salud.gob.mx': ['gob.mx'],
#  'cmmc.nhs.uk': ['nhs.uk'],
#  'swindon.gov.uk': ['gov.uk'],
#  'lfc.gob.mx': ['gob.mx'],
#  'heart.nhs.uk': ['nhs.uk'],
#  'jaralgto.gob.mx': ['gob.mx'],
#  'ncdc.gov.uk': ['gov.uk'],
#  'poolepct.nhs.uk': ['nhs.uk'],
#  'islington.gov.uk': ['gov.uk'],
#  'hillingdon.gov.uk': ['gov.uk'],
#  'munimolina.gob.pe': ['gob.pe'],
#  'falkirk.gov.uk': ['gov.uk'],
#  'hse.gov.uk': ['gov.uk'],
#  'segpubtijuana.gob.mx': ['gob.mx'],
#  'cre.gov.uk': ['gov.uk'],
#  'gloucestershire.gov.uk': ['gov.uk'],
#  'milton-keynes.gov.uk': ['gov.uk'],
#  'testvalley.gov.uk': ['gov.uk'],
#  'walsall.gov.uk': ['gov.uk'],
#  'netregs.gov.uk': ['gov.uk'],
#  'oadby-wigston.gov.uk': ['gov.uk'],
#  'intellectual-property.gov.uk': ['gov.uk'],
#  'landreg.gov.uk': ['gov.uk'],
#  'info4local.gov.uk': ['gov.uk'],
#  'sepomex.gob.mx': ['gob.mx'],
#  'nelm.nhs.uk': ['nhs.uk'],
#  'northyorks.gov.uk': ['gov.uk'],
#  'nottinghamshire.gov.uk': ['gov.uk'],
#  'uhb.nhs.uk': ['nhs.uk'],
#  'conanp.gob.mx': ['gob.mx'],
#  'ukmi.nhs.uk': ['nhs.uk'],
#  'localegov.gov.uk': ['gov.uk'],
#  'shrewsbury.gov.uk': ['gov.uk'],
#  'east-ayrshire.gov.uk': ['gov.uk'],
#  'sre.gob.mx': ['gob.mx'],
#  'hermosillo.gob.mx': ['gob.mx'],
#  'bprpct.nhs.uk': ['nhs.uk'],
#  'pfe.gov.uk': ['gov.uk'],
#  'royalmarsden.nhs.uk': ['nhs.uk'],
#  'blaby.gov.uk': ['gov.uk'],
#  'mpf.gov.br': ['gov.br'],
#  'mimdes.gob.pe': ['gob.pe'],
#  'addenbrookes.nhs.uk': ['nhs.uk'],
#  'southwark.gov.uk': ['gov.uk'],
#  'ofmdfmni.gov.uk': ['gov.uk'],
#  'previdencia.gov.br': ['gov.br'],
#  'stalbans.gov.uk': ['gov.uk'],
#  'foodstandards.gov.uk': ['gov.uk'],
#  'highways.gov.uk': ['gov.uk'],
#  'conapo.gob.mx': ['gob.mx'],
#  'britishhighcommission.gov.uk': ['gov.uk'],
#  'north-ayrshire.gov.uk': ['gov.uk'],
#  'croydon.gov.uk': ['gov.uk'],
#  'bhha.nhs.uk': ['nhs.uk'],
#  'presidencia.gub.uy': ['gub.uy'],
#  'corby.gov.uk': ['gov.uk'],
#  'audit-commission.gov.uk': ['gov.uk'],
#  'direct.gov.uk': ['gov.uk'],
#  'courtservice.gov.uk': ['gov.uk'],
#  'corpoflondon.gov.uk': ['gov.uk'],
#  'salisbury.gov.uk': ['gov.uk'],
#  'ssani.gov.uk': ['gov.uk'],
#  'shcp.gob.mx': ['gob.mx'],
#  'preparingforemergencies.gov.uk': ['gov.uk'],
#  'gateway.gov.uk': ['gov.uk'],
#  'shropshire.gov.uk': ['gov.uk'],
#  'tre-rs.gov.br': ['gov.br'],
#  'appeals-service.gov.uk': ['gov.uk'],
#  'almg.gov.br': ['gov.br'],
#  'congresocoahuila.gob.mx': ['gob.mx'],
#  'harrogate.gov.uk': ['gov.uk'],
#  'banxico.gob.mx': ['gob.mx'],
#  'brightonandhovepct.nhs.uk': ['nhs.uk'],
#  'odpm.gov.uk': ['gov.uk'],
#  'homecare.gov.uk': ['gov.uk'],
#  'colima-estado.gob.mx': ['gob.mx'],
#  'lancaster.gov.uk': ['gov.uk'],
#  'queretaro.gob.mx': ['gob.mx'],
#  'judiciary.gov.uk': ['gov.uk'],
#  'ofsted.gov.uk': ['gov.uk'],
#  'lga.gov.uk': ['gov.uk'],
#  'macclesfield.gov.uk': ['gov.uk'],
#  'rohs.gov.uk': ['gov.uk'],
#  'norfolk-pa.gov.uk': ['gov.uk'],
#  'kirklees.gov.uk': ['gov.uk'],
#  'maff.gov.uk': ['gov.uk'],
#  'valuingpeople.gov.uk': ['gov.uk'],
#  'hmcpsi.gov.uk': ['gov.uk'],
#  'cymru.gov.uk': ['gov.uk'],
#  'vallehermoso.gob.mx': ['gob.mx'],
#  'liverpool.gov.uk': ['gov.uk'],
#  'southglos.gov.uk': ['gov.uk'],
#  'hm-treasury.gov.uk': ['gov.uk'],
#  'dnpm.gov.br': ['gov.br'],
#  'sustainable-development.gov.uk': ['gov.uk'],
#  'sct.gob.mx': ['gob.mx'],
#  'moag.gov.il': ['gov.il'],
#  'southbirminghampct.nhs.uk': ['nhs.uk'],
#  'sep.gob.mx': ['gob.mx'],
#  'newcastle.gov.uk': ['gov.uk'],
#  'london.gov.uk': ['gov.uk'],
#  'southlanarkshire.gov.uk': ['gov.uk'],
#  'radiobras.gov.br': ['gov.br'],
#  'gateshead.gov.uk': ['gov.uk'],
#  'repcampdf.gob.mx': ['gob.mx'],
#  'swbh.nhs.uk': ['nhs.uk'],
#  'environment-agency.gov.uk': ['gov.uk'],
#  'redbox.gov.uk': ['gov.uk'],
#  'profeco.gob.mx': ['gob.mx'],
#  'ogc.gov.uk': ['gov.uk'],
#  'calderdale-pct.nhs.uk': ['nhs.uk'],
#  'metepec.gob.mx': ['gob.mx'],
#  'sbs.gob.pe': ['gob.pe'],
#  'deni.gov.uk': ['gov.uk'],
#  'caradon.gov.uk': ['gov.uk'],
#  'nhsetrent.gov.uk': ['gov.uk'],
#  'guysandstthomas.nhs.uk': ['nhs.uk'],
#  'somerset.gov.uk': ['gov.uk'],
#  'passport.gov.uk': ['gov.uk'],
#  'aguaprieta.gob.mx': ['gob.mx'],
#  'nmhct.nhs.uk': ['nhs.uk'],
#  'uruguay.gub.uy': ['gub.uy'],
#  'ruh.nhs.uk': ['nhs.uk'],
#  'ukcites.gov.uk': ['gov.uk'],
#  'torbay.gov.uk': ['gov.uk'],
#  'number-10.gov.uk': ['gov.uk'],
#  'northampton.gov.uk': ['gov.uk'],
#  'poder-judicial-bc.gob.mx': ['gob.mx'],
#  'aberdeenshire.gov.uk': ['gov.uk'],
#  'mmc.nhs.uk': ['nhs.uk'],
#  'avon.nhs.uk': ['nhs.uk'],
#  'welltown.gov.uk': ['gov.uk'],
#  'cheltenham.gov.uk': ['gov.uk'],
#  'nwest.nhs.uk': ['nhs.uk'],
#  'jncc.gov.uk': ['gov.uk'],
#  'bracknell-forest.gov.uk': ['gov.uk'],
#  'senado.gov.br': ['gov.br'],
#  'bradfordhospitals.nhs.uk': ['nhs.uk'],
#  'nta.nhs.uk': ['nhs.uk'],
#  'nhsdirect.nhs.uk': ['nhs.uk'],
#  'royalparks.gov.uk': ['gov.uk'],
#  'mintra.gob.pe': ['gob.pe'],
#  'qmc.nhs.uk': ['nhs.uk'],
#  'bcrp.gob.pe': ['gob.pe'],
#  'parkingandtrafficappeals.gov.uk': ['gov.uk'],
#  'warrington.gov.uk': ['gov.uk'],
#  'northamptonshire.gov.uk': ['gov.uk'],
#  'municipiotecoman.gob.mx': ['gob.mx'],
#  'numberten.gov.uk': ['gov.uk'],
#  'northwilts.gov.uk': ['gov.uk'],
#  'aberdeencity.gov.uk': ['gov.uk'],
#  'ver.gob.mx': ['gob.mx'],
#  'bolton.gov.uk': ['gov.uk'],
#  'princeofwales.gov.uk': ['gov.uk'],
#  'angus.gov.uk': ['gov.uk'],
#  'surestart.gov.uk': ['gov.uk'],
#  'loterianacional.gob.mx': ['gob.mx'],
#  'leon.gob.mx': ['gob.mx'],
#  'communicationsbill.gov.uk': ['gov.uk'],
#  'rbkc.gov.uk': ['gov.uk'],
#  'prompex.gob.pe': ['gob.pe'],
#  'peakdistrict.gov.uk': ['gov.uk'],
#  'surrey.gov.uk': ['gov.uk'],
#  'diputados.gob.mx': ['gob.mx'],
#  'ngfl.gov.uk': ['gov.uk'],
#  'hounslow.gov.uk': ['gov.uk'],
#  'chooseandbook.nhs.uk': ['nhs.uk'],
#  'meto.gov.uk': ['gov.uk'],
#  'semar.gob.mx': ['gob.mx'],
#  'bexley.gov.uk': ['gov.uk'],
#  'met-office.gov.uk': ['gov.uk'],
#  'pcm.gob.pe': ['gob.pe'],
#  'institute.nhs.uk': ['nhs.uk'],
#  'manchester.gov.uk': ['gov.uk'],
#  'ims.gov.il': ['gov.il'],
#  'desenvolvimento.gov.br': ['gov.br'],
#  'avalciudadano.gob.mx': ['gob.mx'],
#  'southwarkpct.nhs.uk': ['nhs.uk'],
#  'canterbury.gov.uk': ['gov.uk'],
#  'diabetes.nhs.uk': ['nhs.uk'],
#  'cultura.gov.br': ['gov.br'],
#  'tepatitlan.gob.mx': ['gob.mx'],
#  'argyll-bute.gov.uk': ['gov.uk'],
#  'cancerscreening.nhs.uk': ['nhs.uk'],
#  'aylesburyvaledc.gov.uk': ['gov.uk'],
#  'lewisham.gov.uk': ['gov.uk'],
#  'merseyfire.gov.uk': ['gov.uk'],
#  'wiltshirecds.nhs.uk': ['nhs.uk'],
#  'humanrights.gov.uk': ['gov.uk'],
#  'cuautla.gob.mx': ['gob.mx'],
#  'employmentservice.gov.uk': ['gov.uk'],
#  'ukpa.gov.uk': ['gov.uk'],
#  'barrowbc.gov.uk': ['gov.uk'],
#  'seapal.gob.mx': ['gob.mx'],
#  'southcambs-pct.nhs.uk': ['nhs.uk'],
#  'student-support-saas.gov.uk': ['gov.uk'],
#  'suht.nhs.uk': ['nhs.uk'],
#  'clinicalanswers.nhs.uk': ['nhs.uk'],
#  'cfe.gob.mx': ['gob.mx'],
#  'sag.gob.cl': ['gob.cl'],
#  'essexcc.gov.uk': ['gov.uk'],
#  'winchester.gov.uk': ['gov.uk'],
#  'fundaj.gov.br': ['gov.br'],
#  ...}

# %%
# %%time
# Checks if any partial match has matched more than one domain.
for k, v in partial_match.items():
    if len(v) != 1:
        print(v)
# Out:
# CPU times: user 258 µs, sys: 210 µs, total: 468 µs
# Wall time: 475 µs

# %%
# %%time
# Organizes data into a dictionary to be loaded into a DataFrame.
d = {'domain': [], 'match': [], 'topics': []}
for case in full_match:
    d['domain'].append(case)
    d['match'].append(case)
    d['topics'].append(topics[topics['domain'] == case]['topics'].to_list()[0])
for k, v in partial_match.items():
    d['domain'].append(k)
    d['match'].append(v[0])
    d['topics'].append(topics[topics['domain'] == case]['topics'].to_list()[0])
# Out:
# CPU times: user 3.2 s, sys: 0 ns, total: 3.2 s
# Wall time: 3.2 s

# %%
display(d)
# Out:
# {'domain': ['officedepot.com.mx',
#   'google.com.br',
#   'google.co.nz',
#   'independent.co.uk',
#   'unionbankonline.co.in',
#   'dominos.co.uk',
#   'aldi.co.uk',
#   'currys.co.uk',
#   'google.co.kr',
#   'google.com.hk',
#   'o2.co.uk',
#   'news.com.au',
#   'mercadolibre.com.uy',
#   'wickes.co.uk',
#   'mcdonalds.co.jp',
#   'jobs.nhs.uk',
#   'bbc.co.uk',
#   'stuff.co.nz',
#   'submarino.com.br',
#   'boticario.com.br',
#   'walla.co.il',
#   'wiggle.co.uk',
#   'mercadolibre.com.ar',
#   'pets4homes.co.uk',
#   'imovelweb.com.br',
#   'kanald.com.tr',
#   'google.com.sa',
#   'sams.com.mx',
#   'kalunga.com.br',
#   'bunnings.com.au',
#   'google.com.pe',
#   'commbank.com.au',
#   'thestar.com.my',
#   'google.com.co',
#   'thetimes.co.uk',
#   'ofuxico.com.br',
#   'dailystar.co.uk',
#   'lagaceta.com.ar',
#   'jbhifi.com.au',
#   'ntv.co.jp',
#   'uol.com.br',
#   'ebay.co.uk',
#   'trademe.co.nz',
#   'clicrbs.com.br',
#   'ciudad.com.ar',
#   'fanatik.com.tr',
#   'pagina12.com.ar',
#   'vivastreet.co.uk',
#   'nld.com.vn',
#   'costco.com.mx',
#   'iceland.co.uk',
#   'divyabhaskar.co.in',
#   'bharian.com.my',
#   'ntv.com.tr',
#   'thesun.co.uk',
#   'smh.com.au',
#   'pravda.com.ua',
#   'upsc.gov.in',
#   'vodafone.co.uk',
#   'gamer.com.tw',
#   'google.com.uy',
#   'bb.com.br',
#   'eluniversal.com.mx',
#   'imss.gob.mx',
#   'caixa.gov.br',
#   'google.com.tr',
#   'marisa.com.br',
#   'spareroom.co.uk',
#   'buscape.com.br',
#   'honda.com.br',
#   'google.com.vn',
#   'indiapost.gov.in',
#   'solodeportes.com.ar',
#   'manchestereveningnews.co.uk',
#   'google.com.tw',
#   'atv.com.tr',
#   'telegraph.co.uk',
#   'jang.com.pk',
#   'maybank2u.com.my',
#   'target.com.au',
#   'google.com.mx',
#   'sunat.gob.pe',
#   'rakuten.co.jp',
#   'kmart.com.au',
#   'google.co.za',
#   'google.com.ph',
#   'google.com.au',
#   'three.co.uk',
#   'set.or.th',
#   'dailynews.co.th',
#   'sonhos.com.br',
#   'abc.com.py',
#   'bigw.com.au',
#   'nzherald.co.nz',
#   'consultaremedios.com.br',
#   '104.com.tw',
#   'sainsburys.co.uk',
#   'mercadolibre.com.mx',
#   'google.co.il',
#   'auspost.com.au',
#   'globes.co.il',
#   'thairath.co.th',
#   'sat.gob.mx',
#   'tfl.gov.uk',
#   'uai.com.br',
#   'sabah.com.tr',
#   'haaretz.co.il',
#   'express.co.uk',
#   'google.com.gt',
#   'matichon.co.th',
#   'oi.com.br',
#   'voegol.com.br',
#   'ynet.co.il',
#   'casasbahia.com.br',
#   'computrabajo.com.mx',
#   'ole.com.ar',
#   'sodimac.com.pe',
#   'vivo.com.br',
#   'excelsior.com.mx',
#   'panorama.com.al',
#   'gumtree.co.za',
#   'mercadolibre.com.co',
#   'itau.com.br',
#   'proceso.com.mx',
#   'domain.com.au',
#   'google.com.ec',
#   'hoseasons.co.uk',
#   'homedepot.com.mx',
#   'computrabajo.com.pe',
#   'next.co.uk',
#   'lacapital.com.ar',
#   'metoffice.gov.uk',
#   'itmedia.co.jp',
#   'casadoscontos.com.br',
#   'tripadvisor.co.uk',
#   'tigo.com.gt',
#   'excite.co.jp',
#   'bom.gov.au',
#   'jdsports.co.uk',
#   'montevideo.com.uy',
#   'lanacion.com.ar',
#   'lidl.co.uk',
#   'milliyet.com.tr',
#   'walmart.com.mx',
#   'preloved.co.uk',
#   'nationallottery.co.za',
#   'autotrader.co.za',
#   'homebase.co.uk',
#   'diariodecuyo.com.ar',
#   'books.com.tw',
#   'thenews.com.pk',
#   'makro.co.za',
#   'dmm.co.jp',
#   'correios.com.br',
#   'seek.com.au',
#   'google.co.ve',
#   'dantri.com.vn',
#   'dailymail.co.uk',
#   'rightmove.co.uk',
#   'hmv.co.jp',
#   'yomiuri.co.jp',
#   'lovehoney.co.uk',
#   'matalan.co.uk',
#   'gumtree.com.au',
#   'eldeber.com.bo',
#   'amazon.co.jp',
#   'newsnow.co.uk',
#   '24h.com.vn',
#   'mercadolibre.com.ve',
#   'lse.co.uk',
#   'lpga.or.jp',
#   'hurriyet.com.tr',
#   'reed.co.uk',
#   'showtv.com.tr',
#   'americanas.com.br',
#   'oricon.co.jp',
#   'mercadolivre.com.br',
#   'jal.co.jp',
#   'autotrader.co.uk',
#   'argos.co.uk',
#   'honda.co.jp',
#   'google.co.in',
#   'metro.co.uk',
#   'google.co.jp',
#   'jobstreet.com.ph',
#   'abc.net.au',
#   'serasa.com.br',
#   'ebay.com.au',
#   'radios.com.br',
#   'google.com.sg',
#   'indianrail.gov.in',
#   'utusan.com.my',
#   'google.com.my',
#   'sears.com.mx',
#   'google.com.ar',
#   'dogstrust.org.uk',
#   'pontofrio.com.br',
#   'elpais.com.uy',
#   'lojasrenner.com.br',
#   'dailyrecord.co.uk',
#   'google.co.id',
#   'terra.com.br',
#   'mirror.co.uk',
#   'nintendo.co.jp',
#   'google.com.pk',
#   'unisa.ac.za',
#   'google.co.uk',
#   'ancestry.co.uk',
#   'singaporepools.com.sg',
#   '1999.co.jp',
#   'occ.com.mx',
#   'cumhuriyet.com.tr',
#   'carsales.com.au',
#   'netvasco.com.br',
#   'liverpool.com.mx',
#   'privateproperty.co.za',
#   'amazon.co.uk',
#   'realestate.com.au',
#   'maariv.co.il',
#   'yahoo.co.jp',
#   'globe.com.ph',
#   'bna.com.ar',
#   'sanborns.com.mx',
#   'zillow.com',
#   'elcorteingles.pt',
#   'antena3.com',
#   'kicker.de',
#   'boxrec.com',
#   'redfin.com',
#   'blizzard.com',
#   'shmu.sk',
#   'thumbzilla.com',
#   'welt.de',
#   'hottopic.com',
#   'aufeminin.com',
#   'jeevansathi.com',
#   'nrl.com',
#   'usatoday.com',
#   'google.se',
#   'freemail.hu',
#   'justdial.com',
#   'vodafone.es',
#   'toyota.jp',
#   'worldstar.com',
#   'ign.com',
#   'tradera.com',
#   'amd.com',
#   'caradisiac.com',
#   'infojobs.net',
#   'meetup.com',
#   'catofashions.com',
#   'menards.com',
#   'ideal.es',
#   'epicgames.com',
#   'anandabazar.com',
#   'cookpad.com',
#   'poradnikzdrowie.pl',
#   'bedbathandbeyond.com',
#   'auctionzip.com',
#   'worldofwarcraft.com',
#   'cdc.gov',
#   'prosport.ro',
#   'adultfriendfinder.com',
#   'tacobell.com',
#   'decolar.com',
#   'landsend.com',
#   'lasprovincias.es',
#   'thesimsresource.com',
#   'joemonster.org',
#   'underarmour.com',
#   'iltempo.it',
#   'officedepot.com',
#   'seneweb.com',
#   'blackpeoplemeet.com',
#   'otto.de',
#   'sba.gov',
#   'lavozdegalicia.es',
#   'nespresso.com',
#   'wral.com',
#   'canadiantire.ca',
#   'onlinesbi.com',
#   'hibbett.com',
#   'realtor.com',
#   'cotilleando.com',
#   'pagesjaunes.fr',
#   'sex.com',
#   'kinopoisk.ru',
#   'youngliving.com',
#   'parismatch.com',
#   'gocomics.com',
#   'ingatlan.com',
#   'elle.com',
#   'superdrug.com',
#   'crutchfield.com',
#   'lg.com',
#   'totalwine.com',
#   'centrum.cz',
#   'windguru.cz',
#   'eurocarparts.com',
#   'thefreedictionary.com',
#   'hollisterco.com',
#   'registrocivil.cl',
#   'tripadvisor.it',
#   'infobae.com',
#   'southwest.com',
#   'gazeta.pl',
#   'billboard.com',
#   'allrecipes.com',
#   'europa.eu',
#   'entrepreneur.com',
#   'skyscrapercity.com',
#   'theweathernetwork.com',
#   'haber7.com',
#   'investopedia.com',
#   '1001fonts.com',
#   'livescore.cz',
#   'nairaland.com',
#   'super.cz',
#   'ncsecu.org',
#   'cdiscount.com',
#   'kyero.com',
#   'interpals.net',
#   'vistaprint.com',
#   'immowelt.de',
#   'bhaskar.com',
#   'sport.es',
#   'juegos.com',
#   'longhornsteakhouse.com',
#   'office.com',
#   'swarovski.com',
#   'dreamstime.com',
#   'azlyrics.com',
#   'abc.es',
#   'orsay.com',
#   'kijiji.ca',
#   'tirerack.com',
#   'chip.de',
#   'tportal.hr',
#   'google.fi',
#   'silverdaddies.com',
#   'indeed.com',
#   'premierleague.com',
#   'npr.org',
#   'shutterstock.com',
#   'albayan.ae',
#   'nifty.org',
#   'newgrounds.com',
#   'google.nl',
#   'wetter.com',
#   'riverisland.com',
#   'tripadvisor.fr',
#   'filmaffinity.com',
#   'king.com',
#   'breitbart.com',
#   'diariolibre.com',
#   'pagesix.com',
#   'cnbc.com',
#   'gov.il',
#   'abc.com',
#   'vnexpress.net',
#   'barchart.com',
#   'tweakers.net',
#   'oggi.it',
#   'olivegarden.com',
#   'portfolio.hu',
#   'insider.com',
#   '4shared.com',
#   'dexonline.ro',
#   'juntadeandalucia.es',
#   'jegs.com',
#   'trovaprezzi.it',
#   'rtp.pt',
#   'schwab.com',
#   'webmd.com',
#   'wireclub.com',
#   'o2.pl',
#   'chase.com',
#   'forbes.com',
#   'voyeurweb.com',
#   'ilmattino.it',
#   'blocket.se',
#   'semana.com',
#   'rds.ca',
#   'toom.de',
#   'victoriassecret.com',
#   'nationalgeographic.com',
#   'google.ru',
#   'msn.com',
#   'sapo.pt',
#   'skyscanner.net',
#   'discounttire.com',
#   'volkskrant.nl',
#   'indiaglitz.com',
#   'study.com',
#   'in.gr',
#   'sweetwater.com',
#   'va.gov',
#   'coches.net',
#   'capitalone.com',
#   'nadaguides.com',
#   'investing.com',
#   'finishline.com',
#   'history.com',
#   'har.com',
#   'rawstory.com',
#   'aljazeera.net',
#   'ebay.it',
#   'vol.at',
#   'altex.ro',
#   'screenrant.com',
#   'lrytas.lt',
#   'gds.it',
#   'aa.com',
#   'garnstudio.com',
#   'nouvelobs.com',
#   'prensalibre.com',
#   'gazzetta.it',
#   'publico.pt',
#   'youtube.com',
#   'attheraces.com',
#   'neopets.com',
#   'heb.com',
#   'bigbadtoystore.com',
#   'hemnet.se',
#   'correos.es',
#   'dhnet.be',
#   'draugiem.lv',
#   'zazzle.com',
#   'tournamentsoftware.com',
#   'behindthename.com',
#   'sexstories.com',
#   'crazyshit.com',
#   'myherbalife.com',
#   'delfi.ee',
#   'gsmarena.com',
#   'ltdcommodities.com',
#   'harborfreight.com',
#   'usps.com',
#   'ae.com',
#   'delfi.lt',
#   'svd.se',
#   'boots.com',
#   'bestbuy.ca',
#   'bbc.com',
#   'malaysiakini.com',
#   'gumtree.pl',
#   'rottentomatoes.com',
#   'zennioptical.com',
#   'carrefour.es',
#   'td.com',
#   'monografias.com',
#   'marapets.com',
#   'pandora.com',
#   'sohu.com',
#   'reuters.com',
#   'chainreactioncycles.com',
#   'conjuguemos.com',
#   'vietnamnet.vn',
#   'fotocasa.es',
#   'iaai.com',
#   'rentacenter.com',
#   'punyu.com',
#   'nfl.com',
#   'istockphoto.com',
#   'potterybarn.com',
#   'imobiliare.ro',
#   'tycsports.com',
#   'ea.com',
#   'imvu.com',
#   'cda.pl',
#   'lequipe.fr',
#   'tiktok.com',
#   'quotidiano.net',
#   'missyusa.com',
#   'elcomercio.com',
#   'grubhub.com',
#   'samsung.com',
#   'andhrajyothy.com',
#   'newlook.com',
#   'mapquest.com',
#   'academy.com',
#   'tagesschau.de',
#   'futbolred.com',
#   'estrepublicain.fr',
#   'hollandandbarrett.com',
#   'nelly.com',
#   'ebay.ie',
#   'nicematin.com',
#   'pch.com',
#   'gismeteo.ru',
#   'cabelas.com',
#   'webstaurantstore.com',
#   'midwayusa.com',
#   'ancestry.com',
#   'vimm.net',
#   'carrefour.fr',
#   'cardkingdom.com',
#   'caracoltv.com',
#   'worldjournal.com',
#   'expedia.com',
#   'google.ca',
#   'brainyquote.com',
#   'pizzahut.com',
#   'boursorama.com',
#   'goldengate.hu',
#   'livescience.com',
#   'mixi.jp',
#   'formula1.com',
#   'menupix.com',
#   'bloomingdales.com',
#   'joann.com',
#   'radiozet.pl',
#   'citi.com',
#   'google.at',
#   'autotrader.com',
#   'explorelearning.com',
#   'goodhousekeeping.com',
#   'airg.com',
#   'uline.com',
#   'tsn.ca',
#   'libertaddigital.com',
#   'bunte.de',
#   'united.com',
#   'ganeshaspeaks.com',
#   'nos.nl',
#   'bt.com',
#   'livedoor.com',
#   'globo.com',
#   'hvg.hu',
#   'minijuegos.com',
#   'marriott.com',
#   'google.de',
#   'stockcharts.com',
#   'horoscope.com',
#   'spanishdict.com',
#   'shine.com',
#   'sante.fr',
#   'kay.com',
#   'mail.ru',
#   'woman.ru',
#   'ansa.it',
#   'naslovi.net',
#   'egun.de',
#   'fragrancenet.com',
#   'cbc.ca',
#   'euroleague.net',
#   'google.lk',
#   'hotnews.ro',
#   'wetterzentrale.de',
#   'russianfood.com',
#   'dhl.de',
#   'tigerdroppings.com',
#   'repubblica.it',
#   'laprensa.hn',
#   'vocabulary.com',
#   'cars.com',
#   'perfectgirls.net',
#   'expressen.se',
#   'wsj.com',
#   'duluthtrading.com',
#   'petsmart.com',
#   'kayak.com',
#   'xe.com',
#   'squirt.org',
#   'pornpics.com',
#   'minsal.cl',
#   'boostmobile.com',
#   'multiplication.com',
#   'priceline.com',
#   'bridgebase.com',
#   'kindgirls.com',
#   'casadellibro.com',
#   'blesk.cz',
#   'carsforsale.com',
#   'google.it',
#   'latimes.com',
#   'usbank.com',
#   'fossil.com',
#   'dairyqueen.com',
#   'melaleuca.com',
#   'greetingsisland.com',
#   'eonline.com',
#   'discover.com',
#   'hermes.com',
#   'hobbylobby.com',
#   'tf1.fr',
#   'autogidas.lt',
#   'qvc.com',
#   'nps.gov',
#   'biglots.com',
#   'hrblock.com',
#   'autoscout24.de',
#   'nordstrom.com',
#   'orf.at',
#   'newspapers.com',
#   'nowtv.com',
#   'pichunter.com',
#   'kathimerini.gr',
#   'eurosport.fr',
#   'telegraaf.nl',
#   'netspend.com',
#   'freetaxusa.com',
#   'mlb.com',
#   'gamestop.com',
#   'google.pl',
#   'lenovo.com',
#   'famousfootwear.com',
#   'canarias7.es',
#   'larazon.es',
#   'haberturk.com',
#   'amazon.com',
#   'fidelity.com',
#   'dn.se',
#   '90minut.pl',
#   'vegasinsider.com',
#   'uniqlo.com',
#   'itv.com',
#   'shoecarnival.com',
#   'losarcanos.com',
#   'ducksters.com',
#   'uscis.gov',
#   'dafont.com',
#   'rtve.es',
#   'canalrcn.com',
#   'lampsplus.com',
#   'hsn.com',
#   'drmartens.com',
#   'adac.de',
#   'tff.org',
#   'timeanddate.com',
#   'ebay.de',
#   'origo.hu',
#   'lne.es',
#   'scielo.br',
#   'dagbladet.no',
#   'google.lv',
#   'thehill.com',
#   '24ur.com',
#   'telcel.com',
#   'accuweather.com',
#   'lenta.ru',
#   'diy.com',
#   'mercadolibre.cl',
#   'starfall.com',
#   'funimation.com',
#   'callofduty.com',
#   'screwfix.com',
#   'walmart.ca',
#   'xataka.com',
#   'mitbbs.com',
#   'sprint.com',
#   'ilmessaggero.it',
#   'immonet.de',
#   'wizardingworld.com',
#   'assoass.com',
#   'ibm.com',
#   'paypal.com',
#   'covers.com',
#   'todocoleccion.net',
#   'familysearch.org',
#   'ksl.com',
#   'insomnia.gr',
#   'eros.com',
#   'allocine.fr',
#   'tibia.com',
#   'hornbach.de',
#   'fedex.com',
#   'lotterypost.com',
#   'fingerhut.com',
#   'apartments.com',
#   'meetic.fr',
#   'marksandspencer.com',
#   'gunbroker.com',
#   'khaleejtimes.com',
#   'yle.fi',
#   'alarabiya.net',
#   'skechers.com',
#   'patch.com',
#   'portalinmobiliario.com',
#   'pogo.com',
#   'instructables.com',
#   'blick.ch',
#   'pbskids.org',
#   'macys.com',
#   'ebay.at',
#   'proxibid.com',
#   'loopnet.com',
#   'postfun.com',
#   'google.sk',
#   'rosario3.com',
#   'livescores.com',
#   'nasa.gov',
#   'interia.pl',
#   'uhaul.com',
#   'google.ro',
#   'mercadolibre.com',
#   'gamesradar.com',
#   'adressa.no',
#   'sbazar.cz',
#   'rtvslo.si',
#   'sodimac.cl',
#   'rte.ie',
#   'latercera.com',
#   'google.com',
#   'news24.com',
#   'guitarcenter.com',
#   'dr.dk',
#   'shutterfly.com',
#   'nettiauto.com',
#   'wordpress.org',
#   'movistar.es',
#   'rtl.be',
#   'qatarliving.com',
#   'senukai.lt',
#   'ar15.com',
#   'tuttosport.com',
#   'payscale.com',
#   'publix.com',
#   'w3schools.com',
#   'thedrive.com',
#   'chosun.com',
#   'telmex.com',
#   'hotels.com',
#   'playground.ru',
#   'nhs.uk',
#   'au.com',
#   'dhgate.com',
#   'rotowire.com',
#   'sanook.com',
#   'kleinezeitung.at',
#   'pitchfork.com',
#   '24sata.hr',
#   'esquire.com',
#   'vanguardia.com',
#   'netflix.com',
#   'jeuxvideo.com',
#   'ancestry.ca',
#   'adam4adam.com',
#   'bartleby.com',
#   'ebay.es',
#   'flalottery.com',
#   'elcorteingles.es',
#   'timesofindia.com',
#   'bathandbodyworks.com',
#   'ledauphine.com',
#   'johnlewis.com',
#   'smokva.com',
#   'kidshealth.org',
#   'tiava.com',
#   'teamtalk.com',
#   'nypost.com',
#   'linternaute.com',
#   'manhunt.net',
#   'ashleyfurniture.com',
#   'tchatche.com',
#   'delta.com',
#   'drugs.com',
#   'adidas.com',
#   'mumsnet.com',
#   'scmp.com',
#   'wordreference.com',
#   'kakaku.com',
#   'nrk.no',
#   'datezone.com',
#   'sueddeutsche.de',
#   'oreillyauto.com',
#   'newegg.com',
#   'ft.com',
#   'yaplakal.com',
#   'playstation.com',
#   'diariovasco.com',
#   'caranddriver.com',
#   'laredoute.fr',
#   '7sur7.be',
#   'cbsnews.com',
#   'index.hu',
#   'g2g.com',
#   'tripadvisor.es',
#   'scapino.nl',
#   'sudoku.com',
#   'mobile01.com',
#   'pcgamer.com',
#   'pap.fr',
#   'sii.cl',
#   'britannica.com',
#   'rtl.fr',
#   'target.com',
#   'edmunds.com',
#   'skybet.com',
#   'forocoches.com',
#   'google.ae',
#   'pakwheels.com',
#   'sony.jp',
#   'fernsehserien.de',
#   'tagged.com',
#   'expatriates.com',
#   'indiamart.com',
#   'chefkoch.de',
#   'derstandard.at',
#   'papajohns.com',
#   'consumerreports.org',
#   'bhphotovideo.com',
#   'bhg.com',
#   'udn.com',
#   'marktplaats.nl',
#   '750g.com',
#   'joyclub.de',
#   'lapresse.ca',
#   'cvs.com',
#   'galottery.com',
#   'nature.com',
#   'vesti.ru',
#   'clasificadosonline.com',
#   'bershka.com',
#   'chileautos.cl',
#   'rent.com',
#   'cox.com',
#   'property24.com',
#   'ojogo.pt',
#   'skatteverket.se',
#   'myfreecams.com',
#   'ozon.ru',
#   'etsy.com',
#   'csfd.cz',
#   'sunporno.com',
#   'bseindia.com',
#   'ilsole24ore.com',
#   'slate.com',
#   'gulfnews.com',
#   'xuite.net',
#   'hindustantimes.com',
#   'ameba.jp',
#   'cadenaser.com',
#   'bankofamerica.com',
#   'hyundai.com',
#   'urbandictionary.com',
#   'truckpaper.com',
#   'kirklands.com',
#   'trojmiasto.pl',
#   'tvgids.nl',
#   'freesexyindians.com',
#   'milenio.com',
#   'nclottery.com',
#   'rossmann.de',
#   'yelp.com',
#   'dxlive.com',
#   '3movs.com',
#   'build.com',
#   'brigitte.de',
#   'drudgereport.com',
#   'michigan.gov',
#   'aastocks.com',
#   'ebay.fr',
#   'icicibank.com',
#   'tabelog.com',
#   'rbcroyalbank.com',
#   'ica.se',
#   'torn.com',
#   'dlsite.com',
#   'sciaga.pl',
#   'astrology.com',
#   'sbicard.com',
#   'dickssportinggoods.com',
#   'athome.com',
#   'rambler.ru',
#   'brainpop.com',
#   'zeit.de',
#   'opticsplanet.com',
#   'mass.gov',
#   'alibaba.com',
#   'britishairways.com',
#   'poste.it',
#   'krone.at',
#   'dominos.com',
#   'arkadium.com',
#   'nuskin.com',
#   'whattoexpect.com',
#   'nike.com',
#   'utorrent.com',
#   'sfgate.com',
#   'viz.com',
#   'slobodnadalmacija.hr',
#   'rvtrader.com',
#   'naver.com',
#   'pnp.de',
#   'wetteronline.de',
#   'people.com',
#   'ad.nl',
#   'jutarnji.hr',
#   'scoresandodds.com',
#   'kooora.com',
#   'daserste.de',
#   'moneysavingexpert.com',
#   '20minutos.es',
#   'furaffinity.net',
#   'bt.dk',
#   'bloomberg.com',
#   'sportchek.ca',
#   'pricesmart.com',
#   'grammy.com',
#   'bancsabadell.com',
#   'o2online.de',
#   'soccerstand.com',
#   'zoominfo.com',
#   'tvn.cl',
#   'habitaclia.com',
#   'jpay.com',
#   'famousbirthdays.com',
#   'gab.com',
#   'carfax.com',
#   'hilton.com',
#   'jumbo.com',
#   'rona.ca',
#   'cellufun.com',
#   'antenna.gr',
#   'hotukdeals.com',
#   'tvmovie.de',
#   'si.com',
#   'xxx.com',
#   'marketwatch.com',
#   'tipcars.com',
#   'rackroomshoes.com',
#   'telecinco.es',
#   'tmz.com',
#   'tv2.no',
#   'uefa.com',
#   'indianexpress.com',
#   'rotter.net',
#   'delfi.lv',
#   'google.es',
#   'lego.com',
#   'tesco.com',
#   'ixbt.com',
#   'jstor.org',
#   'sgcarmart.com',
#   'di.se',
#   'coldwellbankerhomes.com',
#   'sauto.cz',
#   'hm.com',
#   'budsgunshop.com',
#   'applebees.com',
#   'boardgamegeek.com',
#   'komputerswiat.pl',
#   'erotikforum.at',
#   'tim.it',
#   'yoox.com',
#   'wordpress.com',
#   'skype.com',
#   'google.lt',
#   'chess.com',
#   'crateandbarrel.com',
#   'kitco.com',
#   'banamex.com',
#   'thesaurus.com',
#   'who.int',
#   'lepoint.fr',
#   'predskazanie.ru',
#   'thepiratebay.org',
#   'channelnewsasia.com',
#   'ebay.com',
#   'medicinenet.com',
#   'dictionary.com',
#   'specialized.com',
#   'toutelatele.com',
#   'ultimahora.es',
#   'gumtree.com',
#   'att.net',
#   'blogto.com',
#   'literotica.com',
#   'viabcp.com',
#   'michaels.com',
#   'samsclub.com',
#   'easyjet.com',
#   'forever21.com',
#   'nvidia.com',
#   'lci.fr',
#   'yallakora.com',
#   'euroresidentes.com',
#   'flightaware.com',
#   'cycletrader.com',
#   'xnxx.net',
#   'equibase.com',
#   'auto.ru',
#   'dell.com',
#   'royallepage.ca',
#   'sahibinden.com',
#   'sierra.com',
#   'gratka.pl',
#   'b92.net',
#   'idnes.cz',
#   'bricklink.com',
#   'tanea.gr',
#   'lotteryusa.com',
#   'casa.it',
#   'visir.is',
#   'xoom.com',
#   'morningstar.com',
#   'univision.com',
#   'petco.com',
#   'belk.com',
#   ...],
#  'match': ['officedepot.com.mx',
#   'google.com.br',
#   'google.co.nz',
#   'independent.co.uk',
#   'unionbankonline.co.in',
#   'dominos.co.uk',
#   'aldi.co.uk',
#   'currys.co.uk',
#   'google.co.kr',
#   'google.com.hk',
#   'o2.co.uk',
#   'news.com.au',
#   'mercadolibre.com.uy',
#   'wickes.co.uk',
#   'mcdonalds.co.jp',
#   'jobs.nhs.uk',
#   'bbc.co.uk',
#   'stuff.co.nz',
#   'submarino.com.br',
#   'boticario.com.br',
#   'walla.co.il',
#   'wiggle.co.uk',
#   'mercadolibre.com.ar',
#   'pets4homes.co.uk',
#   'imovelweb.com.br',
#   'kanald.com.tr',
#   'google.com.sa',
#   'sams.com.mx',
#   'kalunga.com.br',
#   'bunnings.com.au',
#   'google.com.pe',
#   'commbank.com.au',
#   'thestar.com.my',
#   'google.com.co',
#   'thetimes.co.uk',
#   'ofuxico.com.br',
#   'dailystar.co.uk',
#   'lagaceta.com.ar',
#   'jbhifi.com.au',
#   'ntv.co.jp',
#   'uol.com.br',
#   'ebay.co.uk',
#   'trademe.co.nz',
#   'clicrbs.com.br',
#   'ciudad.com.ar',
#   'fanatik.com.tr',
#   'pagina12.com.ar',
#   'vivastreet.co.uk',
#   'nld.com.vn',
#   'costco.com.mx',
#   'iceland.co.uk',
#   'divyabhaskar.co.in',
#   'bharian.com.my',
#   'ntv.com.tr',
#   'thesun.co.uk',
#   'smh.com.au',
#   'pravda.com.ua',
#   'upsc.gov.in',
#   'vodafone.co.uk',
#   'gamer.com.tw',
#   'google.com.uy',
#   'bb.com.br',
#   'eluniversal.com.mx',
#   'imss.gob.mx',
#   'caixa.gov.br',
#   'google.com.tr',
#   'marisa.com.br',
#   'spareroom.co.uk',
#   'buscape.com.br',
#   'honda.com.br',
#   'google.com.vn',
#   'indiapost.gov.in',
#   'solodeportes.com.ar',
#   'manchestereveningnews.co.uk',
#   'google.com.tw',
#   'atv.com.tr',
#   'telegraph.co.uk',
#   'jang.com.pk',
#   'maybank2u.com.my',
#   'target.com.au',
#   'google.com.mx',
#   'sunat.gob.pe',
#   'rakuten.co.jp',
#   'kmart.com.au',
#   'google.co.za',
#   'google.com.ph',
#   'google.com.au',
#   'three.co.uk',
#   'set.or.th',
#   'dailynews.co.th',
#   'sonhos.com.br',
#   'abc.com.py',
#   'bigw.com.au',
#   'nzherald.co.nz',
#   'consultaremedios.com.br',
#   '104.com.tw',
#   'sainsburys.co.uk',
#   'mercadolibre.com.mx',
#   'google.co.il',
#   'auspost.com.au',
#   'globes.co.il',
#   'thairath.co.th',
#   'sat.gob.mx',
#   'tfl.gov.uk',
#   'uai.com.br',
#   'sabah.com.tr',
#   'haaretz.co.il',
#   'express.co.uk',
#   'google.com.gt',
#   'matichon.co.th',
#   'oi.com.br',
#   'voegol.com.br',
#   'ynet.co.il',
#   'casasbahia.com.br',
#   'computrabajo.com.mx',
#   'ole.com.ar',
#   'sodimac.com.pe',
#   'vivo.com.br',
#   'excelsior.com.mx',
#   'panorama.com.al',
#   'gumtree.co.za',
#   'mercadolibre.com.co',
#   'itau.com.br',
#   'proceso.com.mx',
#   'domain.com.au',
#   'google.com.ec',
#   'hoseasons.co.uk',
#   'homedepot.com.mx',
#   'computrabajo.com.pe',
#   'next.co.uk',
#   'lacapital.com.ar',
#   'metoffice.gov.uk',
#   'itmedia.co.jp',
#   'casadoscontos.com.br',
#   'tripadvisor.co.uk',
#   'tigo.com.gt',
#   'excite.co.jp',
#   'bom.gov.au',
#   'jdsports.co.uk',
#   'montevideo.com.uy',
#   'lanacion.com.ar',
#   'lidl.co.uk',
#   'milliyet.com.tr',
#   'walmart.com.mx',
#   'preloved.co.uk',
#   'nationallottery.co.za',
#   'autotrader.co.za',
#   'homebase.co.uk',
#   'diariodecuyo.com.ar',
#   'books.com.tw',
#   'thenews.com.pk',
#   'makro.co.za',
#   'dmm.co.jp',
#   'correios.com.br',
#   'seek.com.au',
#   'google.co.ve',
#   'dantri.com.vn',
#   'dailymail.co.uk',
#   'rightmove.co.uk',
#   'hmv.co.jp',
#   'yomiuri.co.jp',
#   'lovehoney.co.uk',
#   'matalan.co.uk',
#   'gumtree.com.au',
#   'eldeber.com.bo',
#   'amazon.co.jp',
#   'newsnow.co.uk',
#   '24h.com.vn',
#   'mercadolibre.com.ve',
#   'lse.co.uk',
#   'lpga.or.jp',
#   'hurriyet.com.tr',
#   'reed.co.uk',
#   'showtv.com.tr',
#   'americanas.com.br',
#   'oricon.co.jp',
#   'mercadolivre.com.br',
#   'jal.co.jp',
#   'autotrader.co.uk',
#   'argos.co.uk',
#   'honda.co.jp',
#   'google.co.in',
#   'metro.co.uk',
#   'google.co.jp',
#   'jobstreet.com.ph',
#   'abc.net.au',
#   'serasa.com.br',
#   'ebay.com.au',
#   'radios.com.br',
#   'google.com.sg',
#   'indianrail.gov.in',
#   'utusan.com.my',
#   'google.com.my',
#   'sears.com.mx',
#   'google.com.ar',
#   'dogstrust.org.uk',
#   'pontofrio.com.br',
#   'elpais.com.uy',
#   'lojasrenner.com.br',
#   'dailyrecord.co.uk',
#   'google.co.id',
#   'terra.com.br',
#   'mirror.co.uk',
#   'nintendo.co.jp',
#   'google.com.pk',
#   'unisa.ac.za',
#   'google.co.uk',
#   'ancestry.co.uk',
#   'singaporepools.com.sg',
#   '1999.co.jp',
#   'occ.com.mx',
#   'cumhuriyet.com.tr',
#   'carsales.com.au',
#   'netvasco.com.br',
#   'liverpool.com.mx',
#   'privateproperty.co.za',
#   'amazon.co.uk',
#   'realestate.com.au',
#   'maariv.co.il',
#   'yahoo.co.jp',
#   'globe.com.ph',
#   'bna.com.ar',
#   'sanborns.com.mx',
#   'zillow.com',
#   'elcorteingles.pt',
#   'antena3.com',
#   'kicker.de',
#   'boxrec.com',
#   'redfin.com',
#   'blizzard.com',
#   'shmu.sk',
#   'thumbzilla.com',
#   'welt.de',
#   'hottopic.com',
#   'aufeminin.com',
#   'jeevansathi.com',
#   'nrl.com',
#   'usatoday.com',
#   'google.se',
#   'freemail.hu',
#   'justdial.com',
#   'vodafone.es',
#   'toyota.jp',
#   'worldstar.com',
#   'ign.com',
#   'tradera.com',
#   'amd.com',
#   'caradisiac.com',
#   'infojobs.net',
#   'meetup.com',
#   'catofashions.com',
#   'menards.com',
#   'ideal.es',
#   'epicgames.com',
#   'anandabazar.com',
#   'cookpad.com',
#   'poradnikzdrowie.pl',
#   'bedbathandbeyond.com',
#   'auctionzip.com',
#   'worldofwarcraft.com',
#   'cdc.gov',
#   'prosport.ro',
#   'adultfriendfinder.com',
#   'tacobell.com',
#   'decolar.com',
#   'landsend.com',
#   'lasprovincias.es',
#   'thesimsresource.com',
#   'joemonster.org',
#   'underarmour.com',
#   'iltempo.it',
#   'officedepot.com',
#   'seneweb.com',
#   'blackpeoplemeet.com',
#   'otto.de',
#   'sba.gov',
#   'lavozdegalicia.es',
#   'nespresso.com',
#   'wral.com',
#   'canadiantire.ca',
#   'onlinesbi.com',
#   'hibbett.com',
#   'realtor.com',
#   'cotilleando.com',
#   'pagesjaunes.fr',
#   'sex.com',
#   'kinopoisk.ru',
#   'youngliving.com',
#   'parismatch.com',
#   'gocomics.com',
#   'ingatlan.com',
#   'elle.com',
#   'superdrug.com',
#   'crutchfield.com',
#   'lg.com',
#   'totalwine.com',
#   'centrum.cz',
#   'windguru.cz',
#   'eurocarparts.com',
#   'thefreedictionary.com',
#   'hollisterco.com',
#   'registrocivil.cl',
#   'tripadvisor.it',
#   'infobae.com',
#   'southwest.com',
#   'gazeta.pl',
#   'billboard.com',
#   'allrecipes.com',
#   'europa.eu',
#   'entrepreneur.com',
#   'skyscrapercity.com',
#   'theweathernetwork.com',
#   'haber7.com',
#   'investopedia.com',
#   '1001fonts.com',
#   'livescore.cz',
#   'nairaland.com',
#   'super.cz',
#   'ncsecu.org',
#   'cdiscount.com',
#   'kyero.com',
#   'interpals.net',
#   'vistaprint.com',
#   'immowelt.de',
#   'bhaskar.com',
#   'sport.es',
#   'juegos.com',
#   'longhornsteakhouse.com',
#   'office.com',
#   'swarovski.com',
#   'dreamstime.com',
#   'azlyrics.com',
#   'abc.es',
#   'orsay.com',
#   'kijiji.ca',
#   'tirerack.com',
#   'chip.de',
#   'tportal.hr',
#   'google.fi',
#   'silverdaddies.com',
#   'indeed.com',
#   'premierleague.com',
#   'npr.org',
#   'shutterstock.com',
#   'albayan.ae',
#   'nifty.org',
#   'newgrounds.com',
#   'google.nl',
#   'wetter.com',
#   'riverisland.com',
#   'tripadvisor.fr',
#   'filmaffinity.com',
#   'king.com',
#   'breitbart.com',
#   'diariolibre.com',
#   'pagesix.com',
#   'cnbc.com',
#   'gov.il',
#   'abc.com',
#   'vnexpress.net',
#   'barchart.com',
#   'tweakers.net',
#   'oggi.it',
#   'olivegarden.com',
#   'portfolio.hu',
#   'insider.com',
#   '4shared.com',
#   'dexonline.ro',
#   'juntadeandalucia.es',
#   'jegs.com',
#   'trovaprezzi.it',
#   'rtp.pt',
#   'schwab.com',
#   'webmd.com',
#   'wireclub.com',
#   'o2.pl',
#   'chase.com',
#   'forbes.com',
#   'voyeurweb.com',
#   'ilmattino.it',
#   'blocket.se',
#   'semana.com',
#   'rds.ca',
#   'toom.de',
#   'victoriassecret.com',
#   'nationalgeographic.com',
#   'google.ru',
#   'msn.com',
#   'sapo.pt',
#   'skyscanner.net',
#   'discounttire.com',
#   'volkskrant.nl',
#   'indiaglitz.com',
#   'study.com',
#   'in.gr',
#   'sweetwater.com',
#   'va.gov',
#   'coches.net',
#   'capitalone.com',
#   'nadaguides.com',
#   'investing.com',
#   'finishline.com',
#   'history.com',
#   'har.com',
#   'rawstory.com',
#   'aljazeera.net',
#   'ebay.it',
#   'vol.at',
#   'altex.ro',
#   'screenrant.com',
#   'lrytas.lt',
#   'gds.it',
#   'aa.com',
#   'garnstudio.com',
#   'nouvelobs.com',
#   'prensalibre.com',
#   'gazzetta.it',
#   'publico.pt',
#   'youtube.com',
#   'attheraces.com',
#   'neopets.com',
#   'heb.com',
#   'bigbadtoystore.com',
#   'hemnet.se',
#   'correos.es',
#   'dhnet.be',
#   'draugiem.lv',
#   'zazzle.com',
#   'tournamentsoftware.com',
#   'behindthename.com',
#   'sexstories.com',
#   'crazyshit.com',
#   'myherbalife.com',
#   'delfi.ee',
#   'gsmarena.com',
#   'ltdcommodities.com',
#   'harborfreight.com',
#   'usps.com',
#   'ae.com',
#   'delfi.lt',
#   'svd.se',
#   'boots.com',
#   'bestbuy.ca',
#   'bbc.com',
#   'malaysiakini.com',
#   'gumtree.pl',
#   'rottentomatoes.com',
#   'zennioptical.com',
#   'carrefour.es',
#   'td.com',
#   'monografias.com',
#   'marapets.com',
#   'pandora.com',
#   'sohu.com',
#   'reuters.com',
#   'chainreactioncycles.com',
#   'conjuguemos.com',
#   'vietnamnet.vn',
#   'fotocasa.es',
#   'iaai.com',
#   'rentacenter.com',
#   'punyu.com',
#   'nfl.com',
#   'istockphoto.com',
#   'potterybarn.com',
#   'imobiliare.ro',
#   'tycsports.com',
#   'ea.com',
#   'imvu.com',
#   'cda.pl',
#   'lequipe.fr',
#   'tiktok.com',
#   'quotidiano.net',
#   'missyusa.com',
#   'elcomercio.com',
#   'grubhub.com',
#   'samsung.com',
#   'andhrajyothy.com',
#   'newlook.com',
#   'mapquest.com',
#   'academy.com',
#   'tagesschau.de',
#   'futbolred.com',
#   'estrepublicain.fr',
#   'hollandandbarrett.com',
#   'nelly.com',
#   'ebay.ie',
#   'nicematin.com',
#   'pch.com',
#   'gismeteo.ru',
#   'cabelas.com',
#   'webstaurantstore.com',
#   'midwayusa.com',
#   'ancestry.com',
#   'vimm.net',
#   'carrefour.fr',
#   'cardkingdom.com',
#   'caracoltv.com',
#   'worldjournal.com',
#   'expedia.com',
#   'google.ca',
#   'brainyquote.com',
#   'pizzahut.com',
#   'boursorama.com',
#   'goldengate.hu',
#   'livescience.com',
#   'mixi.jp',
#   'formula1.com',
#   'menupix.com',
#   'bloomingdales.com',
#   'joann.com',
#   'radiozet.pl',
#   'citi.com',
#   'google.at',
#   'autotrader.com',
#   'explorelearning.com',
#   'goodhousekeeping.com',
#   'airg.com',
#   'uline.com',
#   'tsn.ca',
#   'libertaddigital.com',
#   'bunte.de',
#   'united.com',
#   'ganeshaspeaks.com',
#   'nos.nl',
#   'bt.com',
#   'livedoor.com',
#   'globo.com',
#   'hvg.hu',
#   'minijuegos.com',
#   'marriott.com',
#   'google.de',
#   'stockcharts.com',
#   'horoscope.com',
#   'spanishdict.com',
#   'shine.com',
#   'sante.fr',
#   'kay.com',
#   'mail.ru',
#   'woman.ru',
#   'ansa.it',
#   'naslovi.net',
#   'egun.de',
#   'fragrancenet.com',
#   'cbc.ca',
#   'euroleague.net',
#   'google.lk',
#   'hotnews.ro',
#   'wetterzentrale.de',
#   'russianfood.com',
#   'dhl.de',
#   'tigerdroppings.com',
#   'repubblica.it',
#   'laprensa.hn',
#   'vocabulary.com',
#   'cars.com',
#   'perfectgirls.net',
#   'expressen.se',
#   'wsj.com',
#   'duluthtrading.com',
#   'petsmart.com',
#   'kayak.com',
#   'xe.com',
#   'squirt.org',
#   'pornpics.com',
#   'minsal.cl',
#   'boostmobile.com',
#   'multiplication.com',
#   'priceline.com',
#   'bridgebase.com',
#   'kindgirls.com',
#   'casadellibro.com',
#   'blesk.cz',
#   'carsforsale.com',
#   'google.it',
#   'latimes.com',
#   'usbank.com',
#   'fossil.com',
#   'dairyqueen.com',
#   'melaleuca.com',
#   'greetingsisland.com',
#   'eonline.com',
#   'discover.com',
#   'hermes.com',
#   'hobbylobby.com',
#   'tf1.fr',
#   'autogidas.lt',
#   'qvc.com',
#   'nps.gov',
#   'biglots.com',
#   'hrblock.com',
#   'autoscout24.de',
#   'nordstrom.com',
#   'orf.at',
#   'newspapers.com',
#   'nowtv.com',
#   'pichunter.com',
#   'kathimerini.gr',
#   'eurosport.fr',
#   'telegraaf.nl',
#   'netspend.com',
#   'freetaxusa.com',
#   'mlb.com',
#   'gamestop.com',
#   'google.pl',
#   'lenovo.com',
#   'famousfootwear.com',
#   'canarias7.es',
#   'larazon.es',
#   'haberturk.com',
#   'amazon.com',
#   'fidelity.com',
#   'dn.se',
#   '90minut.pl',
#   'vegasinsider.com',
#   'uniqlo.com',
#   'itv.com',
#   'shoecarnival.com',
#   'losarcanos.com',
#   'ducksters.com',
#   'uscis.gov',
#   'dafont.com',
#   'rtve.es',
#   'canalrcn.com',
#   'lampsplus.com',
#   'hsn.com',
#   'drmartens.com',
#   'adac.de',
#   'tff.org',
#   'timeanddate.com',
#   'ebay.de',
#   'origo.hu',
#   'lne.es',
#   'scielo.br',
#   'dagbladet.no',
#   'google.lv',
#   'thehill.com',
#   '24ur.com',
#   'telcel.com',
#   'accuweather.com',
#   'lenta.ru',
#   'diy.com',
#   'mercadolibre.cl',
#   'starfall.com',
#   'funimation.com',
#   'callofduty.com',
#   'screwfix.com',
#   'walmart.ca',
#   'xataka.com',
#   'mitbbs.com',
#   'sprint.com',
#   'ilmessaggero.it',
#   'immonet.de',
#   'wizardingworld.com',
#   'assoass.com',
#   'ibm.com',
#   'paypal.com',
#   'covers.com',
#   'todocoleccion.net',
#   'familysearch.org',
#   'ksl.com',
#   'insomnia.gr',
#   'eros.com',
#   'allocine.fr',
#   'tibia.com',
#   'hornbach.de',
#   'fedex.com',
#   'lotterypost.com',
#   'fingerhut.com',
#   'apartments.com',
#   'meetic.fr',
#   'marksandspencer.com',
#   'gunbroker.com',
#   'khaleejtimes.com',
#   'yle.fi',
#   'alarabiya.net',
#   'skechers.com',
#   'patch.com',
#   'portalinmobiliario.com',
#   'pogo.com',
#   'instructables.com',
#   'blick.ch',
#   'pbskids.org',
#   'macys.com',
#   'ebay.at',
#   'proxibid.com',
#   'loopnet.com',
#   'postfun.com',
#   'google.sk',
#   'rosario3.com',
#   'livescores.com',
#   'nasa.gov',
#   'interia.pl',
#   'uhaul.com',
#   'google.ro',
#   'mercadolibre.com',
#   'gamesradar.com',
#   'adressa.no',
#   'sbazar.cz',
#   'rtvslo.si',
#   'sodimac.cl',
#   'rte.ie',
#   'latercera.com',
#   'google.com',
#   'news24.com',
#   'guitarcenter.com',
#   'dr.dk',
#   'shutterfly.com',
#   'nettiauto.com',
#   'wordpress.org',
#   'movistar.es',
#   'rtl.be',
#   'qatarliving.com',
#   'senukai.lt',
#   'ar15.com',
#   'tuttosport.com',
#   'payscale.com',
#   'publix.com',
#   'w3schools.com',
#   'thedrive.com',
#   'chosun.com',
#   'telmex.com',
#   'hotels.com',
#   'playground.ru',
#   'nhs.uk',
#   'au.com',
#   'dhgate.com',
#   'rotowire.com',
#   'sanook.com',
#   'kleinezeitung.at',
#   'pitchfork.com',
#   '24sata.hr',
#   'esquire.com',
#   'vanguardia.com',
#   'netflix.com',
#   'jeuxvideo.com',
#   'ancestry.ca',
#   'adam4adam.com',
#   'bartleby.com',
#   'ebay.es',
#   'flalottery.com',
#   'elcorteingles.es',
#   'timesofindia.com',
#   'bathandbodyworks.com',
#   'ledauphine.com',
#   'johnlewis.com',
#   'smokva.com',
#   'kidshealth.org',
#   'tiava.com',
#   'teamtalk.com',
#   'nypost.com',
#   'linternaute.com',
#   'manhunt.net',
#   'ashleyfurniture.com',
#   'tchatche.com',
#   'delta.com',
#   'drugs.com',
#   'adidas.com',
#   'mumsnet.com',
#   'scmp.com',
#   'wordreference.com',
#   'kakaku.com',
#   'nrk.no',
#   'datezone.com',
#   'sueddeutsche.de',
#   'oreillyauto.com',
#   'newegg.com',
#   'ft.com',
#   'yaplakal.com',
#   'playstation.com',
#   'diariovasco.com',
#   'caranddriver.com',
#   'laredoute.fr',
#   '7sur7.be',
#   'cbsnews.com',
#   'index.hu',
#   'g2g.com',
#   'tripadvisor.es',
#   'scapino.nl',
#   'sudoku.com',
#   'mobile01.com',
#   'pcgamer.com',
#   'pap.fr',
#   'sii.cl',
#   'britannica.com',
#   'rtl.fr',
#   'target.com',
#   'edmunds.com',
#   'skybet.com',
#   'forocoches.com',
#   'google.ae',
#   'pakwheels.com',
#   'sony.jp',
#   'fernsehserien.de',
#   'tagged.com',
#   'expatriates.com',
#   'indiamart.com',
#   'chefkoch.de',
#   'derstandard.at',
#   'papajohns.com',
#   'consumerreports.org',
#   'bhphotovideo.com',
#   'bhg.com',
#   'udn.com',
#   'marktplaats.nl',
#   '750g.com',
#   'joyclub.de',
#   'lapresse.ca',
#   'cvs.com',
#   'galottery.com',
#   'nature.com',
#   'vesti.ru',
#   'clasificadosonline.com',
#   'bershka.com',
#   'chileautos.cl',
#   'rent.com',
#   'cox.com',
#   'property24.com',
#   'ojogo.pt',
#   'skatteverket.se',
#   'myfreecams.com',
#   'ozon.ru',
#   'etsy.com',
#   'csfd.cz',
#   'sunporno.com',
#   'bseindia.com',
#   'ilsole24ore.com',
#   'slate.com',
#   'gulfnews.com',
#   'xuite.net',
#   'hindustantimes.com',
#   'ameba.jp',
#   'cadenaser.com',
#   'bankofamerica.com',
#   'hyundai.com',
#   'urbandictionary.com',
#   'truckpaper.com',
#   'kirklands.com',
#   'trojmiasto.pl',
#   'tvgids.nl',
#   'freesexyindians.com',
#   'milenio.com',
#   'nclottery.com',
#   'rossmann.de',
#   'yelp.com',
#   'dxlive.com',
#   '3movs.com',
#   'build.com',
#   'brigitte.de',
#   'drudgereport.com',
#   'michigan.gov',
#   'aastocks.com',
#   'ebay.fr',
#   'icicibank.com',
#   'tabelog.com',
#   'rbcroyalbank.com',
#   'ica.se',
#   'torn.com',
#   'dlsite.com',
#   'sciaga.pl',
#   'astrology.com',
#   'sbicard.com',
#   'dickssportinggoods.com',
#   'athome.com',
#   'rambler.ru',
#   'brainpop.com',
#   'zeit.de',
#   'opticsplanet.com',
#   'mass.gov',
#   'alibaba.com',
#   'britishairways.com',
#   'poste.it',
#   'krone.at',
#   'dominos.com',
#   'arkadium.com',
#   'nuskin.com',
#   'whattoexpect.com',
#   'nike.com',
#   'utorrent.com',
#   'sfgate.com',
#   'viz.com',
#   'slobodnadalmacija.hr',
#   'rvtrader.com',
#   'naver.com',
#   'pnp.de',
#   'wetteronline.de',
#   'people.com',
#   'ad.nl',
#   'jutarnji.hr',
#   'scoresandodds.com',
#   'kooora.com',
#   'daserste.de',
#   'moneysavingexpert.com',
#   '20minutos.es',
#   'furaffinity.net',
#   'bt.dk',
#   'bloomberg.com',
#   'sportchek.ca',
#   'pricesmart.com',
#   'grammy.com',
#   'bancsabadell.com',
#   'o2online.de',
#   'soccerstand.com',
#   'zoominfo.com',
#   'tvn.cl',
#   'habitaclia.com',
#   'jpay.com',
#   'famousbirthdays.com',
#   'gab.com',
#   'carfax.com',
#   'hilton.com',
#   'jumbo.com',
#   'rona.ca',
#   'cellufun.com',
#   'antenna.gr',
#   'hotukdeals.com',
#   'tvmovie.de',
#   'si.com',
#   'xxx.com',
#   'marketwatch.com',
#   'tipcars.com',
#   'rackroomshoes.com',
#   'telecinco.es',
#   'tmz.com',
#   'tv2.no',
#   'uefa.com',
#   'indianexpress.com',
#   'rotter.net',
#   'delfi.lv',
#   'google.es',
#   'lego.com',
#   'tesco.com',
#   'ixbt.com',
#   'jstor.org',
#   'sgcarmart.com',
#   'di.se',
#   'coldwellbankerhomes.com',
#   'sauto.cz',
#   'hm.com',
#   'budsgunshop.com',
#   'applebees.com',
#   'boardgamegeek.com',
#   'komputerswiat.pl',
#   'erotikforum.at',
#   'tim.it',
#   'yoox.com',
#   'wordpress.com',
#   'skype.com',
#   'google.lt',
#   'chess.com',
#   'crateandbarrel.com',
#   'kitco.com',
#   'banamex.com',
#   'thesaurus.com',
#   'who.int',
#   'lepoint.fr',
#   'predskazanie.ru',
#   'thepiratebay.org',
#   'channelnewsasia.com',
#   'ebay.com',
#   'medicinenet.com',
#   'dictionary.com',
#   'specialized.com',
#   'toutelatele.com',
#   'ultimahora.es',
#   'gumtree.com',
#   'att.net',
#   'blogto.com',
#   'literotica.com',
#   'viabcp.com',
#   'michaels.com',
#   'samsclub.com',
#   'easyjet.com',
#   'forever21.com',
#   'nvidia.com',
#   'lci.fr',
#   'yallakora.com',
#   'euroresidentes.com',
#   'flightaware.com',
#   'cycletrader.com',
#   'xnxx.net',
#   'equibase.com',
#   'auto.ru',
#   'dell.com',
#   'royallepage.ca',
#   'sahibinden.com',
#   'sierra.com',
#   'gratka.pl',
#   'b92.net',
#   'idnes.cz',
#   'bricklink.com',
#   'tanea.gr',
#   'lotteryusa.com',
#   'casa.it',
#   'visir.is',
#   'xoom.com',
#   'morningstar.com',
#   'univision.com',
#   'petco.com',
#   'belk.com',
#   ...],
#  'topics': ["'103','289'",
#   "'219'",
#   "'219'",
#   "'243'",
#   "'149'",
#   "'172'",
#   "'179','289'",
#   "'23','126','183','210','220'",
#   "'219'",
#   "'219','223'",
#   "'129','215','218'",
#   "'243'",
#   "'289'",
#   "'207','209','211'",
#   "'172'",
#   "'238','239'",
#   "'243'",
#   "'243'",
#   "'289'",
#   "'92','94'",
#   "'1','215','219','243'",
#   "'289'",
#   "'289'",
#   "'265','289'",
#   "'272'",
#   "'1'",
#   "'219','223'",
#   "'289'",
#   "'289'",
#   "'114','211','278'",
#   "'219'",
#   "'149'",
#   "'243'",
#   "'219'",
#   "'243'",
#   "'1','45','243'",
#   "'243'",
#   "'243'",
#   "'126','289'",
#   "'1'",
#   "'1','215','243'",
#   "'289'",
#   "'289'",
#   "'23','243'",
#   "'243'",
#   "'243','299'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'289'",
#   "'172'",
#   "'243'",
#   "'243'",
#   "'1','243'",
#   "'243'",
#   "'243'",
#   "'23','243','252'",
#   "'239'",
#   "'129','215','218'",
#   "'183'",
#   "'219','223'",
#   "'103','149'",
#   "'243'",
#   "'239'",
#   "'149'",
#   "'219'",
#   "'289'",
#   "'272'",
#   "'289','292'",
#   "'57'",
#   "'219'",
#   "'103'",
#   "'243','325'",
#   "'243'",
#   "'219','223'",
#   "'1','48'",
#   "'243','244','247','249'",
#   "'243'",
#   "'149'",
#   "'289'",
#   "'219'",
#   "'103','239'",
#   "'289'",
#   "'289'",
#   "'219'",
#   "'219'",
#   "'219'",
#   "'215','218'",
#   "'103','169','243'",
#   "'243'",
#   "''",
#   "'243'",
#   "'103','289'",
#   "'243'",
#   "''",
#   "'236'",
#   "'289'",
#   "'289'",
#   "'219'",
#   "'103'",
#   "'103','164','243'",
#   "'243'",
#   "'239'",
#   "'332','341'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'219'",
#   "'243'",
#   "'217','218'",
#   "'334'",
#   "'243'",
#   "'129','210','289'",
#   "'238'",
#   "'243','299'",
#   "'289'",
#   "'215'",
#   "'243'",
#   "'243'",
#   "'289'",
#   "'289'",
#   "'149'",
#   "'243'",
#   "'272'",
#   "'219','223'",
#   "'332'",
#   "'114','211'",
#   "'236'",
#   "'207','289'",
#   "'243'",
#   "'248','254','279','284'",
#   "'126','243','279'",
#   "''",
#   "'292','349'",
#   "'215','217','218'",
#   "'1'",
#   "'248','279'",
#   "'289'",
#   "'243'",
#   "'243'",
#   "'179'",
#   "'1','215','243'",
#   "'289'",
#   "'289'",
#   "''",
#   "'83'",
#   "'209','211','289'",
#   "'243','245'",
#   "'100','289'",
#   "'243'",
#   "'289'",
#   "'1'",
#   "'103'",
#   "'238'",
#   "'219','223'",
#   "'243'",
#   "'243'",
#   "'272'",
#   "'289'",
#   "'243'",
#   "'289'",
#   "'289'",
#   "'289'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'243'",
#   "'289'",
#   "'103','164','243'",
#   "'243','299','315'",
#   "'1','215','243'",
#   "'238'",
#   "'1'",
#   "'289'",
#   "'1'",
#   "'289'",
#   "'334'",
#   "'83'",
#   "'126','289'",
#   "'57','70'",
#   "'219'",
#   "'1','243'",
#   "'219'",
#   "'238'",
#   "'1'",
#   "'149'",
#   "'289'",
#   "'1','23'",
#   "'219'",
#   "'292','341'",
#   "'243'",
#   "'219'",
#   "'207','289'",
#   "'219'",
#   "'254','263','268'",
#   "'129','210','289'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'219'",
#   "'243'",
#   "'243'",
#   "'129','183'",
#   "'219'",
#   "'229'",
#   "'219'",
#   "'256'",
#   "'243','299'",
#   "'289'",
#   "'238'",
#   "'243'",
#   "'83'",
#   "'243','299','325'",
#   "'129','207','289'",
#   "'272'",
#   "'289'",
#   "'272'",
#   "'243'",
#   "'1','215'",
#   "'217','218','220'",
#   "'149'",
#   "'289'",
#   "'157','272'",
#   "'289'",
#   "'1'",
#   "'243','299'",
#   "'306'",
#   "'272'",
#   "'183'",
#   "'248'",
#   "''",
#   "'243'",
#   "'196','254','289'",
#   "'254'",
#   "''",
#   "'243','299','322'",
#   "'243'",
#   "'219','223'",
#   "'215'",
#   "'219','275','289','332'",
#   "'215','217','218'",
#   "'57','83'",
#   "'1','32','43','243'",
#   "'12'",
#   "'289'",
#   "'126'",
#   "'83','292'",
#   "'236'",
#   "'253'",
#   "'298'",
#   "'114','207','278'",
#   "'243','245'",
#   "'183'",
#   "'243'",
#   "'173'",
#   "'100'",
#   "'207'",
#   "'289'",
#   "'188','194'",
#   "'239'",
#   "'243','299'",
#   "''",
#   "'172','175'",
#   "'334','340'",
#   "'289'",
#   "'243','245'",
#   "'183','190'",
#   "'1','243'",
#   "'289'",
#   "'243'",
#   "'103','289'",
#   "'243'",
#   "'251'",
#   "'289'",
#   "'103'",
#   "'243','245'",
#   "'172','207','210'",
#   "'243'",
#   "'149','289'",
#   "'149'",
#   "'289'",
#   "'272'",
#   "'1','243'",
#   "'219','275'",
#   "''",
#   "'11','12'",
#   "'88'",
#   "'1','243'",
#   "'3'",
#   "'272'",
#   "'96','100','254'",
#   "'86','289'",
#   "'81','129'",
#   "'129','210'",
#   "''",
#   "'1','215'",
#   "'248','279'",
#   "'81'",
#   "'275'",
#   "'96','289'",
#   "'241','275'",
#   "'275','344','349'",
#   "'243'",
#   "'334'",
#   "'1','215','243'",
#   "'23'",
#   "'173'",
#   "'1','215','239'",
#   "'100','103','243'",
#   "'53','114','252'",
#   "'248'",
#   "'243'",
#   "'164'",
#   "'142'",
#   "'243','299'",
#   "'252'",
#   "'1','243'",
#   "'157','158'",
#   "'289'",
#   "'272','274'",
#   "'253','255','275'",
#   "'123'",
#   "'272'",
#   "'243'",
#   "'243','299'",
#   "'1','180','183','186','254'",
#   "'172'",
#   "'140'",
#   "'196','289'",
#   "'42','103','289'",
#   "'23'",
#   "'243'",
#   "'298'",
#   "'289'",
#   "'81'",
#   "'100','126','129','243','279','292'",
#   "'1','215','243'",
#   "'219','223'",
#   "''",
#   "'238'",
#   "'243','299','325'",
#   "'39','243'",
#   "'42','103','289'",
#   "'243'",
#   "''",
#   "'1','183','186'",
#   "'219'",
#   "'248'",
#   "'289'",
#   "'340','344'",
#   "'12'",
#   "'1','183'",
#   "'243'",
#   "'243'",
#   "'1','243'",
#   "'243'",
#   "'103','239'",
#   "'45'",
#   "'43','243'",
#   "'103','164','243'",
#   "'126','243','279'",
#   "'100','243'",
#   "'172','175'",
#   "'103','243'",
#   "'1','243'",
#   "'215','250'",
#   "'275'",
#   "'239'",
#   "'81'",
#   "'292'",
#   "'1','23'",
#   "'149'",
#   "''",
#   "'252'",
#   "'1','215','243'",
#   "'149'",
#   "'103','149','243'",
#   "''",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'243','299'",
#   "'114','211','289'",
#   "'289'",
#   "'100','263'",
#   "'219','223'",
#   "'1','215','243'",
#   "'1','215'",
#   "'332'",
#   "'81'",
#   "'243'",
#   "'1'",
#   "'227','230'",
#   "'243'",
#   "'23'",
#   "'239'",
#   "'83'",
#   "'149','152'",
#   "'83'",
#   "'103','164','243'",
#   "'289'",
#   "'1','275'",
#   "'272'",
#   "''",
#   "'1','243'",
#   "'289'",
#   "'1','215','243'",
#   "'129','210'",
#   "'1','12','243'",
#   "'243'",
#   "'245'",
#   "'334'",
#   "'200','278'",
#   "'243'",
#   "'243','245'",
#   "'243','299'",
#   "'243'",
#   "'43','250'",
#   "''",
#   "'188','250'",
#   "'172','173'",
#   "'289','290'",
#   "'272'",
#   "'103'",
#   "'243'",
#   "'253'",
#   "'196','289'",
#   "'299'",
#   "'255','275'",
#   "''",
#   "''",
#   "'103'",
#   "'43','243'",
#   "'126','220','243','279'",
#   "'289'",
#   "'211'",
#   "'103'",
#   "'289'",
#   "'243'",
#   "'243'",
#   "'88'",
#   "'129','289'",
#   "'1','243'",
#   "'243'",
#   "'289'",
#   "'1','12','243'",
#   "'289'",
#   "'289'",
#   "'149','153','158'",
#   "'1','215'",
#   "'1','183','186'",
#   "'1','23'",
#   "'103','243'",
#   "'243'",
#   "'57','289','299','310'",
#   "'275'",
#   "'243'",
#   "'272'",
#   "'83','289'",
#   "'289'",
#   "''",
#   "'289','299','300','314'",
#   "'42','103','289'",
#   "'207'",
#   "'272'",
#   "'243','299','325'",
#   "'183'",
#   "'250','252'",
#   "'43'",
#   "'243','299'",
#   "'43','250','253'",
#   "'243'",
#   "'250','254'",
#   "'243','244','245','247','249'",
#   "'172'",
#   "'129'",
#   "'243'",
#   "'196','207','289'",
#   "'275'",
#   "'201','289','299'",
#   "'243'",
#   "'325'",
#   "'243','245'",
#   "''",
#   "'298'",
#   "'289'",
#   "'1','243','245'",
#   "'196'",
#   "'248'",
#   "'289','299'",
#   "'119','172','207'",
#   "'203','289'",
#   "'256'",
#   "'183'",
#   "'179','289'",
#   "'182'",
#   "'1','45'",
#   "'243'",
#   "'332'",
#   "'219'",
#   "'100','275'",
#   "'172'",
#   "'103','149','164','243'",
#   "''",
#   "'279'",
#   "'253'",
#   "'299'",
#   "'172','275'",
#   "'289'",
#   "'196','289'",
#   "'23'",
#   "'149'",
#   "'219'",
#   "'83'",
#   "'227'",
#   "'173','209','278'",
#   "'215'",
#   "'103'",
#   "'243','299'",
#   "'243'",
#   "'243','254'",
#   "'334'",
#   "''",
#   "'243'",
#   "'215'",
#   "'1','215'",
#   "'1','215','243'",
#   "'243'",
#   "'1','183','186'",
#   "'340'",
#   "'219'",
#   "'103','164','243'",
#   "''",
#   "'277'",
#   "'238'",
#   "'239'",
#   "'289'",
#   "'1','215','216'",
#   "'100','254'",
#   "'243'",
#   "'243'",
#   "'202','203','289'",
#   "'88','289'",
#   "'243'",
#   "'243','299','304'",
#   "'219'",
#   "'1','215','243'",
#   "'248'",
#   "'173'",
#   "'103'",
#   "'308'",
#   "'243'",
#   "'243'",
#   "'275'",
#   "'83'",
#   "''",
#   "'243'",
#   "'103','243'",
#   "'201','289'",
#   "'264'",
#   "'332','334'",
#   "'103','166','243'",
#   "''",
#   "''",
#   "'239'",
#   "'129','215','218'",
#   "'227','279'",
#   "'332','344'",
#   "'1','182','183'",
#   "''",
#   "'100','289'",
#   "'243','245','299'",
#   "'83'",
#   "'219'",
#   "'243'",
#   "'149'",
#   "'289'",
#   "'172','173'",
#   "'88','207'",
#   "'196','289'",
#   "'1','243'",
#   "'149','152'",
#   "'96','289'",
#   "'196'",
#   "'1','45'",
#   "'57','289'",
#   "'289'",
#   "'346'",
#   "'289'",
#   "'151'",
#   "'83'",
#   "'289'",
#   "'1','243'",
#   "'240','243','256','275'",
#   "'43'",
#   "''",
#   "'1','215','243'",
#   "'1','243','299'",
#   "'243'",
#   "'149','152'",
#   "'151'",
#   "'243','299','303'",
#   "'183'",
#   "'219','223'",
#   "'129','279'",
#   "'289'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'289'",
#   "'153','164'",
#   "'243'",
#   "'243','299','325'",
#   "'243','299'",
#   "'289'",
#   "'1','45'",
#   "'289'",
#   "''",
#   "'276'",
#   "''",
#   "'142'",
#   "'243'",
#   "'1'",
#   "'207'",
#   "'289'",
#   "'289'",
#   "'83','158','292'",
#   "'243','299','325'",
#   "'275'",
#   "'289'",
#   "'1','215'",
#   "'243','245'",
#   "'275'",
#   "'243'",
#   "'219'",
#   "'239','247'",
#   "'243'",
#   "'217','218','220'",
#   "'248'",
#   "'243'",
#   "'207'",
#   "'289'",
#   "'1','183','227','276'",
#   "'1','43'",
#   "'183'",
#   "'211'",
#   "'289'",
#   "'243'",
#   "'252'",
#   "'218'",
#   "'243','245'",
#   "'272'",
#   "'100','262'",
#   "''",
#   "'126'",
#   "'103','126','149'",
#   "'299'",
#   "'289','290'",
#   "'256'",
#   "'245'",
#   "'126','243','279','289','292'",
#   "''",
#   "'11','12'",
#   "'188','194'",
#   "'114','211','289'",
#   "'103'",
#   "''",
#   "'152'",
#   "'272'",
#   "'251'",
#   "'289'",
#   "''",
#   "'243'",
#   "'1','243'",
#   "'1','243'",
#   "'289'",
#   "'245','248','275'",
#   "'272','289'",
#   "'1','180','183','186'",
#   "'250','278'",
#   "'243'",
#   "'180','215','254'",
#   "'289'",
#   "'289'",
#   "'289'",
#   "'272'",
#   "'1','42','243'",
#   "'219','223'",
#   "'243'",
#   "'243','299','325'",
#   "'103','279'",
#   "'1','215'",
#   "'103'",
#   "'219'",
#   "'289'",
#   "'12','183','278'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'114','211','289'",
#   "'23','43','243'",
#   "'243'",
#   "'219'",
#   "'243'",
#   "'30'",
#   "'1','243'",
#   "'103','196','209','289'",
#   "'57','289'",
#   "'250'",
#   "'215','217','218'",
#   "'243','245','249','299'",
#   "'275'",
#   "'289'",
#   "''",
#   "'243','299'",
#   "'112'",
#   "'172','179'",
#   "'139','227','276','279'",
#   "'62','83','108','292'",
#   "'243'",
#   "'137','215'",
#   "'340'",
#   "'183'",
#   "''",
#   "'129','215','218'",
#   "'289'",
#   "'299'",
#   "'1','215'",
#   "'243','245'",
#   "'23','32','36'",
#   "'1','243'",
#   "'96','100','254'",
#   "'245'",
#   "'43'",
#   "'183'",
#   "'256'",
#   "'251'",
#   "'276'",
#   "'289'",
#   "''",
#   "'289'",
#   "'243'",
#   "'88'",
#   "'240','243','245','247','249'",
#   "'289'",
#   "''",
#   "'258','276'",
#   "''",
#   "'243','299','325'",
#   "'243'",
#   "'243'",
#   "''",
#   "'207','289'",
#   "'251'",
#   "'334'",
#   "''",
#   "'289'",
#   "'258'",
#   "'243','244','245','247','249'",
#   "'275'",
#   "'129','289'",
#   "'1','23','45','243'",
#   "''",
#   "'243'",
#   "'81'",
#   "'126','129'",
#   "'103','243'",
#   "'1'",
#   "'129','183'",
#   "'243','245'",
#   "'57','100','292'",
#   "'96','289'",
#   "'243'",
#   "'243'",
#   "'1','215'",
#   "'183','289'",
#   "'332'",
#   "'289'",
#   "'1','180','183'",
#   "'1'",
#   "'183'",
#   "'272','289'",
#   "'151'",
#   "'275'",
#   "'39','243'",
#   "'289'",
#   "'83'",
#   "'1','183'",
#   "'57'",
#   "'219'",
#   "'83'",
#   "'126'",
#   "'1','45'",
#   "'253'",
#   "'250','289'",
#   "'289'",
#   "'173'",
#   "'243'",
#   "'172'",
#   "'292'",
#   "'56','129'",
#   "'100','173','209'",
#   "'43','243'",
#   "'289'",
#   "'175'",
#   "''",
#   "'243'",
#   "''",
#   "''",
#   "'279'",
#   "'243'",
#   "'289'",
#   "'289','296','298'",
#   "'83'",
#   "'272'",
#   "'215','217'",
#   "'272','289'",
#   "'243','299','325'",
#   "'150'",
#   "''",
#   "'289'",
#   "'196','289'",
#   "'12'",
#   "''",
#   "'103','164','243'",
#   "'103','243'",
#   "'243'",
#   "'1','243'",
#   "'250','349'",
#   "'243'",
#   "'250'",
#   "'23','243'",
#   "'149'",
#   "'57'",
#   "'1','7','275'",
#   "'58','83','289'",
#   "'207','209'",
#   "'245'",
#   "'1','45'",
#   "''",
#   "'243','245'",
#   "''",
#   "'88','99','260','264'",
#   "'172','275'",
#   "''",
#   "''",
#   "'114','207'",
#   "'100','254'",
#   "'243'",
#   "'239'",
#   "'103','243'",
#   "'289'",
#   "'149'",
#   "'172'",
#   "'149'",
#   "'173','179'",
#   "'1','183','194'",
#   "'183'",
#   "'234','276'",
#   "''",
#   "'152'",
#   "'289','299'",
#   "'207','209'",
#   "'1','215','243'",
#   "'180','227','276'",
#   "'243'",
#   "'56','129','201'",
#   "'239'",
#   "'103','126','289'",
#   "'334'",
#   "'103','149'",
#   "'243'",
#   "'172'",
#   "'1','183','186'",
#   "'88'",
#   "''",
#   "'289'",
#   "'215','250'",
#   "'243'",
#   "'1'",
#   "'243'",
#   "'57','83'",
#   "'1','215','219','243'",
#   "'245'",
#   "'248'",
#   "'1','100','243'",
#   "'1','243'",
#   "'243'",
#   "'243','299'",
#   "'243','299'",
#   "'1','43'",
#   "'149','278'",
#   "'243'",
#   "'1','215','250'",
#   "'1','243'",
#   "'103','243'",
#   "'289','299'",
#   "'289'",
#   "'1','6','243'",
#   "'149'",
#   "'129','215','217','218'",
#   "'243','299','325'",
#   "'103','126','140'",
#   "'1','243'",
#   "'272'",
#   "'149'",
#   "'1','198','243'",
#   "'250','253'",
#   "'57','83','84','241','292'",
#   "'340'",
#   "'172','179'",
#   "'209','211'",
#   "'1','183','215','250'",
#   "'1'",
#   "'196','289','293'",
#   "'1','45'",
#   "'243','299'",
#   "''",
#   "'103','164','243'",
#   "'83'",
#   "'289'",
#   "'1','243'",
#   "'1','243'",
#   "'1','243'",
#   "'243','299','325'",
#   "'1','243'",
#   "'1','215','243'",
#   "'243'",
#   "'219'",
#   "'289'",
#   "'179','289'",
#   "'126','243','279'",
#   "'276'",
#   "'83'",
#   "'103','164','243'",
#   "'272'",
#   "'57','81'",
#   "'289'",
#   "''",
#   "'172'",
#   "'180'",
#   "'126'",
#   "''",
#   "'217','218'",
#   "'289'",
#   "'140','224','250'",
#   "'215'",
#   "'219'",
#   "'1','180','183'",
#   "'207'",
#   "'103','165','243'",
#   "'149'",
#   "'275'",
#   "'239'",
#   "'243'",
#   "''",
#   "'215','250'",
#   "'244','245','247','249'",
#   "'289'",
#   "'243'",
#   "'275'",
#   "'57','289','299','310'",
#   "'1','45'",
#   "'243','245'",
#   "'278','289'",
#   "'1','215'",
#   "'243','250'",
#   "''",
#   "'149'",
#   "'196'",
#   "'289'",
#   "'334'",
#   "'289'",
#   "'126'",
#   "'1','243'",
#   "'243','299','325'",
#   "'1','215'",
#   "'109'",
#   "'70','84','289'",
#   "''",
#   "''",
#   "'83','289'",
#   "'126','275','292'",
#   "'272'",
#   "'289'",
#   "'289'",
#   "'289'",
#   "'243'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "''",
#   "'272'",
#   "'243'",
#   "'149'",
#   "'103','164','243'",
#   "'1','215','243'",
#   "'264','265'",
#   "'96','289'",
#   ...]}

# %%
df = pandas.DataFrame(data=d)

# %%
display(df)
# Out:
#                      domain                  match       topics
# 0        officedepot.com.mx     officedepot.com.mx  '103','289'
# 1             google.com.br          google.com.br        '219'
# 2              google.co.nz           google.co.nz        '219'
# 3         independent.co.uk      independent.co.uk        '243'
# 4     unionbankonline.co.in  unionbankonline.co.in        '149'
# ...                     ...                    ...          ...
# 2814        metro.sp.gov.br                 gov.br  '243','299'
# 2815       seplan.go.gov.br                 gov.br  '243','299'
# 2816       polmil.sp.gov.br                 gov.br  '243','299'
# 2817   hyde.tameside.sch.uk                   t.me  '243','299'
# 2818      jucemat.mt.gov.br                 gov.br  '243','299'
#
# [2819 rows x 3 columns]

# %%
# Checks for domains without a topic.
display(df[df['topics'] == "''"])
# Out:
#                        domain                    match topics
# 90              sonhos.com.br            sonhos.com.br     ''
# 94    consultaremedios.com.br  consultaremedios.com.br     ''
# 133      casadoscontos.com.br     casadoscontos.com.br     ''
# 145     nationallottery.co.za    nationallottery.co.za     ''
# 231            thumbzilla.com           thumbzilla.com     ''
# ...                       ...                      ...    ...
# 1458               bet365.com               bet365.com     ''
# 1459           clips4sale.com           clips4sale.com     ''
# 1477             islamweb.net             islamweb.net     ''
# 1522                porzo.com                porzo.com     ''
# 1529  churchofjesuschrist.org  churchofjesuschrist.org     ''
#
# [101 rows x 3 columns]

# %%
# Drops domains without a topic.
df = df.drop(df[df['topics'] == "''"].index.to_list())

# %%
df = df.reset_index(drop=True)

# %%
display(df)
# Out:
#                      domain                  match       topics
# 0        officedepot.com.mx     officedepot.com.mx  '103','289'
# 1             google.com.br          google.com.br        '219'
# 2              google.co.nz           google.co.nz        '219'
# 3         independent.co.uk      independent.co.uk        '243'
# 4     unionbankonline.co.in  unionbankonline.co.in        '149'
# ...                     ...                    ...          ...
# 2713        metro.sp.gov.br                 gov.br  '243','299'
# 2714       seplan.go.gov.br                 gov.br  '243','299'
# 2715       polmil.sp.gov.br                 gov.br  '243','299'
# 2716   hyde.tameside.sch.uk                   t.me  '243','299'
# 2717      jucemat.mt.gov.br                 gov.br  '243','299'
#
# [2718 rows x 3 columns]

# %%
df.to_csv('AOL-treated-Google-Topics-Classification-v1-domain-match.csv')
