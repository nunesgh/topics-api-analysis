# %% [markdown]
# # AOL Experimental Dataset (Citizen Lab)

# %%
import pandas, random
from collections import Counter

# %% [markdown]
# ## AOL reduced dataset with Citizen Lab Classification

# %%
# %%time
# Loads AOL-reduced-Citizen-Lab-Classification dataset into data DataFrame.
aol_reduced_citizen_lab = pandas.read_csv('AOL-reduced-Citizen-Lab-Classification.csv', low_memory=False, on_bad_lines='warn', index_col=0)
# Out:
# CPU times: user 3.94 s, sys: 486 ms, total: 4.43 s
# Wall time: 4.4 s

# %%
# %%time
aol_reduced_citizen_lab['QueryTime'] = pandas.to_datetime(aol_reduced_citizen_lab['QueryTime'])
# Out:
# CPU times: user 1.01 s, sys: 6.52 ms, total: 1.01 s
# Wall time: 996 ms

# %%
display(aol_reduced_citizen_lab)
# Out:
#          RandID           QueryTime          Domain
# 0             1 2006-03-01 11:54:19  kidshealth.org  \
# 1             1 2006-03-01 11:54:19  kidshealth.org
# 2             1 2006-03-01 11:54:19  kidshealth.org
# 3             1 2006-03-01 12:10:38     harvard.edu
# 4             1 2006-03-08 21:16:04     harvard.edu
# ...         ...                 ...             ...
# 3135265  521689 2006-05-05 01:09:28         nih.gov
# 3135266  521689 2006-05-05 02:00:33     typepad.com
# 3135267  521691 2006-03-04 11:36:38          go.com
# 3135268  521691 2006-03-15 19:24:17      google.com
# 3135269  521691 2006-04-01 18:45:41      google.com
#
#                                                     topics
# 0                                                   'PUBH'
# 1                                                   'PUBH'
# 2                                                   'PUBH'
# 3                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# 4                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# ...                                                    ...
# 3135265                                             'GOVT'
# 3135266                                     'HOST', 'NEWS'
# 3135267                                             'NEWS'
# 3135268  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
# 3135269  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
#
# [3135270 rows x 4 columns]

# %% [markdown]
# ### Drop singletons

# %%
# %%time
# Lists rows for RandID individuals with only one domain in their browsing history, to be dropped.
temp = aol_reduced_citizen_lab[['RandID','Domain']].groupby(['RandID']).nunique()
singletons = temp[temp['Domain'] == 1].index.to_list()
print(len(singletons))
# Out:
# 130689
# CPU times: user 778 ms, sys: 81.3 ms, total: 860 ms
# Wall time: 858 ms

# %%
aol_reduced_citizen_lab = aol_reduced_citizen_lab[~aol_reduced_citizen_lab.RandID.isin(singletons)]

# %%
aol_reduced_citizen_lab = aol_reduced_citizen_lab.reset_index(drop=True)

# %%
display(aol_reduced_citizen_lab)
# Out:
#          RandID           QueryTime          Domain
# 0             1 2006-03-01 11:54:19  kidshealth.org  \
# 1             1 2006-03-01 11:54:19  kidshealth.org
# 2             1 2006-03-01 11:54:19  kidshealth.org
# 3             1 2006-03-01 12:10:38     harvard.edu
# 4             1 2006-03-08 21:16:04     harvard.edu
# ...         ...                 ...             ...
# 2871078  521689 2006-05-05 01:09:28         nih.gov
# 2871079  521689 2006-05-05 02:00:33     typepad.com
# 2871080  521691 2006-03-04 11:36:38          go.com
# 2871081  521691 2006-03-15 19:24:17      google.com
# 2871082  521691 2006-04-01 18:45:41      google.com
#
#                                                     topics
# 0                                                   'PUBH'
# 1                                                   'PUBH'
# 2                                                   'PUBH'
# 3                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# 4                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# ...                                                    ...
# 2871078                                             'GOVT'
# 2871079                                     'HOST', 'NEWS'
# 2871080                                             'NEWS'
# 2871081  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
# 2871082  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
#
# [2871083 rows x 4 columns]

# %% [markdown]
# ### Drop outlier

# %%
# %%time
# One individual has too many domains in their browsing history and is most probably a bot, to be dropped.
display(aol_reduced_citizen_lab['RandID'].value_counts())
# Out:
# RandID
# 463921    23505
# 311717     2516
# 352479     1379
# 118679     1167
# 342660     1011
#           ...
# 317417        2
# 120680        2
# 448289        2
# 317341        2
# 193287        2
# Name: count, Length: 211314, dtype: int64
# CPU times: user 52.6 ms, sys: 8.21 ms, total: 60.8 ms
# Wall time: 59.8 ms

# %%
aol_reduced_citizen_lab = aol_reduced_citizen_lab.drop(aol_reduced_citizen_lab[aol_reduced_citizen_lab['RandID'] == 463921].index.to_list())

# %%
aol_reduced_citizen_lab = aol_reduced_citizen_lab.reset_index(drop=True)

# %%
display(aol_reduced_citizen_lab)
# Out:
#          RandID           QueryTime          Domain
# 0             1 2006-03-01 11:54:19  kidshealth.org  \
# 1             1 2006-03-01 11:54:19  kidshealth.org
# 2             1 2006-03-01 11:54:19  kidshealth.org
# 3             1 2006-03-01 12:10:38     harvard.edu
# 4             1 2006-03-08 21:16:04     harvard.edu
# ...         ...                 ...             ...
# 2847573  521689 2006-05-05 01:09:28         nih.gov
# 2847574  521689 2006-05-05 02:00:33     typepad.com
# 2847575  521691 2006-03-04 11:36:38          go.com
# 2847576  521691 2006-03-15 19:24:17      google.com
# 2847577  521691 2006-04-01 18:45:41      google.com
#
#                                                     topics
# 0                                                   'PUBH'
# 1                                                   'PUBH'
# 2                                                   'PUBH'
# 3                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# 4                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# ...                                                    ...
# 2847573                                             'GOVT'
# 2847574                                     'HOST', 'NEWS'
# 2847575                                             'NEWS'
# 2847576  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
# 2847577  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
#
# [2847578 rows x 4 columns]

# %% [markdown]
# ### Statistics

# %%
# %%time
aol_reduced_citizen_lab.info(verbose=True, memory_usage='deep', show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2847578 entries, 0 to 2847577
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   RandID     2847578 non-null  int64
#  1   QueryTime  2847578 non-null  datetime64[ns]
#  2   Domain     2847578 non-null  object
#  3   topics     2847578 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 471.9 MB
# CPU times: user 1.13 s, sys: 5.95 ms, total: 1.14 s
# Wall time: 1.13 s

# %% [markdown]
# Number of unique values per attribute.

# %%
display(aol_reduced_citizen_lab.nunique(dropna=False))
# Out:
# RandID        211313
# QueryTime    1922950
# Domain          4872
# topics           217
# dtype: int64

# %% [markdown]
# `RandID` statistics.

# %%
display(aol_reduced_citizen_lab['RandID'].value_counts().describe([.25,.50,.75,.80,.85,.90,.95,.96,.97,.98,.99]))
# Out:
# count    211313.000000
# mean         13.475640
# std          27.133604
# min           2.000000
# 25%           3.000000
# 50%           6.000000
# 75%          13.000000
# 80%          17.000000
# 85%          21.000000
# 90%          29.000000
# 95%          47.000000
# 96%          53.000000
# 97%          64.000000
# 98%          80.000000
# 99%         116.000000
# max        2516.000000
# Name: count, dtype: float64

# %% [markdown]
# %%
display(aol_reduced_citizen_lab['QueryTime'].max())
# Out:
# Timestamp('2006-05-31 23:59:58')

# %% [markdown]
# Number of unique `Domain` values.

# %%
# %%time
aol_reduced_citizen_lab_domains_counts = dict(Counter(aol_reduced_citizen_lab['Domain'].to_list()))
display(len(aol_reduced_citizen_lab_domains_counts))
# Out:
# 4872
# CPU times: user 184 ms, sys: 3.22 ms, total: 188 ms
# Wall time: 185 ms

# %% [markdown]
# Top `Domain` values by number of records.

# %%
top = 100
with pandas.option_context('display.max_rows', top, 'display.min_rows', top):
    display(pandas.Series(aol_reduced_citizen_lab_domains_counts).sort_values(ascending=False).head(top))
# Out:
# yahoo.com                 386719
# google.com                332319
# myspace.com               203992
# ebay.com                  149904
# wikipedia.org             120136
# amazon.com                101643
# imdb.com                   99581
# msn.com                    97027
# go.com                     76901
# craigslist.org             60366
# aol.com                    58108
# nih.gov                    46997
# bankofamerica.com          42151
# ask.com                    36234
# tripod.com                 30720
# azlyrics.com               22912
# microsoft.com              22484
# cnn.com                    21744
# walmart.com                20942
# angelfire.com              20459
# nytimes.com                19314
# pogo.com                   15549
# bbc.co.uk                  15043
# gamespot.com               13783
# wellsfargo.com             13557
# ign.com                    13354
# army.mil                   12658
# nbc.com                    12651
# reference.com              11470
# xanga.com                  11195
# sapo.pt                    10625
# ivillage.com               10597
# alibaba.com                10082
# flickr.com                  9952
# thefreedictionary.com       9675
# infoplease.com              9511
# whitepages.com              9250
# typepad.com                 9097
# medicinenet.com             8922
# apple.com                   8846
# mtv.com                     8422
# cdc.gov                     8396
# rottentomatoes.com          7941
# usatoday.com                7861
# runescape.com               7836
# barnesandnoble.com          7525
# washingtonpost.com          7492
# facebook.com                7106
# kidshealth.org              7085
# youtube.com                 6672
# utexas.edu                  6605
# harvard.edu                 6584
# navy.mil                    6364
# playboy.com                 6273
# state.gov                   6221
# chase.com                   6126
# blackplanet.com             6093
# columbia.edu                6082
# adultfriendfinder.com       5975
# foxnews.com                 5825
# usda.gov                    5771
# virginia.edu                5745
# nasa.gov                    5656
# worldsex.com                5641
# state.il.us                 5489
# stanford.edu                5474
# cnet.com                    5411
# 89.com                      5077
# ebaumsworld.com             5069
# nydailynews.com             4983
# drudgereport.com            4894
# photobucket.com             4883
# purdue.edu                  4829
# cbsnews.com                 4639
# umn.edu                     4592
# dogpile.com                 4571
# match.com                   4478
# hp.com                      4445
# af.mil                      4429
# nationalgeographic.com      4285
# univision.com               4253
# artistdirect.com            4197
# penisbot.com                4193
# loc.gov                     4138
# whitehouse.gov              4064
# upenn.edu                   4021
# cia.gov                     4004
# pinkworld.com               3820
# victoriassecret.com         3767
# forbes.com                  3674
# literotica.com              3545
# bestbuy.com                 3467
# last.fm                     3441
# lycos.com                   3407
# mp3.com                     3397
# livejournal.com             3394
# cars.com                    3355
# ikea.com                    3319
# youngerbabes.com            3249
# epa.gov                     3199
# dtype: int64

# %% [markdown]
# ### Define browsing histories and lists of topics

# %%
# %%time
aol_reduced_citizen_lab['BrowsingHistory'] = list(zip(aol_reduced_citizen_lab.Domain, aol_reduced_citizen_lab.QueryTime))
# Out:
# CPU times: user 8.42 s, sys: 309 ms, total: 8.73 s
# Wall time: 8.71 s

# %%
display(aol_reduced_citizen_lab)
# Out:
#          RandID           QueryTime          Domain
# 0             1 2006-03-01 11:54:19  kidshealth.org  \
# 1             1 2006-03-01 11:54:19  kidshealth.org
# 2             1 2006-03-01 11:54:19  kidshealth.org
# 3             1 2006-03-01 12:10:38     harvard.edu
# 4             1 2006-03-08 21:16:04     harvard.edu
# ...         ...                 ...             ...
# 2847573  521689 2006-05-05 01:09:28         nih.gov
# 2847574  521689 2006-05-05 02:00:33     typepad.com
# 2847575  521691 2006-03-04 11:36:38          go.com
# 2847576  521691 2006-03-15 19:24:17      google.com
# 2847577  521691 2006-04-01 18:45:41      google.com
#
#                                                     topics
# 0                                                   'PUBH'  \
# 1                                                   'PUBH'
# 2                                                   'PUBH'
# 3                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# 4                           'NEWS', 'CTRL', 'HUMR', 'PUBH'
# ...                                                    ...
# 2847573                                             'GOVT'
# 2847574                                     'HOST', 'NEWS'
# 2847575                                             'NEWS'
# 2847576  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
# 2847577  'COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRCH...
#
#                                BrowsingHistory
# 0        (kidshealth.org, 2006-03-01 11:54:19)
# 1        (kidshealth.org, 2006-03-01 11:54:19)
# 2        (kidshealth.org, 2006-03-01 11:54:19)
# 3           (harvard.edu, 2006-03-01 12:10:38)
# 4           (harvard.edu, 2006-03-08 21:16:04)
# ...                                        ...
# 2847573         (nih.gov, 2006-05-05 01:09:28)
# 2847574     (typepad.com, 2006-05-05 02:00:33)
# 2847575          (go.com, 2006-03-04 11:36:38)
# 2847576      (google.com, 2006-03-15 19:24:17)
# 2847577      (google.com, 2006-04-01 18:45:41)
#
# [2847578 rows x 5 columns]

# %%
# %%time
aol_reduced_citizen_lab['topics'] = aol_reduced_citizen_lab['topics'].map(lambda x : x.replace(" ", "").split(","))
# Out:
# CPU times: user 4.93 s, sys: 601 ms, total: 5.53 s
# Wall time: 5.51 s

# %%
display(aol_reduced_citizen_lab)
# Out:
#          RandID           QueryTime          Domain
# 0             1 2006-03-01 11:54:19  kidshealth.org  \
# 1             1 2006-03-01 11:54:19  kidshealth.org
# 2             1 2006-03-01 11:54:19  kidshealth.org
# 3             1 2006-03-01 12:10:38     harvard.edu
# 4             1 2006-03-08 21:16:04     harvard.edu
# ...         ...                 ...             ...
# 2847573  521689 2006-05-05 01:09:28         nih.gov
# 2847574  521689 2006-05-05 02:00:33     typepad.com
# 2847575  521691 2006-03-04 11:36:38          go.com
# 2847576  521691 2006-03-15 19:24:17      google.com
# 2847577  521691 2006-04-01 18:45:41      google.com
#
#                                                     topics
# 0                                                 ['PUBH']  \
# 1                                                 ['PUBH']
# 2                                                 ['PUBH']
# 3                         ['NEWS', 'CTRL', 'HUMR', 'PUBH']
# 4                         ['NEWS', 'CTRL', 'HUMR', 'PUBH']
# ...                                                    ...
# 2847573                                           ['GOVT']
# 2847574                                   ['HOST', 'NEWS']
# 2847575                                           ['NEWS']
# 2847576  ['COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRC...
# 2847577  ['COMT', 'MMED', 'CTRL', 'CULTR', 'NEWS', 'SRC...
#
#                                BrowsingHistory
# 0        (kidshealth.org, 2006-03-01 11:54:19)
# 1        (kidshealth.org, 2006-03-01 11:54:19)
# 2        (kidshealth.org, 2006-03-01 11:54:19)
# 3           (harvard.edu, 2006-03-01 12:10:38)
# 4           (harvard.edu, 2006-03-08 21:16:04)
# ...                                        ...
# 2847573         (nih.gov, 2006-05-05 01:09:28)
# 2847574     (typepad.com, 2006-05-05 02:00:33)
# 2847575          (go.com, 2006-03-04 11:36:38)
# 2847576      (google.com, 2006-03-15 19:24:17)
# 2847577      (google.com, 2006-04-01 18:45:41)
#
# [2847578 rows x 5 columns]

# %%
# %%time
aol_reduced_citizen_lab_generalization = aol_reduced_citizen_lab[['RandID','BrowsingHistory','topics']].groupby('RandID', sort=False)[['BrowsingHistory','topics']].agg(lambda x : list(x)).reset_index()
# Out:
# CPU times: user 15.6 s, sys: 183 ms, total: 15.8 s
# Wall time: 15.8 s

# %%
display(aol_reduced_citizen_lab_generalization)
# Out:
#         RandID                                    BrowsingHistory
# 0            1  [(kidshealth.org, 2006-03-01 11:54:19), (kidsh...  \
# 1            3  [(dogpile.com, 2006-03-12 16:09:37), (dogpile....
# 2            4  [(foxnews.com, 2006-03-12 20:33:21), (google.c...
# 3            5  [(foxnews.com, 2006-03-22 00:22:53), (senate.g...
# 4            6  [(technorati.com, 2006-03-03 20:48:41), (googl...
# ...        ...                                                ...
# 211308  521674  [(yahoo.com, 2006-03-06 10:04:29), (yahoo.com,...
# 211309  521686  [(flickr.com, 2006-03-12 21:19:11), (partypoke...
# 211310  521688  [(ytmnd.com, 2006-03-12 20:00:14), (aol.com, 2...
# 211311  521689  [(globalwitness.org, 2006-03-04 01:04:05), (ms...
# 211312  521691  [(go.com, 2006-03-04 11:36:38), (google.com, 2...
#
#                                                    topics
# 0       [['PUBH'], ['PUBH'], ['PUBH'], ['NEWS', 'CTRL'...
# 1       [['SRCH'], ['SRCH'], ['HOST', 'NEWS'], ['PUBH'...
# 2       [['NEWS', 'REL'], ['COMT', 'MMED', 'CTRL', 'CU...
# 3       [['NEWS', 'REL'], ['GOVT'], ['SRCH', 'POLR', '...
# 4       [['HOST'], ['COMT', 'MMED', 'CTRL', 'CULTR', '...
# ...                                                   ...
# 211308  [['COMT', 'CULTR', 'COMM', 'NEWS', 'POLR', 'SR...
# 211309  [['LGBT', 'MMED'], ['GMB'], ['HOST', 'GRP', 'C...
# 211310  [['REL'], ['SRCH', 'POLR', 'HUMR', 'REL'], ['C...
# 211311  [['ENV', 'POLR'], ['NEWS', 'SRCH', 'GRP', 'COM...
# 211312  [['NEWS'], ['COMT', 'MMED', 'CTRL', 'CULTR', '...
#
# [211313 rows x 3 columns]

# %%
# %%time
aol_reduced_citizen_lab_generalization['topics'] = aol_reduced_citizen_lab_generalization['topics'].map(lambda x : [topic for t in x for topic in t])
# Out:
# CPU times: user 1.27 s, sys: 8.07 ms, total: 1.28 s
# Wall time: 1.28 s

# %%
display(aol_reduced_citizen_lab_generalization)
# Out:
#         RandID                                    BrowsingHistory
# 0            1  [(kidshealth.org, 2006-03-01 11:54:19), (kidsh...  \
# 1            3  [(dogpile.com, 2006-03-12 16:09:37), (dogpile....
# 2            4  [(foxnews.com, 2006-03-12 20:33:21), (google.c...
# 3            5  [(foxnews.com, 2006-03-22 00:22:53), (senate.g...
# 4            6  [(technorati.com, 2006-03-03 20:48:41), (googl...
# ...        ...                                                ...
# 211308  521674  [(yahoo.com, 2006-03-06 10:04:29), (yahoo.com,...
# 211309  521686  [(flickr.com, 2006-03-12 21:19:11), (partypoke...
# 211310  521688  [(ytmnd.com, 2006-03-12 20:00:14), (aol.com, 2...
# 211311  521689  [(globalwitness.org, 2006-03-04 01:04:05), (ms...
# 211312  521691  [(go.com, 2006-03-04 11:36:38), (google.com, 2...
#
#                                                    topics
# 0       ['PUBH', 'PUBH', 'PUBH', 'NEWS', 'CTRL', 'HUMR...
# 1       ['SRCH', 'SRCH', 'HOST', 'NEWS', 'PUBH', 'COMT...
# 2       ['NEWS', 'REL', 'COMT', 'MMED', 'CTRL', 'CULTR...
# 3       ['NEWS', 'REL', 'GOVT', 'SRCH', 'POLR', 'HUMR'...
# 4       ['HOST', 'COMT', 'MMED', 'CTRL', 'CULTR', 'NEW...
# ...                                                   ...
# 211308  ['COMT', 'CULTR', 'COMM', 'NEWS', 'POLR', 'SRC...
# 211309  ['LGBT', 'MMED', 'GMB', 'HOST', 'GRP', 'CULTR'...
# 211310     ['REL', 'SRCH', 'POLR', 'HUMR', 'REL', 'COMM']
# 211311  ['ENV', 'POLR', 'NEWS', 'SRCH', 'GRP', 'COMT',...
# 211312  ['NEWS', 'COMT', 'MMED', 'CTRL', 'CULTR', 'NEW...
#
# [211313 rows x 3 columns]

# %%
aol_reduced_citizen_lab_generalization = aol_reduced_citizen_lab_generalization.rename(columns={'topics' : 'AllTopics'})

# %%
# %%time
# Computes the number of unique seen topics.
aol_reduced_citizen_lab_seen_topics = sorted(list(set([x for y in aol_reduced_citizen_lab_generalization['AllTopics'] for x in y])))
display(len(aol_reduced_citizen_lab_seen_topics))
# Out:
# 31
# CPU times: user 1.09 s, sys: 43.6 ms, total: 1.13 s
# Wall time: 1.13 s

# %%
# %%time
aol_reduced_citizen_lab_generalization['sTopics'] = aol_reduced_citizen_lab_generalization['AllTopics'].map(lambda x : dict(Counter(x)))
# Out:
# CPU times: user 1.49 s, sys: 24.4 ms, total: 1.51 s
# Wall time: 1.51 s

# %%
display(aol_reduced_citizen_lab_generalization)
# Out:
#         RandID                                    BrowsingHistory
# 0            1  [(kidshealth.org, 2006-03-01 11:54:19), (kidsh...  \
# 1            3  [(dogpile.com, 2006-03-12 16:09:37), (dogpile....
# 2            4  [(foxnews.com, 2006-03-12 20:33:21), (google.c...
# 3            5  [(foxnews.com, 2006-03-22 00:22:53), (senate.g...
# 4            6  [(technorati.com, 2006-03-03 20:48:41), (googl...
# ...        ...                                                ...
# 211308  521674  [(yahoo.com, 2006-03-06 10:04:29), (yahoo.com,...
# 211309  521686  [(flickr.com, 2006-03-12 21:19:11), (partypoke...
# 211310  521688  [(ytmnd.com, 2006-03-12 20:00:14), (aol.com, 2...
# 211311  521689  [(globalwitness.org, 2006-03-04 01:04:05), (ms...
# 211312  521691  [(go.com, 2006-03-04 11:36:38), (google.com, 2...
#
#                                                 AllTopics
# 0       ['PUBH', 'PUBH', 'PUBH', 'NEWS', 'CTRL', 'HUMR...  \
# 1       ['SRCH', 'SRCH', 'HOST', 'NEWS', 'PUBH', 'COMT...
# 2       ['NEWS', 'REL', 'COMT', 'MMED', 'CTRL', 'CULTR...
# 3       ['NEWS', 'REL', 'GOVT', 'SRCH', 'POLR', 'HUMR'...
# 4       ['HOST', 'COMT', 'MMED', 'CTRL', 'CULTR', 'NEW...
# ...                                                   ...
# 211308  ['COMT', 'CULTR', 'COMM', 'NEWS', 'POLR', 'SRC...
# 211309  ['LGBT', 'MMED', 'GMB', 'HOST', 'GRP', 'CULTR'...
# 211310     ['REL', 'SRCH', 'POLR', 'HUMR', 'REL', 'COMM']
# 211311  ['ENV', 'POLR', 'NEWS', 'SRCH', 'GRP', 'COMT',...
# 211312  ['NEWS', 'COMT', 'MMED', 'CTRL', 'CULTR', 'NEW...
#
#                                                   sTopics
# 0       {''PUBH'': 6, ''NEWS'': 4, ''CTRL'': 3, ''HUMR...
# 1       {''SRCH'': 8, ''HOST'': 5, ''NEWS'': 6, ''PUBH...
# 2       {''NEWS'': 2, ''REL'': 2, ''COMT'': 1, ''MMED'...
# 3       {''NEWS'': 1, ''REL'': 2, ''GOVT'': 3, ''SRCH'...
# 4       {''HOST'': 11, ''COMT'': 19, ''MMED'': 10, ''C...
# ...                                                   ...
# 211308  {''COMT'': 7, ''CULTR'': 4, ''COMM'': 7, ''NEW...
# 211309  {''LGBT'': 3, ''MMED'': 2, ''GMB'': 1, ''HOST'...
# 211310  {''REL'': 2, ''SRCH'': 1, ''POLR'': 1, ''HUMR'...
# 211311  {''ENV'': 6, ''POLR'': 6, ''NEWS'': 12, ''SRCH...
# 211312  {''NEWS'': 3, ''COMT'': 2, ''MMED'': 2, ''CTRL...
#
# [211313 rows x 4 columns]

# %%
def s_top(topics, s, allTopics):
    # If RandID's AllTopics list has exactly S topics, this is already their sTopics list.
    if len(topics) == s:
        top_s = list(topics.keys())
    # If RandID's AllTopics list has less than S topics, selects the remaining topics at random from the taxonomy.
    elif len(topics) < s:
        top_s = list(topics.keys())
        top_s.extend(random.sample(list(set(allTopics) - set(top_s)), k=s-len(top_s)))
    # If RandID's AllTopics list has more than S topics, selects only S of them, in decreasing order of occurrence.
    elif len(topics) > s:
        # Creates a temporary copy of RandID's AllTopics list (here a dictionary mapping topic to count).
        temp = topics.copy()
        # Creates the sTopics list with RandID's most seen topic and deletes it from temporary list.
        top_s = [max(temp, key=temp.get)]
        val = temp[top_s[0]]
        del temp[top_s[0]]
        # Creates a temporary list, alternatives, to account for topics with the same number of occurrences.
        v = temp[max(temp, key=temp.get)]
        alternatives = [top_s[0]]
        # While the sTopics list has less than S topics OR the next topic has the same number of occurrences.
        while len(top_s) < s or v == val:
            t = max(temp, key=temp.get)
            # If the current topic has the same number of occurrences as the previous one,
            # append it to alternatives.
            if v == val:
                alternatives.append(t)
            # Otherwise, clear alternatives and append the current topic to it.
            else:
                alternatives.clear()
                alternatives.append(t)
            top_s.append(t)
            val = v
            del temp[t]
            # If the temporary list is empty, break the loop.
            if len(temp) == 0:
                break
            else:
                v = temp[max(temp, key=temp.get)]
        # If the sTopics list has more than S topics, randomly selects the appropriate number of topics
        # from alternatives, i.e. from the topics with the same number of occurrences.
        if len(top_s) > s:
            delta = s - (len(top_s) - len(alternatives))
            top_s = top_s[0:s-delta]
            top_s.extend(random.sample(alternatives, k=delta))
    
    return sorted(top_s)

# %%
# %%time
# Selects S topics to be in sTopics list for each RandID.
random.SystemRandom()
S = 5
aol_reduced_citizen_lab_generalization['sTopics'] = aol_reduced_citizen_lab_generalization['sTopics'].map(lambda x : s_top(x, S, aol_reduced_citizen_lab_seen_topics))
# Out:
# CPU times: user 5.01 s, sys: 20 ms, total: 5.03 s
# Wall time: 5.03 s

# %%
display(aol_reduced_citizen_lab_generalization)
# Out:
#         RandID                                    BrowsingHistory
# 0            1  [(kidshealth.org, 2006-03-01 11:54:19), (kidsh...  \
# 1            3  [(dogpile.com, 2006-03-12 16:09:37), (dogpile....
# 2            4  [(foxnews.com, 2006-03-12 20:33:21), (google.c...
# 3            5  [(foxnews.com, 2006-03-22 00:22:53), (senate.g...
# 4            6  [(technorati.com, 2006-03-03 20:48:41), (googl...
# ...        ...                                                ...
# 211308  521674  [(yahoo.com, 2006-03-06 10:04:29), (yahoo.com,...
# 211309  521686  [(flickr.com, 2006-03-12 21:19:11), (partypoke...
# 211310  521688  [(ytmnd.com, 2006-03-12 20:00:14), (aol.com, 2...
# 211311  521689  [(globalwitness.org, 2006-03-04 01:04:05), (ms...
# 211312  521691  [(go.com, 2006-03-04 11:36:38), (google.com, 2...
#
#                                                 AllTopics
# 0       ['PUBH', 'PUBH', 'PUBH', 'NEWS', 'CTRL', 'HUMR...  \
# 1       ['SRCH', 'SRCH', 'HOST', 'NEWS', 'PUBH', 'COMT...
# 2       ['NEWS', 'REL', 'COMT', 'MMED', 'CTRL', 'CULTR...
# 3       ['NEWS', 'REL', 'GOVT', 'SRCH', 'POLR', 'HUMR'...
# 4       ['HOST', 'COMT', 'MMED', 'CTRL', 'CULTR', 'NEW...
# ...                                                   ...
# 211308  ['COMT', 'CULTR', 'COMM', 'NEWS', 'POLR', 'SRC...
# 211309  ['LGBT', 'MMED', 'GMB', 'HOST', 'GRP', 'CULTR'...
# 211310     ['REL', 'SRCH', 'POLR', 'HUMR', 'REL', 'COMM']
# 211311  ['ENV', 'POLR', 'NEWS', 'SRCH', 'GRP', 'COMT',...
# 211312  ['NEWS', 'COMT', 'MMED', 'CTRL', 'CULTR', 'NEW...
#
#                                           sTopics
# 0        ['COMM', 'CTRL', 'HUMR', 'NEWS', 'PUBH']
# 1        ['COMT', 'HOST', 'NEWS', 'PUBH', 'SRCH']
# 2          ['ENV', 'LGBT', 'NEWS', 'REL', 'SRCH']
# 3         ['GOVT', 'HUMR', 'NEWS', 'POLR', 'REL']
# 4       ['COMT', 'CULTR', 'GOVT', 'NEWS', 'POLR']
# ...                                           ...
# 211308   ['COMM', 'COMT', 'GOVT', 'NEWS', 'SRCH']
# 211309  ['CULTR', 'GOVT', 'HOST', 'LGBT', 'NEWS']
# 211310    ['COMM', 'HUMR', 'POLR', 'REL', 'SRCH']
# 211311    ['COMT', 'CTRL', 'GOVT', 'GRP', 'NEWS']
# 211312  ['CULTR', 'DATE', 'FILE', 'MMED', 'NEWS']
#
# [211313 rows x 4 columns]

# %%
# Checks if every sTopics list has exactly S topics.
display(aol_reduced_citizen_lab_generalization['sTopics'].map(lambda x : True if len(x) == S else False).all())
# Out:
# True

# %% [markdown]
# ### Save to file

# %%
aol_reduced_citizen_lab_generalization.to_csv('AOL-experimental-Citizen-Lab-Classification.csv')
