# %% [markdown]
# # Citizen Lab Classification Data Treatment

# %%
import pandas, re, tldextract, requests
from urllib.parse import urlparse

# %% [markdown]
# ## Filtering by eTLD
#
# Based on `tldextract` and on Mozilla's Public Suffix List.

# %%
extra_suffixes = ['bg.ac.yu','ac.yu','cg.yu','co.yu','edu.yu','gov.yu','net.yu','org.yu','yu','or.tp','tp','an']
extract = tldextract.TLDExtract(suffix_list_urls=["https://raw.githubusercontent.com/publicsuffix/list/5e6ac3a082505ac4cf08858bdb38382d9a912833/public_suffix_list.dat"],
                                cache_dir=None,fallback_to_snapshot=False,
                                extra_suffixes=extra_suffixes,include_psl_private_domains=True)

# %% [markdown]
# ## Load Citizen Lab Classification

# %%
# %%time
data = pandas.read_csv('https://raw.githubusercontent.com/citizenlab/test-lists/ebd0ee8d41977b381972b2f6c471af5437d8d015/lists/global.csv',
                       low_memory=False, on_bad_lines='warn', sep=',')

data = data.dropna(subset=['url'])
data = data.reset_index(drop=True)
data['domain'] = data['url']

for row in data.itertuples():
    temp = urlparse(row.url)
    if temp.netloc != '':
        data.at[row.Index, 'domain'] = temp.netloc
    else:
        data.at[row.Index, 'domain'] = temp.path

check = []

for tup in data.itertuples():
    temp = extract(tup.domain)
    if temp.suffix == '':
        check.append(tup.Index)
    elif (temp.domain == '') and (temp.suffix.count('.') == 0):
        check.append(tup.Index)
    elif (temp.domain == '') and (temp.suffix.count('.') != 0):
        data.at[tup.Index,'domain'] = temp.suffix
    elif (re.search(r'^[w]+$',temp.domain) != None) and (temp.suffix.count('.') != 0):
        data.at[tup.Index,'domain'] = temp.suffix
    elif re.search(r'^[w]+$',temp.domain) == None:
        if re.search(r'[^a-zA-Z0-9-]',temp.domain) != None:
            check.append(tup.Index)
        else:
            data.at[tup.Index,'domain'] = temp.domain.strip('-') + '.' + temp.suffix
    else:
        check.append(tup.Index)

data = data.drop(check)
data = data.drop_duplicates()
data = data.reset_index(drop=True)
# Out:
# CPU times: user 482 ms, sys: 14.2 ms, total: 496 ms
# Wall time: 975 ms

# %%
complete_data = data.copy(deep=True)

# %%
# %%time
countries = pandas.read_csv('https://raw.githubusercontent.com/citizenlab/test-lists/ebd0ee8d41977b381972b2f6c471af5437d8d015/lists/00-LEGEND-country_codes.csv',
                            low_memory=False, on_bad_lines='warn', sep=',', keep_default_na=False)['CountryCode']

lists = [
    'official/it/aams.csv',
    'official/it/bofh.csv',
    'cis.csv',
    'cd.csv',
    'mk.csv',
    'ps.csv',
    'rs.csv',
    'ss.csv',
    'tl.csv'
]

base = 'https://raw.githubusercontent.com/citizenlab/test-lists/ebd0ee8d41977b381972b2f6c471af5437d8d015/lists/'

for country in countries:
    test = requests.get(base + country.lower() + '.csv').status_code
    if test == 200:
        lists.append(country.lower() + '.csv')
    else:
        print(country + ': ' + str(test))
# Out:
# AD: 404
# AG: 404
# AI: 404
# AN: 404
# AQ: 404
# AS: 404
# AW: 404
# BB: 404
# BF: 404
# BJ: 404
# BM: 404
# BN: 404
# BS: 404
# BT: 404
# BU: 404
# BV: 404
# BW: 404
# BZ: 404
# CC: 404
# CF: 404
# CG: 404
# CK: 404
# CS: 404
# CV: 404
# CX: 404
# DD: 404
# DJ: 404
# DM: 404
# EH: 404
# FK: 404
# FM: 404
# FO: 404
# FX: 404
# GD: 404
# GF: 404
# GI: 404
# GL: 404
# GN: 404
# GP: 404
# GQ: 404
# GS: 404
# GU: 404
# GW: 404
# HM: 404
# HT: 404
# IO: 404
# JM: 404
# KI: 404
# KM: 404
# KN: 404
# KY: 404
# LA: 404
# LC: 404
# LI: 404
# LR: 404
# LU: 404
# MC: 404
# MG: 404
# MH: 404
# MO: 404
# MP: 404
# MQ: 404
# MS: 404
# MT: 404
# MU: 404
# MV: 404
# MW: 404
# NA: 404
# NC: 404
# NE: 404
# NR: 404
# NT: 404
# NU: 404
# PF: 404
# PG: 404
# PM: 404
# PN: 404
# PW: 404
# RE: 404
# SB: 404
# SC: 404
# SH: 404
# SJ: 404
# SM: 404
# SR: 404
# ST: 404
# SU: 404
# SZ: 404
# TC: 404
# TF: 404
# TK: 404
# TO: 404
# TP: 404
# TT: 404
# TV: 404
# UM: 404
# VA: 404
# VC: 404
# VG: 404
# VI: 404
# VU: 404
# WF: 404
# WS: 404
# YD: 404
# YT: 404
# YU: 404
# ZR: 404
# CPU times: user 13.1 s, sys: 266 ms, total: 13.4 s
# Wall time: 1min 6s

# %%
# %%time
base = 'https://raw.githubusercontent.com/citizenlab/test-lists/ebd0ee8d41977b381972b2f6c471af5437d8d015/lists/'

for file in lists:
    data = pandas.read_csv(base + file, low_memory=False, on_bad_lines='warn', sep=',')
    
    data = data.dropna(subset=['url'])
    data = data.reset_index(drop=True)
    data['domain'] = data['url']
    
    for row in data.itertuples():
        temp = urlparse(row.url)
        if temp.netloc != '':
            data.at[row.Index, 'domain'] = temp.netloc
        else:
            data.at[row.Index, 'domain'] = temp.path
    
    check = []
    
    for tup in data.itertuples():
        temp = extract(tup.domain)
        if temp.suffix == '':
            check.append(tup.Index)
        elif (temp.domain == '') and (temp.suffix.count('.') == 0):
            check.append(tup.Index)
        elif (temp.domain == '') and (temp.suffix.count('.') != 0):
            data.at[tup.Index,'domain'] = temp.suffix
        elif (re.search(r'^[w]+$',temp.domain) != None) and (temp.suffix.count('.') != 0):
            data.at[tup.Index,'domain'] = temp.suffix
        elif re.search(r'^[w]+$',temp.domain) == None:
            if re.search(r'[^a-zA-Z0-9-]',temp.domain) != None:
                check.append(tup.Index)
            else:
                data.at[tup.Index,'domain'] = temp.domain.strip('-') + '.' + temp.suffix
        else:
            check.append(tup.Index)
    
    data = data.drop(check)
    data = data.drop_duplicates()
    data = data.reset_index(drop=True)
    
    complete_data = pandas.concat([complete_data, data])
    complete_data = complete_data.reset_index(drop=True)
# Out:
# CPU times: user 18.6 s, sys: 669 ms, total: 19.2 s
# Wall time: 49.9 s

# %% [markdown]
# ## Drop unnecessary columns

# %%
# %%time
complete_data = complete_data.drop(columns=['category_description', 'date_added', 'notes', 'name',
                                            'date_published', 'data_format_version', 'authority'],
                                   inplace=False)
# Out:
# CPU times: user 8.54 ms, sys: 0 ns, total: 8.54 ms
# Wall time: 13.1 ms

# %%
display(complete_data)
# Out:
#                                                      url category_code
# 0                            https://4genderjustice.org/          HUMR  \
# 1                                   http://666games.net/          GAME
# 2                              http://abpr2.railfan.net/          MMED
# 3                            https://addons.mozilla.org/          FILE
# 4                                      https://adium.im/           GRP
# ...                                                  ...           ...
# 41180  https://outrightinternational.org/sites/defaul...          LGBT
# 41181       https://www.globalgayz.com/gay-zimbabwe/158/          LGBT
# 41182                           https://www.topup.co.zw/          COMM
# 41183                          https://www.paynow.co.zw/          COMM
# 41184                        https://www.property.co.zw/          COMM
#
#                                  source                     domain
# 0                            citizenlab         4genderjustice.org
# 1                            citizenlab               666games.net
# 2                            citizenlab                railfan.net
# 3                            citizenlab                mozilla.org
# 4                            citizenlab                   adium.im
# ...                                 ...                        ...
# 41180                       Netalitica   outrightinternational.org
# 41181                       Netalitica              globalgayz.com
# 41182  test-lists.ooni.org contribution                topup.co.zw
# 41183  test-lists.ooni.org contribution               paynow.co.zw
# 41184  test-lists.ooni.org contribution             property.co.zw
#
# [41185 rows x 4 columns]

# %%
display(complete_data.nunique())
# Out:
# url              33842
# category_code       34
# source             158
# domain           27793
# dtype: int64

# %% [markdown]
# ## Drop rows without classification

# %%
display(complete_data['domain'].isna().any())
# Out:
# False

# %%
display(complete_data['category_code'].isna().any())
# Out:
# True

# %%
# %%time
for row in complete_data.itertuples():
    if type(row.category_code) != type(str()):
        print(row)
# Out:
# Pandas(Index=4490, url='www.dolomitihomes.it', category_code=nan, source='censura.bofh.it', domain='dolomitihomes.it')
# CPU times: user 101 ms, sys: 4.05 ms, total: 106 ms
# Wall time: 113 ms

# %%
# %%time
complete_data = complete_data.dropna(subset=['category_code'], ignore_index=True)
# Out:
# CPU times: user 14.5 ms, sys: 101 µs, total: 14.6 ms
# Wall time: 21.9 ms

# %% [markdown]
# ## Update all entries to new classification

# %% [markdown]
# As per: https://github.com/citizenlab/test-lists/blob/ebd0ee8d41977b381972b2f6c471af5437d8d015/lists/00-LEGEND-new_category_codes.csv

# %%
display(complete_data[['category_code','domain']].groupby('category_code').indices.keys())
# Out:
# dict_keys(['ALDR', 'ANON', 'COMM', 'COMT', 'CTRL', 'CULTR', 'DATE', 'DEV', 'ECON', 'ENV', 'FEXP', 'FILE', 'GAME', 'GMB', 'GOVT', 'GRP', 'HACK', 'HATE', 'HOST', 'HUMR', 'IGO', 'LGBT', 'MILX', 'MISC', 'MMED', 'NEWS', 'P2P', 'POLR', 'PORN', 'PROV', 'PUBH', 'REL', 'SRCH', 'XED'])

# %%
# %%time
for row in complete_data.itertuples():
    if row.category_code == 'DEV':
        complete_data.at[row.Index,'category_code'] = 'ECON'
    elif row.category_code == 'FEXP':
        complete_data.at[row.Index,'category_code'] = 'NEWS'
    elif row.category_code == 'P2P':
        complete_data.at[row.Index,'category_code'] = 'FILE'
# Out:
# CPU times: user 96.9 ms, sys: 0 ns, total: 96.9 ms
# Wall time: 99.2 ms

# %%
display(complete_data[['category_code','domain']].groupby('category_code').indices.keys())
# Out:
# dict_keys(['ALDR', 'ANON', 'COMM', 'COMT', 'CTRL', 'CULTR', 'DATE', 'ECON', 'ENV', 'FILE', 'GAME', 'GMB', 'GOVT', 'GRP', 'HACK', 'HATE', 'HOST', 'HUMR', 'IGO', 'LGBT', 'MILX', 'MISC', 'MMED', 'NEWS', 'POLR', 'PORN', 'PROV', 'PUBH', 'REL', 'SRCH', 'XED'])

# %%
display(complete_data)
# Out:
#                                                      url category_code
# 0                            https://4genderjustice.org/          HUMR  \
# 1                                   http://666games.net/          GAME
# 2                              http://abpr2.railfan.net/          MMED
# 3                            https://addons.mozilla.org/          FILE
# 4                                      https://adium.im/           GRP
# ...                                                  ...           ...
# 41179  https://outrightinternational.org/sites/defaul...          LGBT
# 41180       https://www.globalgayz.com/gay-zimbabwe/158/          LGBT
# 41181                           https://www.topup.co.zw/          COMM
# 41182                          https://www.paynow.co.zw/          COMM
# 41183                        https://www.property.co.zw/          COMM
#
#                                  source                     domain
# 0                            citizenlab         4genderjustice.org
# 1                            citizenlab               666games.net
# 2                            citizenlab                railfan.net
# 3                            citizenlab                mozilla.org
# 4                            citizenlab                   adium.im
# ...                                 ...                        ...
# 41179                       Netalitica   outrightinternational.org
# 41180                       Netalitica              globalgayz.com
# 41181  test-lists.ooni.org contribution                topup.co.zw
# 41182  test-lists.ooni.org contribution               paynow.co.zw
# 41183  test-lists.ooni.org contribution             property.co.zw
#
# [41184 rows x 4 columns]

# %%
display(complete_data.nunique())
# Out:
# url              33841
# category_code       31
# source             158
# domain           27792
# dtype: int64

# %% [markdown]
# ## Merge classifications by domain

# %%
# %%time
topics = {}
for domain, rows in complete_data[['domain','category_code']].groupby('domain').groups.items():
    temp = []
    for row in rows:
        temp.append(complete_data.iloc[row]['category_code'])
    topics[domain] = str(set(temp)).strip('{}')
# Out:
# CPU times: user 5.48 s, sys: 15.7 ms, total: 5.49 s
# Wall time: 5.49 s

# %%
display(topics)
# Out:
# {'000webhost.com': "'HOST'",
#  '0039bet.com': "'GMB'",
#  '0039casino.com': "'GMB'",
#  '0039casino.eu': "'GMB'",
#  '003ms.ru': "'PUBH'",
#  '007bets.com': "'GMB'",
#  '007casinogames.com': "'GMB'",
#  '007sportsbetting.com': "'GMB'",
#  '00roulette.com': "'GMB'",
#  '015.by': "'SRCH'",
#  '01net.com': "'HACK', 'HOST'",
#  '022.md': "'HOST'",
#  '027pxw.com': "'COMM'",
#  '03.ru': "'PUBH'",
#  '037hdmovie.com': "'CULTR'",
#  '03portal.kz': "'COMM'",
#  '06237.info': "'NEWS'",
#  '06239.com.ua': "'NEWS'",
#  '06252.com.ua': "'NEWS'",
#  '06274.com.ua': "'NEWS'",
#  '07sports.com': "'GMB'",
#  '0dt.net': "'FILE'",
#  '0eb.net': "'FILE'",
#  '0ubada.net': "'FILE'",
#  '1-0-bet.com': "'GMB'",
#  '1-0-bet.it': "'GMB'",
#  '1-x-bet.com': "'GMB'",
#  '10-bet.it': "'GMB'",
#  '10000euroalmese.info': "'GMB'",
#  '1000noticias.com.py': "'NEWS'",
#  '1000poker.net': "'GMB'",
#  '1001casino.com': "'GMB'",
#  '1001roteirinhos.com.br': "'CULTR'",
#  '100basket.com': "'COMM'",
#  '100kcasino.com': "'GMB'",
#  '100kwt.com': "'NEWS'",
#  '100mega.ml': "'POLR'",
#  '100noticias.com.ni': "'NEWS'",
#  '100suzler.org': "'NEWS'",
#  '100webspace.com': "'HOST'",
#  '101-casino.com': "'GMB'",
#  '101.ru': "'NEWS'",
#  '101arts.net': "'CULTR'",
#  '101newsmedia.com': "'NEWS'",
#  '1059thebigkahuna.com': "'COMM'",
#  '105casino.com': "'GMB'",
#  '105casino.eu': "'GMB'",
#  '10be-t.com': "'GMB'",
#  '10bet-it.com': "'GMB'",
#  '10bet-it.it': "'GMB'",
#  '10bet-italia.com': "'GMB'",
#  '10bet.co.it': "'GMB'",
#  '10bet.com': "'GMB'",
#  '10betcalcio.it': "'GMB'",
#  '10betcalcio2.it': "'GMB'",
#  '10betit.com': "'GMB'",
#  '10betitalia.com': "'GMB'",
#  '10betitalia.info': "'GMB'",
#  '10betitalia.it': "'GMB'",
#  '10betitalia.net': "'GMB'",
#  '10betitaly.com': "'GMB'",
#  '10betitaly.eu': "'GMB'",
#  '10betitaly.it': "'GMB'",
#  '10betnews.it': "'GMB'",
#  '10betpro.com': "'GMB'",
#  '10bets.it': "'GMB'",
#  '10betscommesse.it': "'GMB'",
#  '10betsport.com': "'GMB'",
#  '10betsport.it': "'GMB'",
#  '10handpokercasino.com': "'GMB'",
#  '10ngah.com': "'COMM'",
#  '10scommesse.com': "'GMB'",
#  '10sport10it.com': "'GMB'",
#  '10svodok.su': "'NEWS'",
#  '1128bet.com': "'GMB'",
#  '1128bet.net': "'GMB'",
#  '113.com.tw': "'GAME'",
#  '11abril.com': "'CULTR'",
#  '11proxy.pw': "'ANON'",
#  '121winsb.com': "'GMB'",
#  '1221cd.org': "'POLR'",
#  '123allin.com': "'GMB'",
#  '123bingoonline.com': "'GMB'",
#  '123movies.is': "'FILE'",
#  '123movies.to': "'FILE'",
#  '123moviesfreez.com': "'FILE'",
#  '123savemp3.net': "'FILE'",
#  '123tvnow.com': "'MMED'",
#  '123vegaswin.com': "'GMB'",
#  '12bet.com': "'GMB'",
#  '12biying.com': "'GMB'",
#  '1337x.org': "'FILE'",
#  '1337x.st': "'FILE'",
#  '1337x.to': "'FILE'",
#  '1377x.to': "'FILE'",
#  '140journos.com': "'NEWS'",
#  '141hongkong.com': "'PORN'",
#  '148casinos.com': "'GMB'",
#  '14f2011.com': "'POLR'",
#  '14febrayer.com': "'POLR'",
#  '14masom.com': "'HUMR'",
#  '14tula.com': "'CULTR'",
#  '14ymedio.com': "'NEWS'",
#  '150poker.com': "'GMB'",
#  '15880.com': "'LGBT'",
#  '15minut.org': "'NEWS'",
#  '161sex.com': "'PORN'",
#  '163.com': "'DATE', 'GAME'",
#  '168.am': "'NEWS'",
#  '1688.com': "'COMM'",
#  '16honeys.com': "'PORN'",
#  '17.live': "'GRP'",
#  '17.media': "'MMED'",
#  '17paipai.cn': "'DATE'",
#  '180.com.uy': "'NEWS'",
#  '1800respect.org.au': "'XED'",
#  '180bets.com': "'GMB'",
#  '188-bet.org': "'GMB'",
#  '188bet.com': "'GMB'",
#  '19.org': "'REL'",
#  '1asir.com': "'NEWS'",
#  '1bet.com': "'GMB'",
#  '1bet2bet.com': "'GMB'",
#  '1c-bitrix.ru': "'GRP', 'COMM'",
#  '1c.ru': "'COMM'",
#  '1cak.com': "'MMED'",
#  '1casino.com': "'GMB'",
#  '1escorts.net': "'PROV'",
#  '1fichier.com': "'FILE'",
#  '1gay.ru': "'LGBT'",
#  '1in.am': "'NEWS'",
#  '1in99percent.blogspot.com': "'POLR'",
#  '1koreannews.com': "'GOVT'",
#  '1livecasino.com': "'GMB'",
#  '1livecasino.eu': "'GMB'",
#  '1livecasino.net': "'GMB'",
#  '1livecasino.org': "'GMB'",
#  '1luckygambler.com': "'GMB'",
#  '1lurer.am': "'NEWS'",
#  '1news.az': "'NEWS'",
#  '1oman.com': "'NEWS'",
#  '1on1footballsportsbetting.com': "'GMB'",
#  '1pezeshk.com': "'CULTR'",
#  '1plus1.ua': "'NEWS'",
#  '1prime.ru': "'NEWS'",
#  '1push.ng': "'NEWS'",
#  '1redfoxpoker.com': "'GMB'",
#  '1reg.org': "'NEWS'",
#  '1sev.tv': "'NEWS'",
#  '1sportbook.com': "'GMB'",
#  '1st-free-casino-online.com': "'GMB'",
#  '1stlines.com': "'GMB'",
#  '1stonlineinternetcasino.com': "'GMB'",
#  '1supp.org.my': "'POLR'",
#  '1tamilgun.com': "'MMED'",
#  '1thegioi.vn': "'NEWS'",
#  '1tv.af': "'NEWS'",
#  '1tv.am': "'NEWS'",
#  '1tv.com': "'NEWS'",
#  '1tv.ge': "'NEWS'",
#  '1tv.kz': "'NEWS'",
#  '1tv.ru': "'NEWS'",
#  '1tvcrimea.ru': "'NEWS'",
#  '1tvnews.af': "'NEWS'",
#  '1wonodds.com': "'GMB'",
#  '1x-02.com': "'GMB'",
#  '1x-bet.com': "'GMB'",
#  '1x-bet031946.world': "'GMB'",
#  '1x001.com': "'GMB'",
#  '1xbet.com': "'GMB'",
#  '1xbet1.com': "'GMB'",
#  '1xbet101.com': "'GMB'",
#  '1xbet102.com': "'GMB'",
#  '1xbet103.com': "'GMB'",
#  '1xbet104.com': "'GMB'",
#  '1xbet105.com': "'GMB'",
#  '1xbet106.com': "'GMB'",
#  '1xbet107.com': "'GMB'",
#  '1xbet108.com': "'GMB'",
#  '1xbet109.com': "'GMB'",
#  '1xbet110.com': "'GMB'",
#  '1xbet12.com': "'GMB'",
#  '1xbet13.com': "'GMB'",
#  '1xbet14.com': "'GMB'",
#  '1xbet15.com': "'GMB'",
#  '1xbet2.com': "'GMB'",
#  '1xbet26.com': "'GMB'",
#  '1xbet27.com': "'GMB'",
#  '1xbet3.com': "'GMB'",
#  '1xbet32.com': "'GMB'",
#  '1xbet34.com': "'GMB'",
#  '1xbet35.com': "'GMB'",
#  '1xbet36.com': "'GMB'",
#  '1xbet37.com': "'GMB'",
#  '1xbet38.com': "'GMB'",
#  '1xbet39.com': "'GMB'",
#  '1xbet4.com': "'GMB'",
#  '1xbet40.com': "'GMB'",
#  '1xbet41.com': "'GMB'",
#  '1xbet42.com': "'GMB'",
#  '1xbet43.com': "'GMB'",
#  '1xbet45.com': "'GMB'",
#  '1xbet46.com': "'GMB'",
#  '1xbet47.com': "'GMB'",
#  '1xbet48.com': "'GMB'",
#  '1xbet49.com': "'GMB'",
#  '1xbet50.com': "'GMB'",
#  '1xbet51.com': "'GMB'",
#  '1xbet52.com': "'GMB'",
#  '1xbet53.com': "'GMB'",
#  '1xbet54.com': "'GMB'",
#  '1xbet6.com': "'GMB'",
#  '1xbet60.com': "'GMB'",
#  '1xbet61.com': "'GMB'",
#  '1xbet62.com': "'GMB'",
#  '1xbet63.com': "'GMB'",
#  '1xbet64.com': "'GMB'",
#  '1xbet65.com': "'GMB'",
#  '1xbet68.com': "'GMB'",
#  '1xbet7.com': "'GMB'",
#  '1xbet70.com': "'GMB'",
#  '1xbet71.com': "'GMB'",
#  '1xbet72.com': "'GMB'",
#  '1xbet73.com': "'GMB'",
#  '1xbet74.com': "'GMB'",
#  '1xbet75.com': "'GMB'",
#  '1xbet76.com': "'GMB'",
#  '1xbet78.com': "'GMB'",
#  '1xbet8.com': "'GMB'",
#  '1xbet82.com': "'GMB'",
#  '1xbet84.com': "'GMB'",
#  '1xbet86.com': "'GMB'",
#  '1xbet87.com': "'GMB'",
#  '1xbet9.com': "'GMB'",
#  '1xbet90.com': "'GMB'",
#  '1xbet91.com': "'GMB'",
#  '1xbet92.com': "'GMB'",
#  '1xbet94.com': "'GMB'",
#  '1xbet95.com': "'GMB'",
#  '1xbetbk13.com': "'GMB'",
#  '1xbetbk6.com': "'GMB'",
#  '1xbit.com': "'GMB'",
#  '1xbkbet-1.com': "'GMB'",
#  '1xhov.xyz': "'GMB'",
#  '1xsinga.com': "'GMB'",
#  '2000fun.com': "'GAME'",
#  '2001.com.ve': "'NEWS'",
#  '200rf.com': "'HUMR'",
#  '2013nikemercurialvapor.com': "'COMM'",
#  '2016change.net': "'POLR'",
#  '2019gantipresiden.org': "'POLR'",
#  '2020sikhreferendum.org': "'MILX'",
#  '20bet.com': "'GMB'",
#  '20cn.net': "'HACK'",
#  '20fevrier.com': "'POLR'",
#  '20fr.com': "'REL'",
#  '20khvylyn.com': "'NEWS'",
#  '20m.com': "'CULTR', 'ENV', 'HUMR'",
#  '20minutes.fr': "'NEWS'",
#  '20minutos.es': "'NEWS'",
#  '20script.ir': "'FILE'",
#  '20speed.co': "'ANON'",
#  '21-nova.it': "'GMB'",
#  '21.by': "'NEWS'",
#  '214dating.com': "'DATE'",
#  '21bet21.com': "'GMB'",
#  '21bit.org': "'MISC'",
#  '21dukes.com': "'GMB'",
#  '21gc-it.com': "'GMB'",
#  '21gc-it1.com': "'GMB'",
#  '21gc-italia.com': "'GMB'",
#  '21gc2-it.com': "'GMB'",
#  '21grandcasino-it.com': "'GMB'",
#  '21grandcasino-italia.com': "'GMB'",
#  '21grandcasino.com': "'GMB'",
#  '21grandcasino.net': "'GMB'",
#  '21grandcasinoit.com': "'GMB'",
#  '21grandcasinos.com': "'GMB'",
#  '21magic.com': "'GMB'",
#  '21nova.com': "'GMB'",
#  '21nova.it': "'GMB'",
#  '21novacasino.com': "'GMB'",
#  '21novaitalian.com': "'GMB'",
#  '21novaitaly.com': "'GMB'",
#  '21novaitla.com': "'GMB'",
#  '21novaitlyano.com': "'GMB'",
#  '21novaltalya.com': "'GMB'",
#  '21winners.com': "'GMB'",
#  '21za.com': "'DATE'",
#  '220volt.hu': "'COMM'",
#  '228actu.com': "'NEWS'",
#  '22bet.com': "'GMB'",
#  '22bets.me': "'GMB'",
#  '22lottery.com': "'GMB'",
#  '233today.com': "'GRP'",
#  '234next.com': "'NEWS'",
#  '237actu.com': "'NEWS'",
#  '237cameroun.online': "'NEWS'",
#  '237online.com': "'NEWS'",
#  '24-horas.mx': "'NEWS'",
#  '24.ae': "'NEWS'",
#  '24.hu': "'NEWS'",
#  '24.kg': "'NEWS'",
#  '247poker.com': "'GMB'",
#  '248am.com': "'NEWS'",
#  '24Proxy.com': "'ANON'",
#  '24TopProxy.com': "'ANON'",
#  '24Traffic.info': "'ANON'",
#  '24caratcasino.com': "'GMB'",
#  '24dogs.com': "'GMB'",
#  '24h.com.vn': "'NEWS'",
#  '24hbet.com': "'GMB'",
#  '24horas.cl': "'NEWS'",
#  '24horasnews.com.br': "'NEWS'",
#  '24hoursfordarfur.org': "'HUMR'",
#  '24hpoker.com': "'GMB'",
#  '24hpoker.it': "'GMB'",
#  '24info.tn': "'NEWS'",
#  '24ktgoldcasino.com': "'GMB'",
#  '24newshd.tv': "'NEWS'",
#  '24open.ru': "'DATE'",
#  '24opzioni.com': "'GMB'",
#  '24poker.com': "'GMB'",
#  '24porn.com': "'PORN'",
#  '24proxy.com': "'ANON'",
#  '24saat.org': "'NEWS'",
#  '24tsag.mn': "'NEWS'",
#  '24tv.ua': "'NEWS'",
#  '24ur.com': "'NEWS'",
#  '2600.com': "'HACK'",
#  '263chat.com': "'COMT', 'NEWS'",
#  '263newsafrica.co.zw': "'NEWS'",
#  '26sep.net': "'NEWS'",
#  '26sepnews.net': "'NEWS'",
#  '27avril.com': "'NEWS'",
#  '27k.online': "'NEWS'",
#  '28365365.com': "'GMB'",
#  '288-563.com': "'GMB'",
#  '288sb.com': "'GMB'",
#  '2adultflashgames.com': "'PORN'",
#  '2advancedpoker.com': "'GMB'",
#  '2bangkok.com': "'POLR'",
#  '2bet.com': "'GMB'",
#  '2betdsi.com': "'GMB'",
#  '2ch.hk': "'PORN', 'HOST'",
#  '2dec.net': "'NEWS'",
#  '2fastsurfer.com': "'ANON'",
#  '2gheroon.net': "'ECON'",
#  '2gis.ru': "'CTRL'",
#  '2ie-edu.org': "'MMED'",
#  '2ip.ru': "'ANON'",
#  '2m.ma': "'NEWS'",
#  '2merkato.com': "'COMM'",
#  '2nate.com': "'ECON'",
#  '2shared.com': "'FILE'",
#  '2sportgewin.com': "'GMB'",
#  '2stv.net': "'NEWS'",
#  '2up.com': "'GMB'",
#  '2winbet.gr': "'GMB'",
#  '2xq.ir': "'DATE'",
#  '2zaar.net': "'ECON'",
#  '3-mob.com': "'CULTR'",
#  '300mbfilms.org': "'FILE'",
#  '300mbfilms.ws': "'FILE'",
#  '306bets10.com': "'GMB'",
#  '307bets10.com': "'GMB'",
#  '30plusgirls.com': "'PORN'",
#  '31.kz': "'NEWS'",
#  '321bp.com': "'GMB'",
#  '32red.com': "'GMB'",
#  '32redpoker.com': "'GMB'",
#  '32vegas.com': "'GMB'",
#  '32vegasit.com': "'GMB'",
#  '32vegasitalycasino.com': "'GMB'",
#  '337.com': "'GAME'",
#  '33kgallery.com': "'CULTR'",
#  '345proxy.ml': "'ANON'",
#  '347bet.com': "'GMB'",
#  '34mag.net': "'NEWS'",
#  '350.org': "'ENV'",
#  '360.cn': "'FILE'",
#  '360game.vn': "'GAME'",
#  '365-588.com': "'GMB'",
#  '365aams.it': "'GMB'",
#  '365buymy.com': "'PORN'",
#  '365eventisportivi.com': "'GMB'",
#  '365gioca365.com': "'GMB'",
#  '365giocando365.com': "'GMB'",
#  '365giochi365.com': "'GMB'",
#  '365giochiamo365.com': "'GMB'",
#  '365italia365.com': "'GMB'",
#  '365italian.com': "'GMB'",
#  '365italiano.com': "'GMB'",
#  '365italiano365.com': "'GMB'",
#  '365myanmar.com': "'COMM'",
#  '365planet365.com': "'GMB'",
#  '365planetwin.com': "'GMB'",
#  '365sb.com': "'GMB'",
#  '365scommesse.net': "'GMB'",
#  '365scommesse365.com': "'GMB'",
#  '365scommetti365.com': "'GMB'",
#  '365sport365.com': "'GMB'",
#  '365sportgiochi.com': "'GMB'",
#  '365worldstorewrx.com': "'XED'",
#  '368365bet.com': "'GMB'",
#  '36vegas.com': "'GMB'",
#  '3800hk.com': "'HACK'",
#  '3arabporn.com': "'PORN'",
#  '3arbt.com': "'MMED'",
#  '3boyutpoker.com': "'GMB'",
#  '3dcardroom.com': "'GMB'",
#  '3dice.com': "'GMB'",
#  '3djuegos.com': "'GAME'",
#  '3dlat.com': "'GRP'",
#  '3docean.net': "'MMED'",
#  '3droga.pl': "'HATE'",
#  '3dway.org': "'POLR'",
#  '3grbgr.blogspot.com': "'NEWS'",
#  '3hive.com': "'MMED'",
#  '3katherines.blogspot.com': "'POLR'",
#  '3lionspoker.com': "'GMB'",
#  '3lnar.com': "'NEWS'",
#  '3news.com': "'NEWS'",
#  '3piggspoker.co.sz': "'GMB'",
#  '3raq4all.com': "'SRCH'",
#  '3rbdr.net': "'PUBH'",
#  '3rbe.com': "'FILE'",
#  '3rbpro.com': "'FILE'",
#  '3rby.blogspot.com': "'POLR'",
#  '3tlh.com': "'COMM'",
#  '3wishes.com': "'PROV'",
#  '3xnepali.blogspot.com': "'XED'",
#  '40somethingmag.com': "'PORN'",
#  '416family.org': "'POLR'",
#  '444.hu': "'POLR', 'LGBT', 'NEWS'",
#  '45-rpm.net': "'POLR'",
#  '456proxy.ml': "'ANON'",
#  '488365.com': "'GMB'",
#  '49ercasino.com': "'GMB'",
#  '4acesclubpoker.com': "'GMB'",
#  '4acespokerclub.com': "'GMB'",
#  '4assi.biz': "'GMB'",
#  '4assi.com': "'GMB'",
#  '4assi.net': "'GMB'",
#  '4assi1.biz': "'GMB'",
#  '4assi2.biz': "'GMB'",
#  '4assi3.biz': "'GMB'",
#  '4assi4.biz': "'GMB'",
#  '4assi5.biz': "'GMB'",
#  '4assi8.biz': "'GMB'",
#  '4assipoker.com': "'GMB'",
#  '4assipoker.net': "'GMB'",
#  '4bn.ir': "'DATE'",
#  '4c.ma': "'ENV'",
#  '4champs.com': "'GMB'",
#  '4chan.org': "'GRP'",
#  '4donk.com': "'GMB'",
#  '4eco.com': "'ENV'",
#  '4everproxy.com': "'ANON'",
#  '4freephotos.com': "'MMED'",
#  '4genderjustice.org': "'HUMR'",
#  '4helal.co': "'MMED'",
#  '4helal.tv': "'MMED'",
#  '4kings.com': "'GMB'",
#  '4lifepoker.com': "'GMB'",
#  '4may.net': "'MILX', 'NEWS'",
#  '4online-gambling.com': "'GMB'",
#  '4pelagatos.com': "'POLR'",
#  '4platinumsportsbook.com': "'GMB'",
#  '4rd.am': "'NEWS'",
#  '4shared.com': "'FILE'",
#  '4sportsbetting.com': "'GMB'",
#  '4sportspicks.com': "'GMB'",
#  '5-tv.ru': "'NEWS'",
#  '5-yal.com': "'FILE'",
#  '5.ua': "'NEWS'",
#  '500px.com': "'MMED'",
#  '5050poker.com': "'GMB'",
#  '50megs.com': "'ENV'",
#  '50starscasino.com': "'GMB'",
#  '51rry.com': "'PUBH'",
#  '520hack.com': "'HACK'",
#  '52bet.com': "'GMB'",
#  '55clicks.com': "'COMM'",
#  '57nuce.com': "'POLR'",
#  '58.com': "'SRCH'",
#  '5alf.blogspot.com': "'NEWS'",
#  '5dias.com.py': "'NEWS'",
#  '5dimes.com': "'GMB'",
#  '5dimes.eu': "'GMB'",
#  '5dw5l.com': "'CULTR'",
#  '5poker5.com': "'GMB'",
#  '6-ar.com': "'PORN'",
#  '60dtk.com': "'NEWS'",
#  '61.com.tw': "'GAME'",
#  '61saat.com': "'NEWS'",
#  '62.ua': "'NEWS'",
#  '6264.com.ua': "'NEWS'",
#  '64forsuu.org': "'POLR'",
#  '64memo.com': "'HUMR'",
#  '64museum.blogspot.com': "'HUMR'",
#  '666games.net': "'GAME'",
#  '66poker.com': "'GMB'",
#  '678proxy.ml': "'ANON'",
#  '688365.com': "'GMB'",
#  '69gayporno.com': "'PORN'",
#  '6april.org': "'POLR'",
#  '6arabs.com': "'PORN'",
#  '6ixty8ight.com': "'PROV'",
#  '6neek.com': "'PORN'",
#  '6obcy.org': "'COMT'",
#  '6on6.com': "'XED'",
#  '6poker6.com': "'GMB'",
#  '6rang.org': "'LGBT'",
#  '6topoder.com': "'NEWS'",
#  '6topoderweb.com': "'NEWS'",
#  '7-11-casino.com': "'GMB'",
#  '707casino.com': "'GMB'",
#  '710casino.com': "'GMB'",
#  '710casino.eu': "'GMB'",
#  '710games.com': "'GMB'",
#  '710games.eu': "'GMB'",
#  '710live.eu': "'GMB'",
#  '716.kz': "'NEWS'",
#  '724muzik.net': "'MMED'",
#  '724sports.com': "'GMB'",
#  '724sportsbook.com': "'GMB'",
#  '727poker.com': "'GMB'",
#  '73buy.cn': "'MISC'",
#  '76crimes.com': "'LGBT', 'HUMR'",
#  '770.com': "'GMB'",
#  '777.com': "'GMB'",
#  '777betz.com': "'GMB'",
#  '777dragoncasino.com': "'GMB'",
#  '777dragoncasino.eu': "'GMB'",
#  '777jackpotgame.ru': "'GMB'",
#  '777pokerclub.com': "'GMB'",
#  '77betsg.com': "'GMB'",
#  '77betting.com': "'GMB'",
#  '780am.com.py': "'NEWS'",
#  '788-sb.com': "'GMB'",
#  '788365.com': "'GMB'",
#  '789poker.com': "'GMB'",
#  '789proxy.cf': "'ANON'",
#  '7al.net': "'NEWS'",
#  '7alalcasino.com': "'GMB'",
#  '7amleh.org': "'HUMR'",
#  '7anna7inno.blogspot.com': "'NEWS'",
#  '7areer.com': "'NEWS'",
#  '7bitcasino.com': "'GMB'",
#  '7bt.net': "'GMB'",
#  '7carte.com': "'GMB'",
#  '7day.news': "'NEWS'",
#  '7dorim.com': "'REL'",
#  '7epta7.com': "'GMB'",
#  '7gun.az': "'NEWS'",
#  '7iber.com': "'NEWS'",
#  '7kasino.com': "'GMB'",
#  '7kasino.org': "'GMB'",
#  '7olm.org': "'HACK', 'POLR', 'HOST', 'NEWS'",
#  '7onlinecasino.com': "'GMB'",
#  '7or.am': "'NEWS'",
#  '7palms.com': "'GMB'",
#  '7rangers.com': "'POLR'",
#  '7red.com': "'GMB'",
#  '7red.it': "'GMB'",
#  '7reels.com': "'GMB'",
#  '7riosfest.com': "'ENV'",
#  '7spclub4wins.net': "'GMB'",
#  '7spgoldclub.net': "'GMB'",
#  '7spins.com': "'GMB'",
#  '7stareco.org.tw': "'ENV'",
#  '7sultans.com': "'GMB'",
#  '7sultans.eu': "'GMB'",
#  '7sultans.me': "'GMB'",
#  '7sur7.cd': "'NEWS'",
#  '7thbe.at': "'GAME'",
#  '7tv.org': "'MISC'",
#  '7ya.ru': "'PUBH', 'XED'",
#  '8020fashionsblog.com': "'CULTR'",
#  '81.cn': "'NEWS'",
#  '852.com': "'SRCH'",
#  '855bet.com': "'GMB'",
#  '8591.com.tw': "'COMM'",
#  '881903.com': "'NEWS'",
#  '888-free-casino-games.com': "'GMB'",
#  '888-it.com': "'GMB'",
#  '888-online-casino.com': "'GMB'",
#  '888.com': "'GMB'",
#  '888.hu': "'NEWS'",
#  '888bet.com': "'GMB'",
#  '888casino-game.com': "'GMB'",
#  '888casino.com': "'GMB'",
#  '888casinoonnet.com': "'GMB'",
#  '888italia.com': "'GMB'",
#  '888ladies.com': "'GMB'",
#  '888play.com': "'GMB'",
#  '888poker.com': "'GMB'",
#  '888promos.com': "'GMB'",
#  '888sport.com': "'GMB'",
#  '888suite.com': "'GMB'",
#  '88bola.com': "'GMB'",
#  '88box.com': "'GAME'",
#  '88sportsbetting.com': "'GMB'",
#  '88square.com': "'PORN'",
#  '89.com': "'PORN'",
#  '8964museum.com': "'POLR'",
#  '8am.af': "'NEWS'",
#  '8blackclub.com': "'GMB'",
#  '8columnas.com.mx': "'NEWS'",
#  '8game08.com': "'GMB'",
#  '8kun.top': "'HOST'",
#  '8x8.com': "'COMT'",
#  '900.md': "'HOST'",
#  '901bet.com': "'GMB'",
#  '905iptv.com': "'FILE'",
#  '90bet.com': "'GMB'",
#  '90min.com': "'NEWS'",
#  '90minutos.co': "'NEWS'",
#  '911memorial.org': "'CULTR'",
#  '911truth.org': "'CULTR'",
#  '917play.com.tw': "'GAME'",
#  '92newshd.tv': "'NEWS'",
#  '972mag.com': "'NEWS'",
#  '97dounai.top': "'PORN'",
#  '98bestcasino.com': "'GMB'",
#  '99.com': "'GAME'",
#  '999.md': "'HOST'",
#  '99slotmachines.com': "'GMB'",
#  '9anime.live': "'MMED'",
#  '9binh.com': "'POLR'",
#  '9gag.com': "'GRP'",
#  '9gag.tv': "'GRP'",
#  '9nagatangkas.com': "'GMB'",
#  '9nagatangkas.pw': "'GAME'",
#  '9tv.co.il': "'NEWS'",
#  '9x49.com': "'GMB'",
#  'BalochFront.com': "'HUMR'",
#  'BalochVoice.com': "'HOST'",
#  'Easytrackghana.com': "'CULTR'",
#  'Ghana-net.com': "'CULTR'",
#  'Olybet.com': "'GMB'",
#  'ProxyBoost.net': "'ANON'",
#  'ProxyButton.com': "'ANON'",
#  'Real-ThaiPussy.com': "'PORN'",
#  'Redbet69.com': "'GMB'",
#  'SneakzorZ.com': "'ANON'",
#  'Uwants.com': "'GRP'",
#  'Vtunnel.com': "'ANON'",
#  'Vtunnel.info': "'CULTR'",
#  'WizProxy.com': "'ANON'",
#  'a-barricada.blogspot.com': "'POLR'",
#  'a-lct-labour.com': "'HUMR'",
#  'a-russia.ru': "'NEWS'",
#  'a1plus.am': "'NEWS'",
#  'a2larm.cz': "'NEWS'",
#  'a3chabe.com': "'PUBH'",
#  'a7lacasino.com': "'GMB'",
#  'a97aby.com': "'DATE'",
#  'a9p.ir': "'DATE'",
#  'aa.com.tr': "'NEWS'",
#  'aaa-autism.org': "'PUBH'",
#  'aaa-watch.com': "'COMM'",
#  'aaainc.org': "'NEWS'",
#  'aabbir.com': "'NEWS'",
#  'aabtoursandtravel.com': "'SRCH'",
#  'aaci.org.il': "'CTRL'",
#  'aacparty.com': "'POLR'",
#  'aadharcardstatusdownload.com': "'HACK'",
#  'aaf.org.hk': "'HUMR'",
#  'aafaq.org': "'NEWS'",
#  'aafiamovement.com': "'HUMR'",
#  'aahung.org': "'XED'",
#  'aaj.tv': "'NEWS'",
#  'aalinet.net': "'REL'",
#  'aamaadmiparty.org': "'POLR'",
#  'aamagazine.blogspot.com': "'REL'",
#  'aamcomaryland.com': "'COMM'",
#  'aamskiller.com': "'GMB'",
#  'aandmdiary.com': "'CULTR'",
#  'aanonimos.org.ve': "'PUBH'",
#  'aapf.org': "'HUMR'",
#  'aapnews.pk': "'NEWS'",
#  'aappb.org': "'HUMR'",
#  'aardip.org': "'HUMR'",
#  'aarinfreephoto.com': "'MMED'",
#  'aarogyasetu.gov.in': "'PUBH'",
#  'aasha.org.pk': "'HUMR'",
#  'aasoo.org': "'HUMR'",
#  'aau.edu.et': "'NEWS'",
#  'aawsat.com': "'NEWS'",
#  'aazadsamajpartyk.org': "'POLR'",
#  'abaadmena.org': "'HUMR'",
#  'abaadstudies.org': "'HUMR'",
#  'ababiil.net': "'NEWS'",
#  'abahlali.org': "'HUMR'",
#  'abakdash.com': "'POLR'",
#  'abamako.com': "'NEWS'",
#  'abante.com.ph': "'NEWS'",
#  'abbtakk.tv': "'NEWS'",
#  'abc.com.py': "'NEWS'",
#  'abc.es': "'NEWS'",
#  'abc.med.br': "'XED'",
#  'abc.net.au': "'NEWS'",
#  'abcgazetesi.com': "'NEWS'",
#  'abcislands.com': "'GMB'",
#  'abclider.com': "'PORN'",
#  'abcp.org.bo': "'POLR'",
#  'abctaxa.be': "'ENV'",
#  'abctv.com.py': "'NEWS'",
#  'abctv.me': "'FILE'",
#  'abcunderwear.com': "'PROV'",
#  'abczdrowie.pl': "'NEWS'",
#  'abdalladiery.blogspot.com': "'POLR'",
#  'abdwap2.com': "'MMED'",
#  'abedkhattar.com': "'NEWS'",
#  'abelsierramadero.com': "'CULTR'",
#  'abg.org.gt': "'ECON'",
#  'abhazia-sochi.blogspot.com': "'MILX'",
#  'abidjan.net': "'NEWS'",
#  'abidjanplus.com': "'NEWS'",
#  'abidjanshow.com': "'NEWS'",
#  'abidjantv.net': "'NEWS'",
#  'abkhazeti.ru': "'MILX'",
#  'abkhazia.org': "'MILX'",
#  'abkhaziagov.org': "'MILX'",
#  'abkhaziya.org': "'MILX'",
#  'ablyazov.info': "'POLR'",
#  'ablyazov.org': "'POLR'",
#  'abna24.com': "'HUMR'",
#  'aborcjabezgranic.pl': "'XED'",
#  'aborcyjnydreamteam.pl': "'XED'",
#  'aborduna.blogspot.com.br': "'POLR'",
#  'aborsionline.org': "'XED'",
#  'abortion-korea.org': "'XED'",
#  'abortion.eu': "'XED'",
#  'abortion.kr': "'XED'",
#  'abortionfunds.org': "'XED'",
#  'abortionnetwork.amsterdam': "'XED'",
#  'abortionno.org': "'XED'",
#  'abortionpillinfo.org': "'XED'",
#  'abortivo.org': "'XED'",
#  'aborto.com': "'XED'",
#  'abortoinfosegura.com': "'XED'",
#  'abortolegal.com.ar': "'XED'",
#  'abortonanuvem.com': "'XED'",
#  'abortoseguroec.com': "'XED'",
#  'abortoseguroecuador.com': "'XED'",
#  'abortosinbarreras.org': "'XED'",
#  'aboshreek.com': "'COMM'",
#  'about-face.org': "'XED'",
#  'about-watch.com': "'COMM'",
#  'aboutalgeria.com': "'CULTR'",
#  'aboutpixel.de': "'MMED'",
#  'aboutuganda.com': "'SRCH'",
#  'abparti.org.tr': "'POLR'",
#  'abpinfos.com': "'NEWS'",
#  'abplive.com': "'NEWS'",
#  'abpparty.org': "'POLR'",
#  'abril.com.br': "'NEWS'",
#  'abs-cbnnews.com': "'NEWS'",
#  'absdfau.blogspot.com': "'POLR'",
#  'absinth.com': "'ALDR'",
#  'absoluporn.com': "'PORN'",
#  'absolut.com': "'ALDR'",
#  'absolutelifepoker.com': "'GMB'",
#  'absolutepoker.com': "'GMB'",
#  'abstractinfluence.com': "'MMED'",
#  'abu-shreek.blogspot.com': "'POLR'",
#  'abu-yusufmalizi.blogspot.com': "'REL'",
#  'abu.org.my': "'POLR'",
#  'abubakarbukolasaraki.com': "'POLR'",
#  'abubelal1951.blogspot.com': "'HUMR'",
#  'abudhabiae.com': "'HUMR'",
#  'abufares.blogspot.com': "'POLR'",
#  'abw.gov.pl': "'GOVT'",
#  'abwabmag.com': "'NEWS'",
#  'abyssiniabet.com': "'GMB'",
#  'abzas.net': "'NEWS'",
#  'ac24.cz': "'NEWS'",
#  'acacias.org.ve': "'REL'",
#  'academia.edu': "'FILE', 'HUMR'",
#  'academia.sg': "'CULTR'",
#  'academic.ru': "'CULTR'",
#  'academicsingles.hk': "'DATE'",
#  'acafremin.org': "'ENV'",
#  'acage.org': "'NEWS'",
#  'acai.org.bo': "'HUMR'",
#  'acamff.blogspot.com': "'ENV'",
#  'acaoeducativa.org.br': "'HUMR'",
#  'acast.com': "'MMED'",
#  'acbar.org': "'HUMR'",
#  'acbcocc.org': "'REL'",
#  'accademiapierlombardo.it': "'COMM'",
#  'acces-vod.com': "'PORN'",
#  'accesoalajusticia.org': "'HUMR'",
#  'accessibleqatar.com': "'HUMR'",
#  'accessnow.org': "'HUMR'",
#  'accesstohealthfund.org': "'PUBH'",
#  'accioncampesina.com': "'HUMR'",
#  'acciondemocratica.org': "'POLR'",
#  'accionecologica.org': "'ENV'",
#  'accionpopular.org.pe': "'POLR'",
#  'accionsolidaria.info': "'PUBH'",
#  'acciontecnicasocial.com': "'PUBH'",
#  'accm.gov.mm': "'GOVT'",
#  'accord.org.za': "'ECON'",
#  'accountabilityhub.org': "'HUMR'",
#  'accraacaalumni.com': "'CULTR'",
#  'accraconsciousforever.blogspot.com': "'HOST'",
#  'accradailyphoto.blogspot.com': "'HOST'",
#  'accsi.org.ve': "'PUBH'",
#  'acecity.com': "'GMB'",
#  'aced.com': "'GMB'",
#  'acefile.co': "'FILE'",
#  'acelivecasino.com': "'GMB'",
#  'aceproject.org': "'POLR'",
#  'aceproxy.com': "'ANON'",
#  'acescasino.net': "'GMB'",
#  'acev.org': "'HUMR'",
#  'acfode.org': "'HUMR'",
#  'acfun.cn': "'MMED'",
#  'achacachi.com': "'MILX'",
#  'achahed.com': "'NEWS'",
#  'acharaa.com': "'NEWS'",
#  'achpr.org': "'HUMR'",
#  'achr.eu': "'HUMR'",
#  'achrights.org': "'HUMR'",
#  'achrip.org': "'HUMR'",
#  'achrs.org': "'HUMR'",
#  'achrweb.org': "'HUMR'",
#  'achuarperu.org': "'HUMR'",
#  'acidsurvivors.org': "'HUMR'",
#  'acidviolence.org': "'HUMR'",
#  'acij.org.ar': "'HUMR'",
#  'acikradyo.com.tr': "'NEWS'",
#  'aciprensa.com': "'REL'",
#  'aciva.net.ve': "'PUBH'",
#  'acj-ymca.org': "'REL'",
#  'ack.org.pl': "'POLR'",
#  'aclo.org.bo': "'NEWS'",
#  'acme-ug.org': "'NEWS'",
#  'acnu.org.cu': "'HUMR'",
#  'acnudh.org': "'HUMR'",
#  'acnur.org': "'HUMR'",
#  'acoana.org': "'ENV'",
#  'acodep.org.ni': "'ECON'",
#  'acofop.org': "'ENV'",
#  'acolaborarsj.org': "'REL'",
#  'acoso.online': "'HUMR'",
#  'acp.org.hk': "'REL'",
#  'acpcongo.com': "'NEWS', 'POLR'",
#  'acquisitionx.com': "'FILE'",
#  'acrehoje.com': "'NEWS'",
#  'acri.org.il': "'HUMR'",
#  'acropoliscasinos.com': "'GMB'",
#  'acrossthefelt.com': "'GMB'",
#  'acsad.org': "'ENV'",
#  'acsaladazcsalad.hu': "'LGBT'",
#  'acsol.org': "'PUBH'",
#  'act-senegal.com': "'POLR'",
#  'act.gov.au': "'PUBH'",
#  'actforthedisappeared.com': "'HUMR'",
#  'actionaid.org': "'HUMR', 'POLR'",
#  'actionaid.org.br': "'HUMR'",
#  'actionallianceng.org': "'POLR'",
#  'actionbd.net': "'MMED'",
#  'actioncitoyenne-yvetot.org': "'HUMR'",
#  'actionforbolivia.org': "'ENV'",
#  'actionpal.org.uk': "'HUMR'",
#  'actionpoker.com': "'GMB'",
#  'actiunea2012.ro': "'NEWS'",
#  'activatica.org': "'NEWS'",
#  'activeodds.com': "'GMB'",
#  'activismincrisis.com': "'POLR'",
#  'activismofeministadigital.org': "'POLR'",
#  'activists4change.blogspot.com': "'POLR'",
#  'actpalestineforum.org': "'REL'",
#  'actu-press.com': "'NEWS'",
#  'actualidad-24.com': "'NEWS'",
#  'actualidaddelperu.blogspot.com': "'NEWS'",
#  'actualidadpanamericana.com': "'NEWS'",
#  'actualite.cd': "'NEWS'",
#  'actualmd.net': "'XED'",
#  'actucameroun.com': "'NEWS'",
#  'actuel-dz.com': "'NEWS'",
#  'actume.org': "'PUBH'",
#  'actvuganda.org': "'HUMR'",
#  'actwazalendo.or.tz': "'POLR'",
#  'acwua.org': "'ENV'",
#  'adab.com': "'CULTR'",
#  'adabislami.org': "'CULTR'",
#  'adagamov.info': "'NEWS'",
#  'adakar.com': "'NEWS'",
#  'adalah.org': "'HUMR'",
#  'adalaheg.org': "'HUMR'",
#  'adaleh.info': "'COMM'",
#  'adaltimes.net': "'NEWS'",
#  'adam-boissons.fr': "'ALDR'",
#  'adambarfii.com': "'CULTR'",
#  'adamevecasino.com': "'GMB'",
#  'adaminstitute.org.il': "'HUMR'",
#  'adamir.net': "'NEWS'",
#  'adana.bel.tr': "'POLR'",
#  'adayaalam.org': "'HUMR'",
#  'adaymag.com': "'NEWS'",
#  'adb.org': "'ECON', 'IGO', 'HUMR'",
#  'adc.am': "'HOST'",
#  'adc.org.ar': "'LGBT', 'HUMR'",
#  'adcdigital.org.ar': "'HUMR'",
#  'adcoalition.org.ua': "'NEWS'",
#  'adcparty.org.ng': "'POLR'",
#  'addalinews.com': "'NEWS'",
#  'addameer.org': "'HUMR'",
#  'addictivetips.com': "'ANON'",
#  'addikt.hu': "'ALDR'",
#  'addisalliance.org': "'LGBT'",
#  'addisstandard.com': "'NEWS'",
#  'addiszeybe.com': "'NEWS'",
#  'addiyar.com': "'NEWS'",
#  'addustour.com': "'NEWS'",
#  'adelantenoticias.com': "'NEWS'",
#  'ademrights.org': "'HUMR'",
#  'aden-alhadath.info': "'NEWS'",
#  'aden-online.info': "'NEWS'",
#  'aden-post.com': "'NEWS'",
#  'adenalghad.net': "'NEWS'",
#  'adenalyoum.com': "'NEWS'",
#  'adengo.ru': "'NEWS'",
#  'adengulfnews.net': "'NEWS'",
#  'adenhost.com': "'HOST'",
#  'adenlife.net': "'NEWS'",
#  'adennews.net': "'NEWS'",
#  'adenobserver.com': "'NEWS'",
#  'adenprovince.net': "'NEWS'",
#  'adeq.or.th': "'ENV'",
#  'adesca.org.gt': "'HUMR'",
#  'adevarul.ro': "'NEWS'",
#  'adexc.net': "'FILE'",
#  'adf.ly': "'HOST', 'COMM'",
#  'adf.org.au': "'ALDR'",
#  'adguard.com': "'HOST'",
#  'adhoc-cambodia.org': "'HUMR'",
#  'adhoccambodia.org': "'HUMR'",
#  'adhrb.org': "'HUMR'",
#  'adhrrf.org': "'HUMR'",
#  'adicio.asia': "'HOST'",
#  'adictoec.com': "'CULTR'",
#  'adigitaldreamer.com': "'MMED'",
#  'adilet.kg': "'HUMR'",
#  'adilsonsantosfotografo.blogspot.com': "'POLR'",
#  'adilsoz.kz': "'HUMR'",
#  'adindex.ru': "'NEWS'",
#  'adipure11proboots.com': "'COMM'",
#  'adium.im': "'GRP'",
#  'adivasilivesmatter.com': "'NEWS'",
#  'adizero2013.com': "'COMM'",
#  'adl.org': "'REL'",
#  'adlitn.org': "'HUMR'",
#  'admarketplace.com': "'COMM'",
#  'admin-gorlovka.ru': "'NEWS'",
#  'admiralbet.com': "'GMB'",
#  'admiralmarkets.com': "'ECON'",
#  'admwing.gov.hk': "'GOVT'",
#  'adn.com.gt': "'POLR'",
#  'adncuba.com': "'NEWS'",
#  'adndigital.com.py': "'NEWS'",
#  'adnkronos.com': "'NEWS'",
#  'adnlng.info': "'NEWS'",
#  'adnradio.cl': "'NEWS'",
#  'adobe.com': "'COMM'",
#  'adomonline.com': "'NEWS'",
#  'adoptacedar.org': "'ENV'",
#  'adp.ng': "'POLR'",
#  'adpl.org.hk': "'POLR'",
#  'adpverapaz.org': "'HUMR'",
#  'adra.org': "'IGO'",
#  'adracambodia.org': "'ECON'",
#  'adrayemen.org': "'IGO'",
#  'adrianobalaguer.com': "'POLR'",
#  'adrindia.org': "'POLR'",
#  'ads.id': "'GRP'",
#  'adsfreevideos.com': "'NEWS'",
#  'adspaces.co.zw': "'ECON'",
#  'adtv.ae': "'NEWS'",
#  'adugames.com': "'GAME'",
#  'adultfriendfinder.com': "'DATE'",
#  'adultpokerparty.com': "'GMB'",
#  'adultwork.com': "'COMM'",
#  'advancewomen.org': "'HUMR'",
#  'advantagesportsbetting.com': "'GMB'",
#  'adventist.md': "'HUMR'",
#  'adventist.org': "'REL'",
#  'adventistas.org': "'REL'",
#  'advfnpoker.com': "'GMB'",
#  'advice.co.th': "'COMM'",
#  'advivo.com.br': "'ECON'",
#  'advocacy.kg': "'HUMR'",
#  'advocacy4oromia.org': "'HUMR'",
#  'advocate.com': "'LGBT', 'NEWS'",
#  ...}

# %%
data = pandas.DataFrame.from_dict(topics, orient='index', columns=['topics']).reset_index(names=['domain'])

# %%
display(data)
# Out:
#                    domain  topics
# 0          000webhost.com  'HOST'
# 1             0039bet.com   'GMB'
# 2          0039casino.com   'GMB'
# 3           0039casino.eu   'GMB'
# 4                003ms.ru  'PUBH'
# ...                   ...     ...
# 27787          zwnews.com  'NEWS'
# 27788  zwwebdirectory.com  'NEWS'
# 27789          zyzoom.net  'ANON'
# 27790          zzgays.com  'PORN'
# 27791             zzn.com  'COMT'
#
# [27792 rows x 2 columns]

# %% [markdown]
# ## Save to file

# %%
data.to_csv('Citizen-Lab-Classification.csv', index=True)
