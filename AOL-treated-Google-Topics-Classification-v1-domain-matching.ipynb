# %% [markdown]
# # Google Topics v1 Classification Domain Matching

# %%
import pandas, re, os, multiprocessing, tqdm, tldextract

# %%
# %%time
aol = pandas.read_csv('AOL-treated-unique-domains.csv',
                      low_memory=False, on_bad_lines='warn',
                      usecols=[1]).rename(columns={'0':'domain'})
# Out:
# CPU times: user 696 ms, sys: 83.4 ms, total: 779 ms
# Wall time: 777 ms

# %%
# %%time
topics = pandas.read_csv('Google-Topics-Classification-v1.txt',
                         index_col=False, low_memory=False, on_bad_lines='warn')
# Out:
# CPU times: user 5.68 ms, sys: 1.99 ms, total: 7.67 ms
# Wall time: 6.91 ms

# %%
display(aol)
# Out:
#                           domain
# 0                 martinpeak.com
# 1                      mohpa.com
# 2               museum.wa.gov.au
# 3         richardiiimuseum.co.uk
# 4           westgaappraisals.com
# ...                          ...
# 1300479            17designs.com
# 1300480                ebbro.com
# 1300481     goldenstatefence.com
# 1300482  allbabyluv.blogspot.com
# 1300483        azroadrunners.org
#
# [1300484 rows x 1 columns]

# %%
display(topics)
# Out:
#                  domain          topics
# 0        037hdmovie.com            '12'
# 1          0gomovies.sh  '12','43','45'
# 2           1.nbryb.com             '1'
# 3          10.nbryb.com       '1','243'
# 4         1000kitap.com     '100','253'
# ...                 ...             ...
# 9041             zus.pl              ''
# 9042  zvierata.bazos.sk           '289'
# 9043   zvirata.bazos.cz           '289'
# 9044         zyadda.com       '1','254'
# 9045         zyuken.net           '227'
#
# [9046 rows x 2 columns]

# %%
aol_unique = set(aol['domain'].to_list())

# %%
topics_unique = set(topics['domain'].to_list())

# %%
display(len(aol_unique.intersection(topics_unique)))
# Out:
# 1545

# %%
# %%time
size_1 = []
size_2 = []
size_3 = []
size_4 = []
size_5 = []
check = []

for case in aol_unique:
    count = len(re.findall(r'\.', case))
    if count == 0:
        size_1.append(case)
    elif count == 1:
        size_2.append(case)
    elif count == 2:
        size_3.append(case)
    elif count == 3:
        size_4.append(case)
    elif count == 4:
        size_5.append(case)
    else:
        check.append(case)

print(len(size_1),len(size_2),len(size_3),len(size_4),len(size_5),len(check))
# Out:
# 0 1194526 99442 6494 22 0
# CPU times: user 1.1 s, sys: 0 ns, total: 1.1 s
# Wall time: 1.1 s

# %%
# %%time
aol_unique_reduced = []
aol_unique_reduced.extend(size_3)
aol_unique_reduced.extend(size_4)
aol_unique_reduced.extend(size_5)
# Out:
# CPU times: user 2.15 ms, sys: 0 ns, total: 2.15 ms
# Wall time: 2.16 ms

# %%
print(len(aol_unique_reduced))
# Out:
# 105958

# %% [markdown]
# ## Multiprocessing

# %%
data1 = None
data2 = None

def init(_data1,_data2):
    global data1
    data1 = _data1
    global data2
    data2 = _data2

pool_size = multiprocessing.cpu_count() * 1

os.system('taskset -cp 0-%d %s' % (pool_size, os.getpid()))

jobs_count = pool_size * 100

n = round(len(aol_unique_reduced)/jobs_count)
l = [list(aol_unique_reduced)[i:i + n] for i in range(0, len(list(aol_unique_reduced)), n)]

def job(l):
    topics_unique = set(topics['domain'].to_list())
    full = []
    partial = {}
    for dom in l:
        if dom in topics_unique:
            full.append(dom)
        else:
            partial[dom] = []
            for case in topics_unique:
                if re.search(r'.*\.'+case, dom) != None:
                    partial[dom].append(case)
    return(full, partial)

with multiprocessing.Pool(processes=pool_size, maxtasksperchild=1, initializer=init,
                          initargs=(topics[['domain','topics']])) as pool:
    pool_outputs = list(tqdm.tqdm(pool.imap(job, l),
                                  total=sum(1 for _ in l)))
    pool.close()
    pool.join()
# Out:
# pid 1820799's current affinity list: 0-39
# pid 1820799's new affinity list: 0-39
# 100%|██████████████████| 4076/4076 [32:26<00:00,  2.09it/s]

# %%
# %%time
full_match = []
partial_match = {}
for output in pool_outputs:
    if len(output[0]) > 0:
        full_match.extend(output[0])
    for k, v in output[1].items():
        if len(v) > 0:
            partial_match[k] = v
full_match.extend(list(set(size_2).intersection(topics_unique)))
# Out:
# CPU times: user 353 ms, sys: 60.9 ms, total: 414 ms
# Wall time: 410 ms

# %%
print(len(full_match), len(partial_match))
# Out:
# 1545 1274

# %%
display(full_match)
# Out:
# ['computrabajo.com.mx',
#  'walla.co.il',
#  'indiapost.gov.in',
#  'makro.co.za',
#  'lagaceta.com.ar',
#  'mercadolibre.com.uy',
#  'google.com.sa',
#  'boticario.com.br',
#  'ciudad.com.ar',
#  'voegol.com.br',
#  'ofuxico.com.br',
#  '24h.com.vn',
#  'clicrbs.com.br',
#  'google.co.kr',
#  'indianrail.gov.in',
#  'jang.com.pk',
#  'casasbahia.com.br',
#  'hmv.co.jp',
#  'amazon.co.jp',
#  'google.com.tw',
#  'seek.com.au',
#  'mercadolibre.com.mx',
#  'google.com.hk',
#  'bunnings.com.au',
#  'jdsports.co.uk',
#  'vivastreet.co.uk',
#  'google.co.ve',
#  'google.com.my',
#  'kmart.com.au',
#  'dailymail.co.uk',
#  'dominos.co.uk',
#  'homedepot.com.mx',
#  'mercadolibre.com.ar',
#  'nationallottery.co.za',
#  'spareroom.co.uk',
#  'jbhifi.com.au',
#  'reed.co.uk',
#  'matalan.co.uk',
#  'aldi.co.uk',
#  'abc.com.py',
#  'independent.co.uk',
#  'stuff.co.nz',
#  'excelsior.com.mx',
#  'sabah.com.tr',
#  'rightmove.co.uk',
#  'consultaremedios.com.br',
#  'pravda.com.ua',
#  'fanatik.com.tr',
#  'google.co.za',
#  'metro.co.uk',
#  'caixa.gov.br',
#  'kalunga.com.br',
#  'tripadvisor.co.uk',
#  'gumtree.co.za',
#  'amazon.co.uk',
#  'honda.com.br',
#  'google.co.il',
#  'unionbankonline.co.in',
#  'matichon.co.th',
#  'google.com.br',
#  'google.co.uk',
#  'pontofrio.com.br',
#  'divyabhaskar.co.in',
#  'iceland.co.uk',
#  'vivo.com.br',
#  'express.co.uk',
#  'dantri.com.vn',
#  'dailynews.co.th',
#  'officedepot.com.mx',
#  'sunat.gob.pe',
#  'imovelweb.com.br',
#  'ntv.com.tr',
#  'lanacion.com.ar',
#  'eluniversal.com.mx',
#  'serasa.com.br',
#  'mercadolivre.com.br',
#  'itau.com.br',
#  'newsnow.co.uk',
#  'books.com.tw',
#  'tfl.gov.uk',
#  'bbc.co.uk',
#  'elpais.com.uy',
#  'bb.com.br',
#  'kanald.com.tr',
#  'currys.co.uk',
#  'google.com.tr',
#  'google.com.au',
#  'google.com.uy',
#  'wiggle.co.uk',
#  'solodeportes.com.ar',
#  'lacapital.com.ar',
#  'netvasco.com.br',
#  'diariodecuyo.com.ar',
#  'thestar.com.my',
#  'submarino.com.br',
#  'americanas.com.br',
#  'panorama.com.al',
#  'carsales.com.au',
#  'abc.net.au',
#  'manchestereveningnews.co.uk',
#  'sams.com.mx',
#  'proceso.com.mx',
#  'walmart.com.mx',
#  'thairath.co.th',
#  'ole.com.ar',
#  'google.com.mx',
#  'argos.co.uk',
#  'radios.com.br',
#  'oricon.co.jp',
#  'metoffice.gov.uk',
#  'cumhuriyet.com.tr',
#  'globe.com.ph',
#  'globes.co.il',
#  'sonhos.com.br',
#  'google.com.pk',
#  'realestate.com.au',
#  'google.com.ph',
#  'auspost.com.au',
#  'yomiuri.co.jp',
#  'oi.com.br',
#  'google.com.co',
#  'commbank.com.au',
#  'ynet.co.il',
#  'autotrader.co.za',
#  'eldeber.com.bo',
#  'ebay.co.uk',
#  'pagina12.com.ar',
#  'google.com.vn',
#  'singaporepools.com.sg',
#  'o2.co.uk',
#  'uai.com.br',
#  'hoseasons.co.uk',
#  'google.co.jp',
#  'marisa.com.br',
#  'sears.com.mx',
#  'pets4homes.co.uk',
#  'dailystar.co.uk',
#  'google.com.gt',
#  'rakuten.co.jp',
#  'correios.com.br',
#  'sodimac.com.pe',
#  'mercadolibre.com.ve',
#  'gamer.com.tw',
#  'occ.com.mx',
#  'nld.com.vn',
#  'yahoo.co.jp',
#  'preloved.co.uk',
#  'ancestry.co.uk',
#  'lovehoney.co.uk',
#  'costco.com.mx',
#  'google.com.sg',
#  'wickes.co.uk',
#  'sat.gob.mx',
#  'liverpool.com.mx',
#  'ebay.com.au',
#  'next.co.uk',
#  'sanborns.com.mx',
#  'lpga.or.jp',
#  'buscape.com.br',
#  'atv.com.tr',
#  'domain.com.au',
#  'lidl.co.uk',
#  'mirror.co.uk',
#  'maybank2u.com.my',
#  'telegraph.co.uk',
#  'google.co.nz',
#  'thetimes.co.uk',
#  '1999.co.jp',
#  'lse.co.uk',
#  'honda.co.jp',
#  'excite.co.jp',
#  'jobs.nhs.uk',
#  'thenews.com.pk',
#  'nintendo.co.jp',
#  'bigw.com.au',
#  'homebase.co.uk',
#  'google.com.pe',
#  'itmedia.co.jp',
#  'tigo.com.gt',
#  'news.com.au',
#  'jal.co.jp',
#  'trademe.co.nz',
#  'thesun.co.uk',
#  'dailyrecord.co.uk',
#  'jobstreet.com.ph',
#  'upsc.gov.in',
#  'set.or.th',
#  'mcdonalds.co.jp',
#  'showtv.com.tr',
#  'montevideo.com.uy',
#  'dmm.co.jp',
#  'unisa.ac.za',
#  'three.co.uk',
#  'google.com.ec',
#  'dogstrust.org.uk',
#  'nzherald.co.nz',
#  'autotrader.co.uk',
#  'mercadolibre.com.co',
#  'privateproperty.co.za',
#  'lojasrenner.com.br',
#  'target.com.au',
#  'sainsburys.co.uk',
#  '104.com.tw',
#  'ntv.co.jp',
#  'imss.gob.mx',
#  'google.co.in',
#  'haaretz.co.il',
#  'casadoscontos.com.br',
#  'vodafone.co.uk',
#  'milliyet.com.tr',
#  'terra.com.br',
#  'utusan.com.my',
#  'google.co.id',
#  'gumtree.com.au',
#  'bom.gov.au',
#  'uol.com.br',
#  'smh.com.au',
#  'computrabajo.com.pe',
#  'google.com.ar',
#  'bharian.com.my',
#  'bna.com.ar',
#  'maariv.co.il',
#  'hurriyet.com.tr',
#  'lotteryusa.com',
#  'delfi.lv',
#  'aljazeera.net',
#  'paultan.org',
#  'totalwine.com',
#  'libertaddigital.com',
#  'longhornsteakhouse.com',
#  'clubic.com',
#  'worldometers.info',
#  'abercrombie.com',
#  'hornbach.de',
#  'barnesandnoble.com',
#  'newegg.com',
#  'qvc.com',
#  'funimation.com',
#  'bahn.de',
#  'geocaching.com',
#  'apartments.com',
#  'gumtree.pl',
#  'housing.com',
#  'ojogo.pt',
#  'o2.pl',
#  'superdrug.com',
#  'gsmarena.com',
#  'filmaffinity.com',
#  'un.org',
#  'tsn.ca',
#  'chegg.com',
#  'tripadvisor.es',
#  'laposte.net',
#  'budsgunshop.com',
#  'clasificadosonline.com',
#  'fanfiction.net',
#  'immonet.de',
#  'jegs.com',
#  'adidas.com',
#  'otto.de',
#  'udn.com',
#  'islamweb.net',
#  'lequipe.fr',
#  'nytimes.com',
#  'google.se',
#  'postfun.com',
#  'thriftbooks.com',
#  'hollandandbarrett.com',
#  'anandabazar.com',
#  'goldprice.org',
#  'ziare.com',
#  'emol.com',
#  '6park.com',
#  'inbox.lv',
#  'vocabulary.com',
#  'xoom.com',
#  'indeed.com',
#  'skatteverket.se',
#  'rateyourmusic.com',
#  'bancodevenezuela.com',
#  'urbandictionary.com',
#  'nuskin.com',
#  'enotes.com',
#  'adac.de',
#  'findagrave.com',
#  'adultdvdempire.com',
#  'vans.com',
#  'lepoint.fr',
#  'nespresso.com',
#  'adressa.no',
#  'draugiem.lv',
#  'tripadvisor.fr',
#  'ilmattino.it',
#  'flickr.com',
#  'stern.de',
#  'menupix.com',
#  'jw.org',
#  'hrblock.com',
#  'webassign.net',
#  'abebooks.com',
#  'nfl.com',
#  'tf1.fr',
#  'ebay.it',
#  '1001fonts.com',
#  'newlook.com',
#  'livescores.com',
#  'uscis.gov',
#  'estrepublicain.fr',
#  'win2day.at',
#  'evike.com',
#  'chess.com',
#  'clips4sale.com',
#  'globo.com',
#  'msn.com',
#  'gittigidiyor.com',
#  'jcrew.com',
#  'milenio.com',
#  'sport.cz',
#  'nseindia.com',
#  'proximus.be',
#  'furaffinity.net',
#  'albayan.ae',
#  'dagbladet.no',
#  'zillow.com',
#  'livescience.com',
#  'marriott.com',
#  'sport.es',
#  'converse.com',
#  'tibia.com',
#  'marktplaats.nl',
#  'barchart.com',
#  'assoass.com',
#  'elle.com',
#  'baur.de',
#  'pap.fr',
#  'ledauphine.com',
#  'gradesaver.com',
#  'jstor.org',
#  'uline.com',
#  'victoriassecret.com',
#  'elcorteingles.pt',
#  'rockauto.com',
#  'au.com',
#  'thumbzilla.com',
#  'lapresse.ca',
#  'bluewin.ch',
#  'interpals.net',
#  'kidshealth.org',
#  'ceskatelevize.cz',
#  'larazon.es',
#  'abnamro.nl',
#  'ew.com',
#  'indiaglitz.com',
#  'breitbart.com',
#  'discover.com',
#  'blesk.cz',
#  'pagesix.com',
#  'facebook.com',
#  'tripadvisor.com',
#  'formula1.com',
#  'russianfood.com',
#  'ae.com',
#  'bbva.es',
#  'southwest.com',
#  'bible.com',
#  'minijuegos.com',
#  'losarcanos.com',
#  'kotaku.com',
#  'sii.cl',
#  'provincial.com',
#  'shmu.sk',
#  'pudelek.pl',
#  'fnac.com',
#  'akakce.com',
#  'cooperativa.cl',
#  '4shared.com',
#  'shutterfly.com',
#  'in.gr',
#  'vnexpress.net',
#  'novinky.cz',
#  'figma.com',
#  'loopnet.com',
#  'eonline.com',
#  'enterprise.com',
#  'iltalehti.fi',
#  'moddb.com',
#  'hemnet.se',
#  'lenta.ru',
#  'google.gr',
#  'blackpeoplemeet.com',
#  'rackroomshoes.com',
#  '750g.com',
#  'mercadolibre.com',
#  'nezavisne.com',
#  'nadaguides.com',
#  'cars.com',
#  'sme.sk',
#  'auto.ru',
#  'truckpaper.com',
#  'npr.org',
#  'yandex.com',
#  'fossil.com',
#  'movoto.com',
#  'michaels.com',
#  'dlsite.com',
#  'expatriates.com',
#  'smokva.com',
#  'guiainfantil.com',
#  'tweakers.net',
#  'google.at',
#  'sportsmansguide.com',
#  'esquire.com',
#  'scoresandodds.com',
#  'infojobs.net',
#  'rbc.ru',
#  'ixbt.com',
#  'skyscanner.net',
#  'mapquest.com',
#  'lanebryant.com',
#  'abc.com',
#  'latercera.com',
#  'etrailer.com',
#  'aa.com',
#  'marapets.com',
#  'euroleague.net',
#  'zumiez.com',
#  'freevideo.cz',
#  'netdoktor.de',
#  'aastocks.com',
#  'maurices.com',
#  'wetteronline.de',
#  'investopedia.com',
#  'meetic.fr',
#  'krone.at',
#  'toom.de',
#  'ancestry.ca',
#  'blocket.se',
#  'canarias7.es',
#  'thehill.com',
#  'sueddeutsche.de',
#  'surveymonkey.com',
#  'dnb.com',
#  'oracle.com',
#  'seneweb.com',
#  'tchatche.com',
#  'nj.com',
#  'banamex.com',
#  'hepsiburada.com',
#  'vrbo.com',
#  'drudgereport.com',
#  'allocine.fr',
#  'gumtree.com',
#  'nintendo.com',
#  'brainyquote.com',
#  'adultfriendfinder.com',
#  'khaleejtimes.com',
#  'erotikforum.at',
#  'marmiton.org',
#  'skysports.com',
#  'crateandbarrel.com',
#  'vodafone.it',
#  'skechers.com',
#  'sephora.com',
#  '3dnews.ru',
#  'kayak.com',
#  'ebay.ie',
#  'mitbbs.com',
#  'eatthis.com',
#  'squirt.org',
#  'europa.eu',
#  'pantip.com',
#  'dexonline.ro',
#  'laprensa.hn',
#  'vix.com',
#  'vietnamnet.vn',
#  'rte.ie',
#  'lowes.com',
#  'heraldo.es',
#  'gmx.net',
#  'epicgames.com',
#  'sallybeauty.com',
#  'justdial.com',
#  'quia.com',
#  'papajohns.com',
#  'timesofindia.com',
#  'catofashions.com',
#  'porzo.com',
#  'geo.tv',
#  'marca.com',
#  'ft.com',
#  'nairaland.com',
#  'liberation.fr',
#  'cnnturk.com',
#  'nps.gov',
#  'repubblica.it',
#  'mathrubhumi.com',
#  'fedex.com',
#  'ar15.com',
#  'tuttosport.com',
#  'sauto.cz',
#  'dickssportinggoods.com',
#  'forocoches.com',
#  'vistaprint.com',
#  'seekingalpha.com',
#  'kyero.com',
#  'insomnia.gr',
#  'redlobster.com',
#  'icicibank.com',
#  'cinepolis.com',
#  'joyclub.de',
#  'discogs.com',
#  'dr.dk',
#  'pichunter.com',
#  'lipstickalley.com',
#  'kay.com',
#  'utorrent.com',
#  'goal.com',
#  'faz.net',
#  'habitaclia.com',
#  'galottery.com',
#  'konami.com',
#  'tabelog.com',
#  'daserste.de',
#  'cinemagia.ro',
#  'yaplakal.com',
#  'cycletrader.com',
#  'coolinarika.com',
#  'centraldispatch.com',
#  'target.com',
#  'sbazar.cz',
#  'google.com',
#  'usaa.com',
#  'indianexpress.com',
#  'index.hr',
#  'viz.com',
#  'vodafone.es',
#  'blick.ch',
#  'uhaul.com',
#  'worldmarket.com',
#  'poste.it',
#  'dhnet.be',
#  'ksl.com',
#  'carfax.com',
#  'google.ae',
#  'cookpad.com',
#  'priceline.com',
#  'cabelas.com',
#  'venus.com',
#  'medicalnewstoday.com',
#  'lemonde.fr',
#  'tiava.com',
#  'yelp.com',
#  'korrespondent.net',
#  'kia.com',
#  'bridgebase.com',
#  'chilis.com',
#  'torrid.com',
#  'registrocivil.cl',
#  'cuisineaz.com',
#  'tvnet.lv',
#  'autotrader.com',
#  'fda.gov',
#  'attheraces.com',
#  'lavozdegalicia.es',
#  'mavi.com',
#  'slate.com',
#  'qvc.de',
#  'record.pt',
#  'onlinebootycall.com',
#  'scopus.com',
#  'serebii.net',
#  'semana.com',
#  'tacobell.com',
#  'egun.de',
#  'fingerhut.com',
#  'overstock.com',
#  'greetingsisland.com',
#  'autogidas.lt',
#  'linternaute.com',
#  'shabdkosh.com',
#  'jeuxvideo.com',
#  'swinglifestyle.com',
#  'usbank.com',
#  'drmartens.com',
#  'coldwellbankerhomes.com',
#  'office.com',
#  'bhaskar.com',
#  'cheaperthandirt.com',
#  'castorama.fr',
#  'espn.com',
#  'vimeo.com',
#  'xataka.com',
#  'verizon.com',
#  'gulfnews.com',
#  'malaysiakini.com',
#  'channel4.com',
#  'mandmdirect.com',
#  'hobbylobby.com',
#  'wizardingworld.com',
#  'citi.com',
#  'samsung.com',
#  'history.com',
#  'scielo.br',
#  'rtl.be',
#  'who.int',
#  'imagefap.com',
#  'explorelearning.com',
#  'morningstar.com',
#  'gocomics.com',
#  'brigitte.de',
#  'rona.ca',
#  'bathandbodyworks.com',
#  'ltdcommodities.com',
#  'alison.com',
#  'ruv.is',
#  'vegasinsider.com',
#  'audible.com',
#  'carters.com',
#  'boots.com',
#  'bungie.net',
#  'filgoal.com',
#  'google.de',
#  'altex.ro',
#  'jpcycles.com',
#  'pacsun.com',
#  'opticsplanet.com',
#  'expansion.com',
#  'kurier.at',
#  'rotter.net',
#  'gamesradar.com',
#  'euroresidentes.com',
#  'cardkingdom.com',
#  'afrointroductions.com',
#  'clarin.com',
#  'naver.com',
#  'att.net',
#  'svd.se',
#  'tournamentsoftware.com',
#  'masrawy.com',
#  'kitco.com',
#  'thepiratebay.org',
#  'legacy.com',
#  'cbc.ca',
#  'pcmag.com',
#  'rtve.es',
#  'ilsole24ore.com',
#  'chase.com',
#  'orf.at',
#  'wordplays.com',
#  'swarovski.com',
#  'sportinglife.com',
#  'contoerotico.com',
#  'mlb.com',
#  'gosection8.com',
#  'bestbuy.ca',
#  'rambler.ru',
#  'elcomercio.com',
#  'sfgate.com',
#  'dinamalar.com',
#  'cbsnews.com',
#  'ngoisao.net',
#  'jcpenney.com',
#  'xuite.net',
#  'kleinezeitung.at',
#  'motogp.com',
#  'bankofamerica.com',
#  'as.com',
#  'sony.jp',
#  'citationmachine.net',
#  'obi.de',
#  'aarp.org',
#  'consumerreports.org',
#  '24ur.com',
#  'yellowpages.com',
#  'peda.net',
#  'zdf.de',
#  'sky.com',
#  'pakwheels.com',
#  'kindgirls.com',
#  'livescore.cz',
#  'landsend.com',
#  'cricut.com',
#  'tchibo.de',
#  'rtl.de',
#  'haber7.com',
#  'forbes.com',
#  'chip.de',
#  'proxibid.com',
#  'ss.com',
#  'telegraaf.nl',
#  'pastebin.com',
#  'idnes.cz',
#  'slickdeals.net',
#  'tvgids.nl',
#  'instructables.com',
#  'multiplication.com',
#  'bunte.de',
#  'ulta.com',
#  'gazzetta.it',
#  'alhurra.com',
#  'txlottery.org',
#  'mobile01.com',
#  'wunderground.com',
#  'rds.ca',
#  'correos.es',
#  'king.com',
#  'stockcharts.com',
#  'chainreactioncycles.com',
#  'kinopoisk.ru',
#  'sportchek.ca',
#  'bloomberg.com',
#  'sciencedirect.com',
#  'torn.com',
#  'literotica.com',
#  'seloger.com',
#  'trojmiasto.pl',
#  'trovaprezzi.it',
#  'cellufun.com',
#  'elmundo.es',
#  'aol.com',
#  'usatoday.com',
#  'origo.hu',
#  'nationalgeographic.com',
#  'netspend.com',
#  'google.ru',
#  'adameve.com',
#  'discounttire.com',
#  'haberturk.com',
#  'ebird.org',
#  'pch.com',
#  'falabella.com',
#  'wp.pl',
#  'governo.it',
#  'bbc.com',
#  'ptt.cc',
#  'telcel.com',
#  'swr.de',
#  'nba.com',
#  'redfin.com',
#  'livedoor.com',
#  'amd.com',
#  'dnaindia.com',
#  'thesaurus.com',
#  'tvmovie.de',
#  'kroger.com',
#  'hdfcbank.com',
#  'yoox.com',
#  'google.lv',
#  'unip.br',
#  'worldstar.com',
#  'chinatimes.com',
#  'antenna.gr',
#  'chanel.com',
#  'neopets.com',
#  'apartmentguide.com',
#  'journeys.com',
#  'gotquestions.org',
#  'nhl.com',
#  'boxrec.com',
#  'usnews.com',
#  'nypost.com',
#  'skyscrapercity.com',
#  'adoptapet.com',
#  'ebay.ca',
#  'japanesebeauties.net',
#  'cotilleando.com',
#  'google.es',
#  'loc.gov',
#  'casadellibro.com',
#  'brainpop.com',
#  'ndr.de',
#  'healthline.com',
#  'xe.com',
#  'michigan.gov',
#  'perfectgirls.net',
#  'google.pl',
#  'gratka.pl',
#  'lastampa.it',
#  'christianbook.com',
#  'naukri.com',
#  'womenshealthmag.com',
#  'copart.com',
#  'nicematin.com',
#  'mass.gov',
#  'grubhub.com',
#  'famousbirthdays.com',
#  'unionesarda.it',
#  'sweetwater.com',
#  'hyundai.com',
#  '7sur7.be',
#  'guitarcenter.com',
#  'google.org',
#  'starfall.com',
#  'scmp.com',
#  'nvidia.com',
#  'eurosport.fr',
#  'sourceforge.net',
#  'tasteofhome.com',
#  'skybet.com',
#  'wordpress.com',
#  'diy.com',
#  'bbb.org',
#  'listindiario.com',
#  'auctionzip.com',
#  'caranddriver.com',
#  'welt.de',
#  'tvazteca.com',
#  'technopolis.bg',
#  'hs.fi',
#  'mayoclinic.org',
#  'caracoltv.com',
#  'sparknotes.com',
#  'postimees.ee',
#  'msnbc.com',
#  'jeevansathi.com',
#  'tiktok.com',
#  'kooora.com',
#  'google.it',
#  'davidsbridal.com',
#  'bt.com',
#  'ryanair.com',
#  'bestbuy.com',
#  'pnc.com',
#  'boostmobile.com',
#  'viabcp.com',
#  'google.ie',
#  'immobilienscout24.de',
#  'indiamart.com',
#  'shutterstock.com',
#  'turnitin.com',
#  'corrieredellosport.it',
#  'viamichelin.fr',
#  'fool.com',
#  'ica.se',
#  'minsal.cl',
#  'pokemon.com',
#  'petsmart.com',
#  'ingatlan.com',
#  'malavida.com',
#  'webmd.com',
#  'boe.es',
#  'google.cl',
#  'ikea.com',
#  'expressen.se',
#  'google.ca',
#  'conjuguemos.com',
#  'gunbroker.com',
#  'nouvelobs.com',
#  'bancsabadell.com',
#  'gp.se',
#  'dawn.com',
#  'nifty.com',
#  'boardgamegeek.com',
#  'biglots.com',
#  'tacklewarehouse.com',
#  'dairyqueen.com',
#  'nifty.org',
#  'movistar.es',
#  'rawstory.com',
#  'alibaba.com',
#  'tesco.com',
#  'answers.com',
#  'reverso.net',
#  'hindustantimes.com',
#  'woman.ru',
#  'napaonline.com',
#  'dailymotion.com',
#  'insider.com',
#  'experian.com',
#  'mynet.com',
#  'kirklands.com',
#  'latinamericancupid.com',
#  'saksfifthavenue.com',
#  'nyandcompany.com',
#  'nasa.gov',
#  'pnp.de',
#  'thedrive.com',
#  'summitracing.com',
#  'pracuj.pl',
#  'psychologytoday.com',
#  'cvs.com',
#  'build.com',
#  'thehindu.com',
#  'ancestry.com',
#  'gamestop.com',
#  'foodnetwork.com',
#  'nationstates.net',
#  'eluniverso.com',
#  'bigbadtoystore.com',
#  'macys.com',
#  'web.de',
#  'teacherease.com',
#  'ideal.es',
#  'flalottery.com',
#  'walmart.com',
#  'premierleague.com',
#  'csfd.cz',
#  'soccerstand.com',
#  'brownells.com',
#  'jumbo.com',
#  'cdiscount.com',
#  'capitalone.com',
#  'nowtv.com',
#  'bseindia.com',
#  'finanzen.net',
#  'wordreference.com',
#  'pandora.com',
#  'windguru.cz',
#  'ss.lv',
#  'harpersbazaar.com',
#  'microsoft.com',
#  'allrecipes.com',
#  'komputerswiat.pl',
#  'betexplorer.com',
#  'theglobeandmail.com',
#  'elespectador.com',
#  'gob.mx',
#  'antena3.com',
#  'cadenaser.com',
#  'blizzard.com',
#  'bloomingdales.com',
#  'fidelity.com',
#  'thetrainline.com',
#  'fotocasa.es',
#  'google.nl',
#  'futbolred.com',
#  'vimm.net',
#  'bt.dk',
#  'midwayusa.com',
#  'deviantart.com',
#  'foxnews.com',
#  'hm.com',
#  'urdupoint.com',
#  'iditarod.com',
#  'usps.com',
#  'mixi.jp',
#  'booking.com',
#  'milanuncios.com',
#  'pitchfork.com',
#  'caradisiac.com',
#  'tradera.com',
#  'crazyshit.com',
#  'ok.ru',
#  'info.com',
#  'kickoff.com',
#  'imvu.com',
#  'heb.com',
#  'costco.com',
#  'ducksters.com',
#  'manoramaonline.com',
#  'geneanet.org',
#  'super.cz',
#  'latimes.com',
#  'cbs.com',
#  'annunci69.it',
#  'ibm.com',
#  'di.se',
#  'irishexaminer.com',
#  'eurogamer.net',
#  'homedepot.ca',
#  'sba.gov',
#  'alarabiya.net',
#  '24horas.cl',
#  'dir.bg',
#  'rossmann.de',
#  'marocannonces.com',
#  'samsclub.com',
#  'nordstrom.com',
#  'dominos.com',
#  'yle.fi',
#  'inps.it',
#  'newsmax.com',
#  'dni.ru',
#  'hibbett.com',
#  'lacoste.com',
#  'gap.com',
#  'lampsplus.com',
#  'interia.pl',
#  'straitstimes.com',
#  'itv.com',
#  'mathplayground.com',
#  'walmart.ca',
#  'shoecarnival.com',
#  'google.sk',
#  'hsn.com',
#  'playground.ru',
#  'rxlist.com',
#  'tanea.gr',
#  'nasdaq.com',
#  'tvtropes.org',
#  'westernunion.com',
#  'worldofwarcraft.com',
#  'riverisland.com',
#  'microcenter.com',
#  'garnstudio.com',
#  'har.com',
#  'eleconomista.es',
#  'allmusic.com',
#  'publico.pt',
#  'hollisterco.com',
#  ...]

# %%
display(partial_match)
# Out:
# {'gateshead.gov.uk': ['gov.uk'],
#  'firekills.gov.uk': ['gov.uk'],
#  'kent.gov.uk': ['gov.uk'],
#  'wales.nhs.uk': ['nhs.uk'],
#  'gloucestershire.gov.uk': ['gov.uk'],
#  'odpm.gov.uk': ['gov.uk'],
#  'pjetam.gob.mx': ['gob.mx'],
#  'sentencing-guidelines.gov.uk': ['gov.uk'],
#  'doeni.gov.uk': ['gov.uk'],
#  'shrewsbury.gov.uk': ['gov.uk'],
#  'scot.nhs.uk': ['nhs.uk'],
#  'enriquegobernador.gob.mx': ['gob.mx'],
#  'childcarecareers.gov.uk': ['gov.uk'],
#  'metepec.gob.mx': ['gob.mx'],
#  'enfield.gov.uk': ['gov.uk'],
#  'lgiu.gov.uk': ['gov.uk'],
#  'curriculumonline.gov.uk': ['gov.uk'],
#  'voa.gov.uk': ['gov.uk'],
#  'munihuacho.gob.pe': ['gob.pe'],
#  'nhsweb.nhs.uk': ['nhs.uk'],
#  'ngfl.gov.uk': ['gov.uk'],
#  'peoplesnetwork.gov.uk': ['gov.uk'],
#  'guiaweb.gob.cl': ['gob.cl'],
#  'tiger.gov.uk': ['gov.uk'],
#  'mgap.gub.uy': ['gub.uy'],
#  'windsor.gov.uk': ['gov.uk'],
#  'farrier-reg.gov.uk': ['gov.uk'],
#  'civilserviceappealboard.gov.uk': ['gov.uk'],
#  'essexcc.gov.uk': ['gov.uk'],
#  'cnca.gob.mx': ['gob.mx'],
#  'meto.gov.uk': ['gov.uk'],
#  'falkirk.gov.uk': ['gov.uk'],
#  'peatlandsni.gov.uk': ['gov.uk'],
#  'ukcites.gov.uk': ['gov.uk'],
#  'south-ayrshire.gov.uk': ['gov.uk'],
#  'congresocoahuila.gob.mx': ['gob.mx'],
#  'shf.gob.mx': ['gob.mx'],
#  'ipswich.gov.uk': ['gov.uk'],
#  'somerset.nhs.uk': ['nhs.uk'],
#  'barking-dagenham.gov.uk': ['gov.uk'],
#  'southwarkpct.nhs.uk': ['nhs.uk'],
#  'empalme.gob.mx': ['gob.mx'],
#  'conanp.gob.mx': ['gob.mx'],
#  'lewisham.gov.uk': ['gov.uk'],
#  'precisa.gob.mx': ['gob.mx'],
#  'desenvolvimento.gov.br': ['gov.br'],
#  'mansfield.gov.uk': ['gov.uk'],
#  'sws-pct.nhs.uk': ['nhs.uk'],
#  'cambsmentalhealthinfo.nhs.uk': ['nhs.uk'],
#  'staffordshire.gov.uk': ['gov.uk'],
#  'ims.gov.il': ['gov.il'],
#  'doctoronline.nhs.uk': ['nhs.uk'],
#  'leeds.gov.uk': ['gov.uk'],
#  'nyrdtc.nhs.uk': ['nhs.uk'],
#  'dfid.gov.uk': ['gov.uk'],
#  'chooseandbook.nhs.uk': ['nhs.uk'],
#  'segpubtijuana.gob.mx': ['gob.mx'],
#  'worcestershire.gov.uk': ['gov.uk'],
#  'bibna.gub.uy': ['gub.uy'],
#  'sstaffs.gov.uk': ['gov.uk'],
#  'gamadero.gob.mx': ['gob.mx'],
#  'communicationsbill.gov.uk': ['gov.uk'],
#  'spelthorne.gov.uk': ['gov.uk'],
#  'mos.gov.pl': ['gov.pl'],
#  'hastings.gov.uk': ['gov.uk'],
#  'edinburgh.gov.uk': ['gov.uk'],
#  'blaby.gov.uk': ['gov.uk'],
#  'nelh.nhs.uk': ['nhs.uk'],
#  'pmo.gov.il': ['gov.il'],
#  'mre.gov.br': ['gov.br'],
#  'environment-agency.gov.uk': ['gov.uk'],
#  'lsc.gov.uk': ['gov.uk'],
#  'barrowbc.gov.uk': ['gov.uk'],
#  'refer.nhs.uk': ['nhs.uk'],
#  'bajacalifornia.gob.mx': ['gob.mx'],
#  'ynysmon.gov.uk': ['gov.uk'],
#  'islington.gov.uk': ['gov.uk'],
#  'salt.gov.uk': ['gov.uk'],
#  'chester.gov.uk': ['gov.uk'],
#  'newport.gov.uk': ['gov.uk'],
#  'northteespct.nhs.uk': ['nhs.uk'],
#  'workingintheuk.gov.uk': ['gov.uk'],
#  'crb.gov.uk': ['gov.uk'],
#  'royal.gov.uk': ['gov.uk'],
#  'stosyth.gov.uk': ['gov.uk'],
#  'senado.gov.br': ['gov.br'],
#  'northamptonshire.nhs.uk': ['nhs.uk'],
#  'shetland.gov.uk': ['gov.uk'],
#  'east-ayrshire.gov.uk': ['gov.uk'],
#  'shepway.gov.uk': ['gov.uk'],
#  'oxfordradcliffe.nhs.uk': ['nhs.uk'],
#  'esonora.gob.mx': ['gob.mx'],
#  'childtrustfund.gov.uk': ['gov.uk'],
#  'hantsfire.gov.uk': ['gov.uk'],
#  'sectur.gob.mx': ['gob.mx'],
#  'torbay.gov.uk': ['gov.uk'],
#  'nth.nhs.uk': ['nhs.uk'],
#  'staffsamb.nhs.uk': ['nhs.uk'],
#  'kingston.gov.uk': ['gov.uk'],
#  'successforall.gov.uk': ['gov.uk'],
#  'ea-transactions.gov.uk': ['gov.uk'],
#  'profeco.gob.mx': ['gob.mx'],
#  'igp.gob.pe': ['gob.pe'],
#  'student-support-saas.gov.uk': ['gov.uk'],
#  'chesterfieldbc.gov.uk': ['gov.uk'],
#  'haifa.gov.il': ['gov.il'],
#  'copelandbc.gov.uk': ['gov.uk'],
#  'addenbrookes.nhs.uk': ['nhs.uk'],
#  'mfa.gov.il': ['gov.il'],
#  'mein.gov.pl': ['gov.pl'],
#  'mintra.gob.pe': ['gob.pe'],
#  'kirklees.gov.uk': ['gov.uk'],
#  'lga.gov.uk': ['gov.uk'],
#  'nhsleadershipqualities.nhs.uk': ['nhs.uk'],
#  'cheltenham.gov.uk': ['gov.uk'],
#  'equip.nhs.uk': ['nhs.uk'],
#  'congreso.gob.pe': ['gob.pe'],
#  'bradford.nhs.uk': ['nhs.uk'],
#  'niprisonservice.gov.uk': ['gov.uk'],
#  'gos.gov.uk': ['gov.uk'],
#  'sis.gov.uk': ['gov.uk'],
#  'southportandormskirk.nhs.uk': ['nhs.uk'],
#  'forestry.gov.uk': ['gov.uk'],
#  'vosa.gov.uk': ['gov.uk'],
#  'tenampa.gob.mx': ['gob.mx'],
#  'kpk.gov.pl': ['gov.pl'],
#  'cadereytademontes.gob.mx': ['gob.mx'],
#  'cete-sonora.gob.mx': ['gob.mx'],
#  'moit.gov.il': ['gov.il'],
#  'ver.gob.mx': ['gob.mx'],
#  'caerphilly.gov.uk': ['gov.uk'],
#  'agricultura.gov.br': ['gov.br'],
#  'food.gov.uk': ['gov.uk'],
#  'e-lindsey.gov.uk': ['gov.uk'],
#  'e-local.gob.mx': ['gob.mx'],
#  'munisanbartolo.gob.pe': ['gob.pe'],
#  'sais.gov.uk': ['gov.uk'],
#  'dif.gob.mx': ['gob.mx'],
#  'pgr.gob.mx': ['gob.mx'],
#  'dsdni.gov.uk': ['gov.uk'],
#  'shropshire.gov.uk': ['gov.uk'],
#  'mimdes.gob.pe': ['gob.pe'],
#  'highwaycode.gov.uk': ['gov.uk'],
#  'sholland.gov.uk': ['gov.uk'],
#  'ordenjuridico.gob.mx': ['gob.mx'],
#  'ipd.gob.pe': ['gob.pe'],
#  'ccw.gov.uk': ['gov.uk'],
#  'abin.gov.br': ['gov.br'],
#  'mountedgcumbe.gov.uk': ['gov.uk'],
#  'sunderland.gov.uk': ['gov.uk'],
#  'edomexico.gob.mx': ['gob.mx'],
#  'munijesusmaria.gob.pe': ['gob.pe'],
#  'nationalarchives.gov.uk': ['gov.uk'],
#  'cmmc.nhs.uk': ['nhs.uk'],
#  'castlemorpeth.gov.uk': ['gov.uk'],
#  'inapam.gob.mx': ['gob.mx'],
#  'dwp.gov.uk': ['gov.uk'],
#  'cafcass.gov.uk': ['gov.uk'],
#  'msp.gub.uy': ['gub.uy'],
#  'regiontumbes.gob.pe': ['gob.pe'],
#  'cambridge.gov.uk': ['gov.uk'],
#  'dorchester-tc.gov.uk': ['gov.uk'],
#  'nrr.nhs.uk': ['nhs.uk'],
#  'dti.gov.uk': ['gov.uk'],
#  'cft.gob.mx': ['gob.mx'],
#  'rbwm.gov.uk': ['gov.uk'],
#  'aib.gov.uk': ['gov.uk'],
#  'cardiff.gov.uk': ['gov.uk'],
#  'carestandardstribunal.gov.uk': ['gov.uk'],
#  'lbbd.gov.uk': ['gov.uk'],
#  'easington.gov.uk': ['gov.uk'],
#  'manchester.gov.uk': ['gov.uk'],
#  'sheffield.gov.uk': ['gov.uk'],
#  'aberdeencity.gov.uk': ['gov.uk'],
#  'cre.gob.mx': ['gob.mx'],
#  'mmc.nhs.uk': ['nhs.uk'],
#  'preparingforemergencies.gov.uk': ['gov.uk'],
#  'institute.nhs.uk': ['nhs.uk'],
#  'northumberland.gov.uk': ['gov.uk'],
#  'ocpa.gov.uk': ['gov.uk'],
#  'southlanarkshire.gov.uk': ['gov.uk'],
#  'datasus.gov.br': ['gov.br'],
#  'vallehermoso.gob.mx': ['gob.mx'],
#  'mj.gov.br': ['gov.br'],
#  'oxon-lea.gov.uk': ['gov.uk'],
#  'cabinetoffice.gov.uk': ['gov.uk'],
#  'herefordshire.gov.uk': ['gov.uk'],
#  'christie.nhs.uk': ['nhs.uk'],
#  'sutton.gov.uk': ['gov.uk'],
#  'fife.gov.uk': ['gov.uk'],
#  'immunisation.nhs.uk': ['nhs.uk'],
#  'sfpcoahuila.gob.mx': ['gob.mx'],
#  'bfi.gov.uk': ['gov.uk'],
#  'newark-sherwooddc.gov.uk': ['gov.uk'],
#  'fsa.gov.uk': ['gov.uk'],
#  'exeter.gov.uk': ['gov.uk'],
#  'jne.gob.pe': ['gob.pe'],
#  'comitan.gob.mx': ['gob.mx'],
#  'devfire.gov.uk': ['gov.uk'],
#  'agepositive.gov.uk': ['gov.uk'],
#  'toluca.gob.mx': ['gob.mx'],
#  'congresobc.gob.mx': ['gob.mx'],
#  'banxico.gob.mx': ['gob.mx'],
#  'nwlsha.nhs.uk': ['nhs.uk'],
#  'diabetes.nhs.uk': ['nhs.uk'],
#  'doh.gov.uk': ['gov.uk'],
#  'direct.gov.uk': ['gov.uk'],
#  'coi.gov.uk': ['gov.uk'],
#  'cfe.gob.mx': ['gob.mx'],
#  'csl.gov.uk': ['gov.uk'],
#  'cna.gob.mx': ['gob.mx'],
#  'moneyclaim.gov.uk': ['gov.uk'],
#  'swlstg-tr.nhs.uk': ['nhs.uk'],
#  'tin.nhs.uk': ['nhs.uk'],
#  'nuevolaredo.gob.mx': ['gob.mx'],
#  'nurseseyesite.nhs.uk': ['nhs.uk'],
#  'norfolk.gov.uk': ['gov.uk'],
#  'stoke.gov.uk': ['gov.uk'],
#  'bradfordhospitals.nhs.uk': ['nhs.uk'],
#  'gloucester.gov.uk': ['gov.uk'],
#  'stps.gob.mx': ['gob.mx'],
#  'cjf.gob.mx': ['gob.mx'],
#  'southtees.nhs.uk': ['nhs.uk'],
#  'aguascalientes.gob.mx': ['gob.mx'],
#  'scottishexecutive.gov.uk': ['gov.uk'],
#  'dsa.gov.uk': ['gov.uk'],
#  'conida.gob.pe': ['gob.pe'],
#  'ciudadvalles.gob.mx': ['gob.mx'],
#  'parentscentre.gov.uk': ['gov.uk'],
#  'miraflores.gob.pe': ['gob.pe'],
#  'nas.gov.uk': ['gov.uk'],
#  'angus.gov.uk': ['gov.uk'],
#  'insolvency.gov.uk': ['gov.uk'],
#  'impi.gob.mx': ['gob.mx'],
#  'nogales.gob.mx': ['gob.mx'],
#  'swansea.gov.uk': ['gov.uk'],
#  'barnsley.gov.uk': ['gov.uk'],
#  'welltown.gov.uk': ['gov.uk'],
#  'dmddownload.nhs.uk': ['nhs.uk'],
#  'scotcourts.gov.uk': ['gov.uk'],
#  'scotlandspeople.gov.uk': ['gov.uk'],
#  'darlington.gov.uk': ['gov.uk'],
#  'maidstone.gov.uk': ['gov.uk'],
#  'hartlepool.gov.uk': ['gov.uk'],
#  'mazatlan.gob.mx': ['gob.mx'],
#  'northampton.gov.uk': ['gov.uk'],
#  'sanluispotosi.gob.mx': ['gob.mx'],
#  'northlincs.gov.uk': ['gov.uk'],
#  'midlothian.gov.uk': ['gov.uk'],
#  'ofmdfmni.gov.uk': ['gov.uk'],
#  'bcrp.gob.pe': ['gob.pe'],
#  'liconsa.gob.mx': ['gob.mx'],
#  'womenandequalityunit.gov.uk': ['gov.uk'],
#  'ehsni.gov.uk': ['gov.uk'],
#  'nayarit.gob.mx': ['gob.mx'],
#  'interlegis.gov.br': ['gov.br'],
#  'nwml.gov.uk': ['gov.uk'],
#  'hambleton.gov.uk': ['gov.uk'],
#  'childrenfirst.nhs.uk': ['nhs.uk'],
#  'statistics.gov.uk': ['gov.uk'],
#  'judiciary.gov.uk': ['gov.uk'],
#  'justice.gov.il': ['gov.il'],
#  'dartmoor-npa.gov.uk': ['gov.uk'],
#  'extranjeria.gob.cl': ['gob.cl'],
#  'eemspct.nhs.uk': ['nhs.uk'],
#  'wivenhoe.gov.uk': ['gov.uk'],
#  'tepic.gob.mx': ['gob.mx'],
#  'galaxy-h.gov.uk': ['gov.uk'],
#  'sindicatura.gob.mx': ['gob.mx'],
#  'sonoraturismo.gob.mx': ['gob.mx'],
#  'portspct.nhs.uk': ['nhs.uk'],
#  'nbt.nhs.uk': ['nhs.uk'],
#  'blackburn.gov.uk': ['gov.uk'],
#  'sir-benfro.gov.uk': ['gov.uk'],
#  'eastdevon-pct.nhs.uk': ['nhs.uk'],
#  'mod.gov.il': ['gov.il'],
#  'natlotcomm.gov.uk': ['gov.uk'],
#  'targetingbenefitfraud.gov.uk': ['gov.uk'],
#  'rbkc.gov.uk': ['gov.uk'],
#  'healthyliving.gov.uk': ['gov.uk'],
#  'exec.nhs.uk': ['nhs.uk'],
#  'tse.gov.br': ['gov.br'],
#  'eastsussex.gov.uk': ['gov.uk'],
#  'blaenau-gwent.gov.uk': ['gov.uk'],
#  'mof.gov.il': ['gov.il'],
#  'northwilts.gov.uk': ['gov.uk'],
#  'richmondshire.gov.uk': ['gov.uk'],
#  'hants.gov.uk': ['gov.uk'],
#  'btl.gov.il': ['gov.il'],
#  'torreon.gob.mx': ['gob.mx'],
#  'glasgow.gov.uk': ['gov.uk'],
#  'mazamitla.gob.mx': ['gob.mx'],
#  'mcga.gov.uk': ['gov.uk'],
#  'leicester.gov.uk': ['gov.uk'],
#  'number10.gov.uk': ['gov.uk'],
#  'mec.gov.br': ['gov.br'],
#  'coal.gov.uk': ['gov.uk'],
#  'mi6.gov.uk': ['gov.uk'],
#  'cancernorth.nhs.uk': ['nhs.uk'],
#  'inictel.gob.pe': ['gob.pe'],
#  'tradingstandards.gov.uk': ['gov.uk'],
#  'chrd-pct.nhs.uk': ['nhs.uk'],
#  'lnr-prescribing.nhs.uk': ['nhs.uk'],
#  'tapachula.gob.mx': ['gob.mx'],
#  'durham.gov.uk': ['gov.uk'],
#  'ukmi.nhs.uk': ['nhs.uk'],
#  'sheffield-ha.nhs.uk': ['nhs.uk'],
#  'brent.gov.uk': ['gov.uk'],
#  'bc.gov.br': ['gov.br'],
#  'nelm.nhs.uk': ['nhs.uk'],
#  'bassetlawdiabetes.nhs.uk': ['nhs.uk'],
#  'slam.nhs.uk': ['nhs.uk'],
#  'cjsonline.gov.uk': ['gov.uk'],
#  'ruh.nhs.uk': ['nhs.uk'],
#  'nmhct.nhs.uk': ['nhs.uk'],
#  'repcampdf.gob.mx': ['gob.mx'],
#  'portsmouth.gov.uk': ['gov.uk'],
#  'diariooficial.gob.mx': ['gob.mx'],
#  'uttlesford.gov.uk': ['gov.uk'],
#  'banjercito.gob.mx': ['gob.mx'],
#  'sidmouth.gov.uk': ['gov.uk'],
#  'urtip.gov.pl': ['gov.pl'],
#  'mtc.gob.pe': ['gob.pe'],
#  'bhha.nhs.uk': ['nhs.uk'],
#  'networks.nhs.uk': ['nhs.uk'],
#  'hmcourts-service.gov.uk': ['gov.uk'],
#  'poolepct.nhs.uk': ['nhs.uk'],
#  'drugs.gov.uk': ['gov.uk'],
#  'legalservices.gov.uk': ['gov.uk'],
#  'st-marys.nhs.uk': ['nhs.uk'],
#  'lambeth.gov.uk': ['gov.uk'],
#  'scarborough.gov.uk': ['gov.uk'],
#  'archiwa.gov.pl': ['gov.pl'],
#  'southbirminghampct.nhs.uk': ['nhs.uk'],
#  'paisano.gob.mx': ['gob.mx'],
#  'wiltshire.gov.uk': ['gov.uk'],
#  'connectingforhealth.nhs.uk': ['nhs.uk'],
#  'cps.gov.uk': ['gov.uk'],
#  'aguaprieta.gob.mx': ['gob.mx'],
#  'lancashire.gov.uk': ['gov.uk'],
#  'sre.gob.mx': ['gob.mx'],
#  'wyrebc.gov.uk': ['gov.uk'],
#  'turismobc.gob.mx': ['gob.mx'],
#  'cjf.gov.br': ['gov.br'],
#  'blythvalley.gov.uk': ['gov.uk'],
#  'bancomext.gob.mx': ['gob.mx'],
#  'lbwf.gov.uk': ['gov.uk'],
#  'scjn.gob.mx': ['gob.mx'],
#  'ecultura.gob.mx': ['gob.mx'],
#  'dmd.nhs.uk': ['nhs.uk'],
#  'crimereduction.gov.uk': ['gov.uk'],
#  'bexley.gov.uk': ['gov.uk'],
#  'jaralgto.gob.mx': ['gob.mx'],
#  'losreyesmichoacan.gob.mx': ['gob.mx'],
#  'durango.gob.mx': ['gob.mx'],
#  'kingstonhospital.nhs.uk': ['nhs.uk'],
#  'druginfozone.nhs.uk': ['nhs.uk'],
#  'dwi.gov.uk': ['gov.uk'],
#  'kprm.gov.pl': ['gov.pl'],
#  'carmarthenshire.gov.uk': ['gov.uk'],
#  'bedford.gov.uk': ['gov.uk'],
#  'leon.gob.mx': ['gob.mx'],
#  'cotswold.gov.uk': ['gov.uk'],
#  'rohs.gov.uk': ['gov.uk'],
#  'nhsetrent.gov.uk': ['gov.uk'],
#  'halton.gov.uk': ['gov.uk'],
#  'tanzania-online.gov.uk': ['gov.uk'],
#  'south-derbys.gov.uk': ['gov.uk'],
#  'londonpharmacy.nhs.uk': ['nhs.uk'],
#  'greenwich.gov.uk': ['gov.uk'],
#  'stj-chiapas.gob.mx': ['gob.mx'],
#  'eastherts.gov.uk': ['gov.uk'],
#  'avonamb.nhs.uk': ['nhs.uk'],
#  'bartsandthelondon.nhs.uk': ['nhs.uk'],
#  'info4local.gov.uk': ['gov.uk'],
#  'hackney.gov.uk': ['gov.uk'],
#  'helpisathand.gov.uk': ['gov.uk'],
#  'aylesburyvaledc.gov.uk': ['gov.uk'],
#  'pfe.gov.uk': ['gov.uk'],
#  'ciberhabitat.gob.mx': ['gob.mx'],
#  'royalfree.nhs.uk': ['nhs.uk'],
#  'tameside.gov.uk': ['gov.uk'],
#  'cprm.gov.br': ['gov.br'],
#  'orlc.gob.pe': ['gob.pe'],
#  'ukho.gov.uk': ['gov.uk'],
#  'uruguay.gub.uy': ['gub.uy'],
#  'library.nhs.uk': ['nhs.uk'],
#  'merseyfire.gov.uk': ['gov.uk'],
#  'bndes.gov.br': ['gov.br'],
#  'joint-reviews.gov.uk': ['gov.uk'],
#  'cgma.gov.uk': ['gov.uk'],
#  'royalsurrey.nhs.uk': ['nhs.uk'],
#  'tre-mg.gov.br': ['gov.br'],
#  'dudley.gov.uk': ['gov.uk'],
#  'midsussex.gov.uk': ['gov.uk'],
#  'iaa.gov.il': ['gov.il'],
#  'lancaster.gov.uk': ['gov.uk'],
#  'somerset.gov.uk': ['gov.uk'],
#  'cdi.gob.mx': ['gob.mx'],
#  'netregs.gov.uk': ['gov.uk'],
#  'newbury.gov.uk': ['gov.uk'],
#  'purbeck.gov.uk': ['gov.uk'],
#  'agritacna.gob.pe': ['gob.pe'],
#  'uhl-tr.nhs.uk': ['nhs.uk'],
#  'sevenoaks.gov.uk': ['gov.uk'],
#  'kettering.gov.uk': ['gov.uk'],
#  'iwight.gov.uk': ['gov.uk'],
#  'ukpa.gov.uk': ['gov.uk'],
#  'consumerdirect.gov.uk': ['gov.uk'],
#  'landreg.gov.uk': ['gov.uk'],
#  'elmbridge.gov.uk': ['gov.uk'],
#  'christchurch.gov.uk': ['gov.uk'],
#  'guysandstthomas.nhs.uk': ['nhs.uk'],
#  'g8.gov.uk': ['gov.uk'],
#  'thepensionservice.gov.uk': ['gov.uk'],
#  'papantla.gob.mx': ['gob.mx'],
#  'wrwa.gov.uk': ['gov.uk'],
#  'courtservice.gov.uk': ['gov.uk'],
#  'humanrights.gov.uk': ['gov.uk'],
#  'west-norfolk.gov.uk': ['gov.uk'],
#  'saa.gov.uk': ['gov.uk'],
#  'npsa.nhs.uk': ['nhs.uk'],
#  'gsr.gov.uk': ['gov.uk'],
#  'westlincspct.nhs.uk': ['nhs.uk'],
#  'estonia.gov.uk': ['gov.uk'],
#  'turismomichoacan.gob.mx': ['gob.mx'],
#  'modern.nhs.uk': ['nhs.uk'],
#  'shropshire-cc.gov.uk': ['gov.uk'],
#  'north-ayrshire.gov.uk': ['gov.uk'],
#  'lgib.gov.uk': ['gov.uk'],
#  'staffordclinic.nhs.uk': ['nhs.uk'],
#  'tel-aviv.gov.il': ['gov.il'],
#  'hidalgo.gob.mx': ['gob.mx'],
#  'sustainable-development.gov.uk': ['gov.uk'],
#  'whitehorsedc.gov.uk': ['gov.uk'],
#  'lfc.gob.mx': ['gob.mx'],
#  'nlg.nhs.uk': ['nhs.uk'],
#  'asambleadf.gob.mx': ['gob.mx'],
#  'e-hidalgo.gob.mx': ['gob.mx'],
#  'nhsinherts.nhs.uk': ['nhs.uk'],
#  'camara.gov.br': ['gov.br'],
#  'bedfordshire.gov.uk': ['gov.uk'],
#  'staffordshirefire.gov.uk': ['gov.uk'],
#  'guasave.gob.mx': ['gob.mx'],
#  'disclosure.gov.uk': ['gov.uk'],
#  'hmcpsi.gov.uk': ['gov.uk'],
#  'centralmanchesterpct.nhs.uk': ['nhs.uk'],
#  'trafford.nhs.uk': ['nhs.uk'],
#  'wiredforhealth.gov.uk': ['gov.uk'],
#  'dvla.gov.uk': ['gov.uk'],
#  'sedena.gob.mx': ['gob.mx'],
#  'valeofglamorgan.gov.uk': ['gov.uk'],
#  'ges.gov.uk': ['gov.uk'],
#  'warwickdc.gov.uk': ['gov.uk'],
#  'idea-knowledge.gov.uk': ['gov.uk'],
#  'aswcs.nhs.uk': ['nhs.uk'],
#  'eera.gov.uk': ['gov.uk'],
#  'westminster.gov.uk': ['gov.uk'],
#  'oxford.gov.uk': ['gov.uk'],
#  'vizcaino.gob.mx': ['gob.mx'],
#  'companieshouse.gov.uk': ['gov.uk'],
#  'aldama.gob.mx': ['gob.mx'],
#  'fco.gov.uk': ['gov.uk'],
#  'estyn.gov.uk': ['gov.uk'],
#  'emexico.gob.mx': ['gob.mx'],
#  'eastdunbarton.gov.uk': ['gov.uk'],
#  'dinama.gub.uy': ['gub.uy'],
#  'senado.gob.mx': ['gob.mx'],
#  'elbalero.gob.mx': ['gob.mx'],
#  'salford.gov.uk': ['gov.uk'],
#  'paroleboard.gov.uk': ['gov.uk'],
#  'plymouth.gov.uk': ['gov.uk'],
#  'wakefield.gov.uk': ['gov.uk'],
#  'delegacionbenitojuarez.gob.mx': ['gob.mx'],
#  'rpa.gov.uk': ['gov.uk'],
#  'reading.gov.uk': ['gov.uk'],
#  'sae.gob.mx': ['gob.mx'],
#  'northamptonshire.gov.uk': ['gov.uk'],
#  'eastdevon.gov.uk': ['gov.uk'],
#  'puertovallarta.gob.mx': ['gob.mx'],
#  'edu-negev.gov.il': ['gov.il'],
#  'newtownabbey.gov.uk': ['gov.uk'],
#  'infonavit.gob.mx': ['gob.mx'],
#  'hepc.nhs.uk': ['nhs.uk'],
#  'colerainebc.gov.uk': ['gov.uk'],
#  'northcumbriahealth.nhs.uk': ['nhs.uk'],
#  'warwickshire.gov.uk': ['gov.uk'],
#  'basingstoke.gov.uk': ['gov.uk'],
#  'derbyshire.gov.uk': ['gov.uk'],
#  'thurrock.gov.uk': ['gov.uk'],
#  'ibge.gov.br': ['gov.br'],
#  'wiltshirecds.nhs.uk': ['nhs.uk'],
#  'iea.gob.mx': ['gob.mx'],
#  'highways.gov.uk': ['gov.uk'],
#  'economia.gob.mx': ['gob.mx'],
#  'denbighshire.gov.uk': ['gov.uk'],
#  'senamhi.gob.pe': ['gob.pe'],
#  'presidencia.gob.mx': ['gob.mx'],
#  'jalisco.gob.mx': ['gob.mx'],
#  'anglesey.gov.uk': ['gov.uk'],
#  'dh.gov.uk': ['gov.uk'],
#  'turismochiapas.gob.mx': ['gob.mx'],
#  'police.gov.il': ['gov.il'],
#  'pronosticos.gob.mx': ['gob.mx'],
#  'tramitescoahuila.gob.mx': ['gob.mx'],
#  'eppingforestdc.gov.uk': ['gov.uk'],
#  'friendsofscotland.gov.uk': ['gov.uk'],
#  'atlixco.gob.mx': ['gob.mx'],
#  'localegov.gov.uk': ['gov.uk'],
#  'udskior.gov.pl': ['gov.pl'],
#  'cozumel.gob.mx': ['gob.mx'],
#  'caddie.gov.uk': ['gov.uk'],
#  'lincolnshire.gov.uk': ['gov.uk'],
#  'runnymede.gov.uk': ['gov.uk'],
#  'muniags.gob.mx': ['gob.mx'],
#  'clinicalanswers.nhs.uk': ['nhs.uk'],
#  'stalbans.gov.uk': ['gov.uk'],
#  'rbbh.nhs.uk': ['nhs.uk'],
#  'frs-scotland.gov.uk': ['gov.uk'],
#  'ukvisas.gov.uk': ['gov.uk'],
#  'avalciudadano.gob.mx': ['gob.mx'],
#  'gchq.gov.uk': ['gov.uk'],
#  'hounslow.gov.uk': ['gov.uk'],
#  'morelia.gob.mx': ['gob.mx'],
#  'emra.gov.uk': ['gov.uk'],
#  'michoacan.gob.mx': ['gob.mx'],
#  'pa.gob.mx': ['gob.mx'],
#  'cherwell-dc.gov.uk': ['gov.uk'],
#  'funcionpublica.gob.mx': ['gob.mx'],
#  'bucksfire.gov.uk': ['gov.uk'],
#  'nl.gob.mx': ['gob.mx'],
#  'rushcliffe.gov.uk': ['gov.uk'],
#  'rlbuht.nhs.uk': ['nhs.uk'],
#  'delni.gov.uk': ['gov.uk'],
#  'testvalley.gov.uk': ['gov.uk'],
#  'agri.gov.il': ['gov.il'],
#  'lgdu-wales.gov.uk': ['gov.uk'],
#  'princeofwales.gov.uk': ['gov.uk'],
#  'diputados.gob.mx': ['gob.mx'],
#  'maff.gov.uk': ['gov.uk'],
#  'thinkroadsafety.gov.uk': ['gov.uk'],
#  'hmso.gov.uk': ['gov.uk'],
#  'valuingpeople.gov.uk': ['gov.uk'],
#  'swpho.nhs.uk': ['nhs.uk'],
#  'caixaeconomicafederal.gov.br': ['gov.br'],
#  'jerez.gob.mx': ['gob.mx'],
#  'natpact.nhs.uk': ['nhs.uk'],
#  'corpoflondon.gov.uk': ['gov.uk'],
#  'hook.gov.uk': ['gov.uk'],
#  'royalmarsden.nhs.uk': ['nhs.uk'],
#  'haringey.gov.uk': ['gov.uk'],
#  'uhb.nhs.uk': ['nhs.uk'],
#  'trf1.gov.br': ['gov.br'],
#  'wales.gov.uk': ['gov.uk'],
#  'portsmouthcc.gov.uk': ['gov.uk'],
#  'huntsdc.gov.uk': ['gov.uk'],
#  'hrovirosa.gob.mx': ['gob.mx'],
#  'arun.gov.uk': ['gov.uk'],
#  'heron.nhs.uk': ['nhs.uk'],
#  'foros.gob.mx': ['gob.mx'],
#  'poland.gov.pl': ['gov.pl'],
#  'sct.gob.mx': ['gob.mx'],
#  'hdhuacho.gob.pe': ['gob.pe'],
#  'lewishampct.nhs.uk': ['nhs.uk'],
#  'ost.gov.uk': ['gov.uk'],
#  'macclesfield.gov.uk': ['gov.uk'],
#  'ipen.gob.pe': ['gob.pe'],
#  'swindon.gov.uk': ['gov.uk'],
#  'pgjebc.gob.mx': ['gob.mx'],
#  'ceop.gov.uk': ['gov.uk'],
#  'civilservice.gov.uk': ['gov.uk'],
#  'oft.gov.uk': ['gov.uk'],
#  '21stcentury.gov.br': ['gov.br'],
#  'mps.gov.pl': ['gov.pl'],
#  'mot.gov.il': ['gov.il'],
#  'munipiura.gob.pe': ['gob.pe'],
#  'siem.gob.mx': ['gob.mx'],
#  'bathnes.gov.uk': ['gov.uk'],
#  'rhondda-cynon-taff.gov.uk': ['gov.uk'],
#  'guildford.gov.uk': ['gov.uk'],
#  'solihull.gov.uk': ['gov.uk'],
#  'maldon.gov.uk': ['gov.uk'],
#  'everychildmatters.gov.uk': ['gov.uk'],
#  'directorio.gob.mx': ['gob.mx'],
#  'mf.gov.pl': ['gov.pl'],
#  'forensic.gov.uk': ['gov.uk'],
#  'broadland.gov.uk': ['gov.uk'],
#  'dinacyt.gub.uy': ['gub.uy'],
#  'bracknell-forest.gov.uk': ['gov.uk'],
#  'cymru.gov.uk': ['gov.uk'],
#  'cornwall.gov.uk': ['gov.uk'],
#  'civil-service.gov.uk': ['gov.uk'],
#  'homecare.gov.uk': ['gov.uk'],
#  'canolfanbydgwaith.gov.uk': ['gov.uk'],
#  'gmccn.nhs.uk': ['nhs.uk'],
#  'lake-district.gov.uk': ['gov.uk'],
#  'hedgehogs.gov.uk': ['gov.uk'],
#  'swindonpct.nhs.uk': ['nhs.uk'],
#  'tecate.gob.mx': ['gob.mx'],
#  'coggeshall-pc.gov.uk': ['gov.uk'],
#  'secver.gob.mx': ['gob.mx'],
#  'alg.gov.uk': ['gov.uk'],
#  'isb.nhs.uk': ['nhs.uk'],
#  'peru.gob.pe': ['gob.pe'],
#  'dtlr.gov.uk': ['gov.uk'],
#  'londonambulance.nhs.uk': ['nhs.uk'],
#  'innova.gob.mx': ['gob.mx'],
#  'openaccess.gov.uk': ['gov.uk'],
#  'coremisgm.gob.mx': ['gob.mx'],
#  'cre.gov.uk': ['gov.uk'],
#  'sbs.gob.pe': ['gob.pe'],
#  'bournemouth.gov.uk': ['gov.uk'],
#  'essex-fire.gov.uk': ['gov.uk'],
#  'minjus.gob.pe': ['gob.pe'],
#  'shaam.gov.il': ['gov.il'],
#  'waveney.gov.uk': ['gov.uk'],
#  'mawwfire.gov.uk': ['gov.uk'],
#  'liverpool.gov.uk': ['gov.uk'],
#  'jfrs.gov.br': ['gov.br'],
#  'london.nhs.uk': ['nhs.uk'],
#  'bradford.gov.uk': ['gov.uk'],
#  'sinaloa.gob.mx': ['gob.mx'],
#  'ine.gub.uy': ['gub.uy'],
#  'surreyheath.gov.uk': ['gov.uk'],
#  'proni.gov.uk': ['gov.uk'],
#  'nhsprofessionals.nhs.uk': ['nhs.uk'],
#  'nochistlan.gob.mx': ['gob.mx'],
#  'ukmicentral.nhs.uk': ['nhs.uk'],
#  'rnhrd.nhs.uk': ['nhs.uk'],
#  'cgeson.gob.mx': ['gob.mx'],
#  'london-fire.gov.uk': ['gov.uk'],
#  'harrogate.gov.uk': ['gov.uk'],
#  'oadby-wigston.gov.uk': ['gov.uk'],
#  'delicias.gob.mx': ['gob.mx'],
#  'wealden.gov.uk': ['gov.uk'],
#  'south-norfolk.gov.uk': ['gov.uk'],
#  'kgp.gov.pl': ['gov.pl'],
#  'yucatan.gob.mx': ['gob.mx'],
#  'hullcc.gov.uk': ['gov.uk'],
#  'jobcentreplus.gov.uk': ['gov.uk'],
#  'bolton.nhs.uk': ['nhs.uk'],
#  'northtynesidepct.nhs.uk': ['nhs.uk'],
#  'mpt.gov.br': ['gov.br'],
#  'ipn.gov.pl': ['gov.pl'],
#  'eyecareservices.nhs.uk': ['nhs.uk'],
#  'ubht.nhs.uk': ['nhs.uk'],
#  'oaxaca.gob.mx': ['gob.mx'],
#  'minsa.gob.pe': ['gob.pe'],
#  'gnn.gov.uk': ['gov.uk'],
#  'dardni.gov.uk': ['gov.uk'],
#  'conapo.gob.mx': ['gob.mx'],
#  'progresa.gob.mx': ['gob.mx'],
#  'contactopyme.gob.mx': ['gob.mx'],
#  'wlga.gov.uk': ['gov.uk'],
#  'policyhub.gov.uk': ['gov.uk'],
#  'ogc.gov.uk': ['gov.uk'],
#  'munimolina.gob.pe': ['gob.pe'],
#  'childsupportagency.gov.uk': ['gov.uk'],
#  'together.gov.uk': ['gov.uk'],
#  'oxfordeyehospital.nhs.uk': ['nhs.uk'],
#  'preventinghomefalls.gov.uk': ['gov.uk'],
#  'rree.gob.pe': ['gob.pe'],
#  'waverley.gov.uk': ['gov.uk'],
#  'mossad.gov.il': ['gov.il'],
#  'binape.gob.pe': ['gob.pe'],
#  'saludbc.gob.mx': ['gob.mx'],
#  'guerrero.gob.mx': ['gob.mx'],
#  'zacatecas.gob.mx': ['gob.mx'],
#  'tehila.gov.il': ['gov.il'],
#  'groni.gov.uk': ['gov.uk'],
#  'strategy.gov.uk': ['gov.uk'],
#  'ine.gob.mx': ['gob.mx'],
#  'dundeecity.gov.uk': ['gov.uk'],
#  'ncdc.gov.uk': ['gov.uk'],
#  'corby.gov.uk': ['gov.uk'],
#  'pm.gov.uk': ['gov.uk'],
#  'gro-scotland.gov.uk': ['gov.uk'],
#  'salud.gob.mx': ['gob.mx'],
#  'ashfordstpeters.nhs.uk': ['nhs.uk'],
#  'familyrecords.gov.uk': ['gov.uk'],
#  'countryside.gov.uk': ['gov.uk'],
#  'tna.gov.uk': ['gov.uk'],
#  'lisburncity.gov.uk': ['gov.uk'],
#  'audit-commission.gov.uk': ['gov.uk'],
#  'ait.gov.uk': ['gov.uk'],
#  'ico.gov.uk': ['gov.uk'],
#  'leics.gov.uk': ['gov.uk'],
#  'ets.gov.uk': ['gov.uk'],
#  'ofwat.gov.uk': ['gov.uk'],
#  'maib.gov.uk': ['gov.uk'],
#  'sthelens.gov.uk': ['gov.uk'],
#  'buckshealth.nhs.uk': ['nhs.uk'],
#  'minag.gob.pe': ['gob.pe'],
#  'cne-siar.gov.uk': ['gov.uk'],
#  'concyteg.gob.mx': ['gob.mx'],
#  'municipiochihuahua.gob.mx': ['gob.mx'],
#  'inade.gob.pe': ['gob.pe'],
#  'ruralni.gov.uk': ['gov.uk'],
#  'previdenciasocial.gov.br': ['gov.br'],
#  'scotland.gov.uk': ['gov.uk'],
#  'durhamcity.gov.uk': ['gov.uk'],
#  'adur.gov.uk': ['gov.uk'],
#  'cst.gov.uk': ['gov.uk'],
#  'woking.gov.uk': ['gov.uk'],
#  'ssp.gob.mx': ['gob.mx'],
#  'mhra.gov.uk': ['gov.uk'],
#  'blackpool-victoria.nhs.uk': ['nhs.uk'],
#  'poole.gov.uk': ['gov.uk'],
#  'glimari.gob.cl': ['gob.cl'],
#  'healthyheart.nhs.uk': ['nhs.uk'],
#  'stedmundsbury.gov.uk': ['gov.uk'],
#  'paiz.gov.pl': ['gov.pl'],
#  'ssani.gov.uk': ['gov.uk'],
#  'mcht.nhs.uk': ['nhs.uk'],
#  'cefp.gob.mx': ['gob.mx'],
#  'stroud.gov.uk': ['gov.uk'],
#  'chi.nhs.uk': ['nhs.uk'],
#  'bseinquiry.gov.uk': ['gov.uk'],
#  'minem.gob.pe': ['gob.pe'],
#  'broxtowe.gov.uk': ['gov.uk'],
#  'dspdprogramme.gov.uk': ['gov.uk'],
#  'winchester.gov.uk': ['gov.uk'],
#  'hey.nhs.uk': ['nhs.uk'],
#  'n-i.nhs.uk': ['nhs.uk'],
#  'suht.nhs.uk': ['nhs.uk'],
#  'pembrokeshire.gov.uk': ['gov.uk'],
#  'salisbury.gov.uk': ['gov.uk'],
#  'rushmoor.gov.uk': ['gov.uk'],
#  'minedu.gob.pe': ['gob.pe'],
#  'surrey.gov.uk': ['gov.uk'],
#  'cmm.gob.mx': ['gob.mx'],
#  'gobernacion.gob.mx': ['gob.mx'],
#  'newham.gov.uk': ['gov.uk'],
#  'sandwell.gov.uk': ['gov.uk'],
#  'acapulco.gob.mx': ['gob.mx'],
#  'bolton.gov.uk': ['gov.uk'],
#  'cambsphn.nhs.uk': ['nhs.uk'],
#  'nottinghamcity.gov.uk': ['gov.uk'],
#  'kentandmedway.nhs.uk': ['nhs.uk'],
#  'wirral-mbc.gov.uk': ['gov.uk'],
#  'lbhf.gov.uk': ['gov.uk'],
#  'reniec.gob.pe': ['gob.pe'],
#  'deni.gov.uk': ['gov.uk'],
#  'bprpct.nhs.uk': ['nhs.uk'],
#  'surreycc.gov.uk': ['gov.uk'],
#  'banderilla.gob.mx': ['gob.mx'],
#  'culture.gov.uk': ['gov.uk'],
#  'businesslink.gov.uk': ['gov.uk'],
#  'nics.gov.uk': ['gov.uk'],
#  'transportdirect.gov.uk': ['gov.uk'],
#  'slough.gov.uk': ['gov.uk'],
#  'pj.gob.pe': ['gob.pe'],
#  'southend.gov.uk': ['gov.uk'],
#  'sfcoahuila.gob.mx': ['gob.mx'],
#  'comms.gov.uk': ['gov.uk'],
#  'rochford.gov.uk': ['gov.uk'],
#  'gps.gov.uk': ['gov.uk'],
#  'turismo.gov.br': ['gov.br'],
#  'passport-application.gov.uk': ['gov.uk'],
#  'ofgem.gov.uk': ['gov.uk'],
#  'riobravo.gob.mx': ['gob.mx'],
#  'eastriding.gov.uk': ['gov.uk'],
#  'tre-rs.gov.br': ['gov.br'],
#  'e-mexico.gob.mx': ['gob.mx'],
#  'sra.gob.mx': ['gob.mx'],
#  'sagarpa.gob.mx': ['gob.mx'],
#  'conam.gob.pe': ['gob.pe'],
#  'nwest.nhs.uk': ['nhs.uk'],
#  'pr.gov.br': ['gov.br'],
#  'knowsley.gov.uk': ['gov.uk'],
#  'nuneaton.gov.uk': ['gov.uk'],
#  'homerton.nhs.uk': ['nhs.uk'],
#  'nwheartaudit.nhs.uk': ['nhs.uk'],
#  'cnbv.gob.mx': ['gob.mx'],
#  'previdencia.gov.br': ['gov.br'],
#  'derby.gov.uk': ['gov.uk'],
#  'acnfp.gov.uk': ['gov.uk'],
#  'chesterfield.gov.uk': ['gov.uk'],
#  'hillingdon.gov.uk': ['gov.uk'],
#  'nhsplus.nhs.uk': ['nhs.uk'],
#  'acuerdonacional.gob.pe': ['gob.pe'],
#  'rotherhampct.nhs.uk': ['nhs.uk'],
#  'chihuahua.gob.mx': ['gob.mx'],
#  'brighton-hove.gov.uk': ['gov.uk'],
#  'cancercarealliance.nhs.uk': ['nhs.uk'],
#  'charity-commission.gov.uk': ['gov.uk'],
#  'tonala.gob.mx': ['gob.mx'],
#  'dca.gov.uk': ['gov.uk'],
#  'dbh.nhs.uk': ['nhs.uk'],
#  'forestresearch.gov.uk': ['gov.uk'],
#  'dhsspsni.gov.uk': ['gov.uk'],
#  'ceara.gov.br': ['gov.br'],
#  'kingsch.nhs.uk': ['nhs.uk'],
#  'hse.gov.uk': ['gov.uk'],
#  'onpe.gob.pe': ['gob.pe'],
#  'number-10.gov.uk': ['gov.uk'],
#  'irapuato.gob.mx': ['gob.mx'],
#  'lichfield.gov.uk': ['gov.uk'],
#  'carrick.gov.uk': ['gov.uk'],
#  'xalapa.gob.mx': ['gob.mx'],
#  'mc.gov.br': ['gov.br'],
#  'sec-sonora.gob.mx': ['gob.mx'],
#  'ldh.nhs.uk': ['nhs.uk'],
#  'leedsth.nhs.uk': ['nhs.uk'],
#  'hermosillo.gob.mx': ['gob.mx'],
#  'ofsted.gov.uk': ['gov.uk'],
#  'york.gov.uk': ['gov.uk'],
#  'brasil.gov.br': ['gov.br'],
#  'hmprisonservice.gov.uk': ['gov.uk'],
#  'cambridgeshire.gov.uk': ['gov.uk'],
#  'roadsni.gov.uk': ['gov.uk'],
#  'nisra.gov.uk': ['gov.uk'],
#  'pro.gov.uk': ['gov.uk'],
#  'devon.gov.uk': ['gov.uk'],
#  'niassembly.gov.uk': ['gov.uk'],
#  'lagosdemoreno.gob.mx': ['gob.mx'],
#  'eastlothian.gov.uk': ['gov.uk'],
#  'inafed.gob.mx': ['gob.mx'],
#  'sedesol.gob.mx': ['gob.mx'],
#  'i-bio.gov.uk': ['gov.uk'],
#  'northyorks.gov.uk': ['gov.uk'],
#  'learningcurve.gov.uk': ['gov.uk'],
#  'condusef.gob.mx': ['gob.mx'],
#  'neath-porttalbot.gov.uk': ['gov.uk'],
#  'energia.gob.mx': ['gob.mx'],
#  'casaruibarbosa.gov.br': ['gov.br'],
#  'birminghamcancer.nhs.uk': ['nhs.uk'],
#  'foodstandards.gov.uk': ['gov.uk'],
#  'stevenage.gov.uk': ['gov.uk'],
#  'intellectual-property.gov.uk': ['gov.uk'],
#  'izucar.gob.mx': ['gob.mx'],
#  'wmcoe.gov.uk': ['gov.uk'],
#  'gateway.gov.uk': ['gov.uk'],
#  'allerdale.gov.uk': ['gov.uk'],
#  'stockton.gov.uk': ['gov.uk'],
#  'aberdeenshire.gov.uk': ['gov.uk'],
#  'socitm.gov.uk': ['gov.uk'],
#  'southglos.gov.uk': ['gov.uk'],
#  'calderdale-pct.nhs.uk': ['nhs.uk'],
#  'avon.nhs.uk': ['nhs.uk'],
#  'eatwell.gov.uk': ['gov.uk'],
#  'imbel.gov.br': ['gov.br'],
#  'harlowpct.nhs.uk': ['nhs.uk'],
#  'charitycommission.gov.uk': ['gov.uk'],
#  'londonprepared.gov.uk': ['gov.uk'],
#  'scotborders.gov.uk': ['gov.uk'],
#  'camden.gov.uk': ['gov.uk'],
#  'britishembassy.gov.uk': ['gov.uk'],
#  'uksport.gov.uk': ['gov.uk'],
#  'scambs.gov.uk': ['gov.uk'],
#  'hfea.gov.uk': ['gov.uk'],
#  'conaculta.gob.mx': ['gob.mx'],
#  'brentwood-council.gov.uk': ['gov.uk'],
#  'dt.gob.cl': ['gob.cl'],
#  'candinet.nhs.uk': ['nhs.uk'],
#  'glamro.gov.uk': ['gov.uk'],
#  'eastbourne.gov.uk': ['gov.uk'],
#  'tijuana.gob.mx': ['gob.mx'],
#  'surestart.gov.uk': ['gov.uk'],
#  'london.gov.uk': ['gov.uk'],
#  'highland.gov.uk': ['gov.uk'],
#  'qmc.nhs.uk': ['nhs.uk'],
#  'nhsia.nhs.uk': ['nhs.uk'],
#  'nihe.gov.uk': ['gov.uk'],
#  'mecatlan.gob.mx': ['gob.mx'],
#  'shcp.gob.mx': ['gob.mx'],
#  'homeoffice.gov.uk': ['gov.uk'],
#  'tendringdc.gov.uk': ['gov.uk'],
#  'csa.gov.uk': ['gov.uk'],
#  'altamira.gob.mx': ['gob.mx'],
#  'employmentappeals.gov.uk': ['gov.uk'],
#  'lda.gov.uk': ['gov.uk'],
#  'housingcorp.gov.uk': ['gov.uk'],
#  'rugby.gov.uk': ['gov.uk'],
#  'ros.gov.uk': ['gov.uk'],
#  'bnfc.nhs.uk': ['nhs.uk'],
#  'edomex.gob.mx': ['gob.mx'],
#  'mte.gov.br': ['gov.br'],
#  'lawcom.gov.uk': ['gov.uk'],
#  'devonline.gov.uk': ['gov.uk'],
#  'burnley.gov.uk': ['gov.uk'],
#  'newcastle.gov.uk': ['gov.uk'],
#  'merseycare.nhs.uk': ['nhs.uk'],
#  'derbyhospitals.nhs.uk': ['nhs.uk'],
#  'niprvis.gov.uk': ['gov.uk'],
#  'landregisteronline.gov.uk': ['gov.uk'],
#  'agwsha.nhs.uk': ['nhs.uk'],
#  'silicone-review.gov.uk': ['gov.uk'],
#  'wandsworth.gov.uk': ['gov.uk'],
#  'wsh.nhs.uk': ['nhs.uk'],
#  'wirral.gov.uk': ['gov.uk'],
#  'n-somerset.gov.uk': ['gov.uk'],
#  'dumgal.gov.uk': ['gov.uk'],
#  'qroo.gob.mx': ['gob.mx'],
#  'milton-keynes.gov.uk': ['gov.uk'],
#  'sepomex.gob.mx': ['gob.mx'],
#  'sag.gob.cl': ['gob.cl'],
#  'north-dorset.gov.uk': ['gov.uk'],
#  'mincetur.gob.pe': ['gob.pe'],
#  'ashfield-dc.gov.uk': ['gov.uk'],
#  'stj.gov.br': ['gov.br'],
#  'nencki.gov.pl': ['gov.pl'],
#  'cofemermir.gob.mx': ['gob.mx'],
#  'argyll-bute.gov.uk': ['gov.uk'],
#  'munisjl.gob.pe': ['gob.pe'],
#  'heart.nhs.uk': ['nhs.uk'],
#  'lincoln.gov.uk': ['gov.uk'],
#  'inmetro.gov.br': ['gov.br'],
#  'childcarelink.gov.uk': ['gov.uk'],
#  'osha.nhs.uk': ['nhs.uk'],
#  'guanajuato.gob.mx': ['gob.mx'],
#  'almg.gov.br': ['gov.br'],
#  'nhscareers.nhs.uk': ['nhs.uk'],
#  'economia-montevideo.gob.mx': ['gob.mx'],
#  'belfastcity.gov.uk': ['gov.uk'],
#  'softwarelibremorelos.gob.mx': ['gob.mx'],
#  'semarnat.gob.mx': ['gob.mx'],
#  'turismozacatecas.gob.mx': ['gob.mx'],
#  'employmentservice.gov.uk': ['gov.uk'],
#  'redbridge.gov.uk': ['gov.uk'],
#  'worthing.gov.uk': ['gov.uk'],
#  'seplade-coahuila.gob.mx': ['gob.mx'],
#  'treasury.gov.uk': ['gov.uk'],
#  'dartford.gov.uk': ['gov.uk'],
#  'iow.gov.uk': ['gov.uk'],
#  'secodaem.gob.mx': ['gob.mx'],
#  'eng-h.gov.uk': ['gov.uk'],
#  'bcu.gub.uy': ['gub.uy'],
#  'sath.nhs.uk': ['nhs.uk'],
#  'planningportal.gov.uk': ['gov.uk'],
#  'mexicocity.gob.mx': ['gob.mx'],
#  'hmrc.gov.uk': ['gov.uk'],
#  'workpermits.gov.uk': ['gov.uk'],
#  'anvisa.gov.br': ['gov.br'],
#  'oxfordshire.gov.uk': ['gov.uk'],
#  'eu2005.gov.uk': ['gov.uk'],
#  'numberten.gov.uk': ['gov.uk'],
#  'bancodemexico.gob.mx': ['gob.mx'],
#  'sefton.gov.uk': ['gov.uk'],
#  'conae.gob.mx': ['gob.mx'],
#  'ribblevalley.gov.uk': ['gov.uk'],
#  'chelmsford.gov.uk': ['gov.uk'],
#  'mmrthefacts.nhs.uk': ['nhs.uk'],
#  'screening.nhs.uk': ['nhs.uk'],
#  'tda.gov.uk': ['gov.uk'],
#  'ic.nhs.uk': ['nhs.uk'],
#  'veracruz.gob.mx': ['gob.mx'],
#  'ime.gob.mx': ['gob.mx'],
#  'worcestershirehealth.nhs.uk': ['nhs.uk'],
#  'northtyneside.gov.uk': ['gov.uk'],
#  'inmujeres.gob.mx': ['gob.mx'],
#  'fazenda.gov.br': ['gov.br'],
#  'gibraltar.gov.uk': ['gov.uk'],
#  'stockportmbc.gov.uk': ['gov.uk'],
#  'bracknellforest.gov.uk': ['gov.uk'],
#  'swbh.nhs.uk': ['nhs.uk'],
#  'canterbury.gov.uk': ['gov.uk'],
#  'coatzacoalcos.gob.mx': ['gob.mx'],
#  'inba.gob.mx': ['gob.mx'],
#  'hgc.gov.uk': ['gov.uk'],
#  'uktradeinvest.gov.uk': ['gov.uk'],
#  'gro.gov.uk': ['gov.uk'],
#  'concytec.gob.pe': ['gob.pe'],
#  'zamora.gob.mx': ['gob.mx'],
#  'informatics.nhs.uk': ['nhs.uk'],
#  'moia.gov.il': ['gov.il'],
#  'cultura.gov.br': ['gov.br'],
#  'jncc.gov.uk': ['gov.uk'],
#  'conabio.gob.mx': ['gob.mx'],
#  'bankisrael.gov.il': ['gov.il'],
#  'eastcambsandfenland-pct.nhs.uk': ['nhs.uk'],
#  'sc.gov.br': ['gov.br'],
#  'opsi.gov.uk': ['gov.uk'],
#  'shropshirefire.gov.uk': ['gov.uk'],
#  'britishhighcommission.gov.uk': ['gov.uk'],
#  'rio.gov.pl': ['gov.pl'],
#  'inspiringlearningforall.gov.uk': ['gov.uk'],
#  'mi5.gov.uk': ['gov.uk'],
#  'redcar-cleveland.gov.uk': ['gov.uk'],
#  'tourism.gov.il': ['gov.il'],
#  'met-office.gov.uk': ['gov.uk'],
#  'cbs.gov.il': ['gov.il'],
#  'presidencia.gub.uy': ['gub.uy'],
#  'radiobras.gov.br': ['gov.br'],
#  'congresojal.gob.mx': ['gob.mx'],
#  'southcambs-pct.nhs.uk': ['nhs.uk'],
#  'info.gov.il': ['gov.il'],
#  'peterborough.gov.uk': ['gov.uk'],
#  'chichester.gov.uk': ['gov.uk'],
#  'essalud.gob.pe': ['gob.pe'],
#  'bromleyhospitals.nhs.uk': ['nhs.uk'],
#  'nelincs.gov.uk': ['gov.uk'],
#  'passport.gov.uk': ['gov.uk'],
#  'indepa.gob.pe': ['gob.pe'],
#  'lg-employers.gov.uk': ['gov.uk'],
#  'teachernet.gov.uk': ['gov.uk'],
#  'educacionchiapas.gob.mx': ['gob.mx'],
#  'pgi.gov.pl': ['gov.pl'],
#  'cookstown.gov.uk': ['gov.uk'],
#  'ibama.gov.br': ['gov.br'],
#  ...}

# %%
# %%time
for k, v in partial_match.items():
    if len(v) != 1:
        print(v)
# Out:
# CPU times: user 0 ns, sys: 327 µs, total: 327 µs
# Wall time: 337 µs

# %%
# %%time
d = {'domain': [], 'match': [], 'topics': []}
for case in full_match:
    d['domain'].append(case)
    d['match'].append(case)
    d['topics'].append(topics[topics['domain'] == case]['topics'].to_list()[0])
for k, v in partial_match.items():
    d['domain'].append(k)
    d['match'].append(v[0])
    d['topics'].append(topics[topics['domain'] == case]['topics'].to_list()[0])
# Out:
# CPU times: user 2.65 s, sys: 0 ns, total: 2.65 s
# Wall time: 2.63 s

# %%
display(d)
# Out:
# {'domain': ['computrabajo.com.mx',
#   'walla.co.il',
#   'indiapost.gov.in',
#   'makro.co.za',
#   'lagaceta.com.ar',
#   'mercadolibre.com.uy',
#   'google.com.sa',
#   'boticario.com.br',
#   'ciudad.com.ar',
#   'voegol.com.br',
#   'ofuxico.com.br',
#   '24h.com.vn',
#   'clicrbs.com.br',
#   'google.co.kr',
#   'indianrail.gov.in',
#   'jang.com.pk',
#   'casasbahia.com.br',
#   'hmv.co.jp',
#   'amazon.co.jp',
#   'google.com.tw',
#   'seek.com.au',
#   'mercadolibre.com.mx',
#   'google.com.hk',
#   'bunnings.com.au',
#   'jdsports.co.uk',
#   'vivastreet.co.uk',
#   'google.co.ve',
#   'google.com.my',
#   'kmart.com.au',
#   'dailymail.co.uk',
#   'dominos.co.uk',
#   'homedepot.com.mx',
#   'mercadolibre.com.ar',
#   'nationallottery.co.za',
#   'spareroom.co.uk',
#   'jbhifi.com.au',
#   'reed.co.uk',
#   'matalan.co.uk',
#   'aldi.co.uk',
#   'abc.com.py',
#   'independent.co.uk',
#   'stuff.co.nz',
#   'excelsior.com.mx',
#   'sabah.com.tr',
#   'rightmove.co.uk',
#   'consultaremedios.com.br',
#   'pravda.com.ua',
#   'fanatik.com.tr',
#   'google.co.za',
#   'metro.co.uk',
#   'caixa.gov.br',
#   'kalunga.com.br',
#   'tripadvisor.co.uk',
#   'gumtree.co.za',
#   'amazon.co.uk',
#   'honda.com.br',
#   'google.co.il',
#   'unionbankonline.co.in',
#   'matichon.co.th',
#   'google.com.br',
#   'google.co.uk',
#   'pontofrio.com.br',
#   'divyabhaskar.co.in',
#   'iceland.co.uk',
#   'vivo.com.br',
#   'express.co.uk',
#   'dantri.com.vn',
#   'dailynews.co.th',
#   'officedepot.com.mx',
#   'sunat.gob.pe',
#   'imovelweb.com.br',
#   'ntv.com.tr',
#   'lanacion.com.ar',
#   'eluniversal.com.mx',
#   'serasa.com.br',
#   'mercadolivre.com.br',
#   'itau.com.br',
#   'newsnow.co.uk',
#   'books.com.tw',
#   'tfl.gov.uk',
#   'bbc.co.uk',
#   'elpais.com.uy',
#   'bb.com.br',
#   'kanald.com.tr',
#   'currys.co.uk',
#   'google.com.tr',
#   'google.com.au',
#   'google.com.uy',
#   'wiggle.co.uk',
#   'solodeportes.com.ar',
#   'lacapital.com.ar',
#   'netvasco.com.br',
#   'diariodecuyo.com.ar',
#   'thestar.com.my',
#   'submarino.com.br',
#   'americanas.com.br',
#   'panorama.com.al',
#   'carsales.com.au',
#   'abc.net.au',
#   'manchestereveningnews.co.uk',
#   'sams.com.mx',
#   'proceso.com.mx',
#   'walmart.com.mx',
#   'thairath.co.th',
#   'ole.com.ar',
#   'google.com.mx',
#   'argos.co.uk',
#   'radios.com.br',
#   'oricon.co.jp',
#   'metoffice.gov.uk',
#   'cumhuriyet.com.tr',
#   'globe.com.ph',
#   'globes.co.il',
#   'sonhos.com.br',
#   'google.com.pk',
#   'realestate.com.au',
#   'google.com.ph',
#   'auspost.com.au',
#   'yomiuri.co.jp',
#   'oi.com.br',
#   'google.com.co',
#   'commbank.com.au',
#   'ynet.co.il',
#   'autotrader.co.za',
#   'eldeber.com.bo',
#   'ebay.co.uk',
#   'pagina12.com.ar',
#   'google.com.vn',
#   'singaporepools.com.sg',
#   'o2.co.uk',
#   'uai.com.br',
#   'hoseasons.co.uk',
#   'google.co.jp',
#   'marisa.com.br',
#   'sears.com.mx',
#   'pets4homes.co.uk',
#   'dailystar.co.uk',
#   'google.com.gt',
#   'rakuten.co.jp',
#   'correios.com.br',
#   'sodimac.com.pe',
#   'mercadolibre.com.ve',
#   'gamer.com.tw',
#   'occ.com.mx',
#   'nld.com.vn',
#   'yahoo.co.jp',
#   'preloved.co.uk',
#   'ancestry.co.uk',
#   'lovehoney.co.uk',
#   'costco.com.mx',
#   'google.com.sg',
#   'wickes.co.uk',
#   'sat.gob.mx',
#   'liverpool.com.mx',
#   'ebay.com.au',
#   'next.co.uk',
#   'sanborns.com.mx',
#   'lpga.or.jp',
#   'buscape.com.br',
#   'atv.com.tr',
#   'domain.com.au',
#   'lidl.co.uk',
#   'mirror.co.uk',
#   'maybank2u.com.my',
#   'telegraph.co.uk',
#   'google.co.nz',
#   'thetimes.co.uk',
#   '1999.co.jp',
#   'lse.co.uk',
#   'honda.co.jp',
#   'excite.co.jp',
#   'jobs.nhs.uk',
#   'thenews.com.pk',
#   'nintendo.co.jp',
#   'bigw.com.au',
#   'homebase.co.uk',
#   'google.com.pe',
#   'itmedia.co.jp',
#   'tigo.com.gt',
#   'news.com.au',
#   'jal.co.jp',
#   'trademe.co.nz',
#   'thesun.co.uk',
#   'dailyrecord.co.uk',
#   'jobstreet.com.ph',
#   'upsc.gov.in',
#   'set.or.th',
#   'mcdonalds.co.jp',
#   'showtv.com.tr',
#   'montevideo.com.uy',
#   'dmm.co.jp',
#   'unisa.ac.za',
#   'three.co.uk',
#   'google.com.ec',
#   'dogstrust.org.uk',
#   'nzherald.co.nz',
#   'autotrader.co.uk',
#   'mercadolibre.com.co',
#   'privateproperty.co.za',
#   'lojasrenner.com.br',
#   'target.com.au',
#   'sainsburys.co.uk',
#   '104.com.tw',
#   'ntv.co.jp',
#   'imss.gob.mx',
#   'google.co.in',
#   'haaretz.co.il',
#   'casadoscontos.com.br',
#   'vodafone.co.uk',
#   'milliyet.com.tr',
#   'terra.com.br',
#   'utusan.com.my',
#   'google.co.id',
#   'gumtree.com.au',
#   'bom.gov.au',
#   'uol.com.br',
#   'smh.com.au',
#   'computrabajo.com.pe',
#   'google.com.ar',
#   'bharian.com.my',
#   'bna.com.ar',
#   'maariv.co.il',
#   'hurriyet.com.tr',
#   'lotteryusa.com',
#   'delfi.lv',
#   'aljazeera.net',
#   'paultan.org',
#   'totalwine.com',
#   'libertaddigital.com',
#   'longhornsteakhouse.com',
#   'clubic.com',
#   'worldometers.info',
#   'abercrombie.com',
#   'hornbach.de',
#   'barnesandnoble.com',
#   'newegg.com',
#   'qvc.com',
#   'funimation.com',
#   'bahn.de',
#   'geocaching.com',
#   'apartments.com',
#   'gumtree.pl',
#   'housing.com',
#   'ojogo.pt',
#   'o2.pl',
#   'superdrug.com',
#   'gsmarena.com',
#   'filmaffinity.com',
#   'un.org',
#   'tsn.ca',
#   'chegg.com',
#   'tripadvisor.es',
#   'laposte.net',
#   'budsgunshop.com',
#   'clasificadosonline.com',
#   'fanfiction.net',
#   'immonet.de',
#   'jegs.com',
#   'adidas.com',
#   'otto.de',
#   'udn.com',
#   'islamweb.net',
#   'lequipe.fr',
#   'nytimes.com',
#   'google.se',
#   'postfun.com',
#   'thriftbooks.com',
#   'hollandandbarrett.com',
#   'anandabazar.com',
#   'goldprice.org',
#   'ziare.com',
#   'emol.com',
#   '6park.com',
#   'inbox.lv',
#   'vocabulary.com',
#   'xoom.com',
#   'indeed.com',
#   'skatteverket.se',
#   'rateyourmusic.com',
#   'bancodevenezuela.com',
#   'urbandictionary.com',
#   'nuskin.com',
#   'enotes.com',
#   'adac.de',
#   'findagrave.com',
#   'adultdvdempire.com',
#   'vans.com',
#   'lepoint.fr',
#   'nespresso.com',
#   'adressa.no',
#   'draugiem.lv',
#   'tripadvisor.fr',
#   'ilmattino.it',
#   'flickr.com',
#   'stern.de',
#   'menupix.com',
#   'jw.org',
#   'hrblock.com',
#   'webassign.net',
#   'abebooks.com',
#   'nfl.com',
#   'tf1.fr',
#   'ebay.it',
#   '1001fonts.com',
#   'newlook.com',
#   'livescores.com',
#   'uscis.gov',
#   'estrepublicain.fr',
#   'win2day.at',
#   'evike.com',
#   'chess.com',
#   'clips4sale.com',
#   'globo.com',
#   'msn.com',
#   'gittigidiyor.com',
#   'jcrew.com',
#   'milenio.com',
#   'sport.cz',
#   'nseindia.com',
#   'proximus.be',
#   'furaffinity.net',
#   'albayan.ae',
#   'dagbladet.no',
#   'zillow.com',
#   'livescience.com',
#   'marriott.com',
#   'sport.es',
#   'converse.com',
#   'tibia.com',
#   'marktplaats.nl',
#   'barchart.com',
#   'assoass.com',
#   'elle.com',
#   'baur.de',
#   'pap.fr',
#   'ledauphine.com',
#   'gradesaver.com',
#   'jstor.org',
#   'uline.com',
#   'victoriassecret.com',
#   'elcorteingles.pt',
#   'rockauto.com',
#   'au.com',
#   'thumbzilla.com',
#   'lapresse.ca',
#   'bluewin.ch',
#   'interpals.net',
#   'kidshealth.org',
#   'ceskatelevize.cz',
#   'larazon.es',
#   'abnamro.nl',
#   'ew.com',
#   'indiaglitz.com',
#   'breitbart.com',
#   'discover.com',
#   'blesk.cz',
#   'pagesix.com',
#   'facebook.com',
#   'tripadvisor.com',
#   'formula1.com',
#   'russianfood.com',
#   'ae.com',
#   'bbva.es',
#   'southwest.com',
#   'bible.com',
#   'minijuegos.com',
#   'losarcanos.com',
#   'kotaku.com',
#   'sii.cl',
#   'provincial.com',
#   'shmu.sk',
#   'pudelek.pl',
#   'fnac.com',
#   'akakce.com',
#   'cooperativa.cl',
#   '4shared.com',
#   'shutterfly.com',
#   'in.gr',
#   'vnexpress.net',
#   'novinky.cz',
#   'figma.com',
#   'loopnet.com',
#   'eonline.com',
#   'enterprise.com',
#   'iltalehti.fi',
#   'moddb.com',
#   'hemnet.se',
#   'lenta.ru',
#   'google.gr',
#   'blackpeoplemeet.com',
#   'rackroomshoes.com',
#   '750g.com',
#   'mercadolibre.com',
#   'nezavisne.com',
#   'nadaguides.com',
#   'cars.com',
#   'sme.sk',
#   'auto.ru',
#   'truckpaper.com',
#   'npr.org',
#   'yandex.com',
#   'fossil.com',
#   'movoto.com',
#   'michaels.com',
#   'dlsite.com',
#   'expatriates.com',
#   'smokva.com',
#   'guiainfantil.com',
#   'tweakers.net',
#   'google.at',
#   'sportsmansguide.com',
#   'esquire.com',
#   'scoresandodds.com',
#   'infojobs.net',
#   'rbc.ru',
#   'ixbt.com',
#   'skyscanner.net',
#   'mapquest.com',
#   'lanebryant.com',
#   'abc.com',
#   'latercera.com',
#   'etrailer.com',
#   'aa.com',
#   'marapets.com',
#   'euroleague.net',
#   'zumiez.com',
#   'freevideo.cz',
#   'netdoktor.de',
#   'aastocks.com',
#   'maurices.com',
#   'wetteronline.de',
#   'investopedia.com',
#   'meetic.fr',
#   'krone.at',
#   'toom.de',
#   'ancestry.ca',
#   'blocket.se',
#   'canarias7.es',
#   'thehill.com',
#   'sueddeutsche.de',
#   'surveymonkey.com',
#   'dnb.com',
#   'oracle.com',
#   'seneweb.com',
#   'tchatche.com',
#   'nj.com',
#   'banamex.com',
#   'hepsiburada.com',
#   'vrbo.com',
#   'drudgereport.com',
#   'allocine.fr',
#   'gumtree.com',
#   'nintendo.com',
#   'brainyquote.com',
#   'adultfriendfinder.com',
#   'khaleejtimes.com',
#   'erotikforum.at',
#   'marmiton.org',
#   'skysports.com',
#   'crateandbarrel.com',
#   'vodafone.it',
#   'skechers.com',
#   'sephora.com',
#   '3dnews.ru',
#   'kayak.com',
#   'ebay.ie',
#   'mitbbs.com',
#   'eatthis.com',
#   'squirt.org',
#   'europa.eu',
#   'pantip.com',
#   'dexonline.ro',
#   'laprensa.hn',
#   'vix.com',
#   'vietnamnet.vn',
#   'rte.ie',
#   'lowes.com',
#   'heraldo.es',
#   'gmx.net',
#   'epicgames.com',
#   'sallybeauty.com',
#   'justdial.com',
#   'quia.com',
#   'papajohns.com',
#   'timesofindia.com',
#   'catofashions.com',
#   'porzo.com',
#   'geo.tv',
#   'marca.com',
#   'ft.com',
#   'nairaland.com',
#   'liberation.fr',
#   'cnnturk.com',
#   'nps.gov',
#   'repubblica.it',
#   'mathrubhumi.com',
#   'fedex.com',
#   'ar15.com',
#   'tuttosport.com',
#   'sauto.cz',
#   'dickssportinggoods.com',
#   'forocoches.com',
#   'vistaprint.com',
#   'seekingalpha.com',
#   'kyero.com',
#   'insomnia.gr',
#   'redlobster.com',
#   'icicibank.com',
#   'cinepolis.com',
#   'joyclub.de',
#   'discogs.com',
#   'dr.dk',
#   'pichunter.com',
#   'lipstickalley.com',
#   'kay.com',
#   'utorrent.com',
#   'goal.com',
#   'faz.net',
#   'habitaclia.com',
#   'galottery.com',
#   'konami.com',
#   'tabelog.com',
#   'daserste.de',
#   'cinemagia.ro',
#   'yaplakal.com',
#   'cycletrader.com',
#   'coolinarika.com',
#   'centraldispatch.com',
#   'target.com',
#   'sbazar.cz',
#   'google.com',
#   'usaa.com',
#   'indianexpress.com',
#   'index.hr',
#   'viz.com',
#   'vodafone.es',
#   'blick.ch',
#   'uhaul.com',
#   'worldmarket.com',
#   'poste.it',
#   'dhnet.be',
#   'ksl.com',
#   'carfax.com',
#   'google.ae',
#   'cookpad.com',
#   'priceline.com',
#   'cabelas.com',
#   'venus.com',
#   'medicalnewstoday.com',
#   'lemonde.fr',
#   'tiava.com',
#   'yelp.com',
#   'korrespondent.net',
#   'kia.com',
#   'bridgebase.com',
#   'chilis.com',
#   'torrid.com',
#   'registrocivil.cl',
#   'cuisineaz.com',
#   'tvnet.lv',
#   'autotrader.com',
#   'fda.gov',
#   'attheraces.com',
#   'lavozdegalicia.es',
#   'mavi.com',
#   'slate.com',
#   'qvc.de',
#   'record.pt',
#   'onlinebootycall.com',
#   'scopus.com',
#   'serebii.net',
#   'semana.com',
#   'tacobell.com',
#   'egun.de',
#   'fingerhut.com',
#   'overstock.com',
#   'greetingsisland.com',
#   'autogidas.lt',
#   'linternaute.com',
#   'shabdkosh.com',
#   'jeuxvideo.com',
#   'swinglifestyle.com',
#   'usbank.com',
#   'drmartens.com',
#   'coldwellbankerhomes.com',
#   'office.com',
#   'bhaskar.com',
#   'cheaperthandirt.com',
#   'castorama.fr',
#   'espn.com',
#   'vimeo.com',
#   'xataka.com',
#   'verizon.com',
#   'gulfnews.com',
#   'malaysiakini.com',
#   'channel4.com',
#   'mandmdirect.com',
#   'hobbylobby.com',
#   'wizardingworld.com',
#   'citi.com',
#   'samsung.com',
#   'history.com',
#   'scielo.br',
#   'rtl.be',
#   'who.int',
#   'imagefap.com',
#   'explorelearning.com',
#   'morningstar.com',
#   'gocomics.com',
#   'brigitte.de',
#   'rona.ca',
#   'bathandbodyworks.com',
#   'ltdcommodities.com',
#   'alison.com',
#   'ruv.is',
#   'vegasinsider.com',
#   'audible.com',
#   'carters.com',
#   'boots.com',
#   'bungie.net',
#   'filgoal.com',
#   'google.de',
#   'altex.ro',
#   'jpcycles.com',
#   'pacsun.com',
#   'opticsplanet.com',
#   'expansion.com',
#   'kurier.at',
#   'rotter.net',
#   'gamesradar.com',
#   'euroresidentes.com',
#   'cardkingdom.com',
#   'afrointroductions.com',
#   'clarin.com',
#   'naver.com',
#   'att.net',
#   'svd.se',
#   'tournamentsoftware.com',
#   'masrawy.com',
#   'kitco.com',
#   'thepiratebay.org',
#   'legacy.com',
#   'cbc.ca',
#   'pcmag.com',
#   'rtve.es',
#   'ilsole24ore.com',
#   'chase.com',
#   'orf.at',
#   'wordplays.com',
#   'swarovski.com',
#   'sportinglife.com',
#   'contoerotico.com',
#   'mlb.com',
#   'gosection8.com',
#   'bestbuy.ca',
#   'rambler.ru',
#   'elcomercio.com',
#   'sfgate.com',
#   'dinamalar.com',
#   'cbsnews.com',
#   'ngoisao.net',
#   'jcpenney.com',
#   'xuite.net',
#   'kleinezeitung.at',
#   'motogp.com',
#   'bankofamerica.com',
#   'as.com',
#   'sony.jp',
#   'citationmachine.net',
#   'obi.de',
#   'aarp.org',
#   'consumerreports.org',
#   '24ur.com',
#   'yellowpages.com',
#   'peda.net',
#   'zdf.de',
#   'sky.com',
#   'pakwheels.com',
#   'kindgirls.com',
#   'livescore.cz',
#   'landsend.com',
#   'cricut.com',
#   'tchibo.de',
#   'rtl.de',
#   'haber7.com',
#   'forbes.com',
#   'chip.de',
#   'proxibid.com',
#   'ss.com',
#   'telegraaf.nl',
#   'pastebin.com',
#   'idnes.cz',
#   'slickdeals.net',
#   'tvgids.nl',
#   'instructables.com',
#   'multiplication.com',
#   'bunte.de',
#   'ulta.com',
#   'gazzetta.it',
#   'alhurra.com',
#   'txlottery.org',
#   'mobile01.com',
#   'wunderground.com',
#   'rds.ca',
#   'correos.es',
#   'king.com',
#   'stockcharts.com',
#   'chainreactioncycles.com',
#   'kinopoisk.ru',
#   'sportchek.ca',
#   'bloomberg.com',
#   'sciencedirect.com',
#   'torn.com',
#   'literotica.com',
#   'seloger.com',
#   'trojmiasto.pl',
#   'trovaprezzi.it',
#   'cellufun.com',
#   'elmundo.es',
#   'aol.com',
#   'usatoday.com',
#   'origo.hu',
#   'nationalgeographic.com',
#   'netspend.com',
#   'google.ru',
#   'adameve.com',
#   'discounttire.com',
#   'haberturk.com',
#   'ebird.org',
#   'pch.com',
#   'falabella.com',
#   'wp.pl',
#   'governo.it',
#   'bbc.com',
#   'ptt.cc',
#   'telcel.com',
#   'swr.de',
#   'nba.com',
#   'redfin.com',
#   'livedoor.com',
#   'amd.com',
#   'dnaindia.com',
#   'thesaurus.com',
#   'tvmovie.de',
#   'kroger.com',
#   'hdfcbank.com',
#   'yoox.com',
#   'google.lv',
#   'unip.br',
#   'worldstar.com',
#   'chinatimes.com',
#   'antenna.gr',
#   'chanel.com',
#   'neopets.com',
#   'apartmentguide.com',
#   'journeys.com',
#   'gotquestions.org',
#   'nhl.com',
#   'boxrec.com',
#   'usnews.com',
#   'nypost.com',
#   'skyscrapercity.com',
#   'adoptapet.com',
#   'ebay.ca',
#   'japanesebeauties.net',
#   'cotilleando.com',
#   'google.es',
#   'loc.gov',
#   'casadellibro.com',
#   'brainpop.com',
#   'ndr.de',
#   'healthline.com',
#   'xe.com',
#   'michigan.gov',
#   'perfectgirls.net',
#   'google.pl',
#   'gratka.pl',
#   'lastampa.it',
#   'christianbook.com',
#   'naukri.com',
#   'womenshealthmag.com',
#   'copart.com',
#   'nicematin.com',
#   'mass.gov',
#   'grubhub.com',
#   'famousbirthdays.com',
#   'unionesarda.it',
#   'sweetwater.com',
#   'hyundai.com',
#   '7sur7.be',
#   'guitarcenter.com',
#   'google.org',
#   'starfall.com',
#   'scmp.com',
#   'nvidia.com',
#   'eurosport.fr',
#   'sourceforge.net',
#   'tasteofhome.com',
#   'skybet.com',
#   'wordpress.com',
#   'diy.com',
#   'bbb.org',
#   'listindiario.com',
#   'auctionzip.com',
#   'caranddriver.com',
#   'welt.de',
#   'tvazteca.com',
#   'technopolis.bg',
#   'hs.fi',
#   'mayoclinic.org',
#   'caracoltv.com',
#   'sparknotes.com',
#   'postimees.ee',
#   'msnbc.com',
#   'jeevansathi.com',
#   'tiktok.com',
#   'kooora.com',
#   'google.it',
#   'davidsbridal.com',
#   'bt.com',
#   'ryanair.com',
#   'bestbuy.com',
#   'pnc.com',
#   'boostmobile.com',
#   'viabcp.com',
#   'google.ie',
#   'immobilienscout24.de',
#   'indiamart.com',
#   'shutterstock.com',
#   'turnitin.com',
#   'corrieredellosport.it',
#   'viamichelin.fr',
#   'fool.com',
#   'ica.se',
#   'minsal.cl',
#   'pokemon.com',
#   'petsmart.com',
#   'ingatlan.com',
#   'malavida.com',
#   'webmd.com',
#   'boe.es',
#   'google.cl',
#   'ikea.com',
#   'expressen.se',
#   'google.ca',
#   'conjuguemos.com',
#   'gunbroker.com',
#   'nouvelobs.com',
#   'bancsabadell.com',
#   'gp.se',
#   'dawn.com',
#   'nifty.com',
#   'boardgamegeek.com',
#   'biglots.com',
#   'tacklewarehouse.com',
#   'dairyqueen.com',
#   'nifty.org',
#   'movistar.es',
#   'rawstory.com',
#   'alibaba.com',
#   'tesco.com',
#   'answers.com',
#   'reverso.net',
#   'hindustantimes.com',
#   'woman.ru',
#   'napaonline.com',
#   'dailymotion.com',
#   'insider.com',
#   'experian.com',
#   'mynet.com',
#   'kirklands.com',
#   'latinamericancupid.com',
#   'saksfifthavenue.com',
#   'nyandcompany.com',
#   'nasa.gov',
#   'pnp.de',
#   'thedrive.com',
#   'summitracing.com',
#   'pracuj.pl',
#   'psychologytoday.com',
#   'cvs.com',
#   'build.com',
#   'thehindu.com',
#   'ancestry.com',
#   'gamestop.com',
#   'foodnetwork.com',
#   'nationstates.net',
#   'eluniverso.com',
#   'bigbadtoystore.com',
#   'macys.com',
#   'web.de',
#   'teacherease.com',
#   'ideal.es',
#   'flalottery.com',
#   'walmart.com',
#   'premierleague.com',
#   'csfd.cz',
#   'soccerstand.com',
#   'brownells.com',
#   'jumbo.com',
#   'cdiscount.com',
#   'capitalone.com',
#   'nowtv.com',
#   'bseindia.com',
#   'finanzen.net',
#   'wordreference.com',
#   'pandora.com',
#   'windguru.cz',
#   'ss.lv',
#   'harpersbazaar.com',
#   'microsoft.com',
#   'allrecipes.com',
#   'komputerswiat.pl',
#   'betexplorer.com',
#   'theglobeandmail.com',
#   'elespectador.com',
#   'gob.mx',
#   'antena3.com',
#   'cadenaser.com',
#   'blizzard.com',
#   'bloomingdales.com',
#   'fidelity.com',
#   'thetrainline.com',
#   'fotocasa.es',
#   'google.nl',
#   'futbolred.com',
#   'vimm.net',
#   'bt.dk',
#   'midwayusa.com',
#   'deviantart.com',
#   'foxnews.com',
#   'hm.com',
#   'urdupoint.com',
#   'iditarod.com',
#   'usps.com',
#   'mixi.jp',
#   'booking.com',
#   'milanuncios.com',
#   'pitchfork.com',
#   'caradisiac.com',
#   'tradera.com',
#   'crazyshit.com',
#   'ok.ru',
#   'info.com',
#   'kickoff.com',
#   'imvu.com',
#   'heb.com',
#   'costco.com',
#   'ducksters.com',
#   'manoramaonline.com',
#   'geneanet.org',
#   'super.cz',
#   'latimes.com',
#   'cbs.com',
#   'annunci69.it',
#   'ibm.com',
#   'di.se',
#   'irishexaminer.com',
#   'eurogamer.net',
#   'homedepot.ca',
#   'sba.gov',
#   'alarabiya.net',
#   '24horas.cl',
#   'dir.bg',
#   'rossmann.de',
#   'marocannonces.com',
#   'samsclub.com',
#   'nordstrom.com',
#   'dominos.com',
#   'yle.fi',
#   'inps.it',
#   'newsmax.com',
#   'dni.ru',
#   'hibbett.com',
#   'lacoste.com',
#   'gap.com',
#   'lampsplus.com',
#   'interia.pl',
#   'straitstimes.com',
#   'itv.com',
#   'mathplayground.com',
#   'walmart.ca',
#   'shoecarnival.com',
#   'google.sk',
#   'hsn.com',
#   'playground.ru',
#   'rxlist.com',
#   'tanea.gr',
#   'nasdaq.com',
#   'tvtropes.org',
#   'westernunion.com',
#   'worldofwarcraft.com',
#   'riverisland.com',
#   'microcenter.com',
#   'garnstudio.com',
#   'har.com',
#   'eleconomista.es',
#   'allmusic.com',
#   'publico.pt',
#   'hollisterco.com',
#   ...],
#  'match': ['computrabajo.com.mx',
#   'walla.co.il',
#   'indiapost.gov.in',
#   'makro.co.za',
#   'lagaceta.com.ar',
#   'mercadolibre.com.uy',
#   'google.com.sa',
#   'boticario.com.br',
#   'ciudad.com.ar',
#   'voegol.com.br',
#   'ofuxico.com.br',
#   '24h.com.vn',
#   'clicrbs.com.br',
#   'google.co.kr',
#   'indianrail.gov.in',
#   'jang.com.pk',
#   'casasbahia.com.br',
#   'hmv.co.jp',
#   'amazon.co.jp',
#   'google.com.tw',
#   'seek.com.au',
#   'mercadolibre.com.mx',
#   'google.com.hk',
#   'bunnings.com.au',
#   'jdsports.co.uk',
#   'vivastreet.co.uk',
#   'google.co.ve',
#   'google.com.my',
#   'kmart.com.au',
#   'dailymail.co.uk',
#   'dominos.co.uk',
#   'homedepot.com.mx',
#   'mercadolibre.com.ar',
#   'nationallottery.co.za',
#   'spareroom.co.uk',
#   'jbhifi.com.au',
#   'reed.co.uk',
#   'matalan.co.uk',
#   'aldi.co.uk',
#   'abc.com.py',
#   'independent.co.uk',
#   'stuff.co.nz',
#   'excelsior.com.mx',
#   'sabah.com.tr',
#   'rightmove.co.uk',
#   'consultaremedios.com.br',
#   'pravda.com.ua',
#   'fanatik.com.tr',
#   'google.co.za',
#   'metro.co.uk',
#   'caixa.gov.br',
#   'kalunga.com.br',
#   'tripadvisor.co.uk',
#   'gumtree.co.za',
#   'amazon.co.uk',
#   'honda.com.br',
#   'google.co.il',
#   'unionbankonline.co.in',
#   'matichon.co.th',
#   'google.com.br',
#   'google.co.uk',
#   'pontofrio.com.br',
#   'divyabhaskar.co.in',
#   'iceland.co.uk',
#   'vivo.com.br',
#   'express.co.uk',
#   'dantri.com.vn',
#   'dailynews.co.th',
#   'officedepot.com.mx',
#   'sunat.gob.pe',
#   'imovelweb.com.br',
#   'ntv.com.tr',
#   'lanacion.com.ar',
#   'eluniversal.com.mx',
#   'serasa.com.br',
#   'mercadolivre.com.br',
#   'itau.com.br',
#   'newsnow.co.uk',
#   'books.com.tw',
#   'tfl.gov.uk',
#   'bbc.co.uk',
#   'elpais.com.uy',
#   'bb.com.br',
#   'kanald.com.tr',
#   'currys.co.uk',
#   'google.com.tr',
#   'google.com.au',
#   'google.com.uy',
#   'wiggle.co.uk',
#   'solodeportes.com.ar',
#   'lacapital.com.ar',
#   'netvasco.com.br',
#   'diariodecuyo.com.ar',
#   'thestar.com.my',
#   'submarino.com.br',
#   'americanas.com.br',
#   'panorama.com.al',
#   'carsales.com.au',
#   'abc.net.au',
#   'manchestereveningnews.co.uk',
#   'sams.com.mx',
#   'proceso.com.mx',
#   'walmart.com.mx',
#   'thairath.co.th',
#   'ole.com.ar',
#   'google.com.mx',
#   'argos.co.uk',
#   'radios.com.br',
#   'oricon.co.jp',
#   'metoffice.gov.uk',
#   'cumhuriyet.com.tr',
#   'globe.com.ph',
#   'globes.co.il',
#   'sonhos.com.br',
#   'google.com.pk',
#   'realestate.com.au',
#   'google.com.ph',
#   'auspost.com.au',
#   'yomiuri.co.jp',
#   'oi.com.br',
#   'google.com.co',
#   'commbank.com.au',
#   'ynet.co.il',
#   'autotrader.co.za',
#   'eldeber.com.bo',
#   'ebay.co.uk',
#   'pagina12.com.ar',
#   'google.com.vn',
#   'singaporepools.com.sg',
#   'o2.co.uk',
#   'uai.com.br',
#   'hoseasons.co.uk',
#   'google.co.jp',
#   'marisa.com.br',
#   'sears.com.mx',
#   'pets4homes.co.uk',
#   'dailystar.co.uk',
#   'google.com.gt',
#   'rakuten.co.jp',
#   'correios.com.br',
#   'sodimac.com.pe',
#   'mercadolibre.com.ve',
#   'gamer.com.tw',
#   'occ.com.mx',
#   'nld.com.vn',
#   'yahoo.co.jp',
#   'preloved.co.uk',
#   'ancestry.co.uk',
#   'lovehoney.co.uk',
#   'costco.com.mx',
#   'google.com.sg',
#   'wickes.co.uk',
#   'sat.gob.mx',
#   'liverpool.com.mx',
#   'ebay.com.au',
#   'next.co.uk',
#   'sanborns.com.mx',
#   'lpga.or.jp',
#   'buscape.com.br',
#   'atv.com.tr',
#   'domain.com.au',
#   'lidl.co.uk',
#   'mirror.co.uk',
#   'maybank2u.com.my',
#   'telegraph.co.uk',
#   'google.co.nz',
#   'thetimes.co.uk',
#   '1999.co.jp',
#   'lse.co.uk',
#   'honda.co.jp',
#   'excite.co.jp',
#   'jobs.nhs.uk',
#   'thenews.com.pk',
#   'nintendo.co.jp',
#   'bigw.com.au',
#   'homebase.co.uk',
#   'google.com.pe',
#   'itmedia.co.jp',
#   'tigo.com.gt',
#   'news.com.au',
#   'jal.co.jp',
#   'trademe.co.nz',
#   'thesun.co.uk',
#   'dailyrecord.co.uk',
#   'jobstreet.com.ph',
#   'upsc.gov.in',
#   'set.or.th',
#   'mcdonalds.co.jp',
#   'showtv.com.tr',
#   'montevideo.com.uy',
#   'dmm.co.jp',
#   'unisa.ac.za',
#   'three.co.uk',
#   'google.com.ec',
#   'dogstrust.org.uk',
#   'nzherald.co.nz',
#   'autotrader.co.uk',
#   'mercadolibre.com.co',
#   'privateproperty.co.za',
#   'lojasrenner.com.br',
#   'target.com.au',
#   'sainsburys.co.uk',
#   '104.com.tw',
#   'ntv.co.jp',
#   'imss.gob.mx',
#   'google.co.in',
#   'haaretz.co.il',
#   'casadoscontos.com.br',
#   'vodafone.co.uk',
#   'milliyet.com.tr',
#   'terra.com.br',
#   'utusan.com.my',
#   'google.co.id',
#   'gumtree.com.au',
#   'bom.gov.au',
#   'uol.com.br',
#   'smh.com.au',
#   'computrabajo.com.pe',
#   'google.com.ar',
#   'bharian.com.my',
#   'bna.com.ar',
#   'maariv.co.il',
#   'hurriyet.com.tr',
#   'lotteryusa.com',
#   'delfi.lv',
#   'aljazeera.net',
#   'paultan.org',
#   'totalwine.com',
#   'libertaddigital.com',
#   'longhornsteakhouse.com',
#   'clubic.com',
#   'worldometers.info',
#   'abercrombie.com',
#   'hornbach.de',
#   'barnesandnoble.com',
#   'newegg.com',
#   'qvc.com',
#   'funimation.com',
#   'bahn.de',
#   'geocaching.com',
#   'apartments.com',
#   'gumtree.pl',
#   'housing.com',
#   'ojogo.pt',
#   'o2.pl',
#   'superdrug.com',
#   'gsmarena.com',
#   'filmaffinity.com',
#   'un.org',
#   'tsn.ca',
#   'chegg.com',
#   'tripadvisor.es',
#   'laposte.net',
#   'budsgunshop.com',
#   'clasificadosonline.com',
#   'fanfiction.net',
#   'immonet.de',
#   'jegs.com',
#   'adidas.com',
#   'otto.de',
#   'udn.com',
#   'islamweb.net',
#   'lequipe.fr',
#   'nytimes.com',
#   'google.se',
#   'postfun.com',
#   'thriftbooks.com',
#   'hollandandbarrett.com',
#   'anandabazar.com',
#   'goldprice.org',
#   'ziare.com',
#   'emol.com',
#   '6park.com',
#   'inbox.lv',
#   'vocabulary.com',
#   'xoom.com',
#   'indeed.com',
#   'skatteverket.se',
#   'rateyourmusic.com',
#   'bancodevenezuela.com',
#   'urbandictionary.com',
#   'nuskin.com',
#   'enotes.com',
#   'adac.de',
#   'findagrave.com',
#   'adultdvdempire.com',
#   'vans.com',
#   'lepoint.fr',
#   'nespresso.com',
#   'adressa.no',
#   'draugiem.lv',
#   'tripadvisor.fr',
#   'ilmattino.it',
#   'flickr.com',
#   'stern.de',
#   'menupix.com',
#   'jw.org',
#   'hrblock.com',
#   'webassign.net',
#   'abebooks.com',
#   'nfl.com',
#   'tf1.fr',
#   'ebay.it',
#   '1001fonts.com',
#   'newlook.com',
#   'livescores.com',
#   'uscis.gov',
#   'estrepublicain.fr',
#   'win2day.at',
#   'evike.com',
#   'chess.com',
#   'clips4sale.com',
#   'globo.com',
#   'msn.com',
#   'gittigidiyor.com',
#   'jcrew.com',
#   'milenio.com',
#   'sport.cz',
#   'nseindia.com',
#   'proximus.be',
#   'furaffinity.net',
#   'albayan.ae',
#   'dagbladet.no',
#   'zillow.com',
#   'livescience.com',
#   'marriott.com',
#   'sport.es',
#   'converse.com',
#   'tibia.com',
#   'marktplaats.nl',
#   'barchart.com',
#   'assoass.com',
#   'elle.com',
#   'baur.de',
#   'pap.fr',
#   'ledauphine.com',
#   'gradesaver.com',
#   'jstor.org',
#   'uline.com',
#   'victoriassecret.com',
#   'elcorteingles.pt',
#   'rockauto.com',
#   'au.com',
#   'thumbzilla.com',
#   'lapresse.ca',
#   'bluewin.ch',
#   'interpals.net',
#   'kidshealth.org',
#   'ceskatelevize.cz',
#   'larazon.es',
#   'abnamro.nl',
#   'ew.com',
#   'indiaglitz.com',
#   'breitbart.com',
#   'discover.com',
#   'blesk.cz',
#   'pagesix.com',
#   'facebook.com',
#   'tripadvisor.com',
#   'formula1.com',
#   'russianfood.com',
#   'ae.com',
#   'bbva.es',
#   'southwest.com',
#   'bible.com',
#   'minijuegos.com',
#   'losarcanos.com',
#   'kotaku.com',
#   'sii.cl',
#   'provincial.com',
#   'shmu.sk',
#   'pudelek.pl',
#   'fnac.com',
#   'akakce.com',
#   'cooperativa.cl',
#   '4shared.com',
#   'shutterfly.com',
#   'in.gr',
#   'vnexpress.net',
#   'novinky.cz',
#   'figma.com',
#   'loopnet.com',
#   'eonline.com',
#   'enterprise.com',
#   'iltalehti.fi',
#   'moddb.com',
#   'hemnet.se',
#   'lenta.ru',
#   'google.gr',
#   'blackpeoplemeet.com',
#   'rackroomshoes.com',
#   '750g.com',
#   'mercadolibre.com',
#   'nezavisne.com',
#   'nadaguides.com',
#   'cars.com',
#   'sme.sk',
#   'auto.ru',
#   'truckpaper.com',
#   'npr.org',
#   'yandex.com',
#   'fossil.com',
#   'movoto.com',
#   'michaels.com',
#   'dlsite.com',
#   'expatriates.com',
#   'smokva.com',
#   'guiainfantil.com',
#   'tweakers.net',
#   'google.at',
#   'sportsmansguide.com',
#   'esquire.com',
#   'scoresandodds.com',
#   'infojobs.net',
#   'rbc.ru',
#   'ixbt.com',
#   'skyscanner.net',
#   'mapquest.com',
#   'lanebryant.com',
#   'abc.com',
#   'latercera.com',
#   'etrailer.com',
#   'aa.com',
#   'marapets.com',
#   'euroleague.net',
#   'zumiez.com',
#   'freevideo.cz',
#   'netdoktor.de',
#   'aastocks.com',
#   'maurices.com',
#   'wetteronline.de',
#   'investopedia.com',
#   'meetic.fr',
#   'krone.at',
#   'toom.de',
#   'ancestry.ca',
#   'blocket.se',
#   'canarias7.es',
#   'thehill.com',
#   'sueddeutsche.de',
#   'surveymonkey.com',
#   'dnb.com',
#   'oracle.com',
#   'seneweb.com',
#   'tchatche.com',
#   'nj.com',
#   'banamex.com',
#   'hepsiburada.com',
#   'vrbo.com',
#   'drudgereport.com',
#   'allocine.fr',
#   'gumtree.com',
#   'nintendo.com',
#   'brainyquote.com',
#   'adultfriendfinder.com',
#   'khaleejtimes.com',
#   'erotikforum.at',
#   'marmiton.org',
#   'skysports.com',
#   'crateandbarrel.com',
#   'vodafone.it',
#   'skechers.com',
#   'sephora.com',
#   '3dnews.ru',
#   'kayak.com',
#   'ebay.ie',
#   'mitbbs.com',
#   'eatthis.com',
#   'squirt.org',
#   'europa.eu',
#   'pantip.com',
#   'dexonline.ro',
#   'laprensa.hn',
#   'vix.com',
#   'vietnamnet.vn',
#   'rte.ie',
#   'lowes.com',
#   'heraldo.es',
#   'gmx.net',
#   'epicgames.com',
#   'sallybeauty.com',
#   'justdial.com',
#   'quia.com',
#   'papajohns.com',
#   'timesofindia.com',
#   'catofashions.com',
#   'porzo.com',
#   'geo.tv',
#   'marca.com',
#   'ft.com',
#   'nairaland.com',
#   'liberation.fr',
#   'cnnturk.com',
#   'nps.gov',
#   'repubblica.it',
#   'mathrubhumi.com',
#   'fedex.com',
#   'ar15.com',
#   'tuttosport.com',
#   'sauto.cz',
#   'dickssportinggoods.com',
#   'forocoches.com',
#   'vistaprint.com',
#   'seekingalpha.com',
#   'kyero.com',
#   'insomnia.gr',
#   'redlobster.com',
#   'icicibank.com',
#   'cinepolis.com',
#   'joyclub.de',
#   'discogs.com',
#   'dr.dk',
#   'pichunter.com',
#   'lipstickalley.com',
#   'kay.com',
#   'utorrent.com',
#   'goal.com',
#   'faz.net',
#   'habitaclia.com',
#   'galottery.com',
#   'konami.com',
#   'tabelog.com',
#   'daserste.de',
#   'cinemagia.ro',
#   'yaplakal.com',
#   'cycletrader.com',
#   'coolinarika.com',
#   'centraldispatch.com',
#   'target.com',
#   'sbazar.cz',
#   'google.com',
#   'usaa.com',
#   'indianexpress.com',
#   'index.hr',
#   'viz.com',
#   'vodafone.es',
#   'blick.ch',
#   'uhaul.com',
#   'worldmarket.com',
#   'poste.it',
#   'dhnet.be',
#   'ksl.com',
#   'carfax.com',
#   'google.ae',
#   'cookpad.com',
#   'priceline.com',
#   'cabelas.com',
#   'venus.com',
#   'medicalnewstoday.com',
#   'lemonde.fr',
#   'tiava.com',
#   'yelp.com',
#   'korrespondent.net',
#   'kia.com',
#   'bridgebase.com',
#   'chilis.com',
#   'torrid.com',
#   'registrocivil.cl',
#   'cuisineaz.com',
#   'tvnet.lv',
#   'autotrader.com',
#   'fda.gov',
#   'attheraces.com',
#   'lavozdegalicia.es',
#   'mavi.com',
#   'slate.com',
#   'qvc.de',
#   'record.pt',
#   'onlinebootycall.com',
#   'scopus.com',
#   'serebii.net',
#   'semana.com',
#   'tacobell.com',
#   'egun.de',
#   'fingerhut.com',
#   'overstock.com',
#   'greetingsisland.com',
#   'autogidas.lt',
#   'linternaute.com',
#   'shabdkosh.com',
#   'jeuxvideo.com',
#   'swinglifestyle.com',
#   'usbank.com',
#   'drmartens.com',
#   'coldwellbankerhomes.com',
#   'office.com',
#   'bhaskar.com',
#   'cheaperthandirt.com',
#   'castorama.fr',
#   'espn.com',
#   'vimeo.com',
#   'xataka.com',
#   'verizon.com',
#   'gulfnews.com',
#   'malaysiakini.com',
#   'channel4.com',
#   'mandmdirect.com',
#   'hobbylobby.com',
#   'wizardingworld.com',
#   'citi.com',
#   'samsung.com',
#   'history.com',
#   'scielo.br',
#   'rtl.be',
#   'who.int',
#   'imagefap.com',
#   'explorelearning.com',
#   'morningstar.com',
#   'gocomics.com',
#   'brigitte.de',
#   'rona.ca',
#   'bathandbodyworks.com',
#   'ltdcommodities.com',
#   'alison.com',
#   'ruv.is',
#   'vegasinsider.com',
#   'audible.com',
#   'carters.com',
#   'boots.com',
#   'bungie.net',
#   'filgoal.com',
#   'google.de',
#   'altex.ro',
#   'jpcycles.com',
#   'pacsun.com',
#   'opticsplanet.com',
#   'expansion.com',
#   'kurier.at',
#   'rotter.net',
#   'gamesradar.com',
#   'euroresidentes.com',
#   'cardkingdom.com',
#   'afrointroductions.com',
#   'clarin.com',
#   'naver.com',
#   'att.net',
#   'svd.se',
#   'tournamentsoftware.com',
#   'masrawy.com',
#   'kitco.com',
#   'thepiratebay.org',
#   'legacy.com',
#   'cbc.ca',
#   'pcmag.com',
#   'rtve.es',
#   'ilsole24ore.com',
#   'chase.com',
#   'orf.at',
#   'wordplays.com',
#   'swarovski.com',
#   'sportinglife.com',
#   'contoerotico.com',
#   'mlb.com',
#   'gosection8.com',
#   'bestbuy.ca',
#   'rambler.ru',
#   'elcomercio.com',
#   'sfgate.com',
#   'dinamalar.com',
#   'cbsnews.com',
#   'ngoisao.net',
#   'jcpenney.com',
#   'xuite.net',
#   'kleinezeitung.at',
#   'motogp.com',
#   'bankofamerica.com',
#   'as.com',
#   'sony.jp',
#   'citationmachine.net',
#   'obi.de',
#   'aarp.org',
#   'consumerreports.org',
#   '24ur.com',
#   'yellowpages.com',
#   'peda.net',
#   'zdf.de',
#   'sky.com',
#   'pakwheels.com',
#   'kindgirls.com',
#   'livescore.cz',
#   'landsend.com',
#   'cricut.com',
#   'tchibo.de',
#   'rtl.de',
#   'haber7.com',
#   'forbes.com',
#   'chip.de',
#   'proxibid.com',
#   'ss.com',
#   'telegraaf.nl',
#   'pastebin.com',
#   'idnes.cz',
#   'slickdeals.net',
#   'tvgids.nl',
#   'instructables.com',
#   'multiplication.com',
#   'bunte.de',
#   'ulta.com',
#   'gazzetta.it',
#   'alhurra.com',
#   'txlottery.org',
#   'mobile01.com',
#   'wunderground.com',
#   'rds.ca',
#   'correos.es',
#   'king.com',
#   'stockcharts.com',
#   'chainreactioncycles.com',
#   'kinopoisk.ru',
#   'sportchek.ca',
#   'bloomberg.com',
#   'sciencedirect.com',
#   'torn.com',
#   'literotica.com',
#   'seloger.com',
#   'trojmiasto.pl',
#   'trovaprezzi.it',
#   'cellufun.com',
#   'elmundo.es',
#   'aol.com',
#   'usatoday.com',
#   'origo.hu',
#   'nationalgeographic.com',
#   'netspend.com',
#   'google.ru',
#   'adameve.com',
#   'discounttire.com',
#   'haberturk.com',
#   'ebird.org',
#   'pch.com',
#   'falabella.com',
#   'wp.pl',
#   'governo.it',
#   'bbc.com',
#   'ptt.cc',
#   'telcel.com',
#   'swr.de',
#   'nba.com',
#   'redfin.com',
#   'livedoor.com',
#   'amd.com',
#   'dnaindia.com',
#   'thesaurus.com',
#   'tvmovie.de',
#   'kroger.com',
#   'hdfcbank.com',
#   'yoox.com',
#   'google.lv',
#   'unip.br',
#   'worldstar.com',
#   'chinatimes.com',
#   'antenna.gr',
#   'chanel.com',
#   'neopets.com',
#   'apartmentguide.com',
#   'journeys.com',
#   'gotquestions.org',
#   'nhl.com',
#   'boxrec.com',
#   'usnews.com',
#   'nypost.com',
#   'skyscrapercity.com',
#   'adoptapet.com',
#   'ebay.ca',
#   'japanesebeauties.net',
#   'cotilleando.com',
#   'google.es',
#   'loc.gov',
#   'casadellibro.com',
#   'brainpop.com',
#   'ndr.de',
#   'healthline.com',
#   'xe.com',
#   'michigan.gov',
#   'perfectgirls.net',
#   'google.pl',
#   'gratka.pl',
#   'lastampa.it',
#   'christianbook.com',
#   'naukri.com',
#   'womenshealthmag.com',
#   'copart.com',
#   'nicematin.com',
#   'mass.gov',
#   'grubhub.com',
#   'famousbirthdays.com',
#   'unionesarda.it',
#   'sweetwater.com',
#   'hyundai.com',
#   '7sur7.be',
#   'guitarcenter.com',
#   'google.org',
#   'starfall.com',
#   'scmp.com',
#   'nvidia.com',
#   'eurosport.fr',
#   'sourceforge.net',
#   'tasteofhome.com',
#   'skybet.com',
#   'wordpress.com',
#   'diy.com',
#   'bbb.org',
#   'listindiario.com',
#   'auctionzip.com',
#   'caranddriver.com',
#   'welt.de',
#   'tvazteca.com',
#   'technopolis.bg',
#   'hs.fi',
#   'mayoclinic.org',
#   'caracoltv.com',
#   'sparknotes.com',
#   'postimees.ee',
#   'msnbc.com',
#   'jeevansathi.com',
#   'tiktok.com',
#   'kooora.com',
#   'google.it',
#   'davidsbridal.com',
#   'bt.com',
#   'ryanair.com',
#   'bestbuy.com',
#   'pnc.com',
#   'boostmobile.com',
#   'viabcp.com',
#   'google.ie',
#   'immobilienscout24.de',
#   'indiamart.com',
#   'shutterstock.com',
#   'turnitin.com',
#   'corrieredellosport.it',
#   'viamichelin.fr',
#   'fool.com',
#   'ica.se',
#   'minsal.cl',
#   'pokemon.com',
#   'petsmart.com',
#   'ingatlan.com',
#   'malavida.com',
#   'webmd.com',
#   'boe.es',
#   'google.cl',
#   'ikea.com',
#   'expressen.se',
#   'google.ca',
#   'conjuguemos.com',
#   'gunbroker.com',
#   'nouvelobs.com',
#   'bancsabadell.com',
#   'gp.se',
#   'dawn.com',
#   'nifty.com',
#   'boardgamegeek.com',
#   'biglots.com',
#   'tacklewarehouse.com',
#   'dairyqueen.com',
#   'nifty.org',
#   'movistar.es',
#   'rawstory.com',
#   'alibaba.com',
#   'tesco.com',
#   'answers.com',
#   'reverso.net',
#   'hindustantimes.com',
#   'woman.ru',
#   'napaonline.com',
#   'dailymotion.com',
#   'insider.com',
#   'experian.com',
#   'mynet.com',
#   'kirklands.com',
#   'latinamericancupid.com',
#   'saksfifthavenue.com',
#   'nyandcompany.com',
#   'nasa.gov',
#   'pnp.de',
#   'thedrive.com',
#   'summitracing.com',
#   'pracuj.pl',
#   'psychologytoday.com',
#   'cvs.com',
#   'build.com',
#   'thehindu.com',
#   'ancestry.com',
#   'gamestop.com',
#   'foodnetwork.com',
#   'nationstates.net',
#   'eluniverso.com',
#   'bigbadtoystore.com',
#   'macys.com',
#   'web.de',
#   'teacherease.com',
#   'ideal.es',
#   'flalottery.com',
#   'walmart.com',
#   'premierleague.com',
#   'csfd.cz',
#   'soccerstand.com',
#   'brownells.com',
#   'jumbo.com',
#   'cdiscount.com',
#   'capitalone.com',
#   'nowtv.com',
#   'bseindia.com',
#   'finanzen.net',
#   'wordreference.com',
#   'pandora.com',
#   'windguru.cz',
#   'ss.lv',
#   'harpersbazaar.com',
#   'microsoft.com',
#   'allrecipes.com',
#   'komputerswiat.pl',
#   'betexplorer.com',
#   'theglobeandmail.com',
#   'elespectador.com',
#   'gob.mx',
#   'antena3.com',
#   'cadenaser.com',
#   'blizzard.com',
#   'bloomingdales.com',
#   'fidelity.com',
#   'thetrainline.com',
#   'fotocasa.es',
#   'google.nl',
#   'futbolred.com',
#   'vimm.net',
#   'bt.dk',
#   'midwayusa.com',
#   'deviantart.com',
#   'foxnews.com',
#   'hm.com',
#   'urdupoint.com',
#   'iditarod.com',
#   'usps.com',
#   'mixi.jp',
#   'booking.com',
#   'milanuncios.com',
#   'pitchfork.com',
#   'caradisiac.com',
#   'tradera.com',
#   'crazyshit.com',
#   'ok.ru',
#   'info.com',
#   'kickoff.com',
#   'imvu.com',
#   'heb.com',
#   'costco.com',
#   'ducksters.com',
#   'manoramaonline.com',
#   'geneanet.org',
#   'super.cz',
#   'latimes.com',
#   'cbs.com',
#   'annunci69.it',
#   'ibm.com',
#   'di.se',
#   'irishexaminer.com',
#   'eurogamer.net',
#   'homedepot.ca',
#   'sba.gov',
#   'alarabiya.net',
#   '24horas.cl',
#   'dir.bg',
#   'rossmann.de',
#   'marocannonces.com',
#   'samsclub.com',
#   'nordstrom.com',
#   'dominos.com',
#   'yle.fi',
#   'inps.it',
#   'newsmax.com',
#   'dni.ru',
#   'hibbett.com',
#   'lacoste.com',
#   'gap.com',
#   'lampsplus.com',
#   'interia.pl',
#   'straitstimes.com',
#   'itv.com',
#   'mathplayground.com',
#   'walmart.ca',
#   'shoecarnival.com',
#   'google.sk',
#   'hsn.com',
#   'playground.ru',
#   'rxlist.com',
#   'tanea.gr',
#   'nasdaq.com',
#   'tvtropes.org',
#   'westernunion.com',
#   'worldofwarcraft.com',
#   'riverisland.com',
#   'microcenter.com',
#   'garnstudio.com',
#   'har.com',
#   'eleconomista.es',
#   'allmusic.com',
#   'publico.pt',
#   'hollisterco.com',
#   ...],
#  'topics': ["'238'",
#   "'1','215','219','243'",
#   "'103'",
#   "'289'",
#   "'243'",
#   "'289'",
#   "'219','223'",
#   "'92','94'",
#   "'243'",
#   "'334'",
#   "'1','45','243'",
#   "'243'",
#   "'23','243'",
#   "'219'",
#   "'292','341'",
#   "'243'",
#   "'129','210','289'",
#   "'289'",
#   "'289'",
#   "'219','223'",
#   "'238'",
#   "'289'",
#   "'219','223'",
#   "'114','211','278'",
#   "'289'",
#   "'289'",
#   "'219','223'",
#   "'219'",
#   "'289'",
#   "'243'",
#   "'172'",
#   "'114','211'",
#   "'289'",
#   "''",
#   "'272'",
#   "'126','289'",
#   "'238'",
#   "'289'",
#   "'179','289'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'272'",
#   "''",
#   "'23','243','252'",
#   "'243','299'",
#   "'219'",
#   "'1','243'",
#   "'149'",
#   "'289'",
#   "'292','349'",
#   "'289'",
#   "'289'",
#   "'57'",
#   "'219'",
#   "'149'",
#   "'243'",
#   "'219'",
#   "'219'",
#   "'129','210','289'",
#   "'243'",
#   "'172'",
#   "'215'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'103','289'",
#   "'103','239'",
#   "'272'",
#   "'1','243'",
#   "'243'",
#   "'243'",
#   "'149'",
#   "'289'",
#   "'149'",
#   "'243'",
#   "'100','289'",
#   "'332','341'",
#   "'243'",
#   "'243'",
#   "'103','149'",
#   "'1'",
#   "'23','126','183','210','220'",
#   "'219'",
#   "'219'",
#   "'219','223'",
#   "'289'",
#   "'243','325'",
#   "'243'",
#   "'243','299','325'",
#   "'243','245'",
#   "'243'",
#   "'289'",
#   "'289'",
#   "'243'",
#   "'83'",
#   "'1'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'243','299'",
#   "'219'",
#   "'126','289'",
#   "'1','23'",
#   "'1'",
#   "'248','254','279','284'",
#   "'243'",
#   "'217','218','220'",
#   "'103','164','243'",
#   "''",
#   "'219'",
#   "'272'",
#   "'219'",
#   "'103'",
#   "'243'",
#   "'217','218'",
#   "'219'",
#   "'149'",
#   "'243'",
#   "'83'",
#   "'243'",
#   "'289'",
#   "'243'",
#   "'219'",
#   "'243','299'",
#   "'129','215','218'",
#   "'243'",
#   "'332'",
#   "'219'",
#   "'289'",
#   "'207','289'",
#   "'265','289'",
#   "'243'",
#   "'219'",
#   "'289'",
#   "'103'",
#   "'289'",
#   "'289'",
#   "'183'",
#   "'238'",
#   "'243'",
#   "'1','215'",
#   "'289'",
#   "'256'",
#   "'289'",
#   "'289'",
#   "'219'",
#   "'207','209','211'",
#   "'239'",
#   "'129','207','289'",
#   "'289'",
#   "'207','289'",
#   "'289'",
#   "'243','299','315'",
#   "'289','292'",
#   "'1','48'",
#   "'272'",
#   "'179'",
#   "'243'",
#   "'149'",
#   "'243','244','247','249'",
#   "'219'",
#   "'243'",
#   "'289'",
#   "'103','164','243'",
#   "'57','70'",
#   "'1'",
#   "'238','239'",
#   "'243'",
#   "'129','183'",
#   "'103','289'",
#   "'209','211','289'",
#   "'219'",
#   "'126','243','279'",
#   "'215','217','218'",
#   "'243'",
#   "'334'",
#   "'289'",
#   "'243'",
#   "'243'",
#   "'238'",
#   "'239'",
#   "'103','169','243'",
#   "'172'",
#   "'1'",
#   "'243'",
#   "'1'",
#   "'229'",
#   "'215','218'",
#   "'219','223'",
#   "'254','263','268'",
#   "'243'",
#   "'83'",
#   "'289'",
#   "'272'",
#   "'289'",
#   "'289'",
#   "'289'",
#   "'236'",
#   "'1'",
#   "'239'",
#   "'219'",
#   "'243'",
#   "''",
#   "'129','215','218'",
#   "'1','215','243'",
#   "'243'",
#   "'243'",
#   "'219'",
#   "'289'",
#   "'248','279'",
#   "'1','215','243'",
#   "'243'",
#   "'236'",
#   "'219'",
#   "'243'",
#   "'149'",
#   "'243'",
#   "'1','215','243'",
#   "''",
#   "'243'",
#   "'1','243'",
#   "'57'",
#   "''",
#   "'243'",
#   "'172'",
#   "'126','183','292'",
#   "'254','275'",
#   "'289'",
#   "'114','211','289'",
#   "'100','289'",
#   "'126','129'",
#   "'289'",
#   "'1','43'",
#   "'341'",
#   "'201'",
#   "'272'",
#   "'289'",
#   "'272'",
#   "'243','299','325'",
#   "'1','215','243'",
#   "'86','289'",
#   "'126','220','243','279'",
#   "'12'",
#   "'239','254','275'",
#   "'243','299'",
#   "'227','237','276'",
#   "'332'",
#   "'103'",
#   "''",
#   "'289'",
#   "'100'",
#   "'272'",
#   "'81'",
#   "'289'",
#   "'289'",
#   "'43','243'",
#   "''",
#   "'243','299'",
#   "'243'",
#   "'219','223'",
#   "'1','42','243'",
#   "'100','289'",
#   "''",
#   "'243'",
#   "'103','165','243'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'275'",
#   "'149'",
#   "'238'",
#   "'150'",
#   "'23','250'",
#   "'149'",
#   "'1','7','275'",
#   "'88'",
#   "'100','276'",
#   "'83','158','292'",
#   "''",
#   "''",
#   "'289','299'",
#   "'243'",
#   "'172','207','210'",
#   "'243'",
#   "'253'",
#   "'340','344'",
#   "'243'",
#   "'42','250','253'",
#   "'103','243'",
#   "'172','275'",
#   "''",
#   "'151'",
#   "'276'",
#   "'100','289'",
#   "'289','299','300','314'",
#   "'1','45'",
#   "'289'",
#   "'142'",
#   "'196','207','289'",
#   "'243','299','325'",
#   "''",
#   "'243','245'",
#   "''",
#   "'202','204'",
#   "'1','180','183'",
#   "''",
#   "'1','215','243'",
#   "'1','215','243'",
#   "'289'",
#   "'289'",
#   "'243','245'",
#   "'243','299'",
#   "'103','164','243'",
#   "'215'",
#   "'1','215','250'",
#   "'243'",
#   "'243'",
#   "'157','272'",
#   "'279'",
#   "'340'",
#   "'243','299'",
#   "'289'",
#   "'188','194'",
#   "'289'",
#   "'103','164','243'",
#   "''",
#   "'96','100','254'",
#   "'289'",
#   "'272','289'",
#   "'240','243','245','247','249'",
#   "'103','229','234'",
#   "'276'",
#   "'103'",
#   "'289'",
#   "'289'",
#   "'81'",
#   "'129','215','218'",
#   "''",
#   "'243'",
#   "'1','215'",
#   "'253','255','275'",
#   "'258','276'",
#   "'1'",
#   "'243'",
#   "'149'",
#   "'1','100','243'",
#   "'1'",
#   "'243'",
#   "'149','152'",
#   "'243','245','299'",
#   "'1','243'",
#   "'253'",
#   "'332','340','349'",
#   "'299'",
#   "'173'",
#   "'289'",
#   "'149'",
#   "'334'",
#   "'100'",
#   "'1','183','186'",
#   "''",
#   "'183'",
#   "'151'",
#   "'149'",
#   "'248'",
#   "'1','243'",
#   "'289'",
#   "'292'",
#   "'23','243'",
#   "'215','250'",
#   "'103','196','209','289'",
#   "'243'",
#   "'43','243'",
#   "'243','249'",
#   "'103','126','140','144','224'",
#   "'272'",
#   "'1','243'",
#   "'336'",
#   "'243'",
#   "'183'",
#   "'272'",
#   "'243'",
#   "'219','223'",
#   "'251'",
#   "'289'",
#   "'175'",
#   "'289'",
#   "'243'",
#   "'83'",
#   "'83'",
#   "'243'",
#   "'83','289'",
#   "'58','83','289'",
#   "'39','243'",
#   "'219'",
#   "'289'",
#   "'272'",
#   "'196'",
#   "'183'",
#   "'250','289'",
#   "''",
#   "'258'",
#   "'126','243','279'",
#   "'219'",
#   "'201','289'",
#   "'96','100','254'",
#   "'243','299'",
#   "'236'",
#   "'243'",
#   "'126','243','279'",
#   "'332'",
#   "'275'",
#   "'298'",
#   "'45'",
#   "'243'",
#   "'81'",
#   "'334'",
#   "'1','183','186'",
#   "'243','299','304'",
#   "'289','299'",
#   "''",
#   "'243'",
#   "'103','243'",
#   "'289','298'",
#   "'248'",
#   "'164'",
#   "'251'",
#   "'243'",
#   "'114','211','289'",
#   "'256'",
#   "'289'",
#   "'243'",
#   "'239','247'",
#   "'243'",
#   "'223'",
#   "'103','149'",
#   "'126','215'",
#   "'243'",
#   "'251'",
#   "'243','245'",
#   "'149'",
#   "'289'",
#   "'274'",
#   "'243'",
#   "'11','12'",
#   "'278','289'",
#   "'129','183'",
#   "'100','275'",
#   "''",
#   "'243'",
#   "''",
#   "'173'",
#   "'43','243','299','325'",
#   "'207'",
#   "'217','218'",
#   "'289'",
#   "'88','92'",
#   "'126','243','279'",
#   "'332','334'",
#   "'289'",
#   "'252'",
#   "'178'",
#   "''",
#   "'1','215','239'",
#   "'252'",
#   "'275'",
#   "'243'",
#   "'12'",
#   "'243'",
#   "'23','43','243'",
#   "'211','289'",
#   "'243','245','299'",
#   "'1','215'",
#   "'183'",
#   "'99'",
#   "'219','275','289','332'",
#   "'140','227','276'",
#   "'172'",
#   "'243'",
#   "'298'",
#   "''",
#   "'249'",
#   "'243','299'",
#   "'103','243'",
#   "'252'",
#   "'243'",
#   "'1','243'",
#   "'346'",
#   "'243'",
#   "'243','245'",
#   "'103'",
#   "''",
#   "'243','299'",
#   "'57','81'",
#   "'289','299'",
#   "'57'",
#   "'123'",
#   "'103','164','243'",
#   "'272','274'",
#   "'126','243','279','289','292'",
#   "'172'",
#   "'149'",
#   "'11','12'",
#   "''",
#   "'23','289'",
#   "'1','243'",
#   "''",
#   "'253','254'",
#   "'289'",
#   "'215','250'",
#   "'243','299','325'",
#   "'243'",
#   "'272'",
#   "''",
#   "'103','183','243'",
#   "'172'",
#   "'1','43'",
#   "'12'",
#   "'1'",
#   "'70','84','289'",
#   "'173'",
#   "'57','103'",
#   "'289'",
#   "'289'",
#   "'219'",
#   "'149'",
#   "'1','243'",
#   "'1','173','215'",
#   "'1'",
#   "'215','217','218'",
#   "'243'",
#   "'103'",
#   "'207','209'",
#   "'103','149'",
#   "'243'",
#   "'245'",
#   "'57','83','84','241','292'",
#   "'219'",
#   "'173'",
#   "'332','344'",
#   "'289','299'",
#   "'298'",
#   "'243'",
#   "'243'",
#   "''",
#   "'172','275'",
#   "'243'",
#   "'57','83'",
#   "'1','182','183'",
#   "'172'",
#   "'298'",
#   "'241','275'",
#   "'172','173'",
#   "'243'",
#   "'83'",
#   "'239'",
#   "''",
#   "'243','245'",
#   "'289'",
#   "'243'",
#   "'1','289'",
#   "'23','243','299'",
#   "''",
#   "'228'",
#   "'1','183','194'",
#   "'243'",
#   "'172','175'",
#   "'202','203','289'",
#   "'152'",
#   "'207'",
#   "'196','289'",
#   "'57','289'",
#   "'243'",
#   "'275'",
#   "'183'",
#   "''",
#   "'149'",
#   "'289'",
#   "'272'",
#   "'140'",
#   "'243'",
#   "'203'",
#   "'211'",
#   "'1','243','299'",
#   "'43'",
#   "'243'",
#   "'215'",
#   "'1','243'",
#   "'243'",
#   "'43'",
#   "'289'",
#   "'196'",
#   "'100','262'",
#   "'149'",
#   "'129'",
#   "'1','275'",
#   "'275'",
#   "'243','245','249','299'",
#   "'239'",
#   "''",
#   "'227'",
#   "'103','164','243'",
#   "'3'",
#   "'100','254'",
#   "'209','211'",
#   "'88'",
#   "'289'",
#   "'226'",
#   "'243'",
#   "'243','299'",
#   "'23','100'",
#   "'291'",
#   "'88'",
#   "'183'",
#   "'243','299','325'",
#   "'219'",
#   "'129','210'",
#   "'70','81','293'",
#   "'289'",
#   "'56','129','201'",
#   "'149','243'",
#   "'243'",
#   "'1','215','243'",
#   "'12','183','278'",
#   "'1','215'",
#   "'182'",
#   "'251'",
#   "'243'",
#   "'1','215','219','243'",
#   "'1','215'",
#   "'243'",
#   "'299'",
#   "'1','243'",
#   "'103','165','243'",
#   "'215','250'",
#   "''",
#   "'243'",
#   "'126','140','243','278','279'",
#   "'243'",
#   "'103','243'",
#   "'149'",
#   "'1','243'",
#   "'180'",
#   "'196','289'",
#   "'243','299'",
#   "''",
#   "'243','299','303'",
#   "'272'",
#   "'129','289'",
#   "'1','215','243'",
#   "'243','244','245','247','249'",
#   "'243'",
#   "'243'",
#   "'243'",
#   "'1','243'",
#   "'289'",
#   "'250','349'",
#   "'243','245'",
#   "'243','299'",
#   "'149'",
#   "'243','299'",
#   "'126'",
#   "'100','275'",
#   "'114','211'",
#   "'158'",
#   "'292'",
#   "'243'",
#   "'275'",
#   "'227'",
#   "'43'",
#   "'1','215'",
#   "'83'",
#   "''",
#   "'243','299'",
#   "'289'",
#   "'53','196'",
#   "'172','207','210','289'",
#   "'1'",
#   "'243'",
#   "'103','149','243'",
#   "'100','126','129','243','279','292'",
#   "'289'",
#   "'289'",
#   "'243'",
#   "'139'",
#   "'243'",
#   "'293'",
#   "'1','45'",
#   "'250','278'",
#   "'227','279'",
#   "'243','254'",
#   "'88','99'",
#   "'243','299'",
#   "'243'",
#   "''",
#   "'1'",
#   "'248'",
#   "'243','299'",
#   "'103'",
#   "'1','183'",
#   "'103','164','243'",
#   "'57','289','299','310'",
#   "'11','12'",
#   "'289','299'",
#   "'103','243'",
#   "'219','228','279'",
#   "'1','183','194'",
#   "''",
#   "'272','289'",
#   "'245'",
#   "'292'",
#   "'1','183','215','250'",
#   "'243'",
#   "'1','215','243'",
#   "'243'",
#   "'1','215'",
#   "'100','263'",
#   "'149','152'",
#   "'219','223'",
#   "''",
#   "'81'",
#   "'243'",
#   "'263','266','281'",
#   "'196'",
#   "'289'",
#   "'1','215'",
#   "'239'",
#   "'1','243'",
#   "'229','252'",
#   "'217','218','220'",
#   "'243'",
#   "'243','299','304'",
#   "'272'",
#   "'1','215'",
#   "'126'",
#   "'243'",
#   "'275'",
#   "'1','45'",
#   "'179'",
#   "'149'",
#   "'289'",
#   "'219'",
#   "'229'",
#   "'1','32','43','243'",
#   "'243'",
#   "'1'",
#   "'96','289'",
#   "'188','250'",
#   "'272'",
#   "'289'",
#   "'100'",
#   "'243','299','317'",
#   "'306'",
#   "'243'",
#   "'243'",
#   "'53','114','252'",
#   "'254','263','265'",
#   "'289'",
#   "''",
#   "'1','243'",
#   "'219'",
#   "'239','275','344'",
#   "'100','289'",
#   "'180','227','276'",
#   "'1','23','43','243'",
#   "'243'",
#   "'103','166','243'",
#   "'239'",
#   "''",
#   "'219','223'",
#   "'289'",
#   "'243'",
#   "'100'",
#   "'238'",
#   "'86'",
#   "'84','289'",
#   "'1','243','245'",
#   "'239'",
#   "'172'",
#   "'1','198','243'",
#   "'243','245'",
#   "'23'",
#   "'57'",
#   "'243'",
#   "'30'",
#   "'254'",
#   "'1','183','227','276'",
#   "'243','244','245','247','249'",
#   "'126'",
#   "'1','243','299'",
#   "'140'",
#   "'173'",
#   "'1','183'",
#   "'140','224','250'",
#   "'207'",
#   "'275','292'",
#   "'243','245'",
#   "'289'",
#   "'57','100','292'",
#   "'243'",
#   "'1','43','45'",
#   "'129','210','220'",
#   "'243'",
#   "''",
#   "'1','45'",
#   "'276'",
#   "'243'",
#   "'1','243'",
#   "''",
#   "'43','250','253'",
#   "'243','299'",
#   "'219'",
#   "'206'",
#   "'215'",
#   "'334','342'",
#   "'129','289','292'",
#   "'149'",
#   "'129','215','218'",
#   "'149'",
#   "'219'",
#   "'272'",
#   "'289'",
#   "'42','103','289'",
#   "'276'",
#   "'243','299','325'",
#   "'332'",
#   "'103','164','243'",
#   "'173','179'",
#   "'239'",
#   "'1','182','183'",
#   "'264'",
#   "'272'",
#   "'126','140','215','243','279'",
#   "''",
#   "'239'",
#   "'219','223'",
#   "'103','207','289'",
#   "'243'",
#   "'219'",
#   "'275'",
#   "''",
#   "'243'",
#   "'149'",
#   "'243'",
#   "'243'",
#   "'1','215'",
#   "'180'",
#   "'289'",
#   "'202','289'",
#   "'172','173'",
#   "''",
#   "'215','217','218'",
#   "''",
#   "'103','126','289'",
#   "'179','289'",
#   "'275'",
#   "'275'",
#   "'243'",
#   "'100','254'",
#   "'81'",
#   "'43'",
#   "'1','243'",
#   "'149'",
#   "'1','215','243'",
#   "'207','209'",
#   "'251'",
#   "'289'",
#   "'289'",
#   "'103','279'",
#   "'245'",
#   "'62','83','108','292'",
#   "'81'",
#   "'112','236'",
#   "'100','254','275'",
#   "''",
#   "'114','207'",
#   "'243'",
#   "'256'",
#   "'183'",
#   "'173'",
#   "'1','183','190'",
#   "'243'",
#   "'289','290'",
#   "'289'",
#   "'1','215'",
#   "'227'",
#   "'243','245'",
#   "''",
#   "'179','289'",
#   "'243','299','325'",
#   "'12'",
#   "'243','299','325'",
#   "''",
#   "'172','179'",
#   "'289'",
#   "'149','152'",
#   "'43'",
#   "'103','164','243'",
#   "'103','164','243'",
#   "'275'",
#   "'1','23'",
#   "'248','279'",
#   "'289'",
#   "'1','96','100','243'",
#   "'129','140','145','275'",
#   "'173'",
#   "'126'",
#   "''",
#   "'243'",
#   "'243'",
#   "'239'",
#   "'1'",
#   "'23','243'",
#   "'183'",
#   "'289'",
#   "'153','164'",
#   "'332','341'",
#   "'272'",
#   "'219'",
#   "'325'",
#   "'183'",
#   "'1','243'",
#   "'203','289'",
#   "'42','56','250'",
#   "'1','243'",
#   "'289'",
#   "'243'",
#   "'299'",
#   "'103'",
#   "'253'",
#   "'332'",
#   "'289'",
#   "'23','32','36'",
#   "'83','292'",
#   "'289'",
#   "''",
#   "'253'",
#   "'219'",
#   "'325'",
#   "'250','252'",
#   "'172','173'",
#   "'179','289'",
#   "'276'",
#   "'243'",
#   "'256','275'",
#   "'1','243'",
#   "'243'",
#   "'1','243'",
#   "''",
#   "'126'",
#   "'103','164','243'",
#   "'243'",
#   "'183'",
#   "'114','211','289'",
#   "'103'",
#   "'1','243'",
#   "'243'",
#   "'1','215'",
#   "'88','99','260','264'",
#   "'289'",
#   "'289'",
#   "'289'",
#   "'172'",
#   "'1','243'",
#   "'151','154','239'",
#   "'247'",
#   "'243'",
#   "'289'",
#   "'96','289'",
#   "'289'",
#   "'207'",
#   "'1','215'",
#   "'243'",
#   "'1','45'",
#   "'180','183','276','279'",
#   "'289'",
#   "'289'",
#   "'219','223'",
#   "'289'",
#   "'183'",
#   "''",
#   "'243'",
#   "'103','164','243'",
#   "'1'",
#   "'149'",
#   "'188','194'",
#   "'289'",
#   "'126','129'",
#   "'200','278'",
#   "'272'",
#   "'103','243'",
#   "'23'",
#   "'243'",
#   "'96','289'",
#   ...]}

# %%
df = pandas.DataFrame(data=d)

# %%
display(df)
# Out:
#                     domain                match                 topics
# 0      computrabajo.com.mx  computrabajo.com.mx                  '238'
# 1              walla.co.il          walla.co.il  '1','215','219','243'
# 2         indiapost.gov.in     indiapost.gov.in                  '103'
# 3              makro.co.za          makro.co.za                  '289'
# 4          lagaceta.com.ar      lagaceta.com.ar                  '243'
# ...                    ...                  ...                    ...
# 2814  prefeitura.sp.gov.br               gov.br                  '243'
# 2815       sespa.pa.gov.br               gov.br                  '243'
# 2816    camaranh.rs.gov.br               gov.br                  '243'
# 2817         sjc.sp.gov.br               gov.br                  '243'
# 2818          mp.sp.gov.br               gov.br                  '243'
#
# [2819 rows x 3 columns]

# %%
display(df[df['topics'] == "''"])
# Out:
#                        domain                    match topics
# 33      nationallottery.co.za    nationallottery.co.za     ''
# 45    consultaremedios.com.br  consultaremedios.com.br     ''
# 113             sonhos.com.br            sonhos.com.br     ''
# 207      casadoscontos.com.br     casadoscontos.com.br     ''
# 223            lotteryusa.com           lotteryusa.com     ''
# ...                       ...                      ...    ...
# 1505  churchofjesuschrist.org  churchofjesuschrist.org     ''
# 1522      freesexyindians.com      freesexyindians.com     ''
# 1529            astrology.com            astrology.com     ''
# 1531            voyeurweb.com            voyeurweb.com     ''
# 1537                  ssa.gov                  ssa.gov     ''
#
# [101 rows x 3 columns]

# %%
df = df.drop(df[df['topics'] == "''"].index.to_list())

# %%
df = df.reset_index(drop=True)

# %%
display(df)
# Out:
#                     domain                match                 topics
# 0      computrabajo.com.mx  computrabajo.com.mx                  '238'
# 1              walla.co.il          walla.co.il  '1','215','219','243'
# 2         indiapost.gov.in     indiapost.gov.in                  '103'
# 3              makro.co.za          makro.co.za                  '289'
# 4          lagaceta.com.ar      lagaceta.com.ar                  '243'
# ...                    ...                  ...                    ...
# 2713  prefeitura.sp.gov.br               gov.br                  '243'
# 2714       sespa.pa.gov.br               gov.br                  '243'
# 2715    camaranh.rs.gov.br               gov.br                  '243'
# 2716         sjc.sp.gov.br               gov.br                  '243'
# 2717          mp.sp.gov.br               gov.br                  '243'
#
# [2718 rows x 3 columns]

# %%
df.to_csv('AOL-treated-Google-Topics-Classification-v1-domain-match.csv')
